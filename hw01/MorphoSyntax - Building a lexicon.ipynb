# %%
import string
import pandas as pd

# %%
train_file = './data/sr_set-ud-train.conllu'
test_file = './data/sr_set-ud-test.conllu'
dev_file = './data/sr_set-ud-dev.conllu'

# %%
lines = []
with open(train_file, 'r', encoding='utf-8') as f:
    lines = f.readlines()
with open(test_file, 'r', encoding='utf-8') as f:
    lines.extend(f.readlines())
with open(dev_file, 'r', encoding='utf-8') as f:
    lines.extend(f.readlines())

# %%
open_class_tags = ['ADJ', 'ADV', 'INTJ', 'NOUN', 'PROPN', 'VERB']

# %%
ud_content = []
for line in lines:
    if len(line) == 1:
        continue
    if line.startswith("#"):
        continue
    
    parts = line.split('\t') 
    word = parts[1]
    pos_tag = parts[3]
    if pos_tag not in open_class_tags:
        continue
    ud_content.append(word)

# %%
len(ud_content)
# Out:
# 54632

# %% [markdown]
# # Preprocessing

# %% [markdown]
# All words are converted to lowercase.

# %%
ud_content = [word.lower() for word in ud_content]

# %% [markdown]
# Everything that contains digits and punctuation is removed.

# %%
ud_content = [word for word in ud_content if all(not c.isdigit() and c not in string.punctuation for c in word)]

# %%
data = pd.Series(ud_content)
data_freqs = data.value_counts()
data_freqs[:20]
# Out:
# rekao         332
# godine        279
# eu            261
# takođe        166
# bih           151
# kada          141
# kaže          132
# zemlje        131
# kosova        128
# međutim       126
# samo          120
# evra          117
# još           117
# srbije        110
# izjavio       107
# trebalo       107
# predsednik    106
# odsto          99
# više           98
# ministar       94
# dtype: int64

# %% [markdown]
# # Lexicon structure

# %% [markdown]
# Lexicon will be represented as a structure which consists of lemma (the base form), its tag and a list of the derived forms.
# Each derived form consits of the form itself and its tag.

# %%
class LexiconEntry:
    def __init__(self, lemma, tag):
        self.lemma = lemma
        self.tag = tag
        self.derived_forms = []

# %%
lexicon = []

# %% [markdown]
# Defining useful functions:

# %%
def export_lexicon(filename):
    lines_to_export = []
    for lexicon_entry in lexicon:
        lemma = lexicon_entry.lemma
        tag = lexicon_entry.tag
        
        if len(lexicon_entry.derived_forms) == 0:
            line = "{} {}+{}".format(lemma, lemma, tag)
            lines_to_export.append(line)
        else:
            for derived_form_entry in lexicon_entry.derived_forms:
                derived_form, derived_form_info = derived_form_entry
                
                line = "{} {}+{}+{}".format(derived_form, lemma, tag, derived_form_info)
                lines_to_export.append(line)
    
    with open(filename, "w", encoding='utf-8') as f:
        f.write('\n'.join(lines_to_export))

# %%
def print_lexicon():
    for lexicon_entry in lexicon:
        lemma = lexicon_entry.lemma
        tag = lexicon_entry.tag

        print("{} [{}]".format(lemma, tag))
        if len(lexicon_entry.derived_forms) == 0:
            continue
        for idx, derived_form_entry in enumerate(lexicon_entry.derived_forms):
            derived_form, derived_form_info = derived_form_entry
            
            if idx == 0:
                print("    ∟ {} {}".format(derived_form, derived_form_info))
            else:
                print("      {} {}".format(derived_form, derived_form_info))

# %%
def add_to_lexicon(lemma, base_tag, derived_forms = []):
    global ud_content
    lexicon_entry = LexiconEntry(lemma, base_tag)
    for lex in lexicon:
        if lex.lemma == lemma and lex.tag == base_tag:
            return
    
    ud_content = [word for word in ud_content if word != lemma]

    for der_form in derived_forms:
        lexicon_entry.derived_forms.append(der_form)
    lexicon.append(lexicon_entry)
    
    derived_forms_words = [w[0] for w in derived_forms]
    ud_content = [word for word in ud_content if word not in derived_forms_words]

# %%
def get_lexicon_entry(lemma, tag):
    for lex_entry in lexicon:
        if lex_entry.lemma == lemma and lex_entry.tag == tag:
            return lex_entry
        
    return None

# %% [markdown]
# Let's start with the most distinctive suffixes, which can be easily be observed

# %% [markdown]
# # 1. Verbs

# %% [markdown]
# ## 1.1 Infinitive
#
# All verbs in Serbian end with: *-ti* or *-ći*

# %%
infinitive_verbs_ITI = list(set([w for w in ud_content if w.endswith('iti')]))

# %%
infinitive_verbs_ITI
# Out:
# ['pripremiti',
#  'izraditi',
#  'oprostiti',
#  'proširiti',
#  'govoriti',
#  'otkloniti',
#  'unaprediti',
#  'otplatiti',
#  'pretpostaviti',
#  'smanjiti',
#  'pustiti',
#  'značiti',
#  'rešiti',
#  'naslediti',
#  'štiti',
#  'zaštititi',
#  'snositi',
#  'razdvojiti',
#  'ograničiti',
#  'zavisiti',
#  'patiti',
#  'odstupiti',
#  'zaključiti',
#  'učiniti',
#  'uložiti',
#  'ponoviti',
#  'raditi',
#  'usredsrediti',
#  'odrediti',
#  'pojaviti',
#  'obaviti',
#  'prihvatiti',
#  'potrošiti',
#  'ponuditi',
#  'preporučiti',
#  'zameniti',
#  'obezbediti',
#  'izgubiti',
#  'iznositi',
#  'složiti',
#  'odobriti',
#  'omogućiti',
#  'uočiti',
#  'obilaziti',
#  'ostaviti',
#  'staviti',
#  'izmeniti',
#  'unakaziti',
#  'razmotriti',
#  'ohrabriti',
#  'ispuniti',
#  'odbaciti',
#  'suočiti',
#  'rijaliti',
#  'osetiti',
#  'tražiti',
#  'vlastiti',
#  'deliti',
#  'zanemariti',
#  'nastupiti',
#  'vratiti',
#  'udvostručiti',
#  'izvršiti',
#  'zatražiti',
#  'nastaviti',
#  'dozvoliti',
#  'krediti',
#  'razvodniti',
#  'usuditi',
#  'potvrditi',
#  'pružiti',
#  'shvatiti',
#  'desiti',
#  'protiviti',
#  'ostvariti',
#  'povratiti',
#  'izmisliti',
#  'različiti',
#  'uništiti',
#  'preurediti',
#  'skladištiti',
#  'primiti',
#  'otkriti',
#  'odgovoriti',
#  'uraditi',
#  'protumačiti',
#  'zamisliti',
#  'predstaviti',
#  'odnositi',
#  'uspostaviti',
#  'napraviti',
#  'arvaniti',
#  'podnositi',
#  'proceniti',
#  'dobiti',
#  'opslužiti',
#  'posetiti',
#  'pratiti',
#  'povrediti',
#  'napustiti',
#  'posvetiti',
#  'namestiti',
#  'iskoristiti',
#  'nuditi',
#  'zaštiti',
#  'rušiti',
#  'koristiti',
#  'učiti',
#  'umoriti',
#  'dogoditi',
#  'smisliti',
#  'sprovoditi',
#  'uskladiti',
#  'razotkriti',
#  'voditi',
#  'promeniti',
#  'prenositi',
#  'uslediti',
#  'otpustiti',
#  'pridružiti',
#  'otvoriti',
#  'završiti',
#  'razrešiti',
#  'sprečiti',
#  'kazniti',
#  'težiti',
#  'odvratiti',
#  'postaviti',
#  'kupiti',
#  'udružiti',
#  'poslužiti',
#  'uhvatiti',
#  'izgraditi',
#  'ustanoviti',
#  'ugroziti',
#  'proučiti',
#  'slediti',
#  'zaposliti',
#  'predložiti',
#  'osuditi',
#  'nadoknaditi',
#  'obnoviti',
#  'stvoriti',
#  'pristupiti']

# %%
for inf_verb in infinitive_verbs_ITI:
    add_to_lexicon(inf_verb, 'V')

# %%
len(ud_content)
# Out:
# 53283

# %%
infinitive_verbs_ETI = list(set([w for w in ud_content if w.endswith('eti')]))

# %%
infinitive_verbs_ETI
# Out:
# ['oseti',
#  'započeti',
#  'preuzeti',
#  'dopreti',
#  'uzeti',
#  'doprineti',
#  'preduzeti',
#  'doneti',
#  'preoteti',
#  'poseti',
#  'preneti',
#  'animoziteti',
#  'anketi',
#  'peti',
#  'deveti',
#  'našteti',
#  'posveti',
#  'tereti',
#  'meti',
#  'ćančeti',
#  'ahmeti',
#  'univerziteti',
#  'uspeti',
#  'antikviteti',
#  'razumeti',
#  'oteti',
#  'početi',
#  'dijeti',
#  'oživeti',
#  'preti',
#  'videti',
#  'predvideti',
#  'podneti',
#  'aveti',
#  'predmeti',
#  'fakulteti']

# %%
for inf_verb in infinitive_verbs_ETI:
    add_to_lexicon(inf_verb, 'V')

# %%
infinitive_verbs_ATI = list(set([w for w in ud_content if w.endswith('ati')]))

# %%
infinitive_verbs_ATI
# Out:
# ['pozivati',
#  'falsifikovati',
#  'zahtevati',
#  'blokirati',
#  'dokazati',
#  'kopirati',
#  'uračunati',
#  'apstinirati',
#  'podržati',
#  'poboljšati',
#  'morati',
#  'oklevati',
#  'menjati',
#  'omogućavati',
#  'zadržati',
#  'intervenisati',
#  'garantovati',
#  'stajati',
#  'organizovati',
#  'pozvati',
#  'klati',
#  'razmenjivati',
#  'prati',
#  'palati',
#  'sastati',
#  'pokazati',
#  'pisati',
#  'razrešavati',
#  'primenjivati',
#  'obraćati',
#  'otputovati',
#  'prisustvovati',
#  'prebacivati',
#  'sarađivati',
#  'vrati',
#  'investirati',
#  'preispitati',
#  'slati',
#  'pokušati',
#  'poštovati',
#  'trajati',
#  'poslati',
#  'dati',
#  'sećati',
#  'povrati',
#  'postupati',
#  'održavati',
#  'požurivati',
#  'zarađivati',
#  'prihvati',
#  'plati',
#  'zloupotrebljavati',
#  'raspravljati',
#  'prikazati',
#  'uhvati',
#  'obrati',
#  'pridržavati',
#  'rezultati',
#  'zvati',
#  'uticati',
#  'postojati',
#  'koštati',
#  'funkcionisati',
#  'pokušavati',
#  'potpisati',
#  'analizirati',
#  'advokati',
#  'posmatrati',
#  'predstavljati',
#  'rešavati',
#  'dobijati',
#  'modelirati',
#  'mati',
#  'zapošljavati',
#  'pati',
#  'prepoznati',
#  'držati',
#  'bušati',
#  'imati',
#  'dočekivati',
#  'izolovati',
#  'uključivati',
#  'ostati',
#  'održati',
#  'pridati',
#  'okončati',
#  'poznati',
#  'insistirati',
#  'verovati',
#  'zamišljati',
#  'odvijati',
#  'doputovati',
#  'birati',
#  'povećati',
#  'intenzivirati',
#  'postati',
#  'olakšati',
#  'reagovati',
#  'predati',
#  'pružati',
#  'isplati',
#  'sačuvati',
#  'smanjivati',
#  'prestati',
#  'razgovarati',
#  'vraćati',
#  'sati',
#  'obavljati',
#  'pregovarati',
#  'pervati',
#  'ometati',
#  'učestvovati',
#  'oslanjati',
#  'smatrati',
#  'glasati',
#  'zaletati',
#  'suspendovati',
#  'povezati',
#  'kandidati',
#  'hrvati',
#  'nemati',
#  'objavljivati',
#  'izazvati',
#  'nadati',
#  'ojačati',
#  'igrati',
#  'osećati',
#  'razvijati',
#  'ispričati',
#  'izabrati',
#  'fokusirati',
#  'ticati',
#  'artikulisati',
#  'bogati',
#  'zapitati',
#  'postavljati',
#  'delati',
#  'putovati',
#  'finansirati',
#  'izdati',
#  'odavati',
#  'priznati',
#  'plakati',
#  'plaćati',
#  'izdavati',
#  'nadmetati',
#  'aktivirati',
#  'očekivati',
#  'cenjkati',
#  'pojačati',
#  'ratifikovati',
#  'definisati',
#  'zalagati',
#  'izražavati',
#  'preduzimati',
#  'sindikati']

# %%
for inf_verb in infinitive_verbs_ATI:
    add_to_lexicon(inf_verb, 'V')

# %% [markdown]
# ### 1.2 Past participle
#
# Ending with: *-vši*

# %%
past_participle_VSI = list(set([w for w in ud_content if w.endswith('vši')]))
print(past_participle_VSI)
# Out:
# ['počevši', 'uzdrmavši', 'učinivši', 'pretvorivši', 'osvojivši', 'proširivši', 'primetivši', 'dostigavši', 'postavivši', 'zamenivši', 'ponovivši', 'izazvavši', 'pohvalivši', 'bivši', 'završivši', 'rekavši', 'pobedivši', 'naslutivši', 'zabeleživši', 'dobivši']

# %%
for pp_VSI in past_participle_VSI:
    add_to_lexicon(pp_VSI, 'V')

# %% [markdown]
# ### 1.3 Present participle
#
# Ending with: *-jući*

# %%
def add_to_baseform(derived_form, derived_form_info, tag, src_replace, dst_replace):
    for lexicon_entry in lexicon:
        if lexicon_entry.lemma == derived_form.replace(src_replace, dst_replace) and lexicon_entry.tag == tag:
            lexicon_entry.derived_forms.append((derived_form, derived_form_info))
            return
    
    lemma = derived_form.replace(src_replace, dst_replace)
    derived_forms = [(derived_form, derived_form_info)]
    add_to_lexicon(lemma, tag, derived_forms)

# %%
present_participle_JUCI = list(set([w for w in ud_content if w.endswith('jući')]))

for pp in present_participle_JUCI:
    if pp.endswith('ajući'):
        add_to_baseform(pp, "PresentPat", "V", "ajući", "ati")

    elif pp.endswith('ujući'):
        add_to_baseform(pp, "PresentPat", "V", "ujući", "ovati")

# %%
present_participle_JUCI
# Out:
# ['izražavajući',
#  'postavljajući',
#  'upozoravajući',
#  'objašnjavajući',
#  'završavajući',
#  'ubacujući',
#  'čitajući',
#  'potvrđujući',
#  'pozivajući',
#  'ažurirajući',
#  'optužujući',
#  'odgovarajući',
#  'pozdravljajući',
#  'dodajući',
#  'znajući',
#  'otvarajući',
#  'zahtevajući',
#  'primajući',
#  'narastajući',
#  'predsedavajući',
#  'insistirajući',
#  'savetujući',
#  'osuđujući',
#  'imajući',
#  'ohrabrujući',
#  'okončavajući',
#  'podsećajući',
#  'obavljajući',
#  'opisujući',
#  'preduzimajući',
#  'kritikujući',
#  'napominjući',
#  'uveravajući',
#  'saopštavajući',
#  'sprečavajući',
#  'suočavajući',
#  'oslobađajući',
#  'čekajući',
#  'izdvajajući',
#  'diskreditujući',
#  'zatvarajući',
#  'protestujući',
#  'odbijajući',
#  'najavljujući',
#  'nazivajući',
#  'obraćajući',
#  'emigrirajući',
#  'zbližavajući',
#  'prezajući',
#  'zbunjujući',
#  'ukazujući',
#  'pretvarajući',
#  'tragajući',
#  'nedostajući',
#  'prodajući',
#  'primoravajući',
#  'potiskujući',
#  'uključujući',
#  'bacajući',
#  'igrajući',
#  'zahvaljujući',
#  'svrstavajući',
#  'obeležavajući',
#  'obećavajući',
#  'preneražavajući',
#  'otuđujući',
#  'pojavljujući',
#  'dajući',
#  'opstruirajući',
#  'naglašavajući',
#  'uzrokujući',
#  'omogućavajući',
#  'ponavljajući',
#  'favorizujući',
#  'predstavljajući']

# %% [markdown]
# Another type of suffix of present participle form is *-eći*, but it can be mixed with infinitive form.

# %%
suffix_ECI = list(set([w for w in ud_content if w.endswith('eći')]))

# %%
suffix_ECI
# Out:
# ['misleći',
#  'odlazeći',
#  'trudeći',
#  'sledeći',
#  'steći',
#  'kršeći',
#  'veći',
#  'sudeći',
#  'deleći',
#  'donoseći',
#  'nesreći',
#  'beležeći',
#  'preseći',
#  'predstojeći',
#  'preći',
#  'koristeći',
#  'važeći',
#  'reći',
#  'poreći',
#  'doprinoseći',
#  'tražeći',
#  'postojeći',
#  'treći',
#  'navodeći',
#  'paleći',
#  'baveći',
#  'izlazeći',
#  'najveći',
#  'govoreći',
#  'tvrdeći']

# %% [markdown]
# # 2. Adjectives

# %% [markdown]
# ## 2.1 Comparative
#
# Suffixes:
# - Singular: *-niji (m.), -nija (f.), -nije (n.)*
# - Plural: *-nijim

# %%
comparative_forms = [w for w in ud_content if w.endswith('niji') or w.endswith('nija') or w.endswith('nije') or w.endswith('nijim')]
comparative_forms = [w for w in comparative_forms if not w.startswith('naj')]
comparative_forms = list(set(comparative_forms))

# %%
comparative_forms
# Out:
# ['decenije',
#  'unije',
#  'važnija',
#  'svestranije',
#  'linija',
#  'apolonija',
#  'linije',
#  'bezbedniji',
#  'decenija',
#  'kompleksnija',
#  'moćniji',
#  'menija',
#  'pensilvaniji',
#  'alianija',
#  'liniji',
#  'beskompromisniji',
#  'ranije',
#  'nezadovoljniji',
#  'telefonije',
#  'konkurentnija',
#  'makedonije',
#  'sigurnija',
#  'snažnije',
#  'efikasnija',
#  'uticajniji',
#  'unija',
#  'ozbiljniji',
#  'estonije',
#  'pozitivniji',
#  'čečeniji',
#  'opasnijim',
#  'kompanije',
#  'španiji',
#  'iskusnijim',
#  'rasprostranjenija',
#  'ceremonija',
#  'litvanije',
#  'značajniji',
#  'kolonija',
#  'britanije',
#  'albaniji',
#  'striktnije',
#  'kompanija',
#  'očigledniji',
#  'potpunije',
#  'britaniji',
#  'docnije',
#  'tačnije',
#  'slovenije',
#  'diversifikovanija',
#  'ranijim',
#  'kasnije',
#  'izraženijim',
#  'demokratičnija',
#  'siromašnije',
#  'britanija',
#  'konkretnije',
#  'jevtinijim',
#  'španije',
#  'precizniji',
#  'ceremoniji',
#  'kompaniji',
#  'optimalnije',
#  'sigurnije',
#  'španija',
#  'rumuniji',
#  'rasprostranjeniji',
#  'rumunije',
#  'makedoniji',
#  'zainteresovanija',
#  'represivniji',
#  'optimističniji',
#  'letonije',
#  'aktivnije',
#  'jeftinije',
#  'makedonija',
#  'važniji',
#  'slovenija',
#  'urgentniji',
#  'uniji',
#  'transparentnijim',
#  'ceremonije',
#  'rumunija',
#  'albanija',
#  'sloveniji',
#  'važnije',
#  'efikasniji',
#  'slobodniji',
#  'značajnije',
#  'albanije']

# %% [markdown]
# We will build positive forms of the comparative forms:
#
# -niji $\rightarrow$ -an
#
# -nija $\rightarrow$ -na
#
# -nije $\rightarrow$ -no
#
# -nijim $\rightarrow$ -an
#     - there's no way of knowing if the comparative form is supposed to be in masculine, feminine or neutral form, so here it is deliberately chosen that the masculine form will be the base form

# %%
for comparative in comparative_forms:
    positive_lexicon_form = None
    if comparative.endswith("niji"):
        positive = comparative.replace("niji", "an")
        positive_lexicon_form = (comparative, 'Comp+Masc+Sg')
    if comparative.endswith("nija"):
        positive = comparative.replace("nija", "na")
        positive_lexicon_form = (comparative, 'Comp+Fem+Sg')
    if comparative.endswith("nije"):
        positive = comparative.replace("nije", "no")
        positive_lexicon_form = (comparative, 'Comp+Neut+Sg')
    if comparative.endswith("nijim"):
        positive = comparative.replace("nijim", "an")
        positive_lexicon_form = (comparative, 'Comp+Masc+Pl')
    
    add_to_lexicon(positive, 'Adj', [positive_lexicon_form])

# %%
print_lexicon()
# Out:
# pripremiti [V]
# izraditi [V]
# oprostiti [V]
# proširiti [V]
# govoriti [V]
# otkloniti [V]
# unaprediti [V]
# otplatiti [V]
# pretpostaviti [V]
# smanjiti [V]
# pustiti [V]
# značiti [V]
# rešiti [V]
# naslediti [V]
# štiti [V]
# zaštititi [V]
# snositi [V]
# razdvojiti [V]
# ograničiti [V]
# zavisiti [V]
# patiti [V]
# odstupiti [V]
# zaključiti [V]
# učiniti [V]
# uložiti [V]
# ponoviti [V]
# raditi [V]
# usredsrediti [V]
# odrediti [V]
# pojaviti [V]
# obaviti [V]
# prihvatiti [V]
# potrošiti [V]
# ponuditi [V]
# preporučiti [V]
# zameniti [V]
# obezbediti [V]
# izgubiti [V]
# iznositi [V]
# složiti [V]
# odobriti [V]
# omogućiti [V]
# uočiti [V]
# obilaziti [V]
# ostaviti [V]
# staviti [V]
# izmeniti [V]
# unakaziti [V]
# razmotriti [V]
# ohrabriti [V]
# ispuniti [V]
# odbaciti [V]
# suočiti [V]
# rijaliti [V]
# osetiti [V]
# tražiti [V]
# vlastiti [V]
# deliti [V]
# zanemariti [V]
# nastupiti [V]
# vratiti [V]
# udvostručiti [V]
# izvršiti [V]
# zatražiti [V]
# nastaviti [V]
# dozvoliti [V]
# krediti [V]
# razvodniti [V]
# usuditi [V]
# potvrditi [V]
# pružiti [V]
# shvatiti [V]
# desiti [V]
# protiviti [V]
# ostvariti [V]
# povratiti [V]
# izmisliti [V]
# različiti [V]
# uništiti [V]
# preurediti [V]
# skladištiti [V]
# primiti [V]
# otkriti [V]
# odgovoriti [V]
# uraditi [V]
# protumačiti [V]
# zamisliti [V]
# predstaviti [V]
# odnositi [V]
# uspostaviti [V]
# napraviti [V]
# arvaniti [V]
# podnositi [V]
# proceniti [V]
# dobiti [V]
# opslužiti [V]
# posetiti [V]
# pratiti [V]
# povrediti [V]
# napustiti [V]
# posvetiti [V]
# namestiti [V]
# iskoristiti [V]
# nuditi [V]
# zaštiti [V]
# rušiti [V]
# koristiti [V]
# učiti [V]
# umoriti [V]
# dogoditi [V]
# smisliti [V]
# sprovoditi [V]
# uskladiti [V]
# razotkriti [V]
# voditi [V]
# promeniti [V]
# prenositi [V]
# uslediti [V]
# otpustiti [V]
# pridružiti [V]
# otvoriti [V]
# završiti [V]
# razrešiti [V]
# sprečiti [V]
# kazniti [V]
# težiti [V]
# odvratiti [V]
# postaviti [V]
# kupiti [V]
# udružiti [V]
# poslužiti [V]
# uhvatiti [V]
# izgraditi [V]
# ustanoviti [V]
# ugroziti [V]
# proučiti [V]
# slediti [V]
# zaposliti [V]
# predložiti [V]
# osuditi [V]
# nadoknaditi [V]
# obnoviti [V]
# stvoriti [V]
# pristupiti [V]
# oseti [V]
# započeti [V]
# preuzeti [V]
# dopreti [V]
# uzeti [V]
# doprineti [V]
# preduzeti [V]
# doneti [V]
# preoteti [V]
# poseti [V]
# preneti [V]
# animoziteti [V]
# anketi [V]
# peti [V]
# deveti [V]
# našteti [V]
# posveti [V]
# tereti [V]
# meti [V]
# ćančeti [V]
# ahmeti [V]
# univerziteti [V]
# uspeti [V]
# antikviteti [V]
# razumeti [V]
# oteti [V]
# početi [V]
# dijeti [V]
# oživeti [V]
# preti [V]
# videti [V]
# predvideti [V]
# podneti [V]
# aveti [V]
# predmeti [V]
# fakulteti [V]
# pozivati [V]
#     ∟ pozivajući PresentPat
# falsifikovati [V]
# zahtevati [V]
#     ∟ zahtevajući PresentPat
# blokirati [V]
# dokazati [V]
# kopirati [V]
# uračunati [V]
# apstinirati [V]
# podržati [V]
# poboljšati [V]
# morati [V]
# oklevati [V]
# menjati [V]
# omogućavati [V]
#     ∟ omogućavajući PresentPat
# zadržati [V]
# intervenisati [V]
# garantovati [V]
# stajati [V]
# organizovati [V]
# pozvati [V]
# klati [V]
# razmenjivati [V]
# prati [V]
# palati [V]
# sastati [V]
# pokazati [V]
# pisati [V]
# razrešavati [V]
# primenjivati [V]
# obraćati [V]
#     ∟ obraćajući PresentPat
# otputovati [V]
# prisustvovati [V]
# prebacivati [V]
# sarađivati [V]
# vrati [V]
# investirati [V]
# preispitati [V]
# slati [V]
# pokušati [V]
# poštovati [V]
# trajati [V]
# poslati [V]
# dati [V]
#     ∟ dajući PresentPat
# sećati [V]
# povrati [V]
# postupati [V]
# održavati [V]
# požurivati [V]
# zarađivati [V]
# prihvati [V]
# plati [V]
# zloupotrebljavati [V]
# raspravljati [V]
# prikazati [V]
# uhvati [V]
# obrati [V]
# pridržavati [V]
# rezultati [V]
# zvati [V]
# uticati [V]
# postojati [V]
# koštati [V]
# funkcionisati [V]
# pokušavati [V]
# potpisati [V]
# analizirati [V]
# advokati [V]
# posmatrati [V]
# predstavljati [V]
#     ∟ predstavljajući PresentPat
# rešavati [V]
# dobijati [V]
# modelirati [V]
# mati [V]
# zapošljavati [V]
# pati [V]
# prepoznati [V]
# držati [V]
# bušati [V]
# imati [V]
#     ∟ imajući PresentPat
# dočekivati [V]
# izolovati [V]
# uključivati [V]
# ostati [V]
# održati [V]
# pridati [V]
# okončati [V]
# poznati [V]
# insistirati [V]
#     ∟ insistirajući PresentPat
# verovati [V]
# zamišljati [V]
# odvijati [V]
# doputovati [V]
# birati [V]
# povećati [V]
# intenzivirati [V]
# postati [V]
# olakšati [V]
# reagovati [V]
# predati [V]
# pružati [V]
# isplati [V]
# sačuvati [V]
# smanjivati [V]
# prestati [V]
# razgovarati [V]
# vraćati [V]
# sati [V]
# obavljati [V]
#     ∟ obavljajući PresentPat
# pregovarati [V]
# pervati [V]
# ometati [V]
# učestvovati [V]
# oslanjati [V]
# smatrati [V]
# glasati [V]
# zaletati [V]
# suspendovati [V]
# povezati [V]
# kandidati [V]
# hrvati [V]
# nemati [V]
# objavljivati [V]
# izazvati [V]
# nadati [V]
# ojačati [V]
# igrati [V]
#     ∟ igrajući PresentPat
# osećati [V]
# razvijati [V]
# ispričati [V]
# izabrati [V]
# fokusirati [V]
# ticati [V]
# artikulisati [V]
# bogati [V]
# zapitati [V]
# postavljati [V]
#     ∟ postavljajući PresentPat
# delati [V]
# putovati [V]
# finansirati [V]
# izdati [V]
# odavati [V]
# priznati [V]
# plakati [V]
# plaćati [V]
# izdavati [V]
# nadmetati [V]
# aktivirati [V]
# očekivati [V]
# cenjkati [V]
# pojačati [V]
# ratifikovati [V]
# definisati [V]
# zalagati [V]
# izražavati [V]
#     ∟ izražavajući PresentPat
# preduzimati [V]
#     ∟ preduzimajući PresentPat
# sindikati [V]
# počevši [V]
# uzdrmavši [V]
# učinivši [V]
# pretvorivši [V]
# osvojivši [V]
# proširivši [V]
# primetivši [V]
# dostigavši [V]
# postavivši [V]
# zamenivši [V]
# ponovivši [V]
# izazvavši [V]
# pohvalivši [V]
# bivši [V]
# završivši [V]
# rekavši [V]
# pobedivši [V]
# naslutivši [V]
# zabeleživši [V]
# dobivši [V]
# upozoravati [V]
#     ∟ upozoravajući PresentPat
# objašnjavati [V]
#     ∟ objašnjavajući PresentPat
# završavati [V]
#     ∟ završavajući PresentPat
# ubacovati [V]
#     ∟ ubacujući PresentPat
# čitati [V]
#     ∟ čitajući PresentPat
# potvrđovati [V]
#     ∟ potvrđujući PresentPat
# ažurirati [V]
#     ∟ ažurirajući PresentPat
# optužovati [V]
#     ∟ optužujući PresentPat
# odgovarati [V]
#     ∟ odgovarajući PresentPat
# pozdravljati [V]
#     ∟ pozdravljajući PresentPat
# dodati [V]
#     ∟ dodajući PresentPat
# znati [V]
#     ∟ znajući PresentPat
# otvarati [V]
#     ∟ otvarajući PresentPat
# primati [V]
#     ∟ primajući PresentPat
# narastati [V]
#     ∟ narastajući PresentPat
# predsedavati [V]
#     ∟ predsedavajući PresentPat
# savetovati [V]
#     ∟ savetujući PresentPat
# osuđovati [V]
#     ∟ osuđujući PresentPat
# ohrabrovati [V]
#     ∟ ohrabrujući PresentPat
# okončavati [V]
#     ∟ okončavajući PresentPat
# podsećati [V]
#     ∟ podsećajući PresentPat
# opisovati [V]
#     ∟ opisujući PresentPat
# kritikovati [V]
#     ∟ kritikujući PresentPat
# uveravati [V]
#     ∟ uveravajući PresentPat
# saopštavati [V]
#     ∟ saopštavajući PresentPat
# sprečavati [V]
#     ∟ sprečavajući PresentPat
# suočavati [V]
#     ∟ suočavajući PresentPat
# oslobađati [V]
#     ∟ oslobađajući PresentPat
# čekati [V]
#     ∟ čekajući PresentPat
# izdvajati [V]
#     ∟ izdvajajući PresentPat
# diskreditovati [V]
#     ∟ diskreditujući PresentPat
# zatvarati [V]
#     ∟ zatvarajući PresentPat
# protestovati [V]
#     ∟ protestujući PresentPat
# odbijati [V]
#     ∟ odbijajući PresentPat
# najavljovati [V]
#     ∟ najavljujući PresentPat
# nazivati [V]
#     ∟ nazivajući PresentPat
# emigrirati [V]
#     ∟ emigrirajući PresentPat
# zbližavati [V]
#     ∟ zbližavajući PresentPat
# prezati [V]
#     ∟ prezajući PresentPat
# zbunjovati [V]
#     ∟ zbunjujući PresentPat
# ukazovati [V]
#     ∟ ukazujući PresentPat
# pretvarati [V]
#     ∟ pretvarajući PresentPat
# tragati [V]
#     ∟ tragajući PresentPat
# nedostati [V]
#     ∟ nedostajući PresentPat
# prodati [V]
#     ∟ prodajući PresentPat
# primoravati [V]
#     ∟ primoravajući PresentPat
# potiskovati [V]
#     ∟ potiskujući PresentPat
# uključovati [V]
#     ∟ uključujući PresentPat
# bacati [V]
#     ∟ bacajući PresentPat
# zahvaljovati [V]
#     ∟ zahvaljujući PresentPat
# svrstavati [V]
#     ∟ svrstavajući PresentPat
# obeležavati [V]
#     ∟ obeležavajući PresentPat
# obećavati [V]
#     ∟ obećavajući PresentPat
# preneražavati [V]
#     ∟ preneražavajući PresentPat
# otuđovati [V]
#     ∟ otuđujući PresentPat
# pojavljovati [V]
#     ∟ pojavljujući PresentPat
# opstruirati [V]
#     ∟ opstruirajući PresentPat
# naglašavati [V]
#     ∟ naglašavajući PresentPat
# uzrokovati [V]
#     ∟ uzrokujući PresentPat
# ponavljati [V]
#     ∟ ponavljajući PresentPat
# favorizovati [V]
#     ∟ favorizujući PresentPat
# deceno [Adj]
#     ∟ decenije Comp+Neut+Sg
# uno [Adj]
#     ∟ unije Comp+Neut+Sg
# važna [Adj]
#     ∟ važnija Comp+Fem+Sg
# svestrano [Adj]
#     ∟ svestranije Comp+Neut+Sg
# lina [Adj]
#     ∟ linija Comp+Fem+Sg
# apolona [Adj]
#     ∟ apolonija Comp+Fem+Sg
# lino [Adj]
#     ∟ linije Comp+Neut+Sg
# bezbedan [Adj]
#     ∟ bezbedniji Comp+Masc+Sg
# decena [Adj]
#     ∟ decenija Comp+Fem+Sg
# kompleksna [Adj]
#     ∟ kompleksnija Comp+Fem+Sg
# moćan [Adj]
#     ∟ moćniji Comp+Masc+Sg
# mena [Adj]
#     ∟ menija Comp+Fem+Sg
# pensilvaan [Adj]
#     ∟ pensilvaniji Comp+Masc+Sg
# aliana [Adj]
#     ∟ alianija Comp+Fem+Sg
# lian [Adj]
#     ∟ liniji Comp+Masc+Sg
# beskompromisan [Adj]
#     ∟ beskompromisniji Comp+Masc+Sg
# rano [Adj]
#     ∟ ranije Comp+Neut+Sg
# nezadovoljan [Adj]
#     ∟ nezadovoljniji Comp+Masc+Sg
# telefono [Adj]
#     ∟ telefonije Comp+Neut+Sg
# konkurentna [Adj]
#     ∟ konkurentnija Comp+Fem+Sg
# makedono [Adj]
#     ∟ makedonije Comp+Neut+Sg
# sigurna [Adj]
#     ∟ sigurnija Comp+Fem+Sg
# snažno [Adj]
#     ∟ snažnije Comp+Neut+Sg
# efikasna [Adj]
#     ∟ efikasnija Comp+Fem+Sg
# uticajan [Adj]
#     ∟ uticajniji Comp+Masc+Sg
# una [Adj]
#     ∟ unija Comp+Fem+Sg
# ozbiljan [Adj]
#     ∟ ozbiljniji Comp+Masc+Sg
# estono [Adj]
#     ∟ estonije Comp+Neut+Sg
# pozitivan [Adj]
#     ∟ pozitivniji Comp+Masc+Sg
# čečean [Adj]
#     ∟ čečeniji Comp+Masc+Sg
# opasan [Adj]
#     ∟ opasnijim Comp+Masc+Pl
# kompano [Adj]
#     ∟ kompanije Comp+Neut+Sg
# špaan [Adj]
#     ∟ španiji Comp+Masc+Sg
# iskusan [Adj]
#     ∟ iskusnijim Comp+Masc+Pl
# rasprostranjena [Adj]
#     ∟ rasprostranjenija Comp+Fem+Sg
# ceremona [Adj]
#     ∟ ceremonija Comp+Fem+Sg
# litvano [Adj]
#     ∟ litvanije Comp+Neut+Sg
# značajan [Adj]
#     ∟ značajniji Comp+Masc+Sg
# kolona [Adj]
#     ∟ kolonija Comp+Fem+Sg
# britano [Adj]
#     ∟ britanije Comp+Neut+Sg
# albaan [Adj]
#     ∟ albaniji Comp+Masc+Sg
# striktno [Adj]
#     ∟ striktnije Comp+Neut+Sg
# kompana [Adj]
#     ∟ kompanija Comp+Fem+Sg
# očigledan [Adj]
#     ∟ očigledniji Comp+Masc+Sg
# potpuno [Adj]
#     ∟ potpunije Comp+Neut+Sg
# britaan [Adj]
#     ∟ britaniji Comp+Masc+Sg
# docno [Adj]
#     ∟ docnije Comp+Neut+Sg
# tačno [Adj]
#     ∟ tačnije Comp+Neut+Sg
# sloveno [Adj]
#     ∟ slovenije Comp+Neut+Sg
# diversifikovana [Adj]
#     ∟ diversifikovanija Comp+Fem+Sg
# raan [Adj]
#     ∟ ranijim Comp+Masc+Pl
# kasno [Adj]
#     ∟ kasnije Comp+Neut+Sg
# izražean [Adj]
#     ∟ izraženijim Comp+Masc+Pl
# demokratična [Adj]
#     ∟ demokratičnija Comp+Fem+Sg
# siromašno [Adj]
#     ∟ siromašnije Comp+Neut+Sg
# britana [Adj]
#     ∟ britanija Comp+Fem+Sg
# konkretno [Adj]
#     ∟ konkretnije Comp+Neut+Sg
# jevtian [Adj]
#     ∟ jevtinijim Comp+Masc+Pl
# špano [Adj]
#     ∟ španije Comp+Neut+Sg
# precizan [Adj]
#     ∟ precizniji Comp+Masc+Sg
# ceremoan [Adj]
#     ∟ ceremoniji Comp+Masc+Sg
# kompaan [Adj]
#     ∟ kompaniji Comp+Masc+Sg
# optimalno [Adj]
#     ∟ optimalnije Comp+Neut+Sg
# sigurno [Adj]
#     ∟ sigurnije Comp+Neut+Sg
# špana [Adj]
#     ∟ španija Comp+Fem+Sg
# rumuan [Adj]
#     ∟ rumuniji Comp+Masc+Sg
# rasprostranjean [Adj]
#     ∟ rasprostranjeniji Comp+Masc+Sg
# rumuno [Adj]
#     ∟ rumunije Comp+Neut+Sg
# makedoan [Adj]
#     ∟ makedoniji Comp+Masc+Sg
# zainteresovana [Adj]
#     ∟ zainteresovanija Comp+Fem+Sg
# represivan [Adj]
#     ∟ represivniji Comp+Masc+Sg
# optimističan [Adj]
#     ∟ optimističniji Comp+Masc+Sg
# letono [Adj]
#     ∟ letonije Comp+Neut+Sg
# aktivno [Adj]
#     ∟ aktivnije Comp+Neut+Sg
# jeftino [Adj]
#     ∟ jeftinije Comp+Neut+Sg
# makedona [Adj]
#     ∟ makedonija Comp+Fem+Sg
# važan [Adj]
#     ∟ važniji Comp+Masc+Sg
# slovena [Adj]
#     ∟ slovenija Comp+Fem+Sg
# urgentan [Adj]
#     ∟ urgentniji Comp+Masc+Sg
# uan [Adj]
#     ∟ uniji Comp+Masc+Sg
# transparentan [Adj]
#     ∟ transparentnijim Comp+Masc+Pl
# ceremono [Adj]
#     ∟ ceremonije Comp+Neut+Sg
# rumuna [Adj]
#     ∟ rumunija Comp+Fem+Sg
# albana [Adj]
#     ∟ albanija Comp+Fem+Sg
# slovean [Adj]
#     ∟ sloveniji Comp+Masc+Sg
# važno [Adj]
#     ∟ važnije Comp+Neut+Sg
# efikasan [Adj]
#     ∟ efikasniji Comp+Masc+Sg
# slobodan [Adj]
#     ∟ slobodniji Comp+Masc+Sg
# značajno [Adj]
#     ∟ značajnije Comp+Neut+Sg
# albano [Adj]
#     ∟ albanije Comp+Neut+Sg

# %% [markdown]
# ## 2.2 Superlative

# %% [markdown]
# It is fairly easy to find adjectives in superlative form because they almost always have the prefix *naj-*.

# %%
prefix_NAJ = list(set([w for w in ud_content if w.startswith('naj')]))

# %%
prefix_NAJ
# Out:
# ['najefikasnije',
#  'najduži',
#  'najboljim',
#  'najtiražnijeg',
#  'najnovija',
#  'najizolovanijih',
#  'najslobodnija',
#  'najvažnije',
#  'najtraženija',
#  'najmodernijeg',
#  'najsigurnijih',
#  'najavljena',
#  'najznačajnijih',
#  'najnoviju',
#  'najtalentovanijih',
#  'najtežih',
#  'najznačajniji',
#  'najbezbednijim',
#  'najverovatniji',
#  'najjačih',
#  'najurgentniji',
#  'najzad',
#  'najboljem',
#  'najbolja',
#  'najbolji',
#  'najznačajnija',
#  'najstarijim',
#  'najuglednijih',
#  'najvažnija',
#  'najnovijih',
#  'najsiromašnijim',
#  'najnasilniju',
#  'najesen',
#  'najprizemniji',
#  'najpouzdniji',
#  'najstarijih',
#  'najozbiljniji',
#  'najčuvenijih',
#  'najneslobodnija',
#  'najznačajnije',
#  'najveću',
#  'najbogatijih',
#  'najvećim',
#  'najraznovrsnije',
#  'najviše',
#  'najjednostavniji',
#  'najveća',
#  'najnovije',
#  'najavljuje',
#  'najvišeg',
#  'najavila',
#  'najprodavanije',
#  'najmanju',
#  'najgorem',
#  'najmoćniji',
#  'najveće',
#  'najdelikatnijoj',
#  'najvažnijih',
#  'najrashlađenija',
#  'najjače',
#  'najnoviji',
#  'najdinamičnija',
#  'najvažnijim',
#  'najbolju',
#  'najmoćnije',
#  'najrazličitijih',
#  'najmanje',
#  'najčuvanijih',
#  'najpopularnijih',
#  'najgore',
#  'najnovijim',
#  'najsličnija',
#  'najčešće',
#  'najblaže',
#  'najniži',
#  'najplodnija',
#  'najpoznatijih',
#  'najboljih',
#  'najčuvenija',
#  'najrelevantnijih',
#  'najteža',
#  'najbolje',
#  'najperfektnije',
#  'najizolovanijom',
#  'najavljuju',
#  'najveći',
#  'najjača',
#  'najstariji',
#  'najvećeg',
#  'najozbiljnija',
#  'najbezbednija',
#  'najtiražnije',
#  'najpopularnija',
#  'najavio',
#  'najprimetnijih',
#  'najkraća',
#  'najbezbednijih',
#  'najvišim',
#  'najavljenom',
#  'najavljen',
#  'najuspešnija',
#  'najisplativija',
#  'najboljeg',
#  'najpoznatiji',
#  'najverovatnije',
#  'najnovijem',
#  'najavile',
#  'najteže',
#  'najvećih',
#  'najspektakularniji',
#  'najgorim',
#  'najugledniji',
#  'najvećem',
#  'najviši',
#  'najvažniju',
#  'najistaknutiji',
#  'najvažniji']

# %%
def is_superlative_of_existing_base_form(lexicon_entry, superlative):
    if len(lexicon_entry.derived_forms) == 0:
        return False
    
    comparative = superlative[3:]
    for d_form in lexicon_entry.derived_forms:
        if d_form[1].startswith("Comp+") and d_form[0].startswith(comparative):
            gender = d_form[1].split("+")[1]
            number = d_form[1].split("+")[2]
            lexicon_entry.derived_forms.append((superlative, "Sup+{}+{}".format(gender, number)))
            return True
        
    return False
            

for p_NAJ in prefix_NAJ:
    lexicon_entries = [l for l in lexicon if is_superlative_of_existing_base_form(l, p_NAJ)]

# %%
print_lexicon()
# Out:
# pripremiti [V]
# izraditi [V]
# oprostiti [V]
# proširiti [V]
# govoriti [V]
# otkloniti [V]
# unaprediti [V]
# otplatiti [V]
# pretpostaviti [V]
# smanjiti [V]
# pustiti [V]
# značiti [V]
# rešiti [V]
# naslediti [V]
# štiti [V]
# zaštititi [V]
# snositi [V]
# razdvojiti [V]
# ograničiti [V]
# zavisiti [V]
# patiti [V]
# odstupiti [V]
# zaključiti [V]
# učiniti [V]
# uložiti [V]
# ponoviti [V]
# raditi [V]
# usredsrediti [V]
# odrediti [V]
# pojaviti [V]
# obaviti [V]
# prihvatiti [V]
# potrošiti [V]
# ponuditi [V]
# preporučiti [V]
# zameniti [V]
# obezbediti [V]
# izgubiti [V]
# iznositi [V]
# složiti [V]
# odobriti [V]
# omogućiti [V]
# uočiti [V]
# obilaziti [V]
# ostaviti [V]
# staviti [V]
# izmeniti [V]
# unakaziti [V]
# razmotriti [V]
# ohrabriti [V]
# ispuniti [V]
# odbaciti [V]
# suočiti [V]
# rijaliti [V]
# osetiti [V]
# tražiti [V]
# vlastiti [V]
# deliti [V]
# zanemariti [V]
# nastupiti [V]
# vratiti [V]
# udvostručiti [V]
# izvršiti [V]
# zatražiti [V]
# nastaviti [V]
# dozvoliti [V]
# krediti [V]
# razvodniti [V]
# usuditi [V]
# potvrditi [V]
# pružiti [V]
# shvatiti [V]
# desiti [V]
# protiviti [V]
# ostvariti [V]
# povratiti [V]
# izmisliti [V]
# različiti [V]
# uništiti [V]
# preurediti [V]
# skladištiti [V]
# primiti [V]
# otkriti [V]
# odgovoriti [V]
# uraditi [V]
# protumačiti [V]
# zamisliti [V]
# predstaviti [V]
# odnositi [V]
# uspostaviti [V]
# napraviti [V]
# arvaniti [V]
# podnositi [V]
# proceniti [V]
# dobiti [V]
# opslužiti [V]
# posetiti [V]
# pratiti [V]
# povrediti [V]
# napustiti [V]
# posvetiti [V]
# namestiti [V]
# iskoristiti [V]
# nuditi [V]
# zaštiti [V]
# rušiti [V]
# koristiti [V]
# učiti [V]
# umoriti [V]
# dogoditi [V]
# smisliti [V]
# sprovoditi [V]
# uskladiti [V]
# razotkriti [V]
# voditi [V]
# promeniti [V]
# prenositi [V]
# uslediti [V]
# otpustiti [V]
# pridružiti [V]
# otvoriti [V]
# završiti [V]
# razrešiti [V]
# sprečiti [V]
# kazniti [V]
# težiti [V]
# odvratiti [V]
# postaviti [V]
# kupiti [V]
# udružiti [V]
# poslužiti [V]
# uhvatiti [V]
# izgraditi [V]
# ustanoviti [V]
# ugroziti [V]
# proučiti [V]
# slediti [V]
# zaposliti [V]
# predložiti [V]
# osuditi [V]
# nadoknaditi [V]
# obnoviti [V]
# stvoriti [V]
# pristupiti [V]
# oseti [V]
# započeti [V]
# preuzeti [V]
# dopreti [V]
# uzeti [V]
# doprineti [V]
# preduzeti [V]
# doneti [V]
# preoteti [V]
# poseti [V]
# preneti [V]
# animoziteti [V]
# anketi [V]
# peti [V]
# deveti [V]
# našteti [V]
# posveti [V]
# tereti [V]
# meti [V]
# ćančeti [V]
# ahmeti [V]
# univerziteti [V]
# uspeti [V]
# antikviteti [V]
# razumeti [V]
# oteti [V]
# početi [V]
# dijeti [V]
# oživeti [V]
# preti [V]
# videti [V]
# predvideti [V]
# podneti [V]
# aveti [V]
# predmeti [V]
# fakulteti [V]
# pozivati [V]
#     ∟ pozivajući PresentPat
# falsifikovati [V]
# zahtevati [V]
#     ∟ zahtevajući PresentPat
# blokirati [V]
# dokazati [V]
# kopirati [V]
# uračunati [V]
# apstinirati [V]
# podržati [V]
# poboljšati [V]
# morati [V]
# oklevati [V]
# menjati [V]
# omogućavati [V]
#     ∟ omogućavajući PresentPat
# zadržati [V]
# intervenisati [V]
# garantovati [V]
# stajati [V]
# organizovati [V]
# pozvati [V]
# klati [V]
# razmenjivati [V]
# prati [V]
# palati [V]
# sastati [V]
# pokazati [V]
# pisati [V]
# razrešavati [V]
# primenjivati [V]
# obraćati [V]
#     ∟ obraćajući PresentPat
# otputovati [V]
# prisustvovati [V]
# prebacivati [V]
# sarađivati [V]
# vrati [V]
# investirati [V]
# preispitati [V]
# slati [V]
# pokušati [V]
# poštovati [V]
# trajati [V]
# poslati [V]
# dati [V]
#     ∟ dajući PresentPat
# sećati [V]
# povrati [V]
# postupati [V]
# održavati [V]
# požurivati [V]
# zarađivati [V]
# prihvati [V]
# plati [V]
# zloupotrebljavati [V]
# raspravljati [V]
# prikazati [V]
# uhvati [V]
# obrati [V]
# pridržavati [V]
# rezultati [V]
# zvati [V]
# uticati [V]
# postojati [V]
# koštati [V]
# funkcionisati [V]
# pokušavati [V]
# potpisati [V]
# analizirati [V]
# advokati [V]
# posmatrati [V]
# predstavljati [V]
#     ∟ predstavljajući PresentPat
# rešavati [V]
# dobijati [V]
# modelirati [V]
# mati [V]
# zapošljavati [V]
# pati [V]
# prepoznati [V]
# držati [V]
# bušati [V]
# imati [V]
#     ∟ imajući PresentPat
# dočekivati [V]
# izolovati [V]
# uključivati [V]
# ostati [V]
# održati [V]
# pridati [V]
# okončati [V]
# poznati [V]
# insistirati [V]
#     ∟ insistirajući PresentPat
# verovati [V]
# zamišljati [V]
# odvijati [V]
# doputovati [V]
# birati [V]
# povećati [V]
# intenzivirati [V]
# postati [V]
# olakšati [V]
# reagovati [V]
# predati [V]
# pružati [V]
# isplati [V]
# sačuvati [V]
# smanjivati [V]
# prestati [V]
# razgovarati [V]
# vraćati [V]
# sati [V]
# obavljati [V]
#     ∟ obavljajući PresentPat
# pregovarati [V]
# pervati [V]
# ometati [V]
# učestvovati [V]
# oslanjati [V]
# smatrati [V]
# glasati [V]
# zaletati [V]
# suspendovati [V]
# povezati [V]
# kandidati [V]
# hrvati [V]
# nemati [V]
# objavljivati [V]
# izazvati [V]
# nadati [V]
# ojačati [V]
# igrati [V]
#     ∟ igrajući PresentPat
# osećati [V]
# razvijati [V]
# ispričati [V]
# izabrati [V]
# fokusirati [V]
# ticati [V]
# artikulisati [V]
# bogati [V]
# zapitati [V]
# postavljati [V]
#     ∟ postavljajući PresentPat
# delati [V]
# putovati [V]
# finansirati [V]
# izdati [V]
# odavati [V]
# priznati [V]
# plakati [V]
# plaćati [V]
# izdavati [V]
# nadmetati [V]
# aktivirati [V]
# očekivati [V]
# cenjkati [V]
# pojačati [V]
# ratifikovati [V]
# definisati [V]
# zalagati [V]
# izražavati [V]
#     ∟ izražavajući PresentPat
# preduzimati [V]
#     ∟ preduzimajući PresentPat
# sindikati [V]
# počevši [V]
# uzdrmavši [V]
# učinivši [V]
# pretvorivši [V]
# osvojivši [V]
# proširivši [V]
# primetivši [V]
# dostigavši [V]
# postavivši [V]
# zamenivši [V]
# ponovivši [V]
# izazvavši [V]
# pohvalivši [V]
# bivši [V]
# završivši [V]
# rekavši [V]
# pobedivši [V]
# naslutivši [V]
# zabeleživši [V]
# dobivši [V]
# upozoravati [V]
#     ∟ upozoravajući PresentPat
# objašnjavati [V]
#     ∟ objašnjavajući PresentPat
# završavati [V]
#     ∟ završavajući PresentPat
# ubacovati [V]
#     ∟ ubacujući PresentPat
# čitati [V]
#     ∟ čitajući PresentPat
# potvrđovati [V]
#     ∟ potvrđujući PresentPat
# ažurirati [V]
#     ∟ ažurirajući PresentPat
# optužovati [V]
#     ∟ optužujući PresentPat
# odgovarati [V]
#     ∟ odgovarajući PresentPat
# pozdravljati [V]
#     ∟ pozdravljajući PresentPat
# dodati [V]
#     ∟ dodajući PresentPat
# znati [V]
#     ∟ znajući PresentPat
# otvarati [V]
#     ∟ otvarajući PresentPat
# primati [V]
#     ∟ primajući PresentPat
# narastati [V]
#     ∟ narastajući PresentPat
# predsedavati [V]
#     ∟ predsedavajući PresentPat
# savetovati [V]
#     ∟ savetujući PresentPat
# osuđovati [V]
#     ∟ osuđujući PresentPat
# ohrabrovati [V]
#     ∟ ohrabrujući PresentPat
# okončavati [V]
#     ∟ okončavajući PresentPat
# podsećati [V]
#     ∟ podsećajući PresentPat
# opisovati [V]
#     ∟ opisujući PresentPat
# kritikovati [V]
#     ∟ kritikujući PresentPat
# uveravati [V]
#     ∟ uveravajući PresentPat
# saopštavati [V]
#     ∟ saopštavajući PresentPat
# sprečavati [V]
#     ∟ sprečavajući PresentPat
# suočavati [V]
#     ∟ suočavajući PresentPat
# oslobađati [V]
#     ∟ oslobađajući PresentPat
# čekati [V]
#     ∟ čekajući PresentPat
# izdvajati [V]
#     ∟ izdvajajući PresentPat
# diskreditovati [V]
#     ∟ diskreditujući PresentPat
# zatvarati [V]
#     ∟ zatvarajući PresentPat
# protestovati [V]
#     ∟ protestujući PresentPat
# odbijati [V]
#     ∟ odbijajući PresentPat
# najavljovati [V]
#     ∟ najavljujući PresentPat
# nazivati [V]
#     ∟ nazivajući PresentPat
# emigrirati [V]
#     ∟ emigrirajući PresentPat
# zbližavati [V]
#     ∟ zbližavajući PresentPat
# prezati [V]
#     ∟ prezajući PresentPat
# zbunjovati [V]
#     ∟ zbunjujući PresentPat
# ukazovati [V]
#     ∟ ukazujući PresentPat
# pretvarati [V]
#     ∟ pretvarajući PresentPat
# tragati [V]
#     ∟ tragajući PresentPat
# nedostati [V]
#     ∟ nedostajući PresentPat
# prodati [V]
#     ∟ prodajući PresentPat
# primoravati [V]
#     ∟ primoravajući PresentPat
# potiskovati [V]
#     ∟ potiskujući PresentPat
# uključovati [V]
#     ∟ uključujući PresentPat
# bacati [V]
#     ∟ bacajući PresentPat
# zahvaljovati [V]
#     ∟ zahvaljujući PresentPat
# svrstavati [V]
#     ∟ svrstavajući PresentPat
# obeležavati [V]
#     ∟ obeležavajući PresentPat
# obećavati [V]
#     ∟ obećavajući PresentPat
# preneražavati [V]
#     ∟ preneražavajući PresentPat
# otuđovati [V]
#     ∟ otuđujući PresentPat
# pojavljovati [V]
#     ∟ pojavljujući PresentPat
# opstruirati [V]
#     ∟ opstruirajući PresentPat
# naglašavati [V]
#     ∟ naglašavajući PresentPat
# uzrokovati [V]
#     ∟ uzrokujući PresentPat
# ponavljati [V]
#     ∟ ponavljajući PresentPat
# favorizovati [V]
#     ∟ favorizujući PresentPat
# deceno [Adj]
#     ∟ decenije Comp+Neut+Sg
# uno [Adj]
#     ∟ unije Comp+Neut+Sg
# važna [Adj]
#     ∟ važnija Comp+Fem+Sg
#       najvažnija Sup+Fem+Sg
# svestrano [Adj]
#     ∟ svestranije Comp+Neut+Sg
# lina [Adj]
#     ∟ linija Comp+Fem+Sg
# apolona [Adj]
#     ∟ apolonija Comp+Fem+Sg
# lino [Adj]
#     ∟ linije Comp+Neut+Sg
# bezbedan [Adj]
#     ∟ bezbedniji Comp+Masc+Sg
# decena [Adj]
#     ∟ decenija Comp+Fem+Sg
# kompleksna [Adj]
#     ∟ kompleksnija Comp+Fem+Sg
# moćan [Adj]
#     ∟ moćniji Comp+Masc+Sg
#       najmoćniji Sup+Masc+Sg
# mena [Adj]
#     ∟ menija Comp+Fem+Sg
# pensilvaan [Adj]
#     ∟ pensilvaniji Comp+Masc+Sg
# aliana [Adj]
#     ∟ alianija Comp+Fem+Sg
# lian [Adj]
#     ∟ liniji Comp+Masc+Sg
# beskompromisan [Adj]
#     ∟ beskompromisniji Comp+Masc+Sg
# rano [Adj]
#     ∟ ranije Comp+Neut+Sg
# nezadovoljan [Adj]
#     ∟ nezadovoljniji Comp+Masc+Sg
# telefono [Adj]
#     ∟ telefonije Comp+Neut+Sg
# konkurentna [Adj]
#     ∟ konkurentnija Comp+Fem+Sg
# makedono [Adj]
#     ∟ makedonije Comp+Neut+Sg
# sigurna [Adj]
#     ∟ sigurnija Comp+Fem+Sg
# snažno [Adj]
#     ∟ snažnije Comp+Neut+Sg
# efikasna [Adj]
#     ∟ efikasnija Comp+Fem+Sg
# uticajan [Adj]
#     ∟ uticajniji Comp+Masc+Sg
# una [Adj]
#     ∟ unija Comp+Fem+Sg
# ozbiljan [Adj]
#     ∟ ozbiljniji Comp+Masc+Sg
#       najozbiljniji Sup+Masc+Sg
# estono [Adj]
#     ∟ estonije Comp+Neut+Sg
# pozitivan [Adj]
#     ∟ pozitivniji Comp+Masc+Sg
# čečean [Adj]
#     ∟ čečeniji Comp+Masc+Sg
# opasan [Adj]
#     ∟ opasnijim Comp+Masc+Pl
# kompano [Adj]
#     ∟ kompanije Comp+Neut+Sg
# špaan [Adj]
#     ∟ španiji Comp+Masc+Sg
# iskusan [Adj]
#     ∟ iskusnijim Comp+Masc+Pl
# rasprostranjena [Adj]
#     ∟ rasprostranjenija Comp+Fem+Sg
# ceremona [Adj]
#     ∟ ceremonija Comp+Fem+Sg
# litvano [Adj]
#     ∟ litvanije Comp+Neut+Sg
# značajan [Adj]
#     ∟ značajniji Comp+Masc+Sg
#       najznačajniji Sup+Masc+Sg
# kolona [Adj]
#     ∟ kolonija Comp+Fem+Sg
# britano [Adj]
#     ∟ britanije Comp+Neut+Sg
# albaan [Adj]
#     ∟ albaniji Comp+Masc+Sg
# striktno [Adj]
#     ∟ striktnije Comp+Neut+Sg
# kompana [Adj]
#     ∟ kompanija Comp+Fem+Sg
# očigledan [Adj]
#     ∟ očigledniji Comp+Masc+Sg
# potpuno [Adj]
#     ∟ potpunije Comp+Neut+Sg
# britaan [Adj]
#     ∟ britaniji Comp+Masc+Sg
# docno [Adj]
#     ∟ docnije Comp+Neut+Sg
# tačno [Adj]
#     ∟ tačnije Comp+Neut+Sg
# sloveno [Adj]
#     ∟ slovenije Comp+Neut+Sg
# diversifikovana [Adj]
#     ∟ diversifikovanija Comp+Fem+Sg
# raan [Adj]
#     ∟ ranijim Comp+Masc+Pl
# kasno [Adj]
#     ∟ kasnije Comp+Neut+Sg
# izražean [Adj]
#     ∟ izraženijim Comp+Masc+Pl
# demokratična [Adj]
#     ∟ demokratičnija Comp+Fem+Sg
# siromašno [Adj]
#     ∟ siromašnije Comp+Neut+Sg
# britana [Adj]
#     ∟ britanija Comp+Fem+Sg
# konkretno [Adj]
#     ∟ konkretnije Comp+Neut+Sg
# jevtian [Adj]
#     ∟ jevtinijim Comp+Masc+Pl
# špano [Adj]
#     ∟ španije Comp+Neut+Sg
# precizan [Adj]
#     ∟ precizniji Comp+Masc+Sg
# ceremoan [Adj]
#     ∟ ceremoniji Comp+Masc+Sg
# kompaan [Adj]
#     ∟ kompaniji Comp+Masc+Sg
# optimalno [Adj]
#     ∟ optimalnije Comp+Neut+Sg
# sigurno [Adj]
#     ∟ sigurnije Comp+Neut+Sg
# špana [Adj]
#     ∟ španija Comp+Fem+Sg
# rumuan [Adj]
#     ∟ rumuniji Comp+Masc+Sg
# rasprostranjean [Adj]
#     ∟ rasprostranjeniji Comp+Masc+Sg
# rumuno [Adj]
#     ∟ rumunije Comp+Neut+Sg
# makedoan [Adj]
#     ∟ makedoniji Comp+Masc+Sg
# zainteresovana [Adj]
#     ∟ zainteresovanija Comp+Fem+Sg
# represivan [Adj]
#     ∟ represivniji Comp+Masc+Sg
# optimističan [Adj]
#     ∟ optimističniji Comp+Masc+Sg
# letono [Adj]
#     ∟ letonije Comp+Neut+Sg
# aktivno [Adj]
#     ∟ aktivnije Comp+Neut+Sg
# jeftino [Adj]
#     ∟ jeftinije Comp+Neut+Sg
# makedona [Adj]
#     ∟ makedonija Comp+Fem+Sg
# važan [Adj]
#     ∟ važniji Comp+Masc+Sg
#       najvažniji Sup+Masc+Sg
# slovena [Adj]
#     ∟ slovenija Comp+Fem+Sg
# urgentan [Adj]
#     ∟ urgentniji Comp+Masc+Sg
#       najurgentniji Sup+Masc+Sg
# uan [Adj]
#     ∟ uniji Comp+Masc+Sg
# transparentan [Adj]
#     ∟ transparentnijim Comp+Masc+Pl
# ceremono [Adj]
#     ∟ ceremonije Comp+Neut+Sg
# rumuna [Adj]
#     ∟ rumunija Comp+Fem+Sg
# albana [Adj]
#     ∟ albanija Comp+Fem+Sg
# slovean [Adj]
#     ∟ sloveniji Comp+Masc+Sg
# važno [Adj]
#     ∟ važnije Comp+Neut+Sg
#       najvažnije Sup+Neut+Sg
# efikasan [Adj]
#     ∟ efikasniji Comp+Masc+Sg
# slobodan [Adj]
#     ∟ slobodniji Comp+Masc+Sg
# značajno [Adj]
#     ∟ značajnije Comp+Neut+Sg
#       najznačajnije Sup+Neut+Sg
# albano [Adj]
#     ∟ albanije Comp+Neut+Sg

# %% [markdown]
# - Prisvojni pridevi (mesta): -ski, -čki, -ški
# - Prisvojni pridevi (?): -ni
# - Prisvojni pridevi (ljudi): -ov, -in, -ev

# %% [markdown]
# ## 2.3 Possessive adjectives

# %% [markdown]
# Possessive adjectives can be of the following forms depending on the type of entity that *possesses*:
#
# 1. *-ov, -ev, -in*: when the entity that possesses is a human being
#     - Examples: Markov "Mark's", Tonijev "Tony's", Nemanjin "Nemanja's"
# 2. *-ski, -čki, -ški*: usually with toponymical entities - countries, ethnicities, cities, villages, regions, etc.
#     - Examples: srpski "Serbian", nemački "German", praški "Prague's"
# 3. *-ni*
#     - Examples: državni "state"

# %% [markdown]
# Of course, adjectives are changed according to gender as well, so we have:
#
# 2. *-ska* (f.), *-sko* (n.), *-čka* (f.), *-čko (n.), *-ška* (f.), *-ško* (n.)
# 3. *-na* (f.), *-no* (n.)
#
# However, the inflection forms for masculine, feminine and neutral gender are the same when inflecting over different cases. The only difference is in the nominative form, so feminine and neutral forms are put under the masculine form.
#
# Singular
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|srpski|srpska|srpsko|
# |genitive|srpskog|srpske|srpskog|
# |dative|srpskom|srpskoj|srpskom|
# |acusative|srpski|srpsku|srpsko|
# |vocative|srpski|srpska|srpsko|
# |instrumental|srpskim|srpskom|srpskim|
# |locative|srpskom|srpskoj|srpskom|
#
# Plural
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|srpski|srpske|srpska|
# |genitive|srpskih|srpskih|srpske|
# |dative|srpskim|srpskim|srpskoj|
# |acusative|srpske|srpske|srpsku|
# |vocative|srpski|srpske|srpska|
# |instrumental|srpskim|srpskim|srpskom|
# |locative|srpskim|srpskim|srpskoj|

# %% [markdown]
# Possible siffixes: *-ski*, *-skog*, *-skom*, *-skim*, *-ska*, *-ske*, *-skoj*, *-sku*, *-skih*, *-sko*

# %% [markdown]
# ### 2.3.1 suffix *-ski* and its inflections

# %%
possessive_adjectives = list(set([w for w in ud_content if w.endswith('ski')]))

# %%
possessive_adjectives
# Out:
# ['finansijski',
#  'trojanski',
#  'dostojevski',
#  'svetski',
#  'herkulovski',
#  'romski',
#  'ivanovski',
#  'generacijski',
#  'mađarski',
#  'beogradski',
#  'istorijski',
#  'gruevski',
#  'britanski',
#  'diplomatski',
#  'kurdski',
#  'filmski',
#  'švajcarski',
#  'televizijski',
#  'spoljnotrgovinski',
#  'spisateljski',
#  'pakistanski',
#  'socijaldemokratski',
#  'bosforski',
#  'dejtonski',
#  'balkanski',
#  'irski',
#  'geografski',
#  'vremenski',
#  'albanski',
#  'belgijski',
#  'bosanski',
#  'građevinski',
#  'londonski',
#  'lisabonski',
#  'teoretski',
#  'jugoslovenski',
#  'terapeutski',
#  'portugalski',
#  'vijetnamski',
#  'cerovski',
#  'tetovski',
#  'carinski',
#  'avionski',
#  'crvenkovski',
#  'saudijski',
#  'industrijski',
#  'zemunski',
#  'olimpijski',
#  'posttraumatski',
#  'mančevski',
#  'nikolovski',
#  'orvelovski',
#  'argentinski',
#  'imunski',
#  'većinski',
#  'puninski',
#  'engleski',
#  'turski',
#  'trajkovski',
#  'kablovski',
#  'bučkovski',
#  'moldavski',
#  'poljski',
#  'italijanski',
#  'rumunski',
#  'proevropski',
#  'amaterski',
#  'antonovski',
#  'francuski',
#  'penzijski',
#  'akademski',
#  'istinski',
#  'stavrevski',
#  'bliski',
#  'meteorski',
#  'španski',
#  'drumski',
#  'evropski',
#  'izraelski',
#  'konjanovski',
#  'bostonski',
#  'aleksievski',
#  'energetski',
#  'gagovski',
#  'antologijski',
#  'manevski',
#  'nedemokratski',
#  'novozelandski',
#  'azilski',
#  'šahovski',
#  'medijski',
#  'ministarski',
#  'sofijski',
#  'islamski',
#  'sovjetski',
#  'helenski',
#  'verski',
#  'vrhunski',
#  'peruanski',
#  'proruski',
#  'sudski',
#  'hrvatski',
#  'bugarski',
#  'zakonski',
#  'ruski',
#  'crnogorski',
#  'evroatlantski',
#  'ohridski',
#  'berlinski',
#  'poposki',
#  'niski',
#  'srpski',
#  'životinjski',
#  'trgovinski',
#  'katastarski',
#  'kiparski',
#  'novinarski',
#  'holivudski',
#  'nilski',
#  'univerzitetski',
#  'trajkoviski',
#  'kosovski',
#  'majski',
#  'litvanski',
#  'stojčevski',
#  'ramkovski',
#  'levičarski',
#  'prevarantski',
#  'demokratski',
#  'detektivski',
#  'ljudski',
#  'birokratski',
#  'lavovski',
#  'republikanski',
#  'sirijski',
#  'ekonomski',
#  'gruzijski',
#  'poreski',
#  'budžetski',
#  'briselski',
#  'švedski',
#  'studentski',
#  'automatski',
#  'finski',
#  'makedonski',
#  'pariski',
#  'bankarski',
#  'milošoski',
#  'solunski',
#  'fudbalski',
#  'peševski']

# %%
for possesive_adj in possessive_adjectives:
    add_to_lexicon(possesive_adj, "Adj")

# %%
def add_possessive_adjectives(possessive_adjectives, replace_src, replace_dst):
    for possessive_ADJ in possessive_adjectives:
        derived_f = (possessive_ADJ, "Poss")
        base_form = possessive_ADJ.replace(replace_src, replace_dst)
        lexicon_entry = get_lexicon_entry(base_form, "Adj")
        if lexicon_entry is not None:
            lexicon_entry.derived_forms.append(derived_f)
        else:
            add_to_lexicon(base_form, "Adj", [derived_f])

# %%
def add_adjective_inflection_forms(inflection_suffixes):
    for suffix, base_suffix in inflection_suffixes:
        possessive_adjectives = list(set([w for w in ud_content if w.endswith(suffix)]))
        add_possessive_adjectives(possessive_adjectives, suffix, base_suffix)

# %%
inflection_suffixes = [('skog', 'ski'), ('skom', 'ski'), ('skim', 'ski'), ('ska', 'ski'), ('ske', 'ski'), 
                       ('skoj', 'ski'), ('sku', 'ski'), ('skih', 'ski'), ('sko', 'ski')]
add_adjective_inflection_forms(inflection_suffixes)

# %%
print_lexicon()
# Out:
# pripremiti [V]
# izraditi [V]
# oprostiti [V]
# proširiti [V]
# govoriti [V]
# otkloniti [V]
# unaprediti [V]
# otplatiti [V]
# pretpostaviti [V]
# smanjiti [V]
# pustiti [V]
# značiti [V]
# rešiti [V]
# naslediti [V]
# štiti [V]
# zaštititi [V]
# snositi [V]
# razdvojiti [V]
# ograničiti [V]
# zavisiti [V]
# patiti [V]
# odstupiti [V]
# zaključiti [V]
# učiniti [V]
# uložiti [V]
# ponoviti [V]
# raditi [V]
# usredsrediti [V]
# odrediti [V]
# pojaviti [V]
# obaviti [V]
# prihvatiti [V]
# potrošiti [V]
# ponuditi [V]
# preporučiti [V]
# zameniti [V]
# obezbediti [V]
# izgubiti [V]
# iznositi [V]
# složiti [V]
# odobriti [V]
# omogućiti [V]
# uočiti [V]
# obilaziti [V]
# ostaviti [V]
# staviti [V]
# izmeniti [V]
# unakaziti [V]
# razmotriti [V]
# ohrabriti [V]
# ispuniti [V]
# odbaciti [V]
# suočiti [V]
# rijaliti [V]
# osetiti [V]
# tražiti [V]
# vlastiti [V]
# deliti [V]
# zanemariti [V]
# nastupiti [V]
# vratiti [V]
# udvostručiti [V]
# izvršiti [V]
# zatražiti [V]
# nastaviti [V]
# dozvoliti [V]
# krediti [V]
# razvodniti [V]
# usuditi [V]
# potvrditi [V]
# pružiti [V]
# shvatiti [V]
# desiti [V]
# protiviti [V]
# ostvariti [V]
# povratiti [V]
# izmisliti [V]
# različiti [V]
# uništiti [V]
# preurediti [V]
# skladištiti [V]
# primiti [V]
# otkriti [V]
# odgovoriti [V]
# uraditi [V]
# protumačiti [V]
# zamisliti [V]
# predstaviti [V]
# odnositi [V]
# uspostaviti [V]
# napraviti [V]
# arvaniti [V]
# podnositi [V]
# proceniti [V]
# dobiti [V]
# opslužiti [V]
# posetiti [V]
# pratiti [V]
# povrediti [V]
# napustiti [V]
# posvetiti [V]
# namestiti [V]
# iskoristiti [V]
# nuditi [V]
# zaštiti [V]
# rušiti [V]
# koristiti [V]
# učiti [V]
# umoriti [V]
# dogoditi [V]
# smisliti [V]
# sprovoditi [V]
# uskladiti [V]
# razotkriti [V]
# voditi [V]
# promeniti [V]
# prenositi [V]
# uslediti [V]
# otpustiti [V]
# pridružiti [V]
# otvoriti [V]
# završiti [V]
# razrešiti [V]
# sprečiti [V]
# kazniti [V]
# težiti [V]
# odvratiti [V]
# postaviti [V]
# kupiti [V]
# udružiti [V]
# poslužiti [V]
# uhvatiti [V]
# izgraditi [V]
# ustanoviti [V]
# ugroziti [V]
# proučiti [V]
# slediti [V]
# zaposliti [V]
# predložiti [V]
# osuditi [V]
# nadoknaditi [V]
# obnoviti [V]
# stvoriti [V]
# pristupiti [V]
# oseti [V]
# započeti [V]
# preuzeti [V]
# dopreti [V]
# uzeti [V]
# doprineti [V]
# preduzeti [V]
# doneti [V]
# preoteti [V]
# poseti [V]
# preneti [V]
# animoziteti [V]
# anketi [V]
# peti [V]
# deveti [V]
# našteti [V]
# posveti [V]
# tereti [V]
# meti [V]
# ćančeti [V]
# ahmeti [V]
# univerziteti [V]
# uspeti [V]
# antikviteti [V]
# razumeti [V]
# oteti [V]
# početi [V]
# dijeti [V]
# oživeti [V]
# preti [V]
# videti [V]
# predvideti [V]
# podneti [V]
# aveti [V]
# predmeti [V]
# fakulteti [V]
# pozivati [V]
#     ∟ pozivajući PresentPat
# falsifikovati [V]
# zahtevati [V]
#     ∟ zahtevajući PresentPat
# blokirati [V]
# dokazati [V]
# kopirati [V]
# uračunati [V]
# apstinirati [V]
# podržati [V]
# poboljšati [V]
# morati [V]
# oklevati [V]
# menjati [V]
# omogućavati [V]
#     ∟ omogućavajući PresentPat
# zadržati [V]
# intervenisati [V]
# garantovati [V]
# stajati [V]
# organizovati [V]
# pozvati [V]
# klati [V]
# razmenjivati [V]
# prati [V]
# palati [V]
# sastati [V]
# pokazati [V]
# pisati [V]
# razrešavati [V]
# primenjivati [V]
# obraćati [V]
#     ∟ obraćajući PresentPat
# otputovati [V]
# prisustvovati [V]
# prebacivati [V]
# sarađivati [V]
# vrati [V]
# investirati [V]
# preispitati [V]
# slati [V]
# pokušati [V]
# poštovati [V]
# trajati [V]
# poslati [V]
# dati [V]
#     ∟ dajući PresentPat
# sećati [V]
# povrati [V]
# postupati [V]
# održavati [V]
# požurivati [V]
# zarađivati [V]
# prihvati [V]
# plati [V]
# zloupotrebljavati [V]
# raspravljati [V]
# prikazati [V]
# uhvati [V]
# obrati [V]
# pridržavati [V]
# rezultati [V]
# zvati [V]
# uticati [V]
# postojati [V]
# koštati [V]
# funkcionisati [V]
# pokušavati [V]
# potpisati [V]
# analizirati [V]
# advokati [V]
# posmatrati [V]
# predstavljati [V]
#     ∟ predstavljajući PresentPat
# rešavati [V]
# dobijati [V]
# modelirati [V]
# mati [V]
# zapošljavati [V]
# pati [V]
# prepoznati [V]
# držati [V]
# bušati [V]
# imati [V]
#     ∟ imajući PresentPat
# dočekivati [V]
# izolovati [V]
# uključivati [V]
# ostati [V]
# održati [V]
# pridati [V]
# okončati [V]
# poznati [V]
# insistirati [V]
#     ∟ insistirajući PresentPat
# verovati [V]
# zamišljati [V]
# odvijati [V]
# doputovati [V]
# birati [V]
# povećati [V]
# intenzivirati [V]
# postati [V]
# olakšati [V]
# reagovati [V]
# predati [V]
# pružati [V]
# isplati [V]
# sačuvati [V]
# smanjivati [V]
# prestati [V]
# razgovarati [V]
# vraćati [V]
# sati [V]
# obavljati [V]
#     ∟ obavljajući PresentPat
# pregovarati [V]
# pervati [V]
# ometati [V]
# učestvovati [V]
# oslanjati [V]
# smatrati [V]
# glasati [V]
# zaletati [V]
# suspendovati [V]
# povezati [V]
# kandidati [V]
# hrvati [V]
# nemati [V]
# objavljivati [V]
# izazvati [V]
# nadati [V]
# ojačati [V]
# igrati [V]
#     ∟ igrajući PresentPat
# osećati [V]
# razvijati [V]
# ispričati [V]
# izabrati [V]
# fokusirati [V]
# ticati [V]
# artikulisati [V]
# bogati [V]
# zapitati [V]
# postavljati [V]
#     ∟ postavljajući PresentPat
# delati [V]
# putovati [V]
# finansirati [V]
# izdati [V]
# odavati [V]
# priznati [V]
# plakati [V]
# plaćati [V]
# izdavati [V]
# nadmetati [V]
# aktivirati [V]
# očekivati [V]
# cenjkati [V]
# pojačati [V]
# ratifikovati [V]
# definisati [V]
# zalagati [V]
# izražavati [V]
#     ∟ izražavajući PresentPat
# preduzimati [V]
#     ∟ preduzimajući PresentPat
# sindikati [V]
# počevši [V]
# uzdrmavši [V]
# učinivši [V]
# pretvorivši [V]
# osvojivši [V]
# proširivši [V]
# primetivši [V]
# dostigavši [V]
# postavivši [V]
# zamenivši [V]
# ponovivši [V]
# izazvavši [V]
# pohvalivši [V]
# bivši [V]
# završivši [V]
# rekavši [V]
# pobedivši [V]
# naslutivši [V]
# zabeleživši [V]
# dobivši [V]
# upozoravati [V]
#     ∟ upozoravajući PresentPat
# objašnjavati [V]
#     ∟ objašnjavajući PresentPat
# završavati [V]
#     ∟ završavajući PresentPat
# ubacovati [V]
#     ∟ ubacujući PresentPat
# čitati [V]
#     ∟ čitajući PresentPat
# potvrđovati [V]
#     ∟ potvrđujući PresentPat
# ažurirati [V]
#     ∟ ažurirajući PresentPat
# optužovati [V]
#     ∟ optužujući PresentPat
# odgovarati [V]
#     ∟ odgovarajući PresentPat
# pozdravljati [V]
#     ∟ pozdravljajući PresentPat
# dodati [V]
#     ∟ dodajući PresentPat
# znati [V]
#     ∟ znajući PresentPat
# otvarati [V]
#     ∟ otvarajući PresentPat
# primati [V]
#     ∟ primajući PresentPat
# narastati [V]
#     ∟ narastajući PresentPat
# predsedavati [V]
#     ∟ predsedavajući PresentPat
# savetovati [V]
#     ∟ savetujući PresentPat
# osuđovati [V]
#     ∟ osuđujući PresentPat
# ohrabrovati [V]
#     ∟ ohrabrujući PresentPat
# okončavati [V]
#     ∟ okončavajući PresentPat
# podsećati [V]
#     ∟ podsećajući PresentPat
# opisovati [V]
#     ∟ opisujući PresentPat
# kritikovati [V]
#     ∟ kritikujući PresentPat
# uveravati [V]
#     ∟ uveravajući PresentPat
# saopštavati [V]
#     ∟ saopštavajući PresentPat
# sprečavati [V]
#     ∟ sprečavajući PresentPat
# suočavati [V]
#     ∟ suočavajući PresentPat
# oslobađati [V]
#     ∟ oslobađajući PresentPat
# čekati [V]
#     ∟ čekajući PresentPat
# izdvajati [V]
#     ∟ izdvajajući PresentPat
# diskreditovati [V]
#     ∟ diskreditujući PresentPat
# zatvarati [V]
#     ∟ zatvarajući PresentPat
# protestovati [V]
#     ∟ protestujući PresentPat
# odbijati [V]
#     ∟ odbijajući PresentPat
# najavljovati [V]
#     ∟ najavljujući PresentPat
# nazivati [V]
#     ∟ nazivajući PresentPat
# emigrirati [V]
#     ∟ emigrirajući PresentPat
# zbližavati [V]
#     ∟ zbližavajući PresentPat
# prezati [V]
#     ∟ prezajući PresentPat
# zbunjovati [V]
#     ∟ zbunjujući PresentPat
# ukazovati [V]
#     ∟ ukazujući PresentPat
# pretvarati [V]
#     ∟ pretvarajući PresentPat
# tragati [V]
#     ∟ tragajući PresentPat
# nedostati [V]
#     ∟ nedostajući PresentPat
# prodati [V]
#     ∟ prodajući PresentPat
# primoravati [V]
#     ∟ primoravajući PresentPat
# potiskovati [V]
#     ∟ potiskujući PresentPat
# uključovati [V]
#     ∟ uključujući PresentPat
# bacati [V]
#     ∟ bacajući PresentPat
# zahvaljovati [V]
#     ∟ zahvaljujući PresentPat
# svrstavati [V]
#     ∟ svrstavajući PresentPat
# obeležavati [V]
#     ∟ obeležavajući PresentPat
# obećavati [V]
#     ∟ obećavajući PresentPat
# preneražavati [V]
#     ∟ preneražavajući PresentPat
# otuđovati [V]
#     ∟ otuđujući PresentPat
# pojavljovati [V]
#     ∟ pojavljujući PresentPat
# opstruirati [V]
#     ∟ opstruirajući PresentPat
# naglašavati [V]
#     ∟ naglašavajući PresentPat
# uzrokovati [V]
#     ∟ uzrokujući PresentPat
# ponavljati [V]
#     ∟ ponavljajući PresentPat
# favorizovati [V]
#     ∟ favorizujući PresentPat
# deceno [Adj]
#     ∟ decenije Comp+Neut+Sg
# uno [Adj]
#     ∟ unije Comp+Neut+Sg
# važna [Adj]
#     ∟ važnija Comp+Fem+Sg
#       najvažnija Sup+Fem+Sg
# svestrano [Adj]
#     ∟ svestranije Comp+Neut+Sg
# lina [Adj]
#     ∟ linija Comp+Fem+Sg
# apolona [Adj]
#     ∟ apolonija Comp+Fem+Sg
# lino [Adj]
#     ∟ linije Comp+Neut+Sg
# bezbedan [Adj]
#     ∟ bezbedniji Comp+Masc+Sg
# decena [Adj]
#     ∟ decenija Comp+Fem+Sg
# kompleksna [Adj]
#     ∟ kompleksnija Comp+Fem+Sg
# moćan [Adj]
#     ∟ moćniji Comp+Masc+Sg
#       najmoćniji Sup+Masc+Sg
# mena [Adj]
#     ∟ menija Comp+Fem+Sg
# pensilvaan [Adj]
#     ∟ pensilvaniji Comp+Masc+Sg
# aliana [Adj]
#     ∟ alianija Comp+Fem+Sg
# lian [Adj]
#     ∟ liniji Comp+Masc+Sg
# beskompromisan [Adj]
#     ∟ beskompromisniji Comp+Masc+Sg
# rano [Adj]
#     ∟ ranije Comp+Neut+Sg
# nezadovoljan [Adj]
#     ∟ nezadovoljniji Comp+Masc+Sg
# telefono [Adj]
#     ∟ telefonije Comp+Neut+Sg
# konkurentna [Adj]
#     ∟ konkurentnija Comp+Fem+Sg
# makedono [Adj]
#     ∟ makedonije Comp+Neut+Sg
# sigurna [Adj]
#     ∟ sigurnija Comp+Fem+Sg
# snažno [Adj]
#     ∟ snažnije Comp+Neut+Sg
# efikasna [Adj]
#     ∟ efikasnija Comp+Fem+Sg
# uticajan [Adj]
#     ∟ uticajniji Comp+Masc+Sg
# una [Adj]
#     ∟ unija Comp+Fem+Sg
# ozbiljan [Adj]
#     ∟ ozbiljniji Comp+Masc+Sg
#       najozbiljniji Sup+Masc+Sg
# estono [Adj]
#     ∟ estonije Comp+Neut+Sg
# pozitivan [Adj]
#     ∟ pozitivniji Comp+Masc+Sg
# čečean [Adj]
#     ∟ čečeniji Comp+Masc+Sg
# opasan [Adj]
#     ∟ opasnijim Comp+Masc+Pl
# kompano [Adj]
#     ∟ kompanije Comp+Neut+Sg
# špaan [Adj]
#     ∟ španiji Comp+Masc+Sg
# iskusan [Adj]
#     ∟ iskusnijim Comp+Masc+Pl
# rasprostranjena [Adj]
#     ∟ rasprostranjenija Comp+Fem+Sg
# ceremona [Adj]
#     ∟ ceremonija Comp+Fem+Sg
# litvano [Adj]
#     ∟ litvanije Comp+Neut+Sg
# značajan [Adj]
#     ∟ značajniji Comp+Masc+Sg
#       najznačajniji Sup+Masc+Sg
# kolona [Adj]
#     ∟ kolonija Comp+Fem+Sg
# britano [Adj]
#     ∟ britanije Comp+Neut+Sg
# albaan [Adj]
#     ∟ albaniji Comp+Masc+Sg
# striktno [Adj]
#     ∟ striktnije Comp+Neut+Sg
# kompana [Adj]
#     ∟ kompanija Comp+Fem+Sg
# očigledan [Adj]
#     ∟ očigledniji Comp+Masc+Sg
# potpuno [Adj]
#     ∟ potpunije Comp+Neut+Sg
# britaan [Adj]
#     ∟ britaniji Comp+Masc+Sg
# docno [Adj]
#     ∟ docnije Comp+Neut+Sg
# tačno [Adj]
#     ∟ tačnije Comp+Neut+Sg
# sloveno [Adj]
#     ∟ slovenije Comp+Neut+Sg
# diversifikovana [Adj]
#     ∟ diversifikovanija Comp+Fem+Sg
# raan [Adj]
#     ∟ ranijim Comp+Masc+Pl
# kasno [Adj]
#     ∟ kasnije Comp+Neut+Sg
# izražean [Adj]
#     ∟ izraženijim Comp+Masc+Pl
# demokratična [Adj]
#     ∟ demokratičnija Comp+Fem+Sg
# siromašno [Adj]
#     ∟ siromašnije Comp+Neut+Sg
# britana [Adj]
#     ∟ britanija Comp+Fem+Sg
# konkretno [Adj]
#     ∟ konkretnije Comp+Neut+Sg
# jevtian [Adj]
#     ∟ jevtinijim Comp+Masc+Pl
# špano [Adj]
#     ∟ španije Comp+Neut+Sg
# precizan [Adj]
#     ∟ precizniji Comp+Masc+Sg
# ceremoan [Adj]
#     ∟ ceremoniji Comp+Masc+Sg
# kompaan [Adj]
#     ∟ kompaniji Comp+Masc+Sg
# optimalno [Adj]
#     ∟ optimalnije Comp+Neut+Sg
# sigurno [Adj]
#     ∟ sigurnije Comp+Neut+Sg
# špana [Adj]
#     ∟ španija Comp+Fem+Sg
# rumuan [Adj]
#     ∟ rumuniji Comp+Masc+Sg
# rasprostranjean [Adj]
#     ∟ rasprostranjeniji Comp+Masc+Sg
# rumuno [Adj]
#     ∟ rumunije Comp+Neut+Sg
# makedoan [Adj]
#     ∟ makedoniji Comp+Masc+Sg
# zainteresovana [Adj]
#     ∟ zainteresovanija Comp+Fem+Sg
# represivan [Adj]
#     ∟ represivniji Comp+Masc+Sg
# optimističan [Adj]
#     ∟ optimističniji Comp+Masc+Sg
# letono [Adj]
#     ∟ letonije Comp+Neut+Sg
# aktivno [Adj]
#     ∟ aktivnije Comp+Neut+Sg
# jeftino [Adj]
#     ∟ jeftinije Comp+Neut+Sg
# makedona [Adj]
#     ∟ makedonija Comp+Fem+Sg
# važan [Adj]
#     ∟ važniji Comp+Masc+Sg
#       najvažniji Sup+Masc+Sg
# slovena [Adj]
#     ∟ slovenija Comp+Fem+Sg
# urgentan [Adj]
#     ∟ urgentniji Comp+Masc+Sg
#       najurgentniji Sup+Masc+Sg
# uan [Adj]
#     ∟ uniji Comp+Masc+Sg
# transparentan [Adj]
#     ∟ transparentnijim Comp+Masc+Pl
# ceremono [Adj]
#     ∟ ceremonije Comp+Neut+Sg
# rumuna [Adj]
#     ∟ rumunija Comp+Fem+Sg
# albana [Adj]
#     ∟ albanija Comp+Fem+Sg
# slovean [Adj]
#     ∟ sloveniji Comp+Masc+Sg
# važno [Adj]
#     ∟ važnije Comp+Neut+Sg
#       najvažnije Sup+Neut+Sg
# efikasan [Adj]
#     ∟ efikasniji Comp+Masc+Sg
# slobodan [Adj]
#     ∟ slobodniji Comp+Masc+Sg
# značajno [Adj]
#     ∟ značajnije Comp+Neut+Sg
#       najznačajnije Sup+Neut+Sg
# albano [Adj]
#     ∟ albanije Comp+Neut+Sg
# finansijski [Adj]
#     ∟ finansijskog Poss
#       finansijskom Poss
#       finansijskim Poss
#       finansijska Poss
#       finansijske Poss
#       finansijsku Poss
#       finansijskih Poss
# trojanski [Adj]
# dostojevski [Adj]
# svetski [Adj]
#     ∟ svetskog Poss
#       svetskom Poss
#       svetskim Poss
#       svetska Poss
#       svetske Poss
#       svetskoj Poss
#       svetsku Poss
#       svetskih Poss
#       svetsko Poss
# herkulovski [Adj]
# romski [Adj]
#     ∟ romskog Poss
#       romskom Poss
#       romskim Poss
#       romska Poss
#       romske Poss
#       romskoj Poss
# ivanovski [Adj]
# generacijski [Adj]
# mađarski [Adj]
#     ∟ mađarske Poss
#       mađarskoj Poss
# beogradski [Adj]
#     ∟ beogradskog Poss
#       beogradskom Poss
#       beogradska Poss
#       beogradske Poss
#       beogradskoj Poss
#       beogradsku Poss
# istorijski [Adj]
#     ∟ istorijskog Poss
#       istorijskom Poss
#       istorijskim Poss
#       istorijska Poss
#       istorijsku Poss
#       istorijskih Poss
# gruevski [Adj]
#     ∟ gruevskog Poss
#       gruevskim Poss
# britanski [Adj]
#     ∟ britanskog Poss
#       britanskom Poss
#       britanska Poss
#       britanske Poss
#       britansku Poss
#       britanskih Poss
# diplomatski [Adj]
#     ∟ diplomatskog Poss
#       diplomatskom Poss
#       diplomatskim Poss
#       diplomatska Poss
#       diplomatske Poss
#       diplomatskoj Poss
#       diplomatsku Poss
# kurdski [Adj]
#     ∟ kurdskog Poss
#       kurdskom Poss
#       kurdske Poss
#       kurdskoj Poss
#       kurdsku Poss
#       kurdskih Poss
# filmski [Adj]
#     ∟ filmskom Poss
#       filmskih Poss
# švajcarski [Adj]
#     ∟ švajcarskog Poss
#       švajcarske Poss
#       švajcarskoj Poss
# televizijski [Adj]
#     ∟ televizijske Poss
# spoljnotrgovinski [Adj]
# spisateljski [Adj]
# pakistanski [Adj]
#     ∟ pakistanske Poss
# socijaldemokratski [Adj]
#     ∟ socijaldemokratskog Poss
#       socijaldemokratskom Poss
#       socijaldemokratska Poss
#       socijaldemokratske Poss
#       socijaldemokratskoj Poss
# bosforski [Adj]
# dejtonski [Adj]
#     ∟ dejtonskog Poss
#       dejtonskim Poss
# balkanski [Adj]
#     ∟ balkanskim Poss
#       balkanska Poss
#       balkanske Poss
#       balkanskoj Poss
#       balkansku Poss
#       balkanskih Poss
# irski [Adj]
#     ∟ irskim Poss
#       irska Poss
#       irske Poss
#       irskoj Poss
# geografski [Adj]
# vremenski [Adj]
#     ∟ vremenskim Poss
#       vremenskih Poss
# albanski [Adj]
#     ∟ albanskog Poss
#       albanskom Poss
#       albanskim Poss
#       albanska Poss
#       albanske Poss
#       albanskoj Poss
#       albansku Poss
#       albanskih Poss
# belgijski [Adj]
#     ∟ belgijskom Poss
# bosanski [Adj]
#     ∟ bosanskim Poss
#       bosanska Poss
#       bosanske Poss
#       bosanskih Poss
# građevinski [Adj]
#     ∟ građevinskog Poss
#       građevinske Poss
# londonski [Adj]
#     ∟ londonskoj Poss
# lisabonski [Adj]
# teoretski [Adj]
# jugoslovenski [Adj]
#     ∟ jugoslovenskog Poss
#       jugoslovenske Poss
#       jugoslovenskoj Poss
# terapeutski [Adj]
#     ∟ terapeutsko Poss
# portugalski [Adj]
#     ∟ portugalske Poss
# vijetnamski [Adj]
# cerovski [Adj]
# tetovski [Adj]
# carinski [Adj]
#     ∟ carinskog Poss
#       carinska Poss
#       carinske Poss
#       carinskoj Poss
#       carinskih Poss
# avionski [Adj]
#     ∟ avionskih Poss
# crvenkovski [Adj]
#     ∟ crvenkovskim Poss
# saudijski [Adj]
#     ∟ saudijskog Poss
#       saudijska Poss
#       saudijske Poss
# industrijski [Adj]
#     ∟ industrijskim Poss
#       industrijskih Poss
# zemunski [Adj]
#     ∟ zemunskog Poss
# olimpijski [Adj]
#     ∟ olimpijskom Poss
#       olimpijska Poss
# posttraumatski [Adj]
#     ∟ posttraumatskog Poss
# mančevski [Adj]
#     ∟ mančevskog Poss
# nikolovski [Adj]
# orvelovski [Adj]
# argentinski [Adj]
#     ∟ argentinske Poss
# imunski [Adj]
# većinski [Adj]
# puninski [Adj]
# engleski [Adj]
#     ∟ engleska Poss
# turski [Adj]
#     ∟ turskog Poss
#       turskom Poss
#       turskim Poss
#       turska Poss
#       turske Poss
#       turskoj Poss
#       tursku Poss
#       turskih Poss
#       tursko Poss
# trajkovski [Adj]
#     ∟ trajkovskog Poss
# kablovski [Adj]
#     ∟ kablovske Poss
# bučkovski [Adj]
# moldavski [Adj]
#     ∟ moldavska Poss
#       moldavske Poss
#       moldavskih Poss
# poljski [Adj]
#     ∟ poljske Poss
#       poljskoj Poss
#       poljskih Poss
# italijanski [Adj]
#     ∟ italijanskog Poss
#       italijanske Poss
# rumunski [Adj]
#     ∟ rumunskog Poss
#       rumunskom Poss
#       rumunskim Poss
#       rumunska Poss
#       rumunske Poss
#       rumunskoj Poss
#       rumunskih Poss
#       rumunsko Poss
# proevropski [Adj]
#     ∟ proevropske Poss
#       proevropskoj Poss
# amaterski [Adj]
#     ∟ amaterske Poss
# antonovski [Adj]
# francuski [Adj]
#     ∟ francuskog Poss
#       francuskom Poss
#       francuska Poss
#       francuske Poss
#       francuskoj Poss
#       francusku Poss
#       francuskih Poss
# penzijski [Adj]
#     ∟ penzijskog Poss
# akademski [Adj]
#     ∟ akademska Poss
#       akademske Poss
#       akademskoj Poss
#       akademskih Poss
# istinski [Adj]
#     ∟ istinske Poss
# stavrevski [Adj]
# bliski [Adj]
#     ∟ bliskog Poss
#       bliskom Poss
#       bliskoj Poss
#       blisku Poss
# meteorski [Adj]
# španski [Adj]
#     ∟ španskog Poss
#       španskim Poss
#       španske Poss
#       španskih Poss
# drumski [Adj]
# evropski [Adj]
#     ∟ evropskog Poss
#       evropskom Poss
#       evropskim Poss
#       evropska Poss
#       evropske Poss
#       evropskoj Poss
#       evropsku Poss
#       evropskih Poss
#       evropsko Poss
# izraelski [Adj]
# konjanovski [Adj]
#     ∟ konjanovskog Poss
# bostonski [Adj]
# aleksievski [Adj]
# energetski [Adj]
#     ∟ energetskim Poss
#       energetska Poss
#       energetske Poss
#       energetskih Poss
# gagovski [Adj]
# antologijski [Adj]
# manevski [Adj]
# nedemokratski [Adj]
# novozelandski [Adj]
# azilski [Adj]
#     ∟ azilskog Poss
# šahovski [Adj]
#     ∟ šahovska Poss
# medijski [Adj]
#     ∟ medijskog Poss
#       medijskom Poss
#       medijske Poss
#       medijskih Poss
# ministarski [Adj]
#     ∟ ministarska Poss
# sofijski [Adj]
#     ∟ sofijskoj Poss
# islamski [Adj]
#     ∟ islamskim Poss
#       islamska Poss
#       islamske Poss
#       islamsku Poss
#       islamskih Poss
# sovjetski [Adj]
#     ∟ sovjetskom Poss
# helenski [Adj]
#     ∟ helensko Poss
# verski [Adj]
#     ∟ verskog Poss
#       verskim Poss
#       verske Poss
#       versku Poss
#       verskih Poss
#       versko Poss
# vrhunski [Adj]
#     ∟ vrhunskom Poss
#       vrhunske Poss
#       vrhunskih Poss
# peruanski [Adj]
# proruski [Adj]
# sudski [Adj]
#     ∟ sudskog Poss
#       sudskom Poss
#       sudskim Poss
#       sudskoj Poss
#       sudskih Poss
#       sudsko Poss
# hrvatski [Adj]
#     ∟ hrvatskog Poss
#       hrvatskom Poss
#       hrvatskim Poss
#       hrvatska Poss
#       hrvatske Poss
#       hrvatskoj Poss
#       hrvatsku Poss
#       hrvatsko Poss
# bugarski [Adj]
#     ∟ bugarskog Poss
#       bugarskom Poss
#       bugarskim Poss
#       bugarska Poss
#       bugarske Poss
#       bugarskoj Poss
#       bugarsku Poss
#       bugarskih Poss
#       bugarsko Poss
# zakonski [Adj]
#     ∟ zakonskog Poss
#       zakonskom Poss
#       zakonske Poss
#       zakonsku Poss
#       zakonskih Poss
# ruski [Adj]
#     ∟ ruskog Poss
#       ruskim Poss
#       ruske Poss
#       ruskoj Poss
#       rusku Poss
#       ruskih Poss
# crnogorski [Adj]
#     ∟ crnogorskom Poss
#       crnogorskim Poss
#       crnogorska Poss
#       crnogorske Poss
#       crnogorskoj Poss
#       crnogorsku Poss
# evroatlantski [Adj]
#     ∟ evroatlantskim Poss
#       evroatlantske Poss
#       evroatlantskoj Poss
#       evroatlantsku Poss
#       evroatlantskih Poss
# ohridski [Adj]
#     ∟ ohridske Poss
# berlinski [Adj]
# poposki [Adj]
# niski [Adj]
#     ∟ niskom Poss
#       niska Poss
#       nisku Poss
#       niskih Poss
# srpski [Adj]
#     ∟ srpskog Poss
#       srpskom Poss
#       srpskim Poss
#       srpska Poss
#       srpske Poss
#       srpskoj Poss
#       srpsku Poss
#       srpskih Poss
#       srpsko Poss
# životinjski [Adj]
# trgovinski [Adj]
#     ∟ trgovinskog Poss
#       trgovinske Poss
# katastarski [Adj]
# kiparski [Adj]
#     ∟ kiparskog Poss
#       kiparskom Poss
#       kiparskim Poss
#       kiparske Poss
#       kiparskih Poss
# novinarski [Adj]
#     ∟ novinarska Poss
# holivudski [Adj]
#     ∟ holivudskih Poss
# nilski [Adj]
#     ∟ nilskog Poss
# univerzitetski [Adj]
#     ∟ univerzitetskom Poss
#       univerzitetskim Poss
#       univerzitetske Poss
#       univerzitetskih Poss
# trajkoviski [Adj]
# kosovski [Adj]
#     ∟ kosovskog Poss
#       kosovskom Poss
#       kosovskim Poss
#       kosovska Poss
#       kosovske Poss
#       kosovskoj Poss
#       kosovskih Poss
#       kosovsko Poss
# majski [Adj]
#     ∟ majskog Poss
# litvanski [Adj]
# stojčevski [Adj]
# ramkovski [Adj]
#     ∟ ramkovskog Poss
#       ramkovskom Poss
# levičarski [Adj]
#     ∟ levičarskim Poss
#       levičarska Poss
#       levičarskoj Poss
# prevarantski [Adj]
# demokratski [Adj]
#     ∟ demokratskog Poss
#       demokratskom Poss
#       demokratskim Poss
#       demokratska Poss
#       demokratske Poss
#       demokratsku Poss
#       demokratskih Poss
#       demokratsko Poss
# detektivski [Adj]
# ljudski [Adj]
#     ∟ ljudskim Poss
#       ljudska Poss
#       ljudske Poss
#       ljudskih Poss
# birokratski [Adj]
#     ∟ birokratske Poss
# lavovski [Adj]
# republikanski [Adj]
#     ∟ republikanska Poss
# sirijski [Adj]
#     ∟ sirijskog Poss
# ekonomski [Adj]
#     ∟ ekonomskog Poss
#       ekonomskom Poss
#       ekonomskim Poss
#       ekonomska Poss
#       ekonomske Poss
#       ekonomskoj Poss
#       ekonomsku Poss
#       ekonomskih Poss
# gruzijski [Adj]
#     ∟ gruzijske Poss
#       gruzijskoj Poss
# poreski [Adj]
#     ∟ poreskom Poss
#       poreska Poss
#       poreske Poss
#       poreskoj Poss
#       poreskih Poss
# budžetski [Adj]
#     ∟ budžetskog Poss
#       budžetskom Poss
#       budžetskim Poss
#       budžetska Poss
#       budžetskih Poss
# briselski [Adj]
#     ∟ briselske Poss
# švedski [Adj]
#     ∟ švedskom Poss
#       švedska Poss
#       švedske Poss
#       švedskoj Poss
#       švedsku Poss
# studentski [Adj]
#     ∟ studentskog Poss
#       studentskim Poss
#       studentske Poss
#       studentskih Poss
# automatski [Adj]
#     ∟ automatskom Poss
# finski [Adj]
#     ∟ finska Poss
#       finske Poss
# makedonski [Adj]
#     ∟ makedonskog Poss
#       makedonskom Poss
#       makedonskim Poss
#       makedonska Poss
#       makedonske Poss
#       makedonskoj Poss
#       makedonsku Poss
#       makedonskih Poss
#       makedonsko Poss
# pariski [Adj]
# bankarski [Adj]
#     ∟ bankarskim Poss
#       bankarske Poss
# milošoski [Adj]
# solunski [Adj]
#     ∟ solunske Poss
#       solunsku Poss
# fudbalski [Adj]
#     ∟ fudbalskog Poss
#       fudbalskim Poss
#       fudbalska Poss
#       fudbalske Poss
#       fudbalskih Poss
#       fudbalsko Poss
# peševski [Adj]
# kineski [Adj]
#     ∟ kineskog Poss
# letonski [Adj]
#     ∟ letonskog Poss
# softverski [Adj]
#     ∟ softverskog Poss
#       softverskoj Poss
#       softverskih Poss
# filharmonijski [Adj]
#     ∟ filharmonijskog Poss
# jadranski [Adj]
#     ∟ jadranskog Poss
#       jadranske Poss
# pokrajinski [Adj]
#     ∟ pokrajinskog Poss
# arapski [Adj]
#     ∟ arapskog Poss
#       arapskim Poss
# arhajski [Adj]
#     ∟ arhajskog Poss
# egipatski [Adj]
#     ∟ egipatskog Poss
# istanbulski [Adj]
#     ∟ istanbulskog Poss
#       istanbulskom Poss
#       istanbulska Poss
#       istanbulske Poss
# praistorijski [Adj]
#     ∟ praistorijskog Poss
# sportski [Adj]
#     ∟ sportskog Poss
#       sportskom Poss
#       sportske Poss
#       sportskih Poss
# telefonski [Adj]
#     ∟ telefonskog Poss
#       telefonske Poss
# muslimanski [Adj]
#     ∟ muslimanskog Poss
#       muslimanska Poss
#       muslimanske Poss
#       muslimanskoj Poss
# piranski [Adj]
#     ∟ piranskog Poss
# palestinski [Adj]
#     ∟ palestinskog Poss
# sarajevski [Adj]
#     ∟ sarajevskog Poss
#       sarajevskom Poss
#       sarajevskim Poss
#       sarajevska Poss
#       sarajevskoj Poss
# akcijski [Adj]
#     ∟ akcijskog Poss
#       akcijskih Poss
# višedecenijski [Adj]
#     ∟ višedecenijskog Poss
#       višedecenijske Poss
# libijski [Adj]
#     ∟ libijskog Poss
# tuzlanski [Adj]
#     ∟ tuzlanskog Poss
# sufijski [Adj]
#     ∟ sufijskog Poss
# gangsterski [Adj]
#     ∟ gangsterskog Poss
# filozofski [Adj]
#     ∟ filozofskog Poss
# oktobarski [Adj]
#     ∟ oktobarskog Poss
#       oktobarske Poss
#       oktobarskih Poss
# reformski [Adj]
#     ∟ reformskog Poss
#       reformskim Poss
#       reformske Poss
#       reformskih Poss
# suštinski [Adj]
#     ∟ suštinskog Poss
#       suštinskim Poss
#       suštinska Poss
# ženski [Adj]
#     ∟ ženskog Poss
#       ženskom Poss
#       ženskim Poss
#       ženska Poss
#       ženskoj Poss
#       ženskih Poss
#       žensko Poss
# vehabijski [Adj]
#     ∟ vehabijskog Poss
# vizantijski [Adj]
#     ∟ vizantijskog Poss
# masačusetski [Adj]
#     ∟ masačusetskog Poss
# policijski [Adj]
#     ∟ policijskog Poss
#       policijskim Poss
#       policijska Poss
#       policijske Poss
#       policijskoj Poss
#       policijsku Poss
#       policijskih Poss
# rimski [Adj]
#     ∟ rimskog Poss
#       rimskih Poss
# mediteranski [Adj]
#     ∟ mediteranskog Poss
#       mediteranskim Poss
# transbalkanski [Adj]
#     ∟ transbalkanskog Poss
# trenerski [Adj]
#     ∟ trenerskog Poss
# holandski [Adj]
#     ∟ holandskog Poss
#       holandska Poss
#       holandske Poss
# deoničarski [Adj]
#     ∟ deoničarskog Poss
# partenonski [Adj]
#     ∟ partenonskog Poss
# duvanski [Adj]
#     ∟ duvanskog Poss
# indijski [Adj]
#     ∟ indijskog Poss
# pridnjestrovski [Adj]
#     ∟ pridnjestrovskog Poss
# tračanski [Adj]
#     ∟ tračanskog Poss
#       tračansko Poss
# zatvorski [Adj]
#     ∟ zatvorskog Poss
#       zatvorskom Poss
#       zatvorska Poss
#       zatvorske Poss
#       zatvorsku Poss
# aprilski [Adj]
#     ∟ aprilskog Poss
# gradski [Adj]
#     ∟ gradskog Poss
#       gradskoj Poss
# lezbejski [Adj]
#     ∟ lezbejskog Poss
# operski [Adj]
#     ∟ operskom Poss
# pritiski [Adj]
#     ∟ pritiskom Poss
#       pritiska Poss
# radikalski [Adj]
#     ∟ radikalskom Poss
# vojski [Adj]
#     ∟ vojskom Poss
#       vojska Poss
#       vojske Poss
#       vojsku Poss
# atletski [Adj]
#     ∟ atletskom Poss
# austrijski [Adj]
#     ∟ austrijskom Poss
#       austrijska Poss
#       austrijske Poss
# teniski [Adj]
#     ∟ teniskom Poss
# crnomorski [Adj]
#     ∟ crnomorskom Poss
#       crnomorska Poss
#       crnomorske Poss
# februarski [Adj]
#     ∟ februarskom Poss
# skadarski [Adj]
#     ∟ skadarskom Poss
#       skadarsko Poss
# utiski [Adj]
#     ∟ utiskom Poss
# konsultantski [Adj]
#     ∟ konsultantskom Poss
# dvoranski [Adj]
#     ∟ dvoranskom Poss
# manjinski [Adj]
#     ∟ manjinskom Poss
#       manjinskim Poss
#       manjinska Poss
#       manjinske Poss
#       manjinsku Poss
#       manjinskih Poss
#       manjinsko Poss
# polistirenski [Adj]
#     ∟ polistirenskom Poss
# germanski [Adj]
#     ∟ germanskom Poss
# junski [Adj]
#     ∟ junskom Poss
# biometrijski [Adj]
#     ∟ biometrijskom Poss
#       biometrijskim Poss
#       biometrijske Poss
# ilirski [Adj]
#     ∟ ilirskim Poss
# genetski [Adj]
#     ∟ genetskim Poss
# predatorski [Adj]
#     ∟ predatorskim Poss
# rodopski [Adj]
#     ∟ rodopskim Poss
# diktatorski [Adj]
#     ∟ diktatorskim Poss
# tajlandski [Adj]
#     ∟ tajlandskim Poss
# martovski [Adj]
#     ∟ martovskim Poss
#       martovskih Poss
# građanski [Adj]
#     ∟ građanskim Poss
#       građanska Poss
#       građanske Poss
#       građanskoj Poss
#       građanskih Poss
# novembarski [Adj]
#     ∟ novembarskim Poss
# transatlantski [Adj]
#     ∟ transatlantskim Poss
#       transatlantskih Poss
# izvorski [Adj]
#     ∟ izvorskim Poss
# sociodemografski [Adj]
#     ∟ sociodemografskim Poss
# kajmanski [Adj]
#     ∟ kajmanskim Poss
# kišlovski [Adj]
#     ∟ kišlovskim Poss
# pomorski [Adj]
#     ∟ pomorskim Poss
#       pomorska Poss
# kroski [Adj]
#     ∟ kroska Poss
# protivtenkovski [Adj]
#     ∟ protivtenkovska Poss
#       protivtenkovske Poss
# dvotrećinski [Adj]
#     ∟ dvotrećinska Poss
#       dvotrećinsku Poss
# paparoski [Adj]
#     ∟ paparoska Poss
# proročanski [Adj]
#     ∟ proročanska Poss
# izlaski [Adj]
#     ∟ izlaska Poss
#       izlasku Poss
# novinski [Adj]
#     ∟ novinska Poss
#       novinskoj Poss
#       novinskih Poss
# peski [Adj]
#     ∟ peska Poss
# tinejdžerski [Adj]
#     ∟ tinejdžerska Poss
# kinematografski [Adj]
#     ∟ kinematografska Poss
# elektroenergetski [Adj]
#     ∟ elektroenergetska Poss
#       elektroenergetsku Poss
# spiski [Adj]
#     ∟ spiska Poss
# bonski [Adj]
#     ∟ bonska Poss
#       bonskih Poss
# zafirovski [Adj]
#     ∟ zafirovska Poss
# stojkovski [Adj]
#     ∟ stojkovska Poss
# danski [Adj]
#     ∟ danska Poss
#       danskoj Poss
#       dansku Poss
# velinovski [Adj]
#     ∟ velinovska Poss
# imovinski [Adj]
#     ∟ imovinska Poss
#       imovinsku Poss
#       imovinskih Poss
# farmaceutski [Adj]
#     ∟ farmaceutska Poss
#       farmaceutskoj Poss
#       farmaceutskih Poss
# grozdanovski [Adj]
#     ∟ grozdanovska Poss
# disciplinski [Adj]
#     ∟ disciplinska Poss
# prekomorski [Adj]
#     ∟ prekomorska Poss
# elektronski [Adj]
#     ∟ elektronska Poss
#       elektronsku Poss
#       elektronskih Poss
#       elektronsko Poss
# socioekonomski [Adj]
#     ∟ socioekonomska Poss
# štipski [Adj]
#     ∟ štipska Poss
# skopski [Adj]
#     ∟ skopska Poss
# kaspijski [Adj]
#     ∟ kaspijska Poss
# valkanovski [Adj]
#     ∟ valkanovska Poss
# prijateljski [Adj]
#     ∟ prijateljska Poss
#       prijateljske Poss
#       prijateljskih Poss
# ekspertski [Adj]
#     ∟ ekspertska Poss
#       ekspertskih Poss
# zalaski [Adj]
#     ∟ zalaska Poss
# ulaski [Adj]
#     ∟ ulaska Poss
#       ulasku Poss
# panevropski [Adj]
#     ∟ panevropska Poss
# elenovski [Adj]
#     ∟ elenovska Poss
# jevrejski [Adj]
#     ∟ jevrejska Poss
#       jevrejskih Poss
# bavarski [Adj]
#     ∟ bavarska Poss
# jermenski [Adj]
#     ∟ jermenska Poss
# damaski [Adj]
#     ∟ damaska Poss
# autokratski [Adj]
#     ∟ autokratska Poss
# podravski [Adj]
#     ∟ podravska Poss
# vojvođanski [Adj]
#     ∟ vojvođanska Poss
#       vojvođanske Poss
#       vojvođanskih Poss
# floreaski [Adj]
#     ∟ floreaska Poss
# šengenski [Adj]
#     ∟ šengenska Poss
# padinski [Adj]
#     ∟ padinska Poss
# kraljevski [Adj]
#     ∟ kraljevska Poss
# petkovski [Adj]
#     ∟ petkovska Poss
# štamparski [Adj]
#     ∟ štamparske Poss
# snajperski [Adj]
#     ∟ snajperske Poss
# medicinski [Adj]
#     ∟ medicinske Poss
# inženjerski [Adj]
#     ∟ inženjerske Poss
# dablinski [Adj]
#     ∟ dablinske Poss
# makroekonomski [Adj]
#     ∟ makroekonomske Poss
# profesorski [Adj]
#     ∟ profesorske Poss
# dorski [Adj]
#     ∟ dorske Poss
# laserski [Adj]
#     ∟ laserske Poss
# partijski [Adj]
#     ∟ partijske Poss
# registarski [Adj]
#     ∟ registarske Poss
#       registarskih Poss
# tenderski [Adj]
#     ∟ tenderske Poss
#       tendersku Poss
# omladinski [Adj]
#     ∟ omladinske Poss
# školski [Adj]
#     ∟ školske Poss
# topografski [Adj]
#     ∟ topografske Poss
# ljuski [Adj]
#     ∟ ljuske Poss
# božinovski [Adj]
#     ∟ božinovske Poss
# dunavski [Adj]
#     ∟ dunavske Poss
# revizorski [Adj]
#     ∟ revizorske Poss
# postdiplomski [Adj]
#     ∟ postdiplomske Poss
# vašingtonski [Adj]
#     ∟ vašingtonske Poss
# islandski [Adj]
#     ∟ islandske Poss
#       islandsku Poss
# terenski [Adj]
#     ∟ terenske Poss
# aerodromski [Adj]
#     ∟ aerodromske Poss
# demografski [Adj]
#     ∟ demografske Poss
# neprijateljski [Adj]
#     ∟ neprijateljske Poss
# pivarski [Adj]
#     ∟ pivarske Poss
# planinski [Adj]
#     ∟ planinske Poss
# morski [Adj]
#     ∟ morske Poss
#       morsku Poss
#       morskih Poss
# automobilski [Adj]
#     ∟ automobilske Poss
#       automobilsku Poss
# entitetski [Adj]
#     ∟ entitetske Poss
#       entitetskih Poss
# organski [Adj]
#     ∟ organske Poss
# desničarski [Adj]
#     ∟ desničarske Poss
# međuentitetski [Adj]
#     ∟ međuentitetske Poss
# prištinski [Adj]
#     ∟ prištinske Poss
# kompjuterski [Adj]
#     ∟ kompjuterske Poss
#       kompjutersku Poss
#       kompjuterskih Poss
# uski [Adj]
#     ∟ uske Poss
#       usko Poss
# logorski [Adj]
#     ∟ logorske Poss
# preševski [Adj]
#     ∟ preševskoj Poss
# petrovaradinski [Adj]
#     ∟ petrovaradinskoj Poss
# porodiljski [Adj]
#     ∟ porodiljskoj Poss
# latinski [Adj]
#     ∟ latinskoj Poss
# austrougarski [Adj]
#     ∟ austrougarskoj Poss
# egejski [Adj]
#     ∟ egejskoj Poss
# ambasadorski [Adj]
#     ∟ ambasadorskoj Poss
# draguleski [Adj]
#     ∟ dragulesku Poss
# konferencijski [Adj]
#     ∟ konferencijsku Poss
# baseski [Adj]
#     ∟ basesku Poss
# serotoninski [Adj]
#     ∟ serotoninsku Poss
#       serotoninskih Poss
# popeski [Adj]
#     ∟ popesku Poss
# maneski [Adj]
#     ∟ manesku Poss
# franciski [Adj]
#     ∟ francisku Poss
# teokratski [Adj]
#     ∟ teokratsku Poss
# hemijski [Adj]
#     ∟ hemijskih Poss
#       hemijsko Poss
# špediterski [Adj]
#     ∟ špediterskih Poss
# tematski [Adj]
#     ∟ tematskih Poss
# avganistanski [Adj]
#     ∟ avganistanskih Poss
# opštinski [Adj]
#     ∟ opštinskih Poss
# propalestinski [Adj]
#     ∟ propalestinskih Poss
# sapunski [Adj]
#     ∟ sapunskih Poss
# benzinski [Adj]
#     ∟ benzinskih Poss
# autorski [Adj]
#     ∟ autorskih Poss
# nemuslimanski [Adj]
#     ∟ nemuslimanskih Poss
# pionirski [Adj]
#     ∟ pionirskih Poss
# piratski [Adj]
#     ∟ piratskih Poss
# zemaljski [Adj]
#     ∟ zemaljskih Poss
#       zemaljsko Poss
# dobrosusedski [Adj]
#     ∟ dobrosusedskih Poss
# festivalski [Adj]
#     ∟ festivalskih Poss
# šumski [Adj]
#     ∟ šumskih Poss
# obalski [Adj]
#     ∟ obalskih Poss
# seoski [Adj]
#     ∟ seoskih Poss
# istočnoevropski [Adj]
#     ∟ istočnoevropskih Poss
# azijski [Adj]
#     ∟ azijskih Poss
# hrišćanski [Adj]
#     ∟ hrišćanskih Poss
# komunikacijski [Adj]
#     ∟ komunikacijskih Poss
# partnerski [Adj]
#     ∟ partnerskih Poss
# septembarski [Adj]
#     ∟ septembarskih Poss
# rumuski [Adj]
#     ∟ rumuskih Poss
# klupski [Adj]
#     ∟ klupskih Poss
# otomanski [Adj]
#     ∟ otomansko Poss
# uneski [Adj]
#     ∟ unesko Poss
# premijerski [Adj]
#     ∟ premijersko Poss
# kuhinjski [Adj]
#     ∟ kuhinjsko Poss
# postmiloševićevski [Adj]
#     ∟ postmiloševićevsko Poss
# stihijski [Adj]
#     ∟ stihijsko Poss
# teorijski [Adj]
#     ∟ teorijsko Poss

# %% [markdown]
# ### 2.3.2 suffix *-čki* and its inflections

# %% [markdown]
# Singular
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|nemački|nemačka|nemačko|
# |genitive|nemačkog|nemačke|nemačkog|
# |dative|nemačkom|nemačkoj|nemačkom|
# |acusative|nemački|nemačku|nemačko|
# |vocative|nemački|nemačka|nemačko|
# |instrumental|nemačkim|nemačkom|nemačkim|
# |locative|nemačkom|nemačkoj|nemačkom|
#
# Plural
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|nemački|nemačke|nemačka|
# |genitive|nemačkih|nemačkih|nemačke|
# |dative|nemačkim|nemačkim|nemačkoj|
# |acusative|nemačke|nemačke|nemačku|
# |vocative|nemački|nemačke|nemačka|
# |instrumental|nemačkim|nemačkim|nemačkom|
# |locative|nemačkim|nemačkim|nemačkoj|

# %% [markdown]
# Possible suffixes: *-čki*, *-čkog*, *-čkom*, *-čka*, *-čkih*, *-čkim*, *-čko*, *-čke*, *-čkoj*, *-čku*

# %%
possessive_adjectives = list(set([w for w in ud_content if w.endswith('čki')]))

# %%
possessive_adjectives
# Out:
# ['populistički',
#  'nemački',
#  'železnički',
#  'višestranački',
#  'etnički',
#  'muzički',
#  'posmatrački',
#  'pacifički',
#  'stranački',
#  'ultranacionalistički',
#  'slovenački',
#  'brodovlasnički',
#  'irački',
#  'predsednički',
#  'turistički',
#  'prostački',
#  'politički',
#  'zajednički',
#  'umetnički',
#  'putnički',
#  'monopolistički',
#  'komunistički',
#  'statistički',
#  'preduzetnički',
#  'tehnički',
#  'međuetnički',
#  'radnički',
#  'grčki',
#  'bošnjački',
#  'ekstremistički',
#  'teroristički',
#  'američki',
#  'pregovarački']

# %%
for possesive_adj in possessive_adjectives:
    add_to_lexicon(possesive_adj, "Adj")

# %%
inflection_suffixes = [('čkog', 'čki'), ('čkom', 'čki'), ('čka', 'čki'), ('čkih', 'čki'), ('čkim', 'čki'), ('čko', 'čki'), 
                      ('čke', 'čki'), ('čkoj', 'čki'), ('čku', 'čki')]

add_adjective_inflection_forms(inflection_suffixes)

# %%
print_lexicon()
# Out:
# pripremiti [V]
# izraditi [V]
# oprostiti [V]
# proširiti [V]
# govoriti [V]
# otkloniti [V]
# unaprediti [V]
# otplatiti [V]
# pretpostaviti [V]
# smanjiti [V]
# pustiti [V]
# značiti [V]
# rešiti [V]
# naslediti [V]
# štiti [V]
# zaštititi [V]
# snositi [V]
# razdvojiti [V]
# ograničiti [V]
# zavisiti [V]
# patiti [V]
# odstupiti [V]
# zaključiti [V]
# učiniti [V]
# uložiti [V]
# ponoviti [V]
# raditi [V]
# usredsrediti [V]
# odrediti [V]
# pojaviti [V]
# obaviti [V]
# prihvatiti [V]
# potrošiti [V]
# ponuditi [V]
# preporučiti [V]
# zameniti [V]
# obezbediti [V]
# izgubiti [V]
# iznositi [V]
# složiti [V]
# odobriti [V]
# omogućiti [V]
# uočiti [V]
# obilaziti [V]
# ostaviti [V]
# staviti [V]
# izmeniti [V]
# unakaziti [V]
# razmotriti [V]
# ohrabriti [V]
# ispuniti [V]
# odbaciti [V]
# suočiti [V]
# rijaliti [V]
# osetiti [V]
# tražiti [V]
# vlastiti [V]
# deliti [V]
# zanemariti [V]
# nastupiti [V]
# vratiti [V]
# udvostručiti [V]
# izvršiti [V]
# zatražiti [V]
# nastaviti [V]
# dozvoliti [V]
# krediti [V]
# razvodniti [V]
# usuditi [V]
# potvrditi [V]
# pružiti [V]
# shvatiti [V]
# desiti [V]
# protiviti [V]
# ostvariti [V]
# povratiti [V]
# izmisliti [V]
# različiti [V]
# uništiti [V]
# preurediti [V]
# skladištiti [V]
# primiti [V]
# otkriti [V]
# odgovoriti [V]
# uraditi [V]
# protumačiti [V]
# zamisliti [V]
# predstaviti [V]
# odnositi [V]
# uspostaviti [V]
# napraviti [V]
# arvaniti [V]
# podnositi [V]
# proceniti [V]
# dobiti [V]
# opslužiti [V]
# posetiti [V]
# pratiti [V]
# povrediti [V]
# napustiti [V]
# posvetiti [V]
# namestiti [V]
# iskoristiti [V]
# nuditi [V]
# zaštiti [V]
# rušiti [V]
# koristiti [V]
# učiti [V]
# umoriti [V]
# dogoditi [V]
# smisliti [V]
# sprovoditi [V]
# uskladiti [V]
# razotkriti [V]
# voditi [V]
# promeniti [V]
# prenositi [V]
# uslediti [V]
# otpustiti [V]
# pridružiti [V]
# otvoriti [V]
# završiti [V]
# razrešiti [V]
# sprečiti [V]
# kazniti [V]
# težiti [V]
# odvratiti [V]
# postaviti [V]
# kupiti [V]
# udružiti [V]
# poslužiti [V]
# uhvatiti [V]
# izgraditi [V]
# ustanoviti [V]
# ugroziti [V]
# proučiti [V]
# slediti [V]
# zaposliti [V]
# predložiti [V]
# osuditi [V]
# nadoknaditi [V]
# obnoviti [V]
# stvoriti [V]
# pristupiti [V]
# oseti [V]
# započeti [V]
# preuzeti [V]
# dopreti [V]
# uzeti [V]
# doprineti [V]
# preduzeti [V]
# doneti [V]
# preoteti [V]
# poseti [V]
# preneti [V]
# animoziteti [V]
# anketi [V]
# peti [V]
# deveti [V]
# našteti [V]
# posveti [V]
# tereti [V]
# meti [V]
# ćančeti [V]
# ahmeti [V]
# univerziteti [V]
# uspeti [V]
# antikviteti [V]
# razumeti [V]
# oteti [V]
# početi [V]
# dijeti [V]
# oživeti [V]
# preti [V]
# videti [V]
# predvideti [V]
# podneti [V]
# aveti [V]
# predmeti [V]
# fakulteti [V]
# pozivati [V]
#     ∟ pozivajući PresentPat
# falsifikovati [V]
# zahtevati [V]
#     ∟ zahtevajući PresentPat
# blokirati [V]
# dokazati [V]
# kopirati [V]
# uračunati [V]
# apstinirati [V]
# podržati [V]
# poboljšati [V]
# morati [V]
# oklevati [V]
# menjati [V]
# omogućavati [V]
#     ∟ omogućavajući PresentPat
# zadržati [V]
# intervenisati [V]
# garantovati [V]
# stajati [V]
# organizovati [V]
# pozvati [V]
# klati [V]
# razmenjivati [V]
# prati [V]
# palati [V]
# sastati [V]
# pokazati [V]
# pisati [V]
# razrešavati [V]
# primenjivati [V]
# obraćati [V]
#     ∟ obraćajući PresentPat
# otputovati [V]
# prisustvovati [V]
# prebacivati [V]
# sarađivati [V]
# vrati [V]
# investirati [V]
# preispitati [V]
# slati [V]
# pokušati [V]
# poštovati [V]
# trajati [V]
# poslati [V]
# dati [V]
#     ∟ dajući PresentPat
# sećati [V]
# povrati [V]
# postupati [V]
# održavati [V]
# požurivati [V]
# zarađivati [V]
# prihvati [V]
# plati [V]
# zloupotrebljavati [V]
# raspravljati [V]
# prikazati [V]
# uhvati [V]
# obrati [V]
# pridržavati [V]
# rezultati [V]
# zvati [V]
# uticati [V]
# postojati [V]
# koštati [V]
# funkcionisati [V]
# pokušavati [V]
# potpisati [V]
# analizirati [V]
# advokati [V]
# posmatrati [V]
# predstavljati [V]
#     ∟ predstavljajući PresentPat
# rešavati [V]
# dobijati [V]
# modelirati [V]
# mati [V]
# zapošljavati [V]
# pati [V]
# prepoznati [V]
# držati [V]
# bušati [V]
# imati [V]
#     ∟ imajući PresentPat
# dočekivati [V]
# izolovati [V]
# uključivati [V]
# ostati [V]
# održati [V]
# pridati [V]
# okončati [V]
# poznati [V]
# insistirati [V]
#     ∟ insistirajući PresentPat
# verovati [V]
# zamišljati [V]
# odvijati [V]
# doputovati [V]
# birati [V]
# povećati [V]
# intenzivirati [V]
# postati [V]
# olakšati [V]
# reagovati [V]
# predati [V]
# pružati [V]
# isplati [V]
# sačuvati [V]
# smanjivati [V]
# prestati [V]
# razgovarati [V]
# vraćati [V]
# sati [V]
# obavljati [V]
#     ∟ obavljajući PresentPat
# pregovarati [V]
# pervati [V]
# ometati [V]
# učestvovati [V]
# oslanjati [V]
# smatrati [V]
# glasati [V]
# zaletati [V]
# suspendovati [V]
# povezati [V]
# kandidati [V]
# hrvati [V]
# nemati [V]
# objavljivati [V]
# izazvati [V]
# nadati [V]
# ojačati [V]
# igrati [V]
#     ∟ igrajući PresentPat
# osećati [V]
# razvijati [V]
# ispričati [V]
# izabrati [V]
# fokusirati [V]
# ticati [V]
# artikulisati [V]
# bogati [V]
# zapitati [V]
# postavljati [V]
#     ∟ postavljajući PresentPat
# delati [V]
# putovati [V]
# finansirati [V]
# izdati [V]
# odavati [V]
# priznati [V]
# plakati [V]
# plaćati [V]
# izdavati [V]
# nadmetati [V]
# aktivirati [V]
# očekivati [V]
# cenjkati [V]
# pojačati [V]
# ratifikovati [V]
# definisati [V]
# zalagati [V]
# izražavati [V]
#     ∟ izražavajući PresentPat
# preduzimati [V]
#     ∟ preduzimajući PresentPat
# sindikati [V]
# počevši [V]
# uzdrmavši [V]
# učinivši [V]
# pretvorivši [V]
# osvojivši [V]
# proširivši [V]
# primetivši [V]
# dostigavši [V]
# postavivši [V]
# zamenivši [V]
# ponovivši [V]
# izazvavši [V]
# pohvalivši [V]
# bivši [V]
# završivši [V]
# rekavši [V]
# pobedivši [V]
# naslutivši [V]
# zabeleživši [V]
# dobivši [V]
# upozoravati [V]
#     ∟ upozoravajući PresentPat
# objašnjavati [V]
#     ∟ objašnjavajući PresentPat
# završavati [V]
#     ∟ završavajući PresentPat
# ubacovati [V]
#     ∟ ubacujući PresentPat
# čitati [V]
#     ∟ čitajući PresentPat
# potvrđovati [V]
#     ∟ potvrđujući PresentPat
# ažurirati [V]
#     ∟ ažurirajući PresentPat
# optužovati [V]
#     ∟ optužujući PresentPat
# odgovarati [V]
#     ∟ odgovarajući PresentPat
# pozdravljati [V]
#     ∟ pozdravljajući PresentPat
# dodati [V]
#     ∟ dodajući PresentPat
# znati [V]
#     ∟ znajući PresentPat
# otvarati [V]
#     ∟ otvarajući PresentPat
# primati [V]
#     ∟ primajući PresentPat
# narastati [V]
#     ∟ narastajući PresentPat
# predsedavati [V]
#     ∟ predsedavajući PresentPat
# savetovati [V]
#     ∟ savetujući PresentPat
# osuđovati [V]
#     ∟ osuđujući PresentPat
# ohrabrovati [V]
#     ∟ ohrabrujući PresentPat
# okončavati [V]
#     ∟ okončavajući PresentPat
# podsećati [V]
#     ∟ podsećajući PresentPat
# opisovati [V]
#     ∟ opisujući PresentPat
# kritikovati [V]
#     ∟ kritikujući PresentPat
# uveravati [V]
#     ∟ uveravajući PresentPat
# saopštavati [V]
#     ∟ saopštavajući PresentPat
# sprečavati [V]
#     ∟ sprečavajući PresentPat
# suočavati [V]
#     ∟ suočavajući PresentPat
# oslobađati [V]
#     ∟ oslobađajući PresentPat
# čekati [V]
#     ∟ čekajući PresentPat
# izdvajati [V]
#     ∟ izdvajajući PresentPat
# diskreditovati [V]
#     ∟ diskreditujući PresentPat
# zatvarati [V]
#     ∟ zatvarajući PresentPat
# protestovati [V]
#     ∟ protestujući PresentPat
# odbijati [V]
#     ∟ odbijajući PresentPat
# najavljovati [V]
#     ∟ najavljujući PresentPat
# nazivati [V]
#     ∟ nazivajući PresentPat
# emigrirati [V]
#     ∟ emigrirajući PresentPat
# zbližavati [V]
#     ∟ zbližavajući PresentPat
# prezati [V]
#     ∟ prezajući PresentPat
# zbunjovati [V]
#     ∟ zbunjujući PresentPat
# ukazovati [V]
#     ∟ ukazujući PresentPat
# pretvarati [V]
#     ∟ pretvarajući PresentPat
# tragati [V]
#     ∟ tragajući PresentPat
# nedostati [V]
#     ∟ nedostajući PresentPat
# prodati [V]
#     ∟ prodajući PresentPat
# primoravati [V]
#     ∟ primoravajući PresentPat
# potiskovati [V]
#     ∟ potiskujući PresentPat
# uključovati [V]
#     ∟ uključujući PresentPat
# bacati [V]
#     ∟ bacajući PresentPat
# zahvaljovati [V]
#     ∟ zahvaljujući PresentPat
# svrstavati [V]
#     ∟ svrstavajući PresentPat
# obeležavati [V]
#     ∟ obeležavajući PresentPat
# obećavati [V]
#     ∟ obećavajući PresentPat
# preneražavati [V]
#     ∟ preneražavajući PresentPat
# otuđovati [V]
#     ∟ otuđujući PresentPat
# pojavljovati [V]
#     ∟ pojavljujući PresentPat
# opstruirati [V]
#     ∟ opstruirajući PresentPat
# naglašavati [V]
#     ∟ naglašavajući PresentPat
# uzrokovati [V]
#     ∟ uzrokujući PresentPat
# ponavljati [V]
#     ∟ ponavljajući PresentPat
# favorizovati [V]
#     ∟ favorizujući PresentPat
# deceno [Adj]
#     ∟ decenije Comp+Neut+Sg
# uno [Adj]
#     ∟ unije Comp+Neut+Sg
# važna [Adj]
#     ∟ važnija Comp+Fem+Sg
#       najvažnija Sup+Fem+Sg
# svestrano [Adj]
#     ∟ svestranije Comp+Neut+Sg
# lina [Adj]
#     ∟ linija Comp+Fem+Sg
# apolona [Adj]
#     ∟ apolonija Comp+Fem+Sg
# lino [Adj]
#     ∟ linije Comp+Neut+Sg
# bezbedan [Adj]
#     ∟ bezbedniji Comp+Masc+Sg
# decena [Adj]
#     ∟ decenija Comp+Fem+Sg
# kompleksna [Adj]
#     ∟ kompleksnija Comp+Fem+Sg
# moćan [Adj]
#     ∟ moćniji Comp+Masc+Sg
#       najmoćniji Sup+Masc+Sg
# mena [Adj]
#     ∟ menija Comp+Fem+Sg
# pensilvaan [Adj]
#     ∟ pensilvaniji Comp+Masc+Sg
# aliana [Adj]
#     ∟ alianija Comp+Fem+Sg
# lian [Adj]
#     ∟ liniji Comp+Masc+Sg
# beskompromisan [Adj]
#     ∟ beskompromisniji Comp+Masc+Sg
# rano [Adj]
#     ∟ ranije Comp+Neut+Sg
# nezadovoljan [Adj]
#     ∟ nezadovoljniji Comp+Masc+Sg
# telefono [Adj]
#     ∟ telefonije Comp+Neut+Sg
# konkurentna [Adj]
#     ∟ konkurentnija Comp+Fem+Sg
# makedono [Adj]
#     ∟ makedonije Comp+Neut+Sg
# sigurna [Adj]
#     ∟ sigurnija Comp+Fem+Sg
# snažno [Adj]
#     ∟ snažnije Comp+Neut+Sg
# efikasna [Adj]
#     ∟ efikasnija Comp+Fem+Sg
# uticajan [Adj]
#     ∟ uticajniji Comp+Masc+Sg
# una [Adj]
#     ∟ unija Comp+Fem+Sg
# ozbiljan [Adj]
#     ∟ ozbiljniji Comp+Masc+Sg
#       najozbiljniji Sup+Masc+Sg
# estono [Adj]
#     ∟ estonije Comp+Neut+Sg
# pozitivan [Adj]
#     ∟ pozitivniji Comp+Masc+Sg
# čečean [Adj]
#     ∟ čečeniji Comp+Masc+Sg
# opasan [Adj]
#     ∟ opasnijim Comp+Masc+Pl
# kompano [Adj]
#     ∟ kompanije Comp+Neut+Sg
# špaan [Adj]
#     ∟ španiji Comp+Masc+Sg
# iskusan [Adj]
#     ∟ iskusnijim Comp+Masc+Pl
# rasprostranjena [Adj]
#     ∟ rasprostranjenija Comp+Fem+Sg
# ceremona [Adj]
#     ∟ ceremonija Comp+Fem+Sg
# litvano [Adj]
#     ∟ litvanije Comp+Neut+Sg
# značajan [Adj]
#     ∟ značajniji Comp+Masc+Sg
#       najznačajniji Sup+Masc+Sg
# kolona [Adj]
#     ∟ kolonija Comp+Fem+Sg
# britano [Adj]
#     ∟ britanije Comp+Neut+Sg
# albaan [Adj]
#     ∟ albaniji Comp+Masc+Sg
# striktno [Adj]
#     ∟ striktnije Comp+Neut+Sg
# kompana [Adj]
#     ∟ kompanija Comp+Fem+Sg
# očigledan [Adj]
#     ∟ očigledniji Comp+Masc+Sg
# potpuno [Adj]
#     ∟ potpunije Comp+Neut+Sg
# britaan [Adj]
#     ∟ britaniji Comp+Masc+Sg
# docno [Adj]
#     ∟ docnije Comp+Neut+Sg
# tačno [Adj]
#     ∟ tačnije Comp+Neut+Sg
# sloveno [Adj]
#     ∟ slovenije Comp+Neut+Sg
# diversifikovana [Adj]
#     ∟ diversifikovanija Comp+Fem+Sg
# raan [Adj]
#     ∟ ranijim Comp+Masc+Pl
# kasno [Adj]
#     ∟ kasnije Comp+Neut+Sg
# izražean [Adj]
#     ∟ izraženijim Comp+Masc+Pl
# demokratična [Adj]
#     ∟ demokratičnija Comp+Fem+Sg
# siromašno [Adj]
#     ∟ siromašnije Comp+Neut+Sg
# britana [Adj]
#     ∟ britanija Comp+Fem+Sg
# konkretno [Adj]
#     ∟ konkretnije Comp+Neut+Sg
# jevtian [Adj]
#     ∟ jevtinijim Comp+Masc+Pl
# špano [Adj]
#     ∟ španije Comp+Neut+Sg
# precizan [Adj]
#     ∟ precizniji Comp+Masc+Sg
# ceremoan [Adj]
#     ∟ ceremoniji Comp+Masc+Sg
# kompaan [Adj]
#     ∟ kompaniji Comp+Masc+Sg
# optimalno [Adj]
#     ∟ optimalnije Comp+Neut+Sg
# sigurno [Adj]
#     ∟ sigurnije Comp+Neut+Sg
# špana [Adj]
#     ∟ španija Comp+Fem+Sg
# rumuan [Adj]
#     ∟ rumuniji Comp+Masc+Sg
# rasprostranjean [Adj]
#     ∟ rasprostranjeniji Comp+Masc+Sg
# rumuno [Adj]
#     ∟ rumunije Comp+Neut+Sg
# makedoan [Adj]
#     ∟ makedoniji Comp+Masc+Sg
# zainteresovana [Adj]
#     ∟ zainteresovanija Comp+Fem+Sg
# represivan [Adj]
#     ∟ represivniji Comp+Masc+Sg
# optimističan [Adj]
#     ∟ optimističniji Comp+Masc+Sg
# letono [Adj]
#     ∟ letonije Comp+Neut+Sg
# aktivno [Adj]
#     ∟ aktivnije Comp+Neut+Sg
# jeftino [Adj]
#     ∟ jeftinije Comp+Neut+Sg
# makedona [Adj]
#     ∟ makedonija Comp+Fem+Sg
# važan [Adj]
#     ∟ važniji Comp+Masc+Sg
#       najvažniji Sup+Masc+Sg
# slovena [Adj]
#     ∟ slovenija Comp+Fem+Sg
# urgentan [Adj]
#     ∟ urgentniji Comp+Masc+Sg
#       najurgentniji Sup+Masc+Sg
# uan [Adj]
#     ∟ uniji Comp+Masc+Sg
# transparentan [Adj]
#     ∟ transparentnijim Comp+Masc+Pl
# ceremono [Adj]
#     ∟ ceremonije Comp+Neut+Sg
# rumuna [Adj]
#     ∟ rumunija Comp+Fem+Sg
# albana [Adj]
#     ∟ albanija Comp+Fem+Sg
# slovean [Adj]
#     ∟ sloveniji Comp+Masc+Sg
# važno [Adj]
#     ∟ važnije Comp+Neut+Sg
#       najvažnije Sup+Neut+Sg
# efikasan [Adj]
#     ∟ efikasniji Comp+Masc+Sg
# slobodan [Adj]
#     ∟ slobodniji Comp+Masc+Sg
# značajno [Adj]
#     ∟ značajnije Comp+Neut+Sg
#       najznačajnije Sup+Neut+Sg
# albano [Adj]
#     ∟ albanije Comp+Neut+Sg
# finansijski [Adj]
#     ∟ finansijskog Poss
#       finansijskom Poss
#       finansijskim Poss
#       finansijska Poss
#       finansijske Poss
#       finansijsku Poss
#       finansijskih Poss
# trojanski [Adj]
# dostojevski [Adj]
# svetski [Adj]
#     ∟ svetskog Poss
#       svetskom Poss
#       svetskim Poss
#       svetska Poss
#       svetske Poss
#       svetskoj Poss
#       svetsku Poss
#       svetskih Poss
#       svetsko Poss
# herkulovski [Adj]
# romski [Adj]
#     ∟ romskog Poss
#       romskom Poss
#       romskim Poss
#       romska Poss
#       romske Poss
#       romskoj Poss
# ivanovski [Adj]
# generacijski [Adj]
# mađarski [Adj]
#     ∟ mađarske Poss
#       mađarskoj Poss
# beogradski [Adj]
#     ∟ beogradskog Poss
#       beogradskom Poss
#       beogradska Poss
#       beogradske Poss
#       beogradskoj Poss
#       beogradsku Poss
# istorijski [Adj]
#     ∟ istorijskog Poss
#       istorijskom Poss
#       istorijskim Poss
#       istorijska Poss
#       istorijsku Poss
#       istorijskih Poss
# gruevski [Adj]
#     ∟ gruevskog Poss
#       gruevskim Poss
# britanski [Adj]
#     ∟ britanskog Poss
#       britanskom Poss
#       britanska Poss
#       britanske Poss
#       britansku Poss
#       britanskih Poss
# diplomatski [Adj]
#     ∟ diplomatskog Poss
#       diplomatskom Poss
#       diplomatskim Poss
#       diplomatska Poss
#       diplomatske Poss
#       diplomatskoj Poss
#       diplomatsku Poss
# kurdski [Adj]
#     ∟ kurdskog Poss
#       kurdskom Poss
#       kurdske Poss
#       kurdskoj Poss
#       kurdsku Poss
#       kurdskih Poss
# filmski [Adj]
#     ∟ filmskom Poss
#       filmskih Poss
# švajcarski [Adj]
#     ∟ švajcarskog Poss
#       švajcarske Poss
#       švajcarskoj Poss
# televizijski [Adj]
#     ∟ televizijske Poss
# spoljnotrgovinski [Adj]
# spisateljski [Adj]
# pakistanski [Adj]
#     ∟ pakistanske Poss
# socijaldemokratski [Adj]
#     ∟ socijaldemokratskog Poss
#       socijaldemokratskom Poss
#       socijaldemokratska Poss
#       socijaldemokratske Poss
#       socijaldemokratskoj Poss
# bosforski [Adj]
# dejtonski [Adj]
#     ∟ dejtonskog Poss
#       dejtonskim Poss
# balkanski [Adj]
#     ∟ balkanskim Poss
#       balkanska Poss
#       balkanske Poss
#       balkanskoj Poss
#       balkansku Poss
#       balkanskih Poss
# irski [Adj]
#     ∟ irskim Poss
#       irska Poss
#       irske Poss
#       irskoj Poss
# geografski [Adj]
# vremenski [Adj]
#     ∟ vremenskim Poss
#       vremenskih Poss
# albanski [Adj]
#     ∟ albanskog Poss
#       albanskom Poss
#       albanskim Poss
#       albanska Poss
#       albanske Poss
#       albanskoj Poss
#       albansku Poss
#       albanskih Poss
# belgijski [Adj]
#     ∟ belgijskom Poss
# bosanski [Adj]
#     ∟ bosanskim Poss
#       bosanska Poss
#       bosanske Poss
#       bosanskih Poss
# građevinski [Adj]
#     ∟ građevinskog Poss
#       građevinske Poss
# londonski [Adj]
#     ∟ londonskoj Poss
# lisabonski [Adj]
# teoretski [Adj]
# jugoslovenski [Adj]
#     ∟ jugoslovenskog Poss
#       jugoslovenske Poss
#       jugoslovenskoj Poss
# terapeutski [Adj]
#     ∟ terapeutsko Poss
# portugalski [Adj]
#     ∟ portugalske Poss
# vijetnamski [Adj]
# cerovski [Adj]
# tetovski [Adj]
# carinski [Adj]
#     ∟ carinskog Poss
#       carinska Poss
#       carinske Poss
#       carinskoj Poss
#       carinskih Poss
# avionski [Adj]
#     ∟ avionskih Poss
# crvenkovski [Adj]
#     ∟ crvenkovskim Poss
# saudijski [Adj]
#     ∟ saudijskog Poss
#       saudijska Poss
#       saudijske Poss
# industrijski [Adj]
#     ∟ industrijskim Poss
#       industrijskih Poss
# zemunski [Adj]
#     ∟ zemunskog Poss
# olimpijski [Adj]
#     ∟ olimpijskom Poss
#       olimpijska Poss
# posttraumatski [Adj]
#     ∟ posttraumatskog Poss
# mančevski [Adj]
#     ∟ mančevskog Poss
# nikolovski [Adj]
# orvelovski [Adj]
# argentinski [Adj]
#     ∟ argentinske Poss
# imunski [Adj]
# većinski [Adj]
# puninski [Adj]
# engleski [Adj]
#     ∟ engleska Poss
# turski [Adj]
#     ∟ turskog Poss
#       turskom Poss
#       turskim Poss
#       turska Poss
#       turske Poss
#       turskoj Poss
#       tursku Poss
#       turskih Poss
#       tursko Poss
# trajkovski [Adj]
#     ∟ trajkovskog Poss
# kablovski [Adj]
#     ∟ kablovske Poss
# bučkovski [Adj]
# moldavski [Adj]
#     ∟ moldavska Poss
#       moldavske Poss
#       moldavskih Poss
# poljski [Adj]
#     ∟ poljske Poss
#       poljskoj Poss
#       poljskih Poss
# italijanski [Adj]
#     ∟ italijanskog Poss
#       italijanske Poss
# rumunski [Adj]
#     ∟ rumunskog Poss
#       rumunskom Poss
#       rumunskim Poss
#       rumunska Poss
#       rumunske Poss
#       rumunskoj Poss
#       rumunskih Poss
#       rumunsko Poss
# proevropski [Adj]
#     ∟ proevropske Poss
#       proevropskoj Poss
# amaterski [Adj]
#     ∟ amaterske Poss
# antonovski [Adj]
# francuski [Adj]
#     ∟ francuskog Poss
#       francuskom Poss
#       francuska Poss
#       francuske Poss
#       francuskoj Poss
#       francusku Poss
#       francuskih Poss
# penzijski [Adj]
#     ∟ penzijskog Poss
# akademski [Adj]
#     ∟ akademska Poss
#       akademske Poss
#       akademskoj Poss
#       akademskih Poss
# istinski [Adj]
#     ∟ istinske Poss
# stavrevski [Adj]
# bliski [Adj]
#     ∟ bliskog Poss
#       bliskom Poss
#       bliskoj Poss
#       blisku Poss
# meteorski [Adj]
# španski [Adj]
#     ∟ španskog Poss
#       španskim Poss
#       španske Poss
#       španskih Poss
# drumski [Adj]
# evropski [Adj]
#     ∟ evropskog Poss
#       evropskom Poss
#       evropskim Poss
#       evropska Poss
#       evropske Poss
#       evropskoj Poss
#       evropsku Poss
#       evropskih Poss
#       evropsko Poss
# izraelski [Adj]
# konjanovski [Adj]
#     ∟ konjanovskog Poss
# bostonski [Adj]
# aleksievski [Adj]
# energetski [Adj]
#     ∟ energetskim Poss
#       energetska Poss
#       energetske Poss
#       energetskih Poss
# gagovski [Adj]
# antologijski [Adj]
# manevski [Adj]
# nedemokratski [Adj]
# novozelandski [Adj]
# azilski [Adj]
#     ∟ azilskog Poss
# šahovski [Adj]
#     ∟ šahovska Poss
# medijski [Adj]
#     ∟ medijskog Poss
#       medijskom Poss
#       medijske Poss
#       medijskih Poss
# ministarski [Adj]
#     ∟ ministarska Poss
# sofijski [Adj]
#     ∟ sofijskoj Poss
# islamski [Adj]
#     ∟ islamskim Poss
#       islamska Poss
#       islamske Poss
#       islamsku Poss
#       islamskih Poss
# sovjetski [Adj]
#     ∟ sovjetskom Poss
# helenski [Adj]
#     ∟ helensko Poss
# verski [Adj]
#     ∟ verskog Poss
#       verskim Poss
#       verske Poss
#       versku Poss
#       verskih Poss
#       versko Poss
# vrhunski [Adj]
#     ∟ vrhunskom Poss
#       vrhunske Poss
#       vrhunskih Poss
# peruanski [Adj]
# proruski [Adj]
# sudski [Adj]
#     ∟ sudskog Poss
#       sudskom Poss
#       sudskim Poss
#       sudskoj Poss
#       sudskih Poss
#       sudsko Poss
# hrvatski [Adj]
#     ∟ hrvatskog Poss
#       hrvatskom Poss
#       hrvatskim Poss
#       hrvatska Poss
#       hrvatske Poss
#       hrvatskoj Poss
#       hrvatsku Poss
#       hrvatsko Poss
# bugarski [Adj]
#     ∟ bugarskog Poss
#       bugarskom Poss
#       bugarskim Poss
#       bugarska Poss
#       bugarske Poss
#       bugarskoj Poss
#       bugarsku Poss
#       bugarskih Poss
#       bugarsko Poss
# zakonski [Adj]
#     ∟ zakonskog Poss
#       zakonskom Poss
#       zakonske Poss
#       zakonsku Poss
#       zakonskih Poss
# ruski [Adj]
#     ∟ ruskog Poss
#       ruskim Poss
#       ruske Poss
#       ruskoj Poss
#       rusku Poss
#       ruskih Poss
# crnogorski [Adj]
#     ∟ crnogorskom Poss
#       crnogorskim Poss
#       crnogorska Poss
#       crnogorske Poss
#       crnogorskoj Poss
#       crnogorsku Poss
# evroatlantski [Adj]
#     ∟ evroatlantskim Poss
#       evroatlantske Poss
#       evroatlantskoj Poss
#       evroatlantsku Poss
#       evroatlantskih Poss
# ohridski [Adj]
#     ∟ ohridske Poss
# berlinski [Adj]
# poposki [Adj]
# niski [Adj]
#     ∟ niskom Poss
#       niska Poss
#       nisku Poss
#       niskih Poss
# srpski [Adj]
#     ∟ srpskog Poss
#       srpskom Poss
#       srpskim Poss
#       srpska Poss
#       srpske Poss
#       srpskoj Poss
#       srpsku Poss
#       srpskih Poss
#       srpsko Poss
# životinjski [Adj]
# trgovinski [Adj]
#     ∟ trgovinskog Poss
#       trgovinske Poss
# katastarski [Adj]
# kiparski [Adj]
#     ∟ kiparskog Poss
#       kiparskom Poss
#       kiparskim Poss
#       kiparske Poss
#       kiparskih Poss
# novinarski [Adj]
#     ∟ novinarska Poss
# holivudski [Adj]
#     ∟ holivudskih Poss
# nilski [Adj]
#     ∟ nilskog Poss
# univerzitetski [Adj]
#     ∟ univerzitetskom Poss
#       univerzitetskim Poss
#       univerzitetske Poss
#       univerzitetskih Poss
# trajkoviski [Adj]
# kosovski [Adj]
#     ∟ kosovskog Poss
#       kosovskom Poss
#       kosovskim Poss
#       kosovska Poss
#       kosovske Poss
#       kosovskoj Poss
#       kosovskih Poss
#       kosovsko Poss
# majski [Adj]
#     ∟ majskog Poss
# litvanski [Adj]
# stojčevski [Adj]
# ramkovski [Adj]
#     ∟ ramkovskog Poss
#       ramkovskom Poss
# levičarski [Adj]
#     ∟ levičarskim Poss
#       levičarska Poss
#       levičarskoj Poss
# prevarantski [Adj]
# demokratski [Adj]
#     ∟ demokratskog Poss
#       demokratskom Poss
#       demokratskim Poss
#       demokratska Poss
#       demokratske Poss
#       demokratsku Poss
#       demokratskih Poss
#       demokratsko Poss
# detektivski [Adj]
# ljudski [Adj]
#     ∟ ljudskim Poss
#       ljudska Poss
#       ljudske Poss
#       ljudskih Poss
# birokratski [Adj]
#     ∟ birokratske Poss
# lavovski [Adj]
# republikanski [Adj]
#     ∟ republikanska Poss
# sirijski [Adj]
#     ∟ sirijskog Poss
# ekonomski [Adj]
#     ∟ ekonomskog Poss
#       ekonomskom Poss
#       ekonomskim Poss
#       ekonomska Poss
#       ekonomske Poss
#       ekonomskoj Poss
#       ekonomsku Poss
#       ekonomskih Poss
# gruzijski [Adj]
#     ∟ gruzijske Poss
#       gruzijskoj Poss
# poreski [Adj]
#     ∟ poreskom Poss
#       poreska Poss
#       poreske Poss
#       poreskoj Poss
#       poreskih Poss
# budžetski [Adj]
#     ∟ budžetskog Poss
#       budžetskom Poss
#       budžetskim Poss
#       budžetska Poss
#       budžetskih Poss
# briselski [Adj]
#     ∟ briselske Poss
# švedski [Adj]
#     ∟ švedskom Poss
#       švedska Poss
#       švedske Poss
#       švedskoj Poss
#       švedsku Poss
# studentski [Adj]
#     ∟ studentskog Poss
#       studentskim Poss
#       studentske Poss
#       studentskih Poss
# automatski [Adj]
#     ∟ automatskom Poss
# finski [Adj]
#     ∟ finska Poss
#       finske Poss
# makedonski [Adj]
#     ∟ makedonskog Poss
#       makedonskom Poss
#       makedonskim Poss
#       makedonska Poss
#       makedonske Poss
#       makedonskoj Poss
#       makedonsku Poss
#       makedonskih Poss
#       makedonsko Poss
# pariski [Adj]
# bankarski [Adj]
#     ∟ bankarskim Poss
#       bankarske Poss
# milošoski [Adj]
# solunski [Adj]
#     ∟ solunske Poss
#       solunsku Poss
# fudbalski [Adj]
#     ∟ fudbalskog Poss
#       fudbalskim Poss
#       fudbalska Poss
#       fudbalske Poss
#       fudbalskih Poss
#       fudbalsko Poss
# peševski [Adj]
# kineski [Adj]
#     ∟ kineskog Poss
# letonski [Adj]
#     ∟ letonskog Poss
# softverski [Adj]
#     ∟ softverskog Poss
#       softverskoj Poss
#       softverskih Poss
# filharmonijski [Adj]
#     ∟ filharmonijskog Poss
# jadranski [Adj]
#     ∟ jadranskog Poss
#       jadranske Poss
# pokrajinski [Adj]
#     ∟ pokrajinskog Poss
# arapski [Adj]
#     ∟ arapskog Poss
#       arapskim Poss
# arhajski [Adj]
#     ∟ arhajskog Poss
# egipatski [Adj]
#     ∟ egipatskog Poss
# istanbulski [Adj]
#     ∟ istanbulskog Poss
#       istanbulskom Poss
#       istanbulska Poss
#       istanbulske Poss
# praistorijski [Adj]
#     ∟ praistorijskog Poss
# sportski [Adj]
#     ∟ sportskog Poss
#       sportskom Poss
#       sportske Poss
#       sportskih Poss
# telefonski [Adj]
#     ∟ telefonskog Poss
#       telefonske Poss
# muslimanski [Adj]
#     ∟ muslimanskog Poss
#       muslimanska Poss
#       muslimanske Poss
#       muslimanskoj Poss
# piranski [Adj]
#     ∟ piranskog Poss
# palestinski [Adj]
#     ∟ palestinskog Poss
# sarajevski [Adj]
#     ∟ sarajevskog Poss
#       sarajevskom Poss
#       sarajevskim Poss
#       sarajevska Poss
#       sarajevskoj Poss
# akcijski [Adj]
#     ∟ akcijskog Poss
#       akcijskih Poss
# višedecenijski [Adj]
#     ∟ višedecenijskog Poss
#       višedecenijske Poss
# libijski [Adj]
#     ∟ libijskog Poss
# tuzlanski [Adj]
#     ∟ tuzlanskog Poss
# sufijski [Adj]
#     ∟ sufijskog Poss
# gangsterski [Adj]
#     ∟ gangsterskog Poss
# filozofski [Adj]
#     ∟ filozofskog Poss
# oktobarski [Adj]
#     ∟ oktobarskog Poss
#       oktobarske Poss
#       oktobarskih Poss
# reformski [Adj]
#     ∟ reformskog Poss
#       reformskim Poss
#       reformske Poss
#       reformskih Poss
# suštinski [Adj]
#     ∟ suštinskog Poss
#       suštinskim Poss
#       suštinska Poss
# ženski [Adj]
#     ∟ ženskog Poss
#       ženskom Poss
#       ženskim Poss
#       ženska Poss
#       ženskoj Poss
#       ženskih Poss
#       žensko Poss
# vehabijski [Adj]
#     ∟ vehabijskog Poss
# vizantijski [Adj]
#     ∟ vizantijskog Poss
# masačusetski [Adj]
#     ∟ masačusetskog Poss
# policijski [Adj]
#     ∟ policijskog Poss
#       policijskim Poss
#       policijska Poss
#       policijske Poss
#       policijskoj Poss
#       policijsku Poss
#       policijskih Poss
# rimski [Adj]
#     ∟ rimskog Poss
#       rimskih Poss
# mediteranski [Adj]
#     ∟ mediteranskog Poss
#       mediteranskim Poss
# transbalkanski [Adj]
#     ∟ transbalkanskog Poss
# trenerski [Adj]
#     ∟ trenerskog Poss
# holandski [Adj]
#     ∟ holandskog Poss
#       holandska Poss
#       holandske Poss
# deoničarski [Adj]
#     ∟ deoničarskog Poss
# partenonski [Adj]
#     ∟ partenonskog Poss
# duvanski [Adj]
#     ∟ duvanskog Poss
# indijski [Adj]
#     ∟ indijskog Poss
# pridnjestrovski [Adj]
#     ∟ pridnjestrovskog Poss
# tračanski [Adj]
#     ∟ tračanskog Poss
#       tračansko Poss
# zatvorski [Adj]
#     ∟ zatvorskog Poss
#       zatvorskom Poss
#       zatvorska Poss
#       zatvorske Poss
#       zatvorsku Poss
# aprilski [Adj]
#     ∟ aprilskog Poss
# gradski [Adj]
#     ∟ gradskog Poss
#       gradskoj Poss
# lezbejski [Adj]
#     ∟ lezbejskog Poss
# operski [Adj]
#     ∟ operskom Poss
# pritiski [Adj]
#     ∟ pritiskom Poss
#       pritiska Poss
# radikalski [Adj]
#     ∟ radikalskom Poss
# vojski [Adj]
#     ∟ vojskom Poss
#       vojska Poss
#       vojske Poss
#       vojsku Poss
# atletski [Adj]
#     ∟ atletskom Poss
# austrijski [Adj]
#     ∟ austrijskom Poss
#       austrijska Poss
#       austrijske Poss
# teniski [Adj]
#     ∟ teniskom Poss
# crnomorski [Adj]
#     ∟ crnomorskom Poss
#       crnomorska Poss
#       crnomorske Poss
# februarski [Adj]
#     ∟ februarskom Poss
# skadarski [Adj]
#     ∟ skadarskom Poss
#       skadarsko Poss
# utiski [Adj]
#     ∟ utiskom Poss
# konsultantski [Adj]
#     ∟ konsultantskom Poss
# dvoranski [Adj]
#     ∟ dvoranskom Poss
# manjinski [Adj]
#     ∟ manjinskom Poss
#       manjinskim Poss
#       manjinska Poss
#       manjinske Poss
#       manjinsku Poss
#       manjinskih Poss
#       manjinsko Poss
# polistirenski [Adj]
#     ∟ polistirenskom Poss
# germanski [Adj]
#     ∟ germanskom Poss
# junski [Adj]
#     ∟ junskom Poss
# biometrijski [Adj]
#     ∟ biometrijskom Poss
#       biometrijskim Poss
#       biometrijske Poss
# ilirski [Adj]
#     ∟ ilirskim Poss
# genetski [Adj]
#     ∟ genetskim Poss
# predatorski [Adj]
#     ∟ predatorskim Poss
# rodopski [Adj]
#     ∟ rodopskim Poss
# diktatorski [Adj]
#     ∟ diktatorskim Poss
# tajlandski [Adj]
#     ∟ tajlandskim Poss
# martovski [Adj]
#     ∟ martovskim Poss
#       martovskih Poss
# građanski [Adj]
#     ∟ građanskim Poss
#       građanska Poss
#       građanske Poss
#       građanskoj Poss
#       građanskih Poss
# novembarski [Adj]
#     ∟ novembarskim Poss
# transatlantski [Adj]
#     ∟ transatlantskim Poss
#       transatlantskih Poss
# izvorski [Adj]
#     ∟ izvorskim Poss
# sociodemografski [Adj]
#     ∟ sociodemografskim Poss
# kajmanski [Adj]
#     ∟ kajmanskim Poss
# kišlovski [Adj]
#     ∟ kišlovskim Poss
# pomorski [Adj]
#     ∟ pomorskim Poss
#       pomorska Poss
# kroski [Adj]
#     ∟ kroska Poss
# protivtenkovski [Adj]
#     ∟ protivtenkovska Poss
#       protivtenkovske Poss
# dvotrećinski [Adj]
#     ∟ dvotrećinska Poss
#       dvotrećinsku Poss
# paparoski [Adj]
#     ∟ paparoska Poss
# proročanski [Adj]
#     ∟ proročanska Poss
# izlaski [Adj]
#     ∟ izlaska Poss
#       izlasku Poss
# novinski [Adj]
#     ∟ novinska Poss
#       novinskoj Poss
#       novinskih Poss
# peski [Adj]
#     ∟ peska Poss
# tinejdžerski [Adj]
#     ∟ tinejdžerska Poss
# kinematografski [Adj]
#     ∟ kinematografska Poss
# elektroenergetski [Adj]
#     ∟ elektroenergetska Poss
#       elektroenergetsku Poss
# spiski [Adj]
#     ∟ spiska Poss
# bonski [Adj]
#     ∟ bonska Poss
#       bonskih Poss
# zafirovski [Adj]
#     ∟ zafirovska Poss
# stojkovski [Adj]
#     ∟ stojkovska Poss
# danski [Adj]
#     ∟ danska Poss
#       danskoj Poss
#       dansku Poss
# velinovski [Adj]
#     ∟ velinovska Poss
# imovinski [Adj]
#     ∟ imovinska Poss
#       imovinsku Poss
#       imovinskih Poss
# farmaceutski [Adj]
#     ∟ farmaceutska Poss
#       farmaceutskoj Poss
#       farmaceutskih Poss
# grozdanovski [Adj]
#     ∟ grozdanovska Poss
# disciplinski [Adj]
#     ∟ disciplinska Poss
# prekomorski [Adj]
#     ∟ prekomorska Poss
# elektronski [Adj]
#     ∟ elektronska Poss
#       elektronsku Poss
#       elektronskih Poss
#       elektronsko Poss
# socioekonomski [Adj]
#     ∟ socioekonomska Poss
# štipski [Adj]
#     ∟ štipska Poss
# skopski [Adj]
#     ∟ skopska Poss
# kaspijski [Adj]
#     ∟ kaspijska Poss
# valkanovski [Adj]
#     ∟ valkanovska Poss
# prijateljski [Adj]
#     ∟ prijateljska Poss
#       prijateljske Poss
#       prijateljskih Poss
# ekspertski [Adj]
#     ∟ ekspertska Poss
#       ekspertskih Poss
# zalaski [Adj]
#     ∟ zalaska Poss
# ulaski [Adj]
#     ∟ ulaska Poss
#       ulasku Poss
# panevropski [Adj]
#     ∟ panevropska Poss
# elenovski [Adj]
#     ∟ elenovska Poss
# jevrejski [Adj]
#     ∟ jevrejska Poss
#       jevrejskih Poss
# bavarski [Adj]
#     ∟ bavarska Poss
# jermenski [Adj]
#     ∟ jermenska Poss
# damaski [Adj]
#     ∟ damaska Poss
# autokratski [Adj]
#     ∟ autokratska Poss
# podravski [Adj]
#     ∟ podravska Poss
# vojvođanski [Adj]
#     ∟ vojvođanska Poss
#       vojvođanske Poss
#       vojvođanskih Poss
# floreaski [Adj]
#     ∟ floreaska Poss
# šengenski [Adj]
#     ∟ šengenska Poss
# padinski [Adj]
#     ∟ padinska Poss
# kraljevski [Adj]
#     ∟ kraljevska Poss
# petkovski [Adj]
#     ∟ petkovska Poss
# štamparski [Adj]
#     ∟ štamparske Poss
# snajperski [Adj]
#     ∟ snajperske Poss
# medicinski [Adj]
#     ∟ medicinske Poss
# inženjerski [Adj]
#     ∟ inženjerske Poss
# dablinski [Adj]
#     ∟ dablinske Poss
# makroekonomski [Adj]
#     ∟ makroekonomske Poss
# profesorski [Adj]
#     ∟ profesorske Poss
# dorski [Adj]
#     ∟ dorske Poss
# laserski [Adj]
#     ∟ laserske Poss
# partijski [Adj]
#     ∟ partijske Poss
# registarski [Adj]
#     ∟ registarske Poss
#       registarskih Poss
# tenderski [Adj]
#     ∟ tenderske Poss
#       tendersku Poss
# omladinski [Adj]
#     ∟ omladinske Poss
# školski [Adj]
#     ∟ školske Poss
# topografski [Adj]
#     ∟ topografske Poss
# ljuski [Adj]
#     ∟ ljuske Poss
# božinovski [Adj]
#     ∟ božinovske Poss
# dunavski [Adj]
#     ∟ dunavske Poss
# revizorski [Adj]
#     ∟ revizorske Poss
# postdiplomski [Adj]
#     ∟ postdiplomske Poss
# vašingtonski [Adj]
#     ∟ vašingtonske Poss
# islandski [Adj]
#     ∟ islandske Poss
#       islandsku Poss
# terenski [Adj]
#     ∟ terenske Poss
# aerodromski [Adj]
#     ∟ aerodromske Poss
# demografski [Adj]
#     ∟ demografske Poss
# neprijateljski [Adj]
#     ∟ neprijateljske Poss
# pivarski [Adj]
#     ∟ pivarske Poss
# planinski [Adj]
#     ∟ planinske Poss
# morski [Adj]
#     ∟ morske Poss
#       morsku Poss
#       morskih Poss
# automobilski [Adj]
#     ∟ automobilske Poss
#       automobilsku Poss
# entitetski [Adj]
#     ∟ entitetske Poss
#       entitetskih Poss
# organski [Adj]
#     ∟ organske Poss
# desničarski [Adj]
#     ∟ desničarske Poss
# međuentitetski [Adj]
#     ∟ međuentitetske Poss
# prištinski [Adj]
#     ∟ prištinske Poss
# kompjuterski [Adj]
#     ∟ kompjuterske Poss
#       kompjutersku Poss
#       kompjuterskih Poss
# uski [Adj]
#     ∟ uske Poss
#       usko Poss
# logorski [Adj]
#     ∟ logorske Poss
# preševski [Adj]
#     ∟ preševskoj Poss
# petrovaradinski [Adj]
#     ∟ petrovaradinskoj Poss
# porodiljski [Adj]
#     ∟ porodiljskoj Poss
# latinski [Adj]
#     ∟ latinskoj Poss
# austrougarski [Adj]
#     ∟ austrougarskoj Poss
# egejski [Adj]
#     ∟ egejskoj Poss
# ambasadorski [Adj]
#     ∟ ambasadorskoj Poss
# draguleski [Adj]
#     ∟ dragulesku Poss
# konferencijski [Adj]
#     ∟ konferencijsku Poss
# baseski [Adj]
#     ∟ basesku Poss
# serotoninski [Adj]
#     ∟ serotoninsku Poss
#       serotoninskih Poss
# popeski [Adj]
#     ∟ popesku Poss
# maneski [Adj]
#     ∟ manesku Poss
# franciski [Adj]
#     ∟ francisku Poss
# teokratski [Adj]
#     ∟ teokratsku Poss
# hemijski [Adj]
#     ∟ hemijskih Poss
#       hemijsko Poss
# špediterski [Adj]
#     ∟ špediterskih Poss
# tematski [Adj]
#     ∟ tematskih Poss
# avganistanski [Adj]
#     ∟ avganistanskih Poss
# opštinski [Adj]
#     ∟ opštinskih Poss
# propalestinski [Adj]
#     ∟ propalestinskih Poss
# sapunski [Adj]
#     ∟ sapunskih Poss
# benzinski [Adj]
#     ∟ benzinskih Poss
# autorski [Adj]
#     ∟ autorskih Poss
# nemuslimanski [Adj]
#     ∟ nemuslimanskih Poss
# pionirski [Adj]
#     ∟ pionirskih Poss
# piratski [Adj]
#     ∟ piratskih Poss
# zemaljski [Adj]
#     ∟ zemaljskih Poss
#       zemaljsko Poss
# dobrosusedski [Adj]
#     ∟ dobrosusedskih Poss
# festivalski [Adj]
#     ∟ festivalskih Poss
# šumski [Adj]
#     ∟ šumskih Poss
# obalski [Adj]
#     ∟ obalskih Poss
# seoski [Adj]
#     ∟ seoskih Poss
# istočnoevropski [Adj]
#     ∟ istočnoevropskih Poss
# azijski [Adj]
#     ∟ azijskih Poss
# hrišćanski [Adj]
#     ∟ hrišćanskih Poss
# komunikacijski [Adj]
#     ∟ komunikacijskih Poss
# partnerski [Adj]
#     ∟ partnerskih Poss
# septembarski [Adj]
#     ∟ septembarskih Poss
# rumuski [Adj]
#     ∟ rumuskih Poss
# klupski [Adj]
#     ∟ klupskih Poss
# otomanski [Adj]
#     ∟ otomansko Poss
# uneski [Adj]
#     ∟ unesko Poss
# premijerski [Adj]
#     ∟ premijersko Poss
# kuhinjski [Adj]
#     ∟ kuhinjsko Poss
# postmiloševićevski [Adj]
#     ∟ postmiloševićevsko Poss
# stihijski [Adj]
#     ∟ stihijsko Poss
# teorijski [Adj]
#     ∟ teorijsko Poss
# populistički [Adj]
# nemački [Adj]
#     ∟ nemačkog Poss
#       nemačka Poss
#       nemačkih Poss
#       nemačkim Poss
#       nemačke Poss
#       nemačkoj Poss
#       nemačku Poss
# železnički [Adj]
#     ∟ železnička Poss
#       železničkih Poss
#       železničkim Poss
#       železničke Poss
#       železničkoj Poss
# višestranački [Adj]
#     ∟ višestranačke Poss
#       višestranačku Poss
# etnički [Adj]
#     ∟ etničkog Poss
#       etnička Poss
#       etničkih Poss
#       etničkim Poss
#       etničke Poss
#       etničkoj Poss
#       etničku Poss
# muzički [Adj]
#     ∟ muzičkog Poss
#       muzičkom Poss
#       muzičku Poss
# posmatrački [Adj]
#     ∟ posmatračkog Poss
#       posmatračka Poss
#       posmatračkoj Poss
# pacifički [Adj]
# stranački [Adj]
#     ∟ stranačka Poss
#       stranačkih Poss
#       stranačkim Poss
# ultranacionalistički [Adj]
#     ∟ ultranacionalističkih Poss
#       ultranacionalističke Poss
# slovenački [Adj]
#     ∟ slovenačkom Poss
#       slovenačka Poss
#       slovenačkim Poss
#       slovenačko Poss
# brodovlasnički [Adj]
# irački [Adj]
#     ∟ iračkih Poss
#       iračkim Poss
#       iračkoj Poss
# predsednički [Adj]
#     ∟ predsedničkog Poss
#       predsedničkih Poss
#       predsedničke Poss
#       predsedničku Poss
# turistički [Adj]
#     ∟ turističkog Poss
#       turističkom Poss
#       turistička Poss
#       turističkih Poss
#       turističkoj Poss
# prostački [Adj]
# politički [Adj]
#     ∟ političkog Poss
#       političkom Poss
#       politička Poss
#       političkih Poss
#       političkim Poss
#       političko Poss
#       političke Poss
#       političkoj Poss
#       političku Poss
# zajednički [Adj]
#     ∟ zajedničkog Poss
#       zajedničkom Poss
#       zajednička Poss
#       zajedničkim Poss
#       zajedničko Poss
#       zajedničke Poss
#       zajedničkoj Poss
#       zajedničku Poss
# umetnički [Adj]
#     ∟ umetnička Poss
#       umetničke Poss
#       umetničkoj Poss
# putnički [Adj]
# monopolistički [Adj]
#     ∟ monopolističkih Poss
#       monopolističke Poss
#       monopolističku Poss
# komunistički [Adj]
#     ∟ komunističkog Poss
#       komunističkim Poss
#       komunističke Poss
#       komunističku Poss
# statistički [Adj]
#     ∟ statističkog Poss
#       statističkim Poss
# preduzetnički [Adj]
# tehnički [Adj]
#     ∟ tehničkih Poss
#       tehničkim Poss
#       tehničko Poss
#       tehničke Poss
# međuetnički [Adj]
#     ∟ međuetničkih Poss
# radnički [Adj]
#     ∟ radničke Poss
# grčki [Adj]
#     ∟ grčkog Poss
#       grčkom Poss
#       grčka Poss
#       grčkih Poss
#       grčkim Poss
#       grčko Poss
#       grčke Poss
#       grčkoj Poss
#       grčku Poss
# bošnjački [Adj]
#     ∟ bošnjačkog Poss
#       bošnjačkom Poss
#       bošnjačkih Poss
#       bošnjačke Poss
# ekstremistički [Adj]
#     ∟ ekstremistička Poss
#       ekstremističkih Poss
#       ekstremističke Poss
# teroristički [Adj]
#     ∟ terorističkog Poss
#       teroristička Poss
#       terorističkih Poss
#       terorističkim Poss
#       terorističke Poss
# američki [Adj]
#     ∟ američkog Poss
#       američkom Poss
#       američka Poss
#       američkih Poss
#       američkim Poss
#       američke Poss
#       američku Poss
# pregovarački [Adj]
#     ∟ pregovaračkog Poss
#       pregovaračka Poss
#       pregovaračkih Poss
#       pregovaračku Poss
# severnoafrički [Adj]
#     ∟ severnoafričkog Poss
# čitalački [Adj]
#     ∟ čitalačkog Poss
# srebrenički [Adj]
#     ∟ srebreničkog Poss
#       srebreničkom Poss
# staljinistički [Adj]
#     ∟ staljinističkog Poss
# predstavnički [Adj]
#     ∟ predstavničkog Poss
# fizički [Adj]
#     ∟ fizičkog Poss
#       fizička Poss
#       fizičko Poss
#       fizičke Poss
# predavački [Adj]
#     ∟ predavačkog Poss
#       predavačkih Poss
# poslanički [Adj]
#     ∟ poslaničkog Poss
#       poslaničkih Poss
#       poslaničke Poss
# analitički [Adj]
#     ∟ analitičkog Poss
# geopolitički [Adj]
#     ∟ geopolitičkog Poss
#       geopolitičkom Poss
#       geopolitičkoj Poss
# veštački [Adj]
#     ∟ veštačkog Poss
#       veštačku Poss
# prevoznički [Adj]
#     ∟ prevozničkog Poss
# plivački [Adj]
#     ∟ plivačkom Poss
#       plivačkim Poss
# postkomunistički [Adj]
#     ∟ postkomunističkom Poss
#       postkomunističkih Poss
# nacistički [Adj]
#     ∟ nacističkom Poss
#       nacističkim Poss
#       nacističke Poss
# vlasnički [Adj]
#     ∟ vlasničkom Poss
#       vlasnička Poss
#       vlasničkih Poss
# jezički [Adj]
#     ∟ jezičkom Poss
#       jezičku Poss
# brčki [Adj]
#     ∟ brčkom Poss
# zagrebački [Adj]
#     ∟ zagrebačkom Poss
#       zagrebačke Poss
# ludački [Adj]
#     ∟ ludačka Poss
# osvetnički [Adj]
#     ∟ osvetnička Poss
# pljački [Adj]
#     ∟ pljačka Poss
#       pljačke Poss
# nacionalistički [Adj]
#     ∟ nacionalistička Poss
#       nacionalističke Poss
#       nacionalističku Poss
# borački [Adj]
#     ∟ boračka Poss
# tački [Adj]
#     ∟ tačka Poss
#       tačku Poss
# dugački [Adj]
#     ∟ dugačka Poss
#       dugačke Poss
# socijalistički [Adj]
#     ∟ socijalistička Poss
#       socijalističkih Poss
#       socijalističke Poss
#       socijalističkoj Poss
#       socijalističku Poss
# opljački [Adj]
#     ∟ opljačka Poss
# antiteroristički [Adj]
#     ∟ antiteroristička Poss
#       antiterorističke Poss
# ručki [Adj]
#     ∟ ručka Poss
# antički [Adj]
#     ∟ antičkih Poss
# nedomorodački [Adj]
#     ∟ nedomorodačkih Poss
# etički [Adj]
#     ∟ etičkih Poss
# forenzički [Adj]
#     ∟ forenzičkih Poss
# kriminalistički [Adj]
#     ∟ kriminalističkih Poss
#       kriminalističke Poss
# dužnički [Adj]
#     ∟ dužničkih Poss
# katolički [Adj]
#     ∟ katoličkih Poss
#       katoličke Poss
# protivnički [Adj]
#     ∟ protivničkih Poss
#       protivničke Poss
# afrički [Adj]
#     ∟ afričkih Poss
# glasački [Adj]
#     ∟ glasačkih Poss
#       glasačke Poss
# unutarpolitički [Adj]
#     ∟ unutarpolitičkih Poss
# nasilnički [Adj]
#     ∟ nasilničkih Poss
# lingvistički [Adj]
#     ∟ lingvističkim Poss
# senzacionalistički [Adj]
#     ∟ senzacionalističkim Poss
#       senzacionalističke Poss
# vozački [Adj]
#     ∟ vozačkim Poss
# seizmički [Adj]
#     ∟ seizmičkim Poss
# birački [Adj]
#     ∟ biračko Poss
# multietnički [Adj]
#     ∟ multietničko Poss
# narkotički [Adj]
#     ∟ narkotičko Poss
# informatički [Adj]
#     ∟ informatičko Poss
# zaključki [Adj]
#     ∟ zaključke Poss
# dijagnostički [Adj]
#     ∟ dijagnostičke Poss
# kukavički [Adj]
#     ∟ kukavičke Poss
# sandžački [Adj]
#     ∟ sandžačke Poss
# igrački [Adj]
#     ∟ igračke Poss
# borilački [Adj]
#     ∟ borilačke Poss
# oslobodilački [Adj]
#     ∟ oslobodilačke Poss
# oportunistički [Adj]
#     ∟ oportunističke Poss
# aktivistički [Adj]
#     ∟ aktivističke Poss
# rasistički [Adj]
#     ∟ rasističke Poss
# glumački [Adj]
#     ∟ glumačke Poss
#       glumačku Poss
# bečki [Adj]
#     ∟ bečkoj Poss
# riječki [Adj]
#     ∟ riječkoj Poss
# optuženički [Adj]
#     ∟ optuženičkoj Poss
# bački [Adj]
#     ∟ bačku Poss
# lučki [Adj]
#     ∟ lučku Poss
# uređivački [Adj]
#     ∟ uređivačku Poss
# antikomunistički [Adj]
#     ∟ antikomunističku Poss
# državnički [Adj]
#     ∟ državničku Poss

# %% [markdown]
# ### 2.3.3 suffix *-ški* and its inflections

# %% [markdown]
# Singular
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|češki|češka|češko|
# |genitive|češkog|češke|češkog|
# |dative|češkom|češkoj|češkom|
# |acusative|češki|češku|češko|
# |vocative|češki|češka|češko|
# |instrumental|češkim|češkom|češkim|
# |locative|češkom|češkoj|češkom|
#
# Plural
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|češki|češke|češka|
# |genitive|čeških|čeških|češke|
# |dative|češkim|češkim|češkoj|
# |acusative|češke|češke|češku|
# |vocative|češki|češke|češka|
# |instrumental|češkim|češkim|češkom|
# |locative|češkim|češkim|češkoj|

# %% [markdown]
# Possible suffixes: *-ški*, *-škog*, *-škom*, *-ška*, *-ških*, *-škim*, *-ško*, *-ške*, *-škoj*, *-šku*

# %%
possessive_adjectives = list(set([w for w in ud_content if w.endswith('ški')]))

# %%
possessive_adjectives
# Out:
# ['češki',
#  'muški',
#  'tehnološki',
#  'ideološki',
#  'njujorški',
#  'bombaški',
#  'malteški',
#  'norveški',
#  'strateški',
#  'haški',
#  'zoološki',
#  'luksemburški']

# %%
for possesive_adj in possessive_adjectives:
    add_to_lexicon(possesive_adj, "Adj")

# %%
inflection_suffixes = [('škog', 'ški'), ('škom', 'ški'), ('ška', 'ški'), 
                       ('ških', 'ški'), ('škim', 'ški'), ('ško', 'ški'), 
                       ('ške', 'ški'), ('škoj', 'ški'), ('šku', 'ški')]

add_adjective_inflection_forms(inflection_suffixes)

# %%
print_lexicon()
# Out:
# pripremiti [V]
# izraditi [V]
# oprostiti [V]
# proširiti [V]
# govoriti [V]
# otkloniti [V]
# unaprediti [V]
# otplatiti [V]
# pretpostaviti [V]
# smanjiti [V]
# pustiti [V]
# značiti [V]
# rešiti [V]
# naslediti [V]
# štiti [V]
# zaštititi [V]
# snositi [V]
# razdvojiti [V]
# ograničiti [V]
# zavisiti [V]
# patiti [V]
# odstupiti [V]
# zaključiti [V]
# učiniti [V]
# uložiti [V]
# ponoviti [V]
# raditi [V]
# usredsrediti [V]
# odrediti [V]
# pojaviti [V]
# obaviti [V]
# prihvatiti [V]
# potrošiti [V]
# ponuditi [V]
# preporučiti [V]
# zameniti [V]
# obezbediti [V]
# izgubiti [V]
# iznositi [V]
# složiti [V]
# odobriti [V]
# omogućiti [V]
# uočiti [V]
# obilaziti [V]
# ostaviti [V]
# staviti [V]
# izmeniti [V]
# unakaziti [V]
# razmotriti [V]
# ohrabriti [V]
# ispuniti [V]
# odbaciti [V]
# suočiti [V]
# rijaliti [V]
# osetiti [V]
# tražiti [V]
# vlastiti [V]
# deliti [V]
# zanemariti [V]
# nastupiti [V]
# vratiti [V]
# udvostručiti [V]
# izvršiti [V]
# zatražiti [V]
# nastaviti [V]
# dozvoliti [V]
# krediti [V]
# razvodniti [V]
# usuditi [V]
# potvrditi [V]
# pružiti [V]
# shvatiti [V]
# desiti [V]
# protiviti [V]
# ostvariti [V]
# povratiti [V]
# izmisliti [V]
# različiti [V]
# uništiti [V]
# preurediti [V]
# skladištiti [V]
# primiti [V]
# otkriti [V]
# odgovoriti [V]
# uraditi [V]
# protumačiti [V]
# zamisliti [V]
# predstaviti [V]
# odnositi [V]
# uspostaviti [V]
# napraviti [V]
# arvaniti [V]
# podnositi [V]
# proceniti [V]
# dobiti [V]
# opslužiti [V]
# posetiti [V]
# pratiti [V]
# povrediti [V]
# napustiti [V]
# posvetiti [V]
# namestiti [V]
# iskoristiti [V]
# nuditi [V]
# zaštiti [V]
# rušiti [V]
# koristiti [V]
# učiti [V]
# umoriti [V]
# dogoditi [V]
# smisliti [V]
# sprovoditi [V]
# uskladiti [V]
# razotkriti [V]
# voditi [V]
# promeniti [V]
# prenositi [V]
# uslediti [V]
# otpustiti [V]
# pridružiti [V]
# otvoriti [V]
# završiti [V]
# razrešiti [V]
# sprečiti [V]
# kazniti [V]
# težiti [V]
# odvratiti [V]
# postaviti [V]
# kupiti [V]
# udružiti [V]
# poslužiti [V]
# uhvatiti [V]
# izgraditi [V]
# ustanoviti [V]
# ugroziti [V]
# proučiti [V]
# slediti [V]
# zaposliti [V]
# predložiti [V]
# osuditi [V]
# nadoknaditi [V]
# obnoviti [V]
# stvoriti [V]
# pristupiti [V]
# oseti [V]
# započeti [V]
# preuzeti [V]
# dopreti [V]
# uzeti [V]
# doprineti [V]
# preduzeti [V]
# doneti [V]
# preoteti [V]
# poseti [V]
# preneti [V]
# animoziteti [V]
# anketi [V]
# peti [V]
# deveti [V]
# našteti [V]
# posveti [V]
# tereti [V]
# meti [V]
# ćančeti [V]
# ahmeti [V]
# univerziteti [V]
# uspeti [V]
# antikviteti [V]
# razumeti [V]
# oteti [V]
# početi [V]
# dijeti [V]
# oživeti [V]
# preti [V]
# videti [V]
# predvideti [V]
# podneti [V]
# aveti [V]
# predmeti [V]
# fakulteti [V]
# pozivati [V]
#     ∟ pozivajući PresentPat
# falsifikovati [V]
# zahtevati [V]
#     ∟ zahtevajući PresentPat
# blokirati [V]
# dokazati [V]
# kopirati [V]
# uračunati [V]
# apstinirati [V]
# podržati [V]
# poboljšati [V]
# morati [V]
# oklevati [V]
# menjati [V]
# omogućavati [V]
#     ∟ omogućavajući PresentPat
# zadržati [V]
# intervenisati [V]
# garantovati [V]
# stajati [V]
# organizovati [V]
# pozvati [V]
# klati [V]
# razmenjivati [V]
# prati [V]
# palati [V]
# sastati [V]
# pokazati [V]
# pisati [V]
# razrešavati [V]
# primenjivati [V]
# obraćati [V]
#     ∟ obraćajući PresentPat
# otputovati [V]
# prisustvovati [V]
# prebacivati [V]
# sarađivati [V]
# vrati [V]
# investirati [V]
# preispitati [V]
# slati [V]
# pokušati [V]
# poštovati [V]
# trajati [V]
# poslati [V]
# dati [V]
#     ∟ dajući PresentPat
# sećati [V]
# povrati [V]
# postupati [V]
# održavati [V]
# požurivati [V]
# zarađivati [V]
# prihvati [V]
# plati [V]
# zloupotrebljavati [V]
# raspravljati [V]
# prikazati [V]
# uhvati [V]
# obrati [V]
# pridržavati [V]
# rezultati [V]
# zvati [V]
# uticati [V]
# postojati [V]
# koštati [V]
# funkcionisati [V]
# pokušavati [V]
# potpisati [V]
# analizirati [V]
# advokati [V]
# posmatrati [V]
# predstavljati [V]
#     ∟ predstavljajući PresentPat
# rešavati [V]
# dobijati [V]
# modelirati [V]
# mati [V]
# zapošljavati [V]
# pati [V]
# prepoznati [V]
# držati [V]
# bušati [V]
# imati [V]
#     ∟ imajući PresentPat
# dočekivati [V]
# izolovati [V]
# uključivati [V]
# ostati [V]
# održati [V]
# pridati [V]
# okončati [V]
# poznati [V]
# insistirati [V]
#     ∟ insistirajući PresentPat
# verovati [V]
# zamišljati [V]
# odvijati [V]
# doputovati [V]
# birati [V]
# povećati [V]
# intenzivirati [V]
# postati [V]
# olakšati [V]
# reagovati [V]
# predati [V]
# pružati [V]
# isplati [V]
# sačuvati [V]
# smanjivati [V]
# prestati [V]
# razgovarati [V]
# vraćati [V]
# sati [V]
# obavljati [V]
#     ∟ obavljajući PresentPat
# pregovarati [V]
# pervati [V]
# ometati [V]
# učestvovati [V]
# oslanjati [V]
# smatrati [V]
# glasati [V]
# zaletati [V]
# suspendovati [V]
# povezati [V]
# kandidati [V]
# hrvati [V]
# nemati [V]
# objavljivati [V]
# izazvati [V]
# nadati [V]
# ojačati [V]
# igrati [V]
#     ∟ igrajući PresentPat
# osećati [V]
# razvijati [V]
# ispričati [V]
# izabrati [V]
# fokusirati [V]
# ticati [V]
# artikulisati [V]
# bogati [V]
# zapitati [V]
# postavljati [V]
#     ∟ postavljajući PresentPat
# delati [V]
# putovati [V]
# finansirati [V]
# izdati [V]
# odavati [V]
# priznati [V]
# plakati [V]
# plaćati [V]
# izdavati [V]
# nadmetati [V]
# aktivirati [V]
# očekivati [V]
# cenjkati [V]
# pojačati [V]
# ratifikovati [V]
# definisati [V]
# zalagati [V]
# izražavati [V]
#     ∟ izražavajući PresentPat
# preduzimati [V]
#     ∟ preduzimajući PresentPat
# sindikati [V]
# počevši [V]
# uzdrmavši [V]
# učinivši [V]
# pretvorivši [V]
# osvojivši [V]
# proširivši [V]
# primetivši [V]
# dostigavši [V]
# postavivši [V]
# zamenivši [V]
# ponovivši [V]
# izazvavši [V]
# pohvalivši [V]
# bivši [V]
# završivši [V]
# rekavši [V]
# pobedivši [V]
# naslutivši [V]
# zabeleživši [V]
# dobivši [V]
# upozoravati [V]
#     ∟ upozoravajući PresentPat
# objašnjavati [V]
#     ∟ objašnjavajući PresentPat
# završavati [V]
#     ∟ završavajući PresentPat
# ubacovati [V]
#     ∟ ubacujući PresentPat
# čitati [V]
#     ∟ čitajući PresentPat
# potvrđovati [V]
#     ∟ potvrđujući PresentPat
# ažurirati [V]
#     ∟ ažurirajući PresentPat
# optužovati [V]
#     ∟ optužujući PresentPat
# odgovarati [V]
#     ∟ odgovarajući PresentPat
# pozdravljati [V]
#     ∟ pozdravljajući PresentPat
# dodati [V]
#     ∟ dodajući PresentPat
# znati [V]
#     ∟ znajući PresentPat
# otvarati [V]
#     ∟ otvarajući PresentPat
# primati [V]
#     ∟ primajući PresentPat
# narastati [V]
#     ∟ narastajući PresentPat
# predsedavati [V]
#     ∟ predsedavajući PresentPat
# savetovati [V]
#     ∟ savetujući PresentPat
# osuđovati [V]
#     ∟ osuđujući PresentPat
# ohrabrovati [V]
#     ∟ ohrabrujući PresentPat
# okončavati [V]
#     ∟ okončavajući PresentPat
# podsećati [V]
#     ∟ podsećajući PresentPat
# opisovati [V]
#     ∟ opisujući PresentPat
# kritikovati [V]
#     ∟ kritikujući PresentPat
# uveravati [V]
#     ∟ uveravajući PresentPat
# saopštavati [V]
#     ∟ saopštavajući PresentPat
# sprečavati [V]
#     ∟ sprečavajući PresentPat
# suočavati [V]
#     ∟ suočavajući PresentPat
# oslobađati [V]
#     ∟ oslobađajući PresentPat
# čekati [V]
#     ∟ čekajući PresentPat
# izdvajati [V]
#     ∟ izdvajajući PresentPat
# diskreditovati [V]
#     ∟ diskreditujući PresentPat
# zatvarati [V]
#     ∟ zatvarajući PresentPat
# protestovati [V]
#     ∟ protestujući PresentPat
# odbijati [V]
#     ∟ odbijajući PresentPat
# najavljovati [V]
#     ∟ najavljujući PresentPat
# nazivati [V]
#     ∟ nazivajući PresentPat
# emigrirati [V]
#     ∟ emigrirajući PresentPat
# zbližavati [V]
#     ∟ zbližavajući PresentPat
# prezati [V]
#     ∟ prezajući PresentPat
# zbunjovati [V]
#     ∟ zbunjujući PresentPat
# ukazovati [V]
#     ∟ ukazujući PresentPat
# pretvarati [V]
#     ∟ pretvarajući PresentPat
# tragati [V]
#     ∟ tragajući PresentPat
# nedostati [V]
#     ∟ nedostajući PresentPat
# prodati [V]
#     ∟ prodajući PresentPat
# primoravati [V]
#     ∟ primoravajući PresentPat
# potiskovati [V]
#     ∟ potiskujući PresentPat
# uključovati [V]
#     ∟ uključujući PresentPat
# bacati [V]
#     ∟ bacajući PresentPat
# zahvaljovati [V]
#     ∟ zahvaljujući PresentPat
# svrstavati [V]
#     ∟ svrstavajući PresentPat
# obeležavati [V]
#     ∟ obeležavajući PresentPat
# obećavati [V]
#     ∟ obećavajući PresentPat
# preneražavati [V]
#     ∟ preneražavajući PresentPat
# otuđovati [V]
#     ∟ otuđujući PresentPat
# pojavljovati [V]
#     ∟ pojavljujući PresentPat
# opstruirati [V]
#     ∟ opstruirajući PresentPat
# naglašavati [V]
#     ∟ naglašavajući PresentPat
# uzrokovati [V]
#     ∟ uzrokujući PresentPat
# ponavljati [V]
#     ∟ ponavljajući PresentPat
# favorizovati [V]
#     ∟ favorizujući PresentPat
# deceno [Adj]
#     ∟ decenije Comp+Neut+Sg
# uno [Adj]
#     ∟ unije Comp+Neut+Sg
# važna [Adj]
#     ∟ važnija Comp+Fem+Sg
#       najvažnija Sup+Fem+Sg
# svestrano [Adj]
#     ∟ svestranije Comp+Neut+Sg
# lina [Adj]
#     ∟ linija Comp+Fem+Sg
# apolona [Adj]
#     ∟ apolonija Comp+Fem+Sg
# lino [Adj]
#     ∟ linije Comp+Neut+Sg
# bezbedan [Adj]
#     ∟ bezbedniji Comp+Masc+Sg
# decena [Adj]
#     ∟ decenija Comp+Fem+Sg
# kompleksna [Adj]
#     ∟ kompleksnija Comp+Fem+Sg
# moćan [Adj]
#     ∟ moćniji Comp+Masc+Sg
#       najmoćniji Sup+Masc+Sg
# mena [Adj]
#     ∟ menija Comp+Fem+Sg
# pensilvaan [Adj]
#     ∟ pensilvaniji Comp+Masc+Sg
# aliana [Adj]
#     ∟ alianija Comp+Fem+Sg
# lian [Adj]
#     ∟ liniji Comp+Masc+Sg
# beskompromisan [Adj]
#     ∟ beskompromisniji Comp+Masc+Sg
# rano [Adj]
#     ∟ ranije Comp+Neut+Sg
# nezadovoljan [Adj]
#     ∟ nezadovoljniji Comp+Masc+Sg
# telefono [Adj]
#     ∟ telefonije Comp+Neut+Sg
# konkurentna [Adj]
#     ∟ konkurentnija Comp+Fem+Sg
# makedono [Adj]
#     ∟ makedonije Comp+Neut+Sg
# sigurna [Adj]
#     ∟ sigurnija Comp+Fem+Sg
# snažno [Adj]
#     ∟ snažnije Comp+Neut+Sg
# efikasna [Adj]
#     ∟ efikasnija Comp+Fem+Sg
# uticajan [Adj]
#     ∟ uticajniji Comp+Masc+Sg
# una [Adj]
#     ∟ unija Comp+Fem+Sg
# ozbiljan [Adj]
#     ∟ ozbiljniji Comp+Masc+Sg
#       najozbiljniji Sup+Masc+Sg
# estono [Adj]
#     ∟ estonije Comp+Neut+Sg
# pozitivan [Adj]
#     ∟ pozitivniji Comp+Masc+Sg
# čečean [Adj]
#     ∟ čečeniji Comp+Masc+Sg
# opasan [Adj]
#     ∟ opasnijim Comp+Masc+Pl
# kompano [Adj]
#     ∟ kompanije Comp+Neut+Sg
# špaan [Adj]
#     ∟ španiji Comp+Masc+Sg
# iskusan [Adj]
#     ∟ iskusnijim Comp+Masc+Pl
# rasprostranjena [Adj]
#     ∟ rasprostranjenija Comp+Fem+Sg
# ceremona [Adj]
#     ∟ ceremonija Comp+Fem+Sg
# litvano [Adj]
#     ∟ litvanije Comp+Neut+Sg
# značajan [Adj]
#     ∟ značajniji Comp+Masc+Sg
#       najznačajniji Sup+Masc+Sg
# kolona [Adj]
#     ∟ kolonija Comp+Fem+Sg
# britano [Adj]
#     ∟ britanije Comp+Neut+Sg
# albaan [Adj]
#     ∟ albaniji Comp+Masc+Sg
# striktno [Adj]
#     ∟ striktnije Comp+Neut+Sg
# kompana [Adj]
#     ∟ kompanija Comp+Fem+Sg
# očigledan [Adj]
#     ∟ očigledniji Comp+Masc+Sg
# potpuno [Adj]
#     ∟ potpunije Comp+Neut+Sg
# britaan [Adj]
#     ∟ britaniji Comp+Masc+Sg
# docno [Adj]
#     ∟ docnije Comp+Neut+Sg
# tačno [Adj]
#     ∟ tačnije Comp+Neut+Sg
# sloveno [Adj]
#     ∟ slovenije Comp+Neut+Sg
# diversifikovana [Adj]
#     ∟ diversifikovanija Comp+Fem+Sg
# raan [Adj]
#     ∟ ranijim Comp+Masc+Pl
# kasno [Adj]
#     ∟ kasnije Comp+Neut+Sg
# izražean [Adj]
#     ∟ izraženijim Comp+Masc+Pl
# demokratična [Adj]
#     ∟ demokratičnija Comp+Fem+Sg
# siromašno [Adj]
#     ∟ siromašnije Comp+Neut+Sg
# britana [Adj]
#     ∟ britanija Comp+Fem+Sg
# konkretno [Adj]
#     ∟ konkretnije Comp+Neut+Sg
# jevtian [Adj]
#     ∟ jevtinijim Comp+Masc+Pl
# špano [Adj]
#     ∟ španije Comp+Neut+Sg
# precizan [Adj]
#     ∟ precizniji Comp+Masc+Sg
# ceremoan [Adj]
#     ∟ ceremoniji Comp+Masc+Sg
# kompaan [Adj]
#     ∟ kompaniji Comp+Masc+Sg
# optimalno [Adj]
#     ∟ optimalnije Comp+Neut+Sg
# sigurno [Adj]
#     ∟ sigurnije Comp+Neut+Sg
# špana [Adj]
#     ∟ španija Comp+Fem+Sg
# rumuan [Adj]
#     ∟ rumuniji Comp+Masc+Sg
# rasprostranjean [Adj]
#     ∟ rasprostranjeniji Comp+Masc+Sg
# rumuno [Adj]
#     ∟ rumunije Comp+Neut+Sg
# makedoan [Adj]
#     ∟ makedoniji Comp+Masc+Sg
# zainteresovana [Adj]
#     ∟ zainteresovanija Comp+Fem+Sg
# represivan [Adj]
#     ∟ represivniji Comp+Masc+Sg
# optimističan [Adj]
#     ∟ optimističniji Comp+Masc+Sg
# letono [Adj]
#     ∟ letonije Comp+Neut+Sg
# aktivno [Adj]
#     ∟ aktivnije Comp+Neut+Sg
# jeftino [Adj]
#     ∟ jeftinije Comp+Neut+Sg
# makedona [Adj]
#     ∟ makedonija Comp+Fem+Sg
# važan [Adj]
#     ∟ važniji Comp+Masc+Sg
#       najvažniji Sup+Masc+Sg
# slovena [Adj]
#     ∟ slovenija Comp+Fem+Sg
# urgentan [Adj]
#     ∟ urgentniji Comp+Masc+Sg
#       najurgentniji Sup+Masc+Sg
# uan [Adj]
#     ∟ uniji Comp+Masc+Sg
# transparentan [Adj]
#     ∟ transparentnijim Comp+Masc+Pl
# ceremono [Adj]
#     ∟ ceremonije Comp+Neut+Sg
# rumuna [Adj]
#     ∟ rumunija Comp+Fem+Sg
# albana [Adj]
#     ∟ albanija Comp+Fem+Sg
# slovean [Adj]
#     ∟ sloveniji Comp+Masc+Sg
# važno [Adj]
#     ∟ važnije Comp+Neut+Sg
#       najvažnije Sup+Neut+Sg
# efikasan [Adj]
#     ∟ efikasniji Comp+Masc+Sg
# slobodan [Adj]
#     ∟ slobodniji Comp+Masc+Sg
# značajno [Adj]
#     ∟ značajnije Comp+Neut+Sg
#       najznačajnije Sup+Neut+Sg
# albano [Adj]
#     ∟ albanije Comp+Neut+Sg
# finansijski [Adj]
#     ∟ finansijskog Poss
#       finansijskom Poss
#       finansijskim Poss
#       finansijska Poss
#       finansijske Poss
#       finansijsku Poss
#       finansijskih Poss
# trojanski [Adj]
# dostojevski [Adj]
# svetski [Adj]
#     ∟ svetskog Poss
#       svetskom Poss
#       svetskim Poss
#       svetska Poss
#       svetske Poss
#       svetskoj Poss
#       svetsku Poss
#       svetskih Poss
#       svetsko Poss
# herkulovski [Adj]
# romski [Adj]
#     ∟ romskog Poss
#       romskom Poss
#       romskim Poss
#       romska Poss
#       romske Poss
#       romskoj Poss
# ivanovski [Adj]
# generacijski [Adj]
# mađarski [Adj]
#     ∟ mađarske Poss
#       mađarskoj Poss
# beogradski [Adj]
#     ∟ beogradskog Poss
#       beogradskom Poss
#       beogradska Poss
#       beogradske Poss
#       beogradskoj Poss
#       beogradsku Poss
# istorijski [Adj]
#     ∟ istorijskog Poss
#       istorijskom Poss
#       istorijskim Poss
#       istorijska Poss
#       istorijsku Poss
#       istorijskih Poss
# gruevski [Adj]
#     ∟ gruevskog Poss
#       gruevskim Poss
# britanski [Adj]
#     ∟ britanskog Poss
#       britanskom Poss
#       britanska Poss
#       britanske Poss
#       britansku Poss
#       britanskih Poss
# diplomatski [Adj]
#     ∟ diplomatskog Poss
#       diplomatskom Poss
#       diplomatskim Poss
#       diplomatska Poss
#       diplomatske Poss
#       diplomatskoj Poss
#       diplomatsku Poss
# kurdski [Adj]
#     ∟ kurdskog Poss
#       kurdskom Poss
#       kurdske Poss
#       kurdskoj Poss
#       kurdsku Poss
#       kurdskih Poss
# filmski [Adj]
#     ∟ filmskom Poss
#       filmskih Poss
# švajcarski [Adj]
#     ∟ švajcarskog Poss
#       švajcarske Poss
#       švajcarskoj Poss
# televizijski [Adj]
#     ∟ televizijske Poss
# spoljnotrgovinski [Adj]
# spisateljski [Adj]
# pakistanski [Adj]
#     ∟ pakistanske Poss
# socijaldemokratski [Adj]
#     ∟ socijaldemokratskog Poss
#       socijaldemokratskom Poss
#       socijaldemokratska Poss
#       socijaldemokratske Poss
#       socijaldemokratskoj Poss
# bosforski [Adj]
# dejtonski [Adj]
#     ∟ dejtonskog Poss
#       dejtonskim Poss
# balkanski [Adj]
#     ∟ balkanskim Poss
#       balkanska Poss
#       balkanske Poss
#       balkanskoj Poss
#       balkansku Poss
#       balkanskih Poss
# irski [Adj]
#     ∟ irskim Poss
#       irska Poss
#       irske Poss
#       irskoj Poss
# geografski [Adj]
# vremenski [Adj]
#     ∟ vremenskim Poss
#       vremenskih Poss
# albanski [Adj]
#     ∟ albanskog Poss
#       albanskom Poss
#       albanskim Poss
#       albanska Poss
#       albanske Poss
#       albanskoj Poss
#       albansku Poss
#       albanskih Poss
# belgijski [Adj]
#     ∟ belgijskom Poss
# bosanski [Adj]
#     ∟ bosanskim Poss
#       bosanska Poss
#       bosanske Poss
#       bosanskih Poss
# građevinski [Adj]
#     ∟ građevinskog Poss
#       građevinske Poss
# londonski [Adj]
#     ∟ londonskoj Poss
# lisabonski [Adj]
# teoretski [Adj]
# jugoslovenski [Adj]
#     ∟ jugoslovenskog Poss
#       jugoslovenske Poss
#       jugoslovenskoj Poss
# terapeutski [Adj]
#     ∟ terapeutsko Poss
# portugalski [Adj]
#     ∟ portugalske Poss
# vijetnamski [Adj]
# cerovski [Adj]
# tetovski [Adj]
# carinski [Adj]
#     ∟ carinskog Poss
#       carinska Poss
#       carinske Poss
#       carinskoj Poss
#       carinskih Poss
# avionski [Adj]
#     ∟ avionskih Poss
# crvenkovski [Adj]
#     ∟ crvenkovskim Poss
# saudijski [Adj]
#     ∟ saudijskog Poss
#       saudijska Poss
#       saudijske Poss
# industrijski [Adj]
#     ∟ industrijskim Poss
#       industrijskih Poss
# zemunski [Adj]
#     ∟ zemunskog Poss
# olimpijski [Adj]
#     ∟ olimpijskom Poss
#       olimpijska Poss
# posttraumatski [Adj]
#     ∟ posttraumatskog Poss
# mančevski [Adj]
#     ∟ mančevskog Poss
# nikolovski [Adj]
# orvelovski [Adj]
# argentinski [Adj]
#     ∟ argentinske Poss
# imunski [Adj]
# većinski [Adj]
# puninski [Adj]
# engleski [Adj]
#     ∟ engleska Poss
# turski [Adj]
#     ∟ turskog Poss
#       turskom Poss
#       turskim Poss
#       turska Poss
#       turske Poss
#       turskoj Poss
#       tursku Poss
#       turskih Poss
#       tursko Poss
# trajkovski [Adj]
#     ∟ trajkovskog Poss
# kablovski [Adj]
#     ∟ kablovske Poss
# bučkovski [Adj]
# moldavski [Adj]
#     ∟ moldavska Poss
#       moldavske Poss
#       moldavskih Poss
# poljski [Adj]
#     ∟ poljske Poss
#       poljskoj Poss
#       poljskih Poss
# italijanski [Adj]
#     ∟ italijanskog Poss
#       italijanske Poss
# rumunski [Adj]
#     ∟ rumunskog Poss
#       rumunskom Poss
#       rumunskim Poss
#       rumunska Poss
#       rumunske Poss
#       rumunskoj Poss
#       rumunskih Poss
#       rumunsko Poss
# proevropski [Adj]
#     ∟ proevropske Poss
#       proevropskoj Poss
# amaterski [Adj]
#     ∟ amaterske Poss
# antonovski [Adj]
# francuski [Adj]
#     ∟ francuskog Poss
#       francuskom Poss
#       francuska Poss
#       francuske Poss
#       francuskoj Poss
#       francusku Poss
#       francuskih Poss
# penzijski [Adj]
#     ∟ penzijskog Poss
# akademski [Adj]
#     ∟ akademska Poss
#       akademske Poss
#       akademskoj Poss
#       akademskih Poss
# istinski [Adj]
#     ∟ istinske Poss
# stavrevski [Adj]
# bliski [Adj]
#     ∟ bliskog Poss
#       bliskom Poss
#       bliskoj Poss
#       blisku Poss
# meteorski [Adj]
# španski [Adj]
#     ∟ španskog Poss
#       španskim Poss
#       španske Poss
#       španskih Poss
# drumski [Adj]
# evropski [Adj]
#     ∟ evropskog Poss
#       evropskom Poss
#       evropskim Poss
#       evropska Poss
#       evropske Poss
#       evropskoj Poss
#       evropsku Poss
#       evropskih Poss
#       evropsko Poss
# izraelski [Adj]
# konjanovski [Adj]
#     ∟ konjanovskog Poss
# bostonski [Adj]
# aleksievski [Adj]
# energetski [Adj]
#     ∟ energetskim Poss
#       energetska Poss
#       energetske Poss
#       energetskih Poss
# gagovski [Adj]
# antologijski [Adj]
# manevski [Adj]
# nedemokratski [Adj]
# novozelandski [Adj]
# azilski [Adj]
#     ∟ azilskog Poss
# šahovski [Adj]
#     ∟ šahovska Poss
# medijski [Adj]
#     ∟ medijskog Poss
#       medijskom Poss
#       medijske Poss
#       medijskih Poss
# ministarski [Adj]
#     ∟ ministarska Poss
# sofijski [Adj]
#     ∟ sofijskoj Poss
# islamski [Adj]
#     ∟ islamskim Poss
#       islamska Poss
#       islamske Poss
#       islamsku Poss
#       islamskih Poss
# sovjetski [Adj]
#     ∟ sovjetskom Poss
# helenski [Adj]
#     ∟ helensko Poss
# verski [Adj]
#     ∟ verskog Poss
#       verskim Poss
#       verske Poss
#       versku Poss
#       verskih Poss
#       versko Poss
# vrhunski [Adj]
#     ∟ vrhunskom Poss
#       vrhunske Poss
#       vrhunskih Poss
# peruanski [Adj]
# proruski [Adj]
# sudski [Adj]
#     ∟ sudskog Poss
#       sudskom Poss
#       sudskim Poss
#       sudskoj Poss
#       sudskih Poss
#       sudsko Poss
# hrvatski [Adj]
#     ∟ hrvatskog Poss
#       hrvatskom Poss
#       hrvatskim Poss
#       hrvatska Poss
#       hrvatske Poss
#       hrvatskoj Poss
#       hrvatsku Poss
#       hrvatsko Poss
# bugarski [Adj]
#     ∟ bugarskog Poss
#       bugarskom Poss
#       bugarskim Poss
#       bugarska Poss
#       bugarske Poss
#       bugarskoj Poss
#       bugarsku Poss
#       bugarskih Poss
#       bugarsko Poss
# zakonski [Adj]
#     ∟ zakonskog Poss
#       zakonskom Poss
#       zakonske Poss
#       zakonsku Poss
#       zakonskih Poss
# ruski [Adj]
#     ∟ ruskog Poss
#       ruskim Poss
#       ruske Poss
#       ruskoj Poss
#       rusku Poss
#       ruskih Poss
# crnogorski [Adj]
#     ∟ crnogorskom Poss
#       crnogorskim Poss
#       crnogorska Poss
#       crnogorske Poss
#       crnogorskoj Poss
#       crnogorsku Poss
# evroatlantski [Adj]
#     ∟ evroatlantskim Poss
#       evroatlantske Poss
#       evroatlantskoj Poss
#       evroatlantsku Poss
#       evroatlantskih Poss
# ohridski [Adj]
#     ∟ ohridske Poss
# berlinski [Adj]
# poposki [Adj]
# niski [Adj]
#     ∟ niskom Poss
#       niska Poss
#       nisku Poss
#       niskih Poss
# srpski [Adj]
#     ∟ srpskog Poss
#       srpskom Poss
#       srpskim Poss
#       srpska Poss
#       srpske Poss
#       srpskoj Poss
#       srpsku Poss
#       srpskih Poss
#       srpsko Poss
# životinjski [Adj]
# trgovinski [Adj]
#     ∟ trgovinskog Poss
#       trgovinske Poss
# katastarski [Adj]
# kiparski [Adj]
#     ∟ kiparskog Poss
#       kiparskom Poss
#       kiparskim Poss
#       kiparske Poss
#       kiparskih Poss
# novinarski [Adj]
#     ∟ novinarska Poss
# holivudski [Adj]
#     ∟ holivudskih Poss
# nilski [Adj]
#     ∟ nilskog Poss
# univerzitetski [Adj]
#     ∟ univerzitetskom Poss
#       univerzitetskim Poss
#       univerzitetske Poss
#       univerzitetskih Poss
# trajkoviski [Adj]
# kosovski [Adj]
#     ∟ kosovskog Poss
#       kosovskom Poss
#       kosovskim Poss
#       kosovska Poss
#       kosovske Poss
#       kosovskoj Poss
#       kosovskih Poss
#       kosovsko Poss
# majski [Adj]
#     ∟ majskog Poss
# litvanski [Adj]
# stojčevski [Adj]
# ramkovski [Adj]
#     ∟ ramkovskog Poss
#       ramkovskom Poss
# levičarski [Adj]
#     ∟ levičarskim Poss
#       levičarska Poss
#       levičarskoj Poss
# prevarantski [Adj]
# demokratski [Adj]
#     ∟ demokratskog Poss
#       demokratskom Poss
#       demokratskim Poss
#       demokratska Poss
#       demokratske Poss
#       demokratsku Poss
#       demokratskih Poss
#       demokratsko Poss
# detektivski [Adj]
# ljudski [Adj]
#     ∟ ljudskim Poss
#       ljudska Poss
#       ljudske Poss
#       ljudskih Poss
# birokratski [Adj]
#     ∟ birokratske Poss
# lavovski [Adj]
# republikanski [Adj]
#     ∟ republikanska Poss
# sirijski [Adj]
#     ∟ sirijskog Poss
# ekonomski [Adj]
#     ∟ ekonomskog Poss
#       ekonomskom Poss
#       ekonomskim Poss
#       ekonomska Poss
#       ekonomske Poss
#       ekonomskoj Poss
#       ekonomsku Poss
#       ekonomskih Poss
# gruzijski [Adj]
#     ∟ gruzijske Poss
#       gruzijskoj Poss
# poreski [Adj]
#     ∟ poreskom Poss
#       poreska Poss
#       poreske Poss
#       poreskoj Poss
#       poreskih Poss
# budžetski [Adj]
#     ∟ budžetskog Poss
#       budžetskom Poss
#       budžetskim Poss
#       budžetska Poss
#       budžetskih Poss
# briselski [Adj]
#     ∟ briselske Poss
# švedski [Adj]
#     ∟ švedskom Poss
#       švedska Poss
#       švedske Poss
#       švedskoj Poss
#       švedsku Poss
# studentski [Adj]
#     ∟ studentskog Poss
#       studentskim Poss
#       studentske Poss
#       studentskih Poss
# automatski [Adj]
#     ∟ automatskom Poss
# finski [Adj]
#     ∟ finska Poss
#       finske Poss
# makedonski [Adj]
#     ∟ makedonskog Poss
#       makedonskom Poss
#       makedonskim Poss
#       makedonska Poss
#       makedonske Poss
#       makedonskoj Poss
#       makedonsku Poss
#       makedonskih Poss
#       makedonsko Poss
# pariski [Adj]
# bankarski [Adj]
#     ∟ bankarskim Poss
#       bankarske Poss
# milošoski [Adj]
# solunski [Adj]
#     ∟ solunske Poss
#       solunsku Poss
# fudbalski [Adj]
#     ∟ fudbalskog Poss
#       fudbalskim Poss
#       fudbalska Poss
#       fudbalske Poss
#       fudbalskih Poss
#       fudbalsko Poss
# peševski [Adj]
# kineski [Adj]
#     ∟ kineskog Poss
# letonski [Adj]
#     ∟ letonskog Poss
# softverski [Adj]
#     ∟ softverskog Poss
#       softverskoj Poss
#       softverskih Poss
# filharmonijski [Adj]
#     ∟ filharmonijskog Poss
# jadranski [Adj]
#     ∟ jadranskog Poss
#       jadranske Poss
# pokrajinski [Adj]
#     ∟ pokrajinskog Poss
# arapski [Adj]
#     ∟ arapskog Poss
#       arapskim Poss
# arhajski [Adj]
#     ∟ arhajskog Poss
# egipatski [Adj]
#     ∟ egipatskog Poss
# istanbulski [Adj]
#     ∟ istanbulskog Poss
#       istanbulskom Poss
#       istanbulska Poss
#       istanbulske Poss
# praistorijski [Adj]
#     ∟ praistorijskog Poss
# sportski [Adj]
#     ∟ sportskog Poss
#       sportskom Poss
#       sportske Poss
#       sportskih Poss
# telefonski [Adj]
#     ∟ telefonskog Poss
#       telefonske Poss
# muslimanski [Adj]
#     ∟ muslimanskog Poss
#       muslimanska Poss
#       muslimanske Poss
#       muslimanskoj Poss
# piranski [Adj]
#     ∟ piranskog Poss
# palestinski [Adj]
#     ∟ palestinskog Poss
# sarajevski [Adj]
#     ∟ sarajevskog Poss
#       sarajevskom Poss
#       sarajevskim Poss
#       sarajevska Poss
#       sarajevskoj Poss
# akcijski [Adj]
#     ∟ akcijskog Poss
#       akcijskih Poss
# višedecenijski [Adj]
#     ∟ višedecenijskog Poss
#       višedecenijske Poss
# libijski [Adj]
#     ∟ libijskog Poss
# tuzlanski [Adj]
#     ∟ tuzlanskog Poss
# sufijski [Adj]
#     ∟ sufijskog Poss
# gangsterski [Adj]
#     ∟ gangsterskog Poss
# filozofski [Adj]
#     ∟ filozofskog Poss
# oktobarski [Adj]
#     ∟ oktobarskog Poss
#       oktobarske Poss
#       oktobarskih Poss
# reformski [Adj]
#     ∟ reformskog Poss
#       reformskim Poss
#       reformske Poss
#       reformskih Poss
# suštinski [Adj]
#     ∟ suštinskog Poss
#       suštinskim Poss
#       suštinska Poss
# ženski [Adj]
#     ∟ ženskog Poss
#       ženskom Poss
#       ženskim Poss
#       ženska Poss
#       ženskoj Poss
#       ženskih Poss
#       žensko Poss
# vehabijski [Adj]
#     ∟ vehabijskog Poss
# vizantijski [Adj]
#     ∟ vizantijskog Poss
# masačusetski [Adj]
#     ∟ masačusetskog Poss
# policijski [Adj]
#     ∟ policijskog Poss
#       policijskim Poss
#       policijska Poss
#       policijske Poss
#       policijskoj Poss
#       policijsku Poss
#       policijskih Poss
# rimski [Adj]
#     ∟ rimskog Poss
#       rimskih Poss
# mediteranski [Adj]
#     ∟ mediteranskog Poss
#       mediteranskim Poss
# transbalkanski [Adj]
#     ∟ transbalkanskog Poss
# trenerski [Adj]
#     ∟ trenerskog Poss
# holandski [Adj]
#     ∟ holandskog Poss
#       holandska Poss
#       holandske Poss
# deoničarski [Adj]
#     ∟ deoničarskog Poss
# partenonski [Adj]
#     ∟ partenonskog Poss
# duvanski [Adj]
#     ∟ duvanskog Poss
# indijski [Adj]
#     ∟ indijskog Poss
# pridnjestrovski [Adj]
#     ∟ pridnjestrovskog Poss
# tračanski [Adj]
#     ∟ tračanskog Poss
#       tračansko Poss
# zatvorski [Adj]
#     ∟ zatvorskog Poss
#       zatvorskom Poss
#       zatvorska Poss
#       zatvorske Poss
#       zatvorsku Poss
# aprilski [Adj]
#     ∟ aprilskog Poss
# gradski [Adj]
#     ∟ gradskog Poss
#       gradskoj Poss
# lezbejski [Adj]
#     ∟ lezbejskog Poss
# operski [Adj]
#     ∟ operskom Poss
# pritiski [Adj]
#     ∟ pritiskom Poss
#       pritiska Poss
# radikalski [Adj]
#     ∟ radikalskom Poss
# vojski [Adj]
#     ∟ vojskom Poss
#       vojska Poss
#       vojske Poss
#       vojsku Poss
# atletski [Adj]
#     ∟ atletskom Poss
# austrijski [Adj]
#     ∟ austrijskom Poss
#       austrijska Poss
#       austrijske Poss
# teniski [Adj]
#     ∟ teniskom Poss
# crnomorski [Adj]
#     ∟ crnomorskom Poss
#       crnomorska Poss
#       crnomorske Poss
# februarski [Adj]
#     ∟ februarskom Poss
# skadarski [Adj]
#     ∟ skadarskom Poss
#       skadarsko Poss
# utiski [Adj]
#     ∟ utiskom Poss
# konsultantski [Adj]
#     ∟ konsultantskom Poss
# dvoranski [Adj]
#     ∟ dvoranskom Poss
# manjinski [Adj]
#     ∟ manjinskom Poss
#       manjinskim Poss
#       manjinska Poss
#       manjinske Poss
#       manjinsku Poss
#       manjinskih Poss
#       manjinsko Poss
# polistirenski [Adj]
#     ∟ polistirenskom Poss
# germanski [Adj]
#     ∟ germanskom Poss
# junski [Adj]
#     ∟ junskom Poss
# biometrijski [Adj]
#     ∟ biometrijskom Poss
#       biometrijskim Poss
#       biometrijske Poss
# ilirski [Adj]
#     ∟ ilirskim Poss
# genetski [Adj]
#     ∟ genetskim Poss
# predatorski [Adj]
#     ∟ predatorskim Poss
# rodopski [Adj]
#     ∟ rodopskim Poss
# diktatorski [Adj]
#     ∟ diktatorskim Poss
# tajlandski [Adj]
#     ∟ tajlandskim Poss
# martovski [Adj]
#     ∟ martovskim Poss
#       martovskih Poss
# građanski [Adj]
#     ∟ građanskim Poss
#       građanska Poss
#       građanske Poss
#       građanskoj Poss
#       građanskih Poss
# novembarski [Adj]
#     ∟ novembarskim Poss
# transatlantski [Adj]
#     ∟ transatlantskim Poss
#       transatlantskih Poss
# izvorski [Adj]
#     ∟ izvorskim Poss
# sociodemografski [Adj]
#     ∟ sociodemografskim Poss
# kajmanski [Adj]
#     ∟ kajmanskim Poss
# kišlovski [Adj]
#     ∟ kišlovskim Poss
# pomorski [Adj]
#     ∟ pomorskim Poss
#       pomorska Poss
# kroski [Adj]
#     ∟ kroska Poss
# protivtenkovski [Adj]
#     ∟ protivtenkovska Poss
#       protivtenkovske Poss
# dvotrećinski [Adj]
#     ∟ dvotrećinska Poss
#       dvotrećinsku Poss
# paparoski [Adj]
#     ∟ paparoska Poss
# proročanski [Adj]
#     ∟ proročanska Poss
# izlaski [Adj]
#     ∟ izlaska Poss
#       izlasku Poss
# novinski [Adj]
#     ∟ novinska Poss
#       novinskoj Poss
#       novinskih Poss
# peski [Adj]
#     ∟ peska Poss
# tinejdžerski [Adj]
#     ∟ tinejdžerska Poss
# kinematografski [Adj]
#     ∟ kinematografska Poss
# elektroenergetski [Adj]
#     ∟ elektroenergetska Poss
#       elektroenergetsku Poss
# spiski [Adj]
#     ∟ spiska Poss
# bonski [Adj]
#     ∟ bonska Poss
#       bonskih Poss
# zafirovski [Adj]
#     ∟ zafirovska Poss
# stojkovski [Adj]
#     ∟ stojkovska Poss
# danski [Adj]
#     ∟ danska Poss
#       danskoj Poss
#       dansku Poss
# velinovski [Adj]
#     ∟ velinovska Poss
# imovinski [Adj]
#     ∟ imovinska Poss
#       imovinsku Poss
#       imovinskih Poss
# farmaceutski [Adj]
#     ∟ farmaceutska Poss
#       farmaceutskoj Poss
#       farmaceutskih Poss
# grozdanovski [Adj]
#     ∟ grozdanovska Poss
# disciplinski [Adj]
#     ∟ disciplinska Poss
# prekomorski [Adj]
#     ∟ prekomorska Poss
# elektronski [Adj]
#     ∟ elektronska Poss
#       elektronsku Poss
#       elektronskih Poss
#       elektronsko Poss
# socioekonomski [Adj]
#     ∟ socioekonomska Poss
# štipski [Adj]
#     ∟ štipska Poss
# skopski [Adj]
#     ∟ skopska Poss
# kaspijski [Adj]
#     ∟ kaspijska Poss
# valkanovski [Adj]
#     ∟ valkanovska Poss
# prijateljski [Adj]
#     ∟ prijateljska Poss
#       prijateljske Poss
#       prijateljskih Poss
# ekspertski [Adj]
#     ∟ ekspertska Poss
#       ekspertskih Poss
# zalaski [Adj]
#     ∟ zalaska Poss
# ulaski [Adj]
#     ∟ ulaska Poss
#       ulasku Poss
# panevropski [Adj]
#     ∟ panevropska Poss
# elenovski [Adj]
#     ∟ elenovska Poss
# jevrejski [Adj]
#     ∟ jevrejska Poss
#       jevrejskih Poss
# bavarski [Adj]
#     ∟ bavarska Poss
# jermenski [Adj]
#     ∟ jermenska Poss
# damaski [Adj]
#     ∟ damaska Poss
# autokratski [Adj]
#     ∟ autokratska Poss
# podravski [Adj]
#     ∟ podravska Poss
# vojvođanski [Adj]
#     ∟ vojvođanska Poss
#       vojvođanske Poss
#       vojvođanskih Poss
# floreaski [Adj]
#     ∟ floreaska Poss
# šengenski [Adj]
#     ∟ šengenska Poss
# padinski [Adj]
#     ∟ padinska Poss
# kraljevski [Adj]
#     ∟ kraljevska Poss
# petkovski [Adj]
#     ∟ petkovska Poss
# štamparski [Adj]
#     ∟ štamparske Poss
# snajperski [Adj]
#     ∟ snajperske Poss
# medicinski [Adj]
#     ∟ medicinske Poss
# inženjerski [Adj]
#     ∟ inženjerske Poss
# dablinski [Adj]
#     ∟ dablinske Poss
# makroekonomski [Adj]
#     ∟ makroekonomske Poss
# profesorski [Adj]
#     ∟ profesorske Poss
# dorski [Adj]
#     ∟ dorske Poss
# laserski [Adj]
#     ∟ laserske Poss
# partijski [Adj]
#     ∟ partijske Poss
# registarski [Adj]
#     ∟ registarske Poss
#       registarskih Poss
# tenderski [Adj]
#     ∟ tenderske Poss
#       tendersku Poss
# omladinski [Adj]
#     ∟ omladinske Poss
# školski [Adj]
#     ∟ školske Poss
# topografski [Adj]
#     ∟ topografske Poss
# ljuski [Adj]
#     ∟ ljuske Poss
# božinovski [Adj]
#     ∟ božinovske Poss
# dunavski [Adj]
#     ∟ dunavske Poss
# revizorski [Adj]
#     ∟ revizorske Poss
# postdiplomski [Adj]
#     ∟ postdiplomske Poss
# vašingtonski [Adj]
#     ∟ vašingtonske Poss
# islandski [Adj]
#     ∟ islandske Poss
#       islandsku Poss
# terenski [Adj]
#     ∟ terenske Poss
# aerodromski [Adj]
#     ∟ aerodromske Poss
# demografski [Adj]
#     ∟ demografske Poss
# neprijateljski [Adj]
#     ∟ neprijateljske Poss
# pivarski [Adj]
#     ∟ pivarske Poss
# planinski [Adj]
#     ∟ planinske Poss
# morski [Adj]
#     ∟ morske Poss
#       morsku Poss
#       morskih Poss
# automobilski [Adj]
#     ∟ automobilske Poss
#       automobilsku Poss
# entitetski [Adj]
#     ∟ entitetske Poss
#       entitetskih Poss
# organski [Adj]
#     ∟ organske Poss
# desničarski [Adj]
#     ∟ desničarske Poss
# međuentitetski [Adj]
#     ∟ međuentitetske Poss
# prištinski [Adj]
#     ∟ prištinske Poss
# kompjuterski [Adj]
#     ∟ kompjuterske Poss
#       kompjutersku Poss
#       kompjuterskih Poss
# uski [Adj]
#     ∟ uske Poss
#       usko Poss
# logorski [Adj]
#     ∟ logorske Poss
# preševski [Adj]
#     ∟ preševskoj Poss
# petrovaradinski [Adj]
#     ∟ petrovaradinskoj Poss
# porodiljski [Adj]
#     ∟ porodiljskoj Poss
# latinski [Adj]
#     ∟ latinskoj Poss
# austrougarski [Adj]
#     ∟ austrougarskoj Poss
# egejski [Adj]
#     ∟ egejskoj Poss
# ambasadorski [Adj]
#     ∟ ambasadorskoj Poss
# draguleski [Adj]
#     ∟ dragulesku Poss
# konferencijski [Adj]
#     ∟ konferencijsku Poss
# baseski [Adj]
#     ∟ basesku Poss
# serotoninski [Adj]
#     ∟ serotoninsku Poss
#       serotoninskih Poss
# popeski [Adj]
#     ∟ popesku Poss
# maneski [Adj]
#     ∟ manesku Poss
# franciski [Adj]
#     ∟ francisku Poss
# teokratski [Adj]
#     ∟ teokratsku Poss
# hemijski [Adj]
#     ∟ hemijskih Poss
#       hemijsko Poss
# špediterski [Adj]
#     ∟ špediterskih Poss
# tematski [Adj]
#     ∟ tematskih Poss
# avganistanski [Adj]
#     ∟ avganistanskih Poss
# opštinski [Adj]
#     ∟ opštinskih Poss
# propalestinski [Adj]
#     ∟ propalestinskih Poss
# sapunski [Adj]
#     ∟ sapunskih Poss
# benzinski [Adj]
#     ∟ benzinskih Poss
# autorski [Adj]
#     ∟ autorskih Poss
# nemuslimanski [Adj]
#     ∟ nemuslimanskih Poss
# pionirski [Adj]
#     ∟ pionirskih Poss
# piratski [Adj]
#     ∟ piratskih Poss
# zemaljski [Adj]
#     ∟ zemaljskih Poss
#       zemaljsko Poss
# dobrosusedski [Adj]
#     ∟ dobrosusedskih Poss
# festivalski [Adj]
#     ∟ festivalskih Poss
# šumski [Adj]
#     ∟ šumskih Poss
# obalski [Adj]
#     ∟ obalskih Poss
# seoski [Adj]
#     ∟ seoskih Poss
# istočnoevropski [Adj]
#     ∟ istočnoevropskih Poss
# azijski [Adj]
#     ∟ azijskih Poss
# hrišćanski [Adj]
#     ∟ hrišćanskih Poss
# komunikacijski [Adj]
#     ∟ komunikacijskih Poss
# partnerski [Adj]
#     ∟ partnerskih Poss
# septembarski [Adj]
#     ∟ septembarskih Poss
# rumuski [Adj]
#     ∟ rumuskih Poss
# klupski [Adj]
#     ∟ klupskih Poss
# otomanski [Adj]
#     ∟ otomansko Poss
# uneski [Adj]
#     ∟ unesko Poss
# premijerski [Adj]
#     ∟ premijersko Poss
# kuhinjski [Adj]
#     ∟ kuhinjsko Poss
# postmiloševićevski [Adj]
#     ∟ postmiloševićevsko Poss
# stihijski [Adj]
#     ∟ stihijsko Poss
# teorijski [Adj]
#     ∟ teorijsko Poss
# populistički [Adj]
# nemački [Adj]
#     ∟ nemačkog Poss
#       nemačka Poss
#       nemačkih Poss
#       nemačkim Poss
#       nemačke Poss
#       nemačkoj Poss
#       nemačku Poss
# železnički [Adj]
#     ∟ železnička Poss
#       železničkih Poss
#       železničkim Poss
#       železničke Poss
#       železničkoj Poss
# višestranački [Adj]
#     ∟ višestranačke Poss
#       višestranačku Poss
# etnički [Adj]
#     ∟ etničkog Poss
#       etnička Poss
#       etničkih Poss
#       etničkim Poss
#       etničke Poss
#       etničkoj Poss
#       etničku Poss
# muzički [Adj]
#     ∟ muzičkog Poss
#       muzičkom Poss
#       muzičku Poss
# posmatrački [Adj]
#     ∟ posmatračkog Poss
#       posmatračka Poss
#       posmatračkoj Poss
# pacifički [Adj]
# stranački [Adj]
#     ∟ stranačka Poss
#       stranačkih Poss
#       stranačkim Poss
# ultranacionalistički [Adj]
#     ∟ ultranacionalističkih Poss
#       ultranacionalističke Poss
# slovenački [Adj]
#     ∟ slovenačkom Poss
#       slovenačka Poss
#       slovenačkim Poss
#       slovenačko Poss
# brodovlasnički [Adj]
# irački [Adj]
#     ∟ iračkih Poss
#       iračkim Poss
#       iračkoj Poss
# predsednički [Adj]
#     ∟ predsedničkog Poss
#       predsedničkih Poss
#       predsedničke Poss
#       predsedničku Poss
# turistički [Adj]
#     ∟ turističkog Poss
#       turističkom Poss
#       turistička Poss
#       turističkih Poss
#       turističkoj Poss
# prostački [Adj]
# politički [Adj]
#     ∟ političkog Poss
#       političkom Poss
#       politička Poss
#       političkih Poss
#       političkim Poss
#       političko Poss
#       političke Poss
#       političkoj Poss
#       političku Poss
# zajednički [Adj]
#     ∟ zajedničkog Poss
#       zajedničkom Poss
#       zajednička Poss
#       zajedničkim Poss
#       zajedničko Poss
#       zajedničke Poss
#       zajedničkoj Poss
#       zajedničku Poss
# umetnički [Adj]
#     ∟ umetnička Poss
#       umetničke Poss
#       umetničkoj Poss
# putnički [Adj]
# monopolistički [Adj]
#     ∟ monopolističkih Poss
#       monopolističke Poss
#       monopolističku Poss
# komunistički [Adj]
#     ∟ komunističkog Poss
#       komunističkim Poss
#       komunističke Poss
#       komunističku Poss
# statistički [Adj]
#     ∟ statističkog Poss
#       statističkim Poss
# preduzetnički [Adj]
# tehnički [Adj]
#     ∟ tehničkih Poss
#       tehničkim Poss
#       tehničko Poss
#       tehničke Poss
# međuetnički [Adj]
#     ∟ međuetničkih Poss
# radnički [Adj]
#     ∟ radničke Poss
# grčki [Adj]
#     ∟ grčkog Poss
#       grčkom Poss
#       grčka Poss
#       grčkih Poss
#       grčkim Poss
#       grčko Poss
#       grčke Poss
#       grčkoj Poss
#       grčku Poss
# bošnjački [Adj]
#     ∟ bošnjačkog Poss
#       bošnjačkom Poss
#       bošnjačkih Poss
#       bošnjačke Poss
# ekstremistički [Adj]
#     ∟ ekstremistička Poss
#       ekstremističkih Poss
#       ekstremističke Poss
# teroristički [Adj]
#     ∟ terorističkog Poss
#       teroristička Poss
#       terorističkih Poss
#       terorističkim Poss
#       terorističke Poss
# američki [Adj]
#     ∟ američkog Poss
#       američkom Poss
#       američka Poss
#       američkih Poss
#       američkim Poss
#       američke Poss
#       američku Poss
# pregovarački [Adj]
#     ∟ pregovaračkog Poss
#       pregovaračka Poss
#       pregovaračkih Poss
#       pregovaračku Poss
# severnoafrički [Adj]
#     ∟ severnoafričkog Poss
# čitalački [Adj]
#     ∟ čitalačkog Poss
# srebrenički [Adj]
#     ∟ srebreničkog Poss
#       srebreničkom Poss
# staljinistički [Adj]
#     ∟ staljinističkog Poss
# predstavnički [Adj]
#     ∟ predstavničkog Poss
# fizički [Adj]
#     ∟ fizičkog Poss
#       fizička Poss
#       fizičko Poss
#       fizičke Poss
# predavački [Adj]
#     ∟ predavačkog Poss
#       predavačkih Poss
# poslanički [Adj]
#     ∟ poslaničkog Poss
#       poslaničkih Poss
#       poslaničke Poss
# analitički [Adj]
#     ∟ analitičkog Poss
# geopolitički [Adj]
#     ∟ geopolitičkog Poss
#       geopolitičkom Poss
#       geopolitičkoj Poss
# veštački [Adj]
#     ∟ veštačkog Poss
#       veštačku Poss
# prevoznički [Adj]
#     ∟ prevozničkog Poss
# plivački [Adj]
#     ∟ plivačkom Poss
#       plivačkim Poss
# postkomunistički [Adj]
#     ∟ postkomunističkom Poss
#       postkomunističkih Poss
# nacistički [Adj]
#     ∟ nacističkom Poss
#       nacističkim Poss
#       nacističke Poss
# vlasnički [Adj]
#     ∟ vlasničkom Poss
#       vlasnička Poss
#       vlasničkih Poss
# jezički [Adj]
#     ∟ jezičkom Poss
#       jezičku Poss
# brčki [Adj]
#     ∟ brčkom Poss
# zagrebački [Adj]
#     ∟ zagrebačkom Poss
#       zagrebačke Poss
# ludački [Adj]
#     ∟ ludačka Poss
# osvetnički [Adj]
#     ∟ osvetnička Poss
# pljački [Adj]
#     ∟ pljačka Poss
#       pljačke Poss
# nacionalistički [Adj]
#     ∟ nacionalistička Poss
#       nacionalističke Poss
#       nacionalističku Poss
# borački [Adj]
#     ∟ boračka Poss
# tački [Adj]
#     ∟ tačka Poss
#       tačku Poss
# dugački [Adj]
#     ∟ dugačka Poss
#       dugačke Poss
# socijalistički [Adj]
#     ∟ socijalistička Poss
#       socijalističkih Poss
#       socijalističke Poss
#       socijalističkoj Poss
#       socijalističku Poss
# opljački [Adj]
#     ∟ opljačka Poss
# antiteroristički [Adj]
#     ∟ antiteroristička Poss
#       antiterorističke Poss
# ručki [Adj]
#     ∟ ručka Poss
# antički [Adj]
#     ∟ antičkih Poss
# nedomorodački [Adj]
#     ∟ nedomorodačkih Poss
# etički [Adj]
#     ∟ etičkih Poss
# forenzički [Adj]
#     ∟ forenzičkih Poss
# kriminalistički [Adj]
#     ∟ kriminalističkih Poss
#       kriminalističke Poss
# dužnički [Adj]
#     ∟ dužničkih Poss
# katolički [Adj]
#     ∟ katoličkih Poss
#       katoličke Poss
# protivnički [Adj]
#     ∟ protivničkih Poss
#       protivničke Poss
# afrički [Adj]
#     ∟ afričkih Poss
# glasački [Adj]
#     ∟ glasačkih Poss
#       glasačke Poss
# unutarpolitički [Adj]
#     ∟ unutarpolitičkih Poss
# nasilnički [Adj]
#     ∟ nasilničkih Poss
# lingvistički [Adj]
#     ∟ lingvističkim Poss
# senzacionalistički [Adj]
#     ∟ senzacionalističkim Poss
#       senzacionalističke Poss
# vozački [Adj]
#     ∟ vozačkim Poss
# seizmički [Adj]
#     ∟ seizmičkim Poss
# birački [Adj]
#     ∟ biračko Poss
# multietnički [Adj]
#     ∟ multietničko Poss
# narkotički [Adj]
#     ∟ narkotičko Poss
# informatički [Adj]
#     ∟ informatičko Poss
# zaključki [Adj]
#     ∟ zaključke Poss
# dijagnostički [Adj]
#     ∟ dijagnostičke Poss
# kukavički [Adj]
#     ∟ kukavičke Poss
# sandžački [Adj]
#     ∟ sandžačke Poss
# igrački [Adj]
#     ∟ igračke Poss
# borilački [Adj]
#     ∟ borilačke Poss
# oslobodilački [Adj]
#     ∟ oslobodilačke Poss
# oportunistički [Adj]
#     ∟ oportunističke Poss
# aktivistički [Adj]
#     ∟ aktivističke Poss
# rasistički [Adj]
#     ∟ rasističke Poss
# glumački [Adj]
#     ∟ glumačke Poss
#       glumačku Poss
# bečki [Adj]
#     ∟ bečkoj Poss
# riječki [Adj]
#     ∟ riječkoj Poss
# optuženički [Adj]
#     ∟ optuženičkoj Poss
# bački [Adj]
#     ∟ bačku Poss
# lučki [Adj]
#     ∟ lučku Poss
# uređivački [Adj]
#     ∟ uređivačku Poss
# antikomunistički [Adj]
#     ∟ antikomunističku Poss
# državnički [Adj]
#     ∟ državničku Poss
# češki [Adj]
#     ∟ češka Poss
#       češke Poss
# muški [Adj]
#     ∟ muškom Poss
#       muška Poss
#       muških Poss
#       muške Poss
#       muškoj Poss
#       mušku Poss
# tehnološki [Adj]
#     ∟ tehnološkog Poss
#       tehnološkim Poss
#       tehnološke Poss
# ideološki [Adj]
#     ∟ ideološko Poss
#       ideološke Poss
# njujorški [Adj]
# bombaški [Adj]
#     ∟ bombaškog Poss
#       bombaškom Poss
#       bombaških Poss
# malteški [Adj]
# norveški [Adj]
#     ∟ norveške Poss
# strateški [Adj]
#     ∟ strateškog Poss
#       strateška Poss
#       strateškim Poss
#       strateško Poss
#       strateške Poss
# haški [Adj]
#     ∟ haškim Poss
# zoološki [Adj]
#     ∟ zoološkog Poss
# luksemburški [Adj]
# pedagoški [Adj]
#     ∟ pedagoškog Poss
# kriminološki [Adj]
#     ∟ kriminološkog Poss
# teški [Adj]
#     ∟ teškog Poss
#       teška Poss
#       teških Poss
#       teškim Poss
#       teško Poss
#       teške Poss
#       teškoj Poss
#       tešku Poss
# imunološki [Adj]
#     ∟ imunološkog Poss
# skijaški [Adj]
#     ∟ skijaškog Poss
# demagoški [Adj]
#     ∟ demagoškog Poss
# helsinški [Adj]
#     ∟ helsinškog Poss
# podrški [Adj]
#     ∟ podrškom Poss
#       podrška Poss
#       podrške Poss
#       podršku Poss
# graški [Adj]
#     ∟ graška Poss
# đumiški [Adj]
#     ∟ đumiška Poss
# košarkaški [Adj]
#     ∟ košarkaška Poss
# ruški [Adj]
#     ∟ ruška Poss
# seizmološki [Adj]
#     ∟ seizmoloških Poss
# ekološki [Adj]
#     ∟ ekoloških Poss
#       ekološkim Poss
# mafijaški [Adj]
#     ∟ mafijaškim Poss
#       mafijaške Poss
# psihološki [Adj]
#     ∟ psihološko Poss
#       psihološke Poss
# duški [Adj]
#     ∟ duško Poss
# puški [Adj]
#     ∟ puške Poss
# arheološki [Adj]
#     ∟ arheološke Poss
#       arheološkoj Poss
#       arheološku Poss
# antimafijaški [Adj]
#     ∟ antimafijaške Poss
# greški [Adj]
#     ∟ greške Poss
# bukureški [Adj]
#     ∟ bukureške Poss
# ćoški [Adj]
#     ∟ ćošku Poss

# %%
export_lexicon("lexicon.txt")
