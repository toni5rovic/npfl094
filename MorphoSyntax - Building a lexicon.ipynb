# %%
import string
import pandas as pd

# %%
train_file = './data/sr_set-ud-train.conllu'
test_file = './data/sr_set-ud-test.conllu'
dev_file = './data/sr_set-ud-dev.conllu'

# %%
lines = []
with open(train_file, 'r', encoding='utf-8') as f:
    lines = f.readlines()
with open(test_file, 'r', encoding='utf-8') as f:
    lines.extend(f.readlines())
with open(dev_file, 'r', encoding='utf-8') as f:
    lines.extend(f.readlines())

# %%
open_class_tags = ['ADJ', 'ADV', 'INTJ', 'NOUN', 'PROPN', 'VERB']

# %%
ud_content = []
for line in lines:
    if len(line) == 1:
        continue
    if line.startswith("#"):
        continue
    
    parts = line.split('\t') 
    word = parts[1]
    pos_tag = parts[3]
    if pos_tag not in open_class_tags:
        continue
    ud_content.append(word)

# %%
len(ud_content)
# Out:
# 54632

# %% [markdown]
# # Preprocessing

# %% [markdown]
# All words are converted to lowercase.

# %%
ud_content = [word.lower() for word in ud_content]

# %% [markdown]
# Everything that contains digits and punctuation is removed.

# %%
ud_content = [word for word in ud_content if all(not c.isdigit() and c not in string.punctuation for c in word)]

# %%
data = pd.Series(ud_content)
data_freqs = data.value_counts()
data_freqs[:20]
# Out:
# rekao         332
# godine        279
# eu            261
# takođe        166
# bih           151
# kada          141
# kaže          132
# zemlje        131
# kosova        128
# međutim       126
# samo          120
# evra          117
# još           117
# srbije        110
# izjavio       107
# trebalo       107
# predsednik    106
# odsto          99
# više           98
# ministar       94
# dtype: int64

# %% [markdown]
# # Lexicon structure

# %% [markdown]
# Lexicon will be represented as a structure which consists of lemma (the base form), its tag and a list of the derived forms.
# Each derived form consits of the form itself and its tag.

# %%
class LexiconEntry:
    def __init__(self, lemma, tag):
        self.lemma = lemma
        self.tag = tag
        self.derived_forms = []

# %%
lexicon = []

# %% [markdown]
# Defining useful functions:

# %%
def print_lexicon():
    for lexicon_entry in lexicon:
        lemma = lexicon_entry.lemma
        tag = lexicon_entry.tag

        print("{} [{}]".format(lemma, tag))
        if len(lexicon_entry.derived_forms) == 0:
            continue
        for idx, derived_form_entry in enumerate(lexicon_entry.derived_forms):
            derived_form, derived_form_info = derived_form_entry
            
            if idx == 0:
                print("    ∟ {} {}".format(derived_form, derived_form_info))
            else:
                print("      {} {}".format(derived_form, derived_form_info))

# %%
def add_to_lexicon(lemma, base_tag, derived_forms = []):
    global ud_content
    lexicon_entry = LexiconEntry(lemma, base_tag)
    for lex in lexicon:
        if lex.lemma == lemma and lex.tag == base_tag:
            return
    
    ud_content = [word for word in ud_content if word != lemma]

    for der_form in derived_forms:
        lexicon_entry.derived_forms.append(der_form)
    lexicon.append(lexicon_entry)
    
    derived_forms_words = [w[0] for w in derived_forms]
    ud_content = [word for word in ud_content if word not in derived_forms_words]

# %%
def get_lexicon_entry(lemma, tag):
    for lex_entry in lexicon:
        if lex_entry.lemma == lemma and lex_entry.tag == tag:
            return lex_entry
        
    return None

# %% [markdown]
# Let's start with the most distinctive suffixes, which can be easily be observed

# %% [markdown]
# # 1. Verbs

# %% [markdown]
# ## 1.1 Infinitive
#
# All verbs in Serbian end with: *-ti* or *-ći*

# %%
infinitive_verbs_ITI = list(set([w for w in ud_content if w.endswith('iti')]))

# %%
infinitive_verbs_ITI
# Out:
# ['rušiti',
#  'zamisliti',
#  'pretpostaviti',
#  'raditi',
#  'odstupiti',
#  'otvoriti',
#  'izvršiti',
#  'otkriti',
#  'iznositi',
#  'ograničiti',
#  'tražiti',
#  'obilaziti',
#  'odvratiti',
#  'dozvoliti',
#  'razrešiti',
#  'proceniti',
#  'uhvatiti',
#  'povrediti',
#  'obaviti',
#  'izraditi',
#  'protiviti',
#  'kazniti',
#  'štiti',
#  'slediti',
#  'pružiti',
#  'nastaviti',
#  'složiti',
#  'posvetiti',
#  'pridružiti',
#  'odrediti',
#  'osetiti',
#  'razvodniti',
#  'obezbediti',
#  'uskladiti',
#  'vlastiti',
#  'otkloniti',
#  'proučiti',
#  'nastupiti',
#  'skladištiti',
#  'nadoknaditi',
#  'rešiti',
#  'uraditi',
#  'ohrabriti',
#  'zaštititi',
#  'odbaciti',
#  'uništiti',
#  'zanemariti',
#  'potrošiti',
#  'nuditi',
#  'vratiti',
#  'ustanoviti',
#  'iskoristiti',
#  'desiti',
#  'završiti',
#  'predstaviti',
#  'suočiti',
#  'opslužiti',
#  'zatražiti',
#  'izgraditi',
#  'ugroziti',
#  'napraviti',
#  'dobiti',
#  'preporučiti',
#  'odobriti',
#  'proširiti',
#  'zaključiti',
#  'namestiti',
#  'izmeniti',
#  'potvrditi',
#  'posetiti',
#  'podnositi',
#  'dogoditi',
#  'usredsrediti',
#  'voditi',
#  'ponuditi',
#  'odgovoriti',
#  'pratiti',
#  'pojaviti',
#  'povratiti',
#  'uspostaviti',
#  'razotkriti',
#  'predložiti',
#  'deliti',
#  'koristiti',
#  'značiti',
#  'uočiti',
#  'staviti',
#  'otpustiti',
#  'promeniti',
#  'smanjiti',
#  'ostvariti',
#  'govoriti',
#  'naslediti',
#  'ostaviti',
#  'krediti',
#  'zaposliti',
#  'osuditi',
#  'smisliti',
#  'udružiti',
#  'razdvojiti',
#  'zaštiti',
#  'otplatiti',
#  'oprostiti',
#  'unaprediti',
#  'uložiti',
#  'shvatiti',
#  'pustiti',
#  'učiti',
#  'prihvatiti',
#  'primiti',
#  'odnositi',
#  'umoriti',
#  'prenositi',
#  'zavisiti',
#  'udvostručiti',
#  'patiti',
#  'snositi',
#  'postaviti',
#  'obnoviti',
#  'kupiti',
#  'razmotriti',
#  'zameniti',
#  'poslužiti',
#  'sprečiti',
#  'pripremiti',
#  'protumačiti',
#  'arvaniti',
#  'različiti',
#  'napustiti',
#  'ponoviti',
#  'izmisliti',
#  'usuditi',
#  'učiniti',
#  'izgubiti',
#  'pristupiti',
#  'omogućiti',
#  'preurediti',
#  'uslediti',
#  'ispuniti',
#  'rijaliti',
#  'sprovoditi',
#  'stvoriti',
#  'težiti',
#  'unakaziti']

# %%
for inf_verb in infinitive_verbs_ITI:
    add_to_lexicon(inf_verb, 'VERB')

# %%
len(ud_content)
# Out:
# 53283

# %%
infinitive_verbs_ETI = list(set([w for w in ud_content if w.endswith('eti')]))

# %%
infinitive_verbs_ETI
# Out:
# ['doneti',
#  'početi',
#  'aveti',
#  'videti',
#  'započeti',
#  'predvideti',
#  'oseti',
#  'uspeti',
#  'tereti',
#  'anketi',
#  'uzeti',
#  'preneti',
#  'fakulteti',
#  'našteti',
#  'ćančeti',
#  'deveti',
#  'preduzeti',
#  'univerziteti',
#  'razumeti',
#  'dijeti',
#  'peti',
#  'oteti',
#  'animoziteti',
#  'dopreti',
#  'posveti',
#  'doprineti',
#  'predmeti',
#  'antikviteti',
#  'preoteti',
#  'meti',
#  'ahmeti',
#  'preti',
#  'oživeti',
#  'poseti',
#  'preuzeti',
#  'podneti']

# %%
for inf_verb in infinitive_verbs_ETI:
    add_to_lexicon(inf_verb, 'VERB')

# %%
infinitive_verbs_ATI = list(set([w for w in ud_content if w.endswith('ati')]))

# %%
infinitive_verbs_ATI
# Out:
# ['menjati',
#  'pati',
#  'očekivati',
#  'izabrati',
#  'obavljati',
#  'vraćati',
#  'pozvati',
#  'održavati',
#  'omogućavati',
#  'hrvati',
#  'učestvovati',
#  'falsifikovati',
#  'prestati',
#  'sećati',
#  'izdavati',
#  'zapošljavati',
#  'organizovati',
#  'postavljati',
#  'aktivirati',
#  'plaćati',
#  'razvijati',
#  'razmenjivati',
#  'imati',
#  'zadržati',
#  'postupati',
#  'uticati',
#  'sati',
#  'preispitati',
#  'povećati',
#  'preduzimati',
#  'klati',
#  'insistirati',
#  'slati',
#  'odavati',
#  'oslanjati',
#  'advokati',
#  'ispričati',
#  'reagovati',
#  'intervenisati',
#  'odvijati',
#  'razrešavati',
#  'rešavati',
#  'uhvati',
#  'posmatrati',
#  'pokušavati',
#  'pregovarati',
#  'analizirati',
#  'sarađivati',
#  'povezati',
#  'koštati',
#  'držati',
#  'funkcionisati',
#  'prebacivati',
#  'pojačati',
#  'pridržavati',
#  'glasati',
#  'garantovati',
#  'pokušati',
#  'izazvati',
#  'trajati',
#  'povrati',
#  'dočekivati',
#  'bogati',
#  'blokirati',
#  'sindikati',
#  'dati',
#  'fokusirati',
#  'verovati',
#  'rezultati',
#  'finansirati',
#  'prisustvovati',
#  'suspendovati',
#  'smatrati',
#  'pružati',
#  'prikazati',
#  'postati',
#  'oklevati',
#  'delati',
#  'definisati',
#  'plakati',
#  'mati',
#  'zapitati',
#  'zloupotrebljavati',
#  'modelirati',
#  'nadmetati',
#  'poboljšati',
#  'poslati',
#  'zaletati',
#  'doputovati',
#  'dobijati',
#  'apstinirati',
#  'zvati',
#  'okončati',
#  'predstavljati',
#  'požurivati',
#  'pokazati',
#  'zalagati',
#  'otputovati',
#  'poznati',
#  'prihvati',
#  'zahtevati',
#  'palati',
#  'nadati',
#  'vrati',
#  'kopirati',
#  'dokazati',
#  'ojačati',
#  'putovati',
#  'investirati',
#  'igrati',
#  'poštovati',
#  'bušati',
#  'zarađivati',
#  'prepoznati',
#  'sastati',
#  'olakšati',
#  'postojati',
#  'izolovati',
#  'ratifikovati',
#  'morati',
#  'izražavati',
#  'kandidati',
#  'podržati',
#  'ometati',
#  'predati',
#  'ostati',
#  'plati',
#  'sačuvati',
#  'cenjkati',
#  'primenjivati',
#  'pisati',
#  'artikulisati',
#  'ticati',
#  'održati',
#  'objavljivati',
#  'pervati',
#  'prati',
#  'intenzivirati',
#  'pridati',
#  'osećati',
#  'raspravljati',
#  'isplati',
#  'stajati',
#  'razgovarati',
#  'uključivati',
#  'nemati',
#  'pozivati',
#  'obraćati',
#  'smanjivati',
#  'zamišljati',
#  'obrati',
#  'birati',
#  'potpisati',
#  'izdati',
#  'priznati',
#  'uračunati']

# %%
for inf_verb in infinitive_verbs_ATI:
    add_to_lexicon(inf_verb, 'VERB')

# %% [markdown]
# ### 1.2 Past participle
#
# Ending with: *-vši*

# %%
past_participle_VSI = list(set([w for w in ud_content if w.endswith('vši')]))
print(past_participle_VSI)
# Out:
# ['učinivši', 'zabeleživši', 'dostigavši', 'izazvavši', 'zamenivši', 'pohvalivši', 'naslutivši', 'završivši', 'postavivši', 'pretvorivši', 'uzdrmavši', 'dobivši', 'proširivši', 'bivši', 'rekavši', 'primetivši', 'počevši', 'osvojivši', 'ponovivši', 'pobedivši']

# %%
for pp_VSI in past_participle_VSI:
    add_to_lexicon(pp_VSI, 'VERB')

# %% [markdown]
# ### 1.3 Present participle
#
# Ending with: *-jući*

# %%
def add_to_baseform(derived_form, derived_form_info, tag, src_replace, dst_replace):
    for lexicon_entry in lexicon:
        if lexicon_entry.lemma == derived_form.replace(src_replace, dst_replace) and lexicon_entry.tag == tag:
            lexicon_entry.derived_forms.append((derived_form, derived_form_info))
            return
    
    lemma = derived_form.replace(src_replace, dst_replace)
    derived_forms = [(derived_form, derived_form_info)]
    add_to_lexicon(lemma, tag, derived_forms)

# %%
present_participle_JUCI = list(set([w for w in ud_content if w.endswith('jući')]))

for pp in present_participle_JUCI:
    if pp.endswith('ajući'):
        add_to_baseform(pp, "PRESENT_PAT", "VERB", "ajući", "ati")

    elif pp.endswith('ujući'):
        add_to_baseform(pp, "PRESENT_PAT", "VERB", "ujući", "ovati")

# %%
present_participle_JUCI
# Out:
# ['nazivajući',
#  'znajući',
#  'izdvajajući',
#  'čitajući',
#  'uzrokujući',
#  'predsedavajući',
#  'omogućavajući',
#  'zahvaljujući',
#  'dajući',
#  'otvarajući',
#  'obeležavajući',
#  'završavajući',
#  'preneražavajući',
#  'napominjući',
#  'pojavljujući',
#  'obećavajući',
#  'nedostajući',
#  'preduzimajući',
#  'primoravajući',
#  'potiskujući',
#  'prezajući',
#  'zbunjujući',
#  'zbližavajući',
#  'zatvarajući',
#  'tragajući',
#  'opisujući',
#  'favorizujući',
#  'oslobađajući',
#  'ažurirajući',
#  'otuđujući',
#  'sprečavajući',
#  'optužujući',
#  'upozoravajući',
#  'igrajući',
#  'obraćajući',
#  'ponavljajući',
#  'uključujući',
#  'pozivajući',
#  'savetujući',
#  'najavljujući',
#  'okončavajući',
#  'odbijajući',
#  'naglašavajući',
#  'pozdravljajući',
#  'dodajući',
#  'bacajući',
#  'suočavajući',
#  'zahtevajući',
#  'diskreditujući',
#  'prodajući',
#  'saopštavajući',
#  'opstruirajući',
#  'podsećajući',
#  'predstavljajući',
#  'ubacujući',
#  'uveravajući',
#  'emigrirajući',
#  'imajući',
#  'postavljajući',
#  'insistirajući',
#  'kritikujući',
#  'narastajući',
#  'ukazujući',
#  'svrstavajući',
#  'pretvarajući',
#  'potvrđujući',
#  'čekajući',
#  'izražavajući',
#  'primajući',
#  'obavljajući',
#  'ohrabrujući',
#  'odgovarajući',
#  'protestujući',
#  'objašnjavajući',
#  'osuđujući']

# %% [markdown]
# Another type of suffix of present participle form is *-eći*, but it can be mixed with infinitive form.

# %%
suffix_ECI = list(set([w for w in ud_content if w.endswith('eći')]))

# %%
suffix_ECI
# Out:
# ['izlazeći',
#  'veći',
#  'tražeći',
#  'paleći',
#  'tvrdeći',
#  'donoseći',
#  'steći',
#  'najveći',
#  'odlazeći',
#  'sudeći',
#  'navodeći',
#  'doprinoseći',
#  'sledeći',
#  'baveći',
#  'preći',
#  'važeći',
#  'deleći',
#  'kršeći',
#  'postojeći',
#  'predstojeći',
#  'beležeći',
#  'govoreći',
#  'nesreći',
#  'reći',
#  'preseći',
#  'koristeći',
#  'trudeći',
#  'poreći',
#  'misleći',
#  'treći']

# %% [markdown]
# # 2. Adjectives

# %% [markdown]
# ## 2.1 Comparative
#
# Suffixes:
# - Singular: *-niji (m.), -nija (f.), -nije (n.)*
# - Plural: *-nijim

# %%
comparative_forms = [w for w in ud_content if w.endswith('niji') or w.endswith('nija') or w.endswith('nije') or w.endswith('nijim')]
comparative_forms = [w for w in comparative_forms if not w.startswith('naj')]
comparative_forms = list(set(comparative_forms))

# %%
comparative_forms
# Out:
# ['sloveniji',
#  'beskompromisniji',
#  'uticajniji',
#  'linija',
#  'kompleksnija',
#  'kompaniji',
#  'estonije',
#  'slovenije',
#  'opasnijim',
#  'važnija',
#  'čečeniji',
#  'decenije',
#  'očigledniji',
#  'transparentnijim',
#  'tačnije',
#  'španiji',
#  'urgentniji',
#  'docnije',
#  'aktivnije',
#  'makedonija',
#  'uniji',
#  'britanija',
#  'precizniji',
#  'alianija',
#  'makedonije',
#  'rumuniji',
#  'represivniji',
#  'ceremoniji',
#  'litvanije',
#  'apolonija',
#  'slobodniji',
#  'unije',
#  'značajnije',
#  'važnije',
#  'jeftinije',
#  'demokratičnija',
#  'konkurentnija',
#  'svestranije',
#  'ranijim',
#  'važniji',
#  'unija',
#  'sigurnije',
#  'letonije',
#  'potpunije',
#  'makedoniji',
#  'menija',
#  'pensilvaniji',
#  'rumunija',
#  'ozbiljniji',
#  'ranije',
#  'britanije',
#  'efikasniji',
#  'zainteresovanija',
#  'rasprostranjenija',
#  'albanije',
#  'kompanije',
#  'bezbedniji',
#  'pozitivniji',
#  'konkretnije',
#  'efikasnija',
#  'britaniji',
#  'jevtinijim',
#  'decenija',
#  'ceremonije',
#  'kompanija',
#  'snažnije',
#  'optimalnije',
#  'albanija',
#  'sigurnija',
#  'izraženijim',
#  'španija',
#  'nezadovoljniji',
#  'kolonija',
#  'linije',
#  'iskusnijim',
#  'optimističniji',
#  'značajniji',
#  'moćniji',
#  'striktnije',
#  'albaniji',
#  'telefonije',
#  'rasprostranjeniji',
#  'slovenija',
#  'diversifikovanija',
#  'liniji',
#  'ceremonija',
#  'kasnije',
#  'rumunije',
#  'španije',
#  'siromašnije']

# %% [markdown]
# We will build positive forms of the comparative forms:
#
# -niji $\rightarrow$ -an
#
# -nija $\rightarrow$ -na
#
# -nije $\rightarrow$ -no
#
# -nijim $\rightarrow$ -an
#     - there's no way of knowing if the comparative form is supposed to be in masculine, feminine or neutral form, so here it is deliberately chosen that the masculine form will be the base form

# %%
for comparative in comparative_forms:
    positive_lexicon_form = None
    if comparative.endswith("niji"):
        positive = comparative.replace("niji", "an")
        positive_lexicon_form = (comparative, 'COMP-M-SG')
    if comparative.endswith("nija"):
        positive = comparative.replace("nija", "na")
        positive_lexicon_form = (comparative, 'COMP-F-SG')
    if comparative.endswith("nije"):
        positive = comparative.replace("nije", "no")
        positive_lexicon_form = (comparative, 'COMP-N-SG')
    if comparative.endswith("nijim"):
        positive = comparative.replace("nijim", "an")
        positive_lexicon_form = (comparative, 'COMP-M-PL')
    
    add_to_lexicon(positive, 'ADJ', [positive_lexicon_form])

# %%
print_lexicon()
# Out:
# rušiti [VERB]
# zamisliti [VERB]
# pretpostaviti [VERB]
# raditi [VERB]
# odstupiti [VERB]
# otvoriti [VERB]
# izvršiti [VERB]
# otkriti [VERB]
# iznositi [VERB]
# ograničiti [VERB]
# tražiti [VERB]
# obilaziti [VERB]
# odvratiti [VERB]
# dozvoliti [VERB]
# razrešiti [VERB]
# proceniti [VERB]
# uhvatiti [VERB]
# povrediti [VERB]
# obaviti [VERB]
# izraditi [VERB]
# protiviti [VERB]
# kazniti [VERB]
# štiti [VERB]
# slediti [VERB]
# pružiti [VERB]
# nastaviti [VERB]
# složiti [VERB]
# posvetiti [VERB]
# pridružiti [VERB]
# odrediti [VERB]
# osetiti [VERB]
# razvodniti [VERB]
# obezbediti [VERB]
# uskladiti [VERB]
# vlastiti [VERB]
# otkloniti [VERB]
# proučiti [VERB]
# nastupiti [VERB]
# skladištiti [VERB]
# nadoknaditi [VERB]
# rešiti [VERB]
# uraditi [VERB]
# ohrabriti [VERB]
# zaštititi [VERB]
# odbaciti [VERB]
# uništiti [VERB]
# zanemariti [VERB]
# potrošiti [VERB]
# nuditi [VERB]
# vratiti [VERB]
# ustanoviti [VERB]
# iskoristiti [VERB]
# desiti [VERB]
# završiti [VERB]
# predstaviti [VERB]
# suočiti [VERB]
# opslužiti [VERB]
# zatražiti [VERB]
# izgraditi [VERB]
# ugroziti [VERB]
# napraviti [VERB]
# dobiti [VERB]
# preporučiti [VERB]
# odobriti [VERB]
# proširiti [VERB]
# zaključiti [VERB]
# namestiti [VERB]
# izmeniti [VERB]
# potvrditi [VERB]
# posetiti [VERB]
# podnositi [VERB]
# dogoditi [VERB]
# usredsrediti [VERB]
# voditi [VERB]
# ponuditi [VERB]
# odgovoriti [VERB]
# pratiti [VERB]
# pojaviti [VERB]
# povratiti [VERB]
# uspostaviti [VERB]
# razotkriti [VERB]
# predložiti [VERB]
# deliti [VERB]
# koristiti [VERB]
# značiti [VERB]
# uočiti [VERB]
# staviti [VERB]
# otpustiti [VERB]
# promeniti [VERB]
# smanjiti [VERB]
# ostvariti [VERB]
# govoriti [VERB]
# naslediti [VERB]
# ostaviti [VERB]
# krediti [VERB]
# zaposliti [VERB]
# osuditi [VERB]
# smisliti [VERB]
# udružiti [VERB]
# razdvojiti [VERB]
# zaštiti [VERB]
# otplatiti [VERB]
# oprostiti [VERB]
# unaprediti [VERB]
# uložiti [VERB]
# shvatiti [VERB]
# pustiti [VERB]
# učiti [VERB]
# prihvatiti [VERB]
# primiti [VERB]
# odnositi [VERB]
# umoriti [VERB]
# prenositi [VERB]
# zavisiti [VERB]
# udvostručiti [VERB]
# patiti [VERB]
# snositi [VERB]
# postaviti [VERB]
# obnoviti [VERB]
# kupiti [VERB]
# razmotriti [VERB]
# zameniti [VERB]
# poslužiti [VERB]
# sprečiti [VERB]
# pripremiti [VERB]
# protumačiti [VERB]
# arvaniti [VERB]
# različiti [VERB]
# napustiti [VERB]
# ponoviti [VERB]
# izmisliti [VERB]
# usuditi [VERB]
# učiniti [VERB]
# izgubiti [VERB]
# pristupiti [VERB]
# omogućiti [VERB]
# preurediti [VERB]
# uslediti [VERB]
# ispuniti [VERB]
# rijaliti [VERB]
# sprovoditi [VERB]
# stvoriti [VERB]
# težiti [VERB]
# unakaziti [VERB]
# doneti [VERB]
# početi [VERB]
# aveti [VERB]
# videti [VERB]
# započeti [VERB]
# predvideti [VERB]
# oseti [VERB]
# uspeti [VERB]
# tereti [VERB]
# anketi [VERB]
# uzeti [VERB]
# preneti [VERB]
# fakulteti [VERB]
# našteti [VERB]
# ćančeti [VERB]
# deveti [VERB]
# preduzeti [VERB]
# univerziteti [VERB]
# razumeti [VERB]
# dijeti [VERB]
# peti [VERB]
# oteti [VERB]
# animoziteti [VERB]
# dopreti [VERB]
# posveti [VERB]
# doprineti [VERB]
# predmeti [VERB]
# antikviteti [VERB]
# preoteti [VERB]
# meti [VERB]
# ahmeti [VERB]
# preti [VERB]
# oživeti [VERB]
# poseti [VERB]
# preuzeti [VERB]
# podneti [VERB]
# menjati [VERB]
# pati [VERB]
# očekivati [VERB]
# izabrati [VERB]
# obavljati [VERB]
#     ∟ obavljajući PRESENT_PAT
# vraćati [VERB]
# pozvati [VERB]
# održavati [VERB]
# omogućavati [VERB]
#     ∟ omogućavajući PRESENT_PAT
# hrvati [VERB]
# učestvovati [VERB]
# falsifikovati [VERB]
# prestati [VERB]
# sećati [VERB]
# izdavati [VERB]
# zapošljavati [VERB]
# organizovati [VERB]
# postavljati [VERB]
#     ∟ postavljajući PRESENT_PAT
# aktivirati [VERB]
# plaćati [VERB]
# razvijati [VERB]
# razmenjivati [VERB]
# imati [VERB]
#     ∟ imajući PRESENT_PAT
# zadržati [VERB]
# postupati [VERB]
# uticati [VERB]
# sati [VERB]
# preispitati [VERB]
# povećati [VERB]
# preduzimati [VERB]
#     ∟ preduzimajući PRESENT_PAT
# klati [VERB]
# insistirati [VERB]
#     ∟ insistirajući PRESENT_PAT
# slati [VERB]
# odavati [VERB]
# oslanjati [VERB]
# advokati [VERB]
# ispričati [VERB]
# reagovati [VERB]
# intervenisati [VERB]
# odvijati [VERB]
# razrešavati [VERB]
# rešavati [VERB]
# uhvati [VERB]
# posmatrati [VERB]
# pokušavati [VERB]
# pregovarati [VERB]
# analizirati [VERB]
# sarađivati [VERB]
# povezati [VERB]
# koštati [VERB]
# držati [VERB]
# funkcionisati [VERB]
# prebacivati [VERB]
# pojačati [VERB]
# pridržavati [VERB]
# glasati [VERB]
# garantovati [VERB]
# pokušati [VERB]
# izazvati [VERB]
# trajati [VERB]
# povrati [VERB]
# dočekivati [VERB]
# bogati [VERB]
# blokirati [VERB]
# sindikati [VERB]
# dati [VERB]
#     ∟ dajući PRESENT_PAT
# fokusirati [VERB]
# verovati [VERB]
# rezultati [VERB]
# finansirati [VERB]
# prisustvovati [VERB]
# suspendovati [VERB]
# smatrati [VERB]
# pružati [VERB]
# prikazati [VERB]
# postati [VERB]
# oklevati [VERB]
# delati [VERB]
# definisati [VERB]
# plakati [VERB]
# mati [VERB]
# zapitati [VERB]
# zloupotrebljavati [VERB]
# modelirati [VERB]
# nadmetati [VERB]
# poboljšati [VERB]
# poslati [VERB]
# zaletati [VERB]
# doputovati [VERB]
# dobijati [VERB]
# apstinirati [VERB]
# zvati [VERB]
# okončati [VERB]
# predstavljati [VERB]
#     ∟ predstavljajući PRESENT_PAT
# požurivati [VERB]
# pokazati [VERB]
# zalagati [VERB]
# otputovati [VERB]
# poznati [VERB]
# prihvati [VERB]
# zahtevati [VERB]
#     ∟ zahtevajući PRESENT_PAT
# palati [VERB]
# nadati [VERB]
# vrati [VERB]
# kopirati [VERB]
# dokazati [VERB]
# ojačati [VERB]
# putovati [VERB]
# investirati [VERB]
# igrati [VERB]
#     ∟ igrajući PRESENT_PAT
# poštovati [VERB]
# bušati [VERB]
# zarađivati [VERB]
# prepoznati [VERB]
# sastati [VERB]
# olakšati [VERB]
# postojati [VERB]
# izolovati [VERB]
# ratifikovati [VERB]
# morati [VERB]
# izražavati [VERB]
#     ∟ izražavajući PRESENT_PAT
# kandidati [VERB]
# podržati [VERB]
# ometati [VERB]
# predati [VERB]
# ostati [VERB]
# plati [VERB]
# sačuvati [VERB]
# cenjkati [VERB]
# primenjivati [VERB]
# pisati [VERB]
# artikulisati [VERB]
# ticati [VERB]
# održati [VERB]
# objavljivati [VERB]
# pervati [VERB]
# prati [VERB]
# intenzivirati [VERB]
# pridati [VERB]
# osećati [VERB]
# raspravljati [VERB]
# isplati [VERB]
# stajati [VERB]
# razgovarati [VERB]
# uključivati [VERB]
# nemati [VERB]
# pozivati [VERB]
#     ∟ pozivajući PRESENT_PAT
# obraćati [VERB]
#     ∟ obraćajući PRESENT_PAT
# smanjivati [VERB]
# zamišljati [VERB]
# obrati [VERB]
# birati [VERB]
# potpisati [VERB]
# izdati [VERB]
# priznati [VERB]
# uračunati [VERB]
# učinivši [VERB]
# zabeleživši [VERB]
# dostigavši [VERB]
# izazvavši [VERB]
# zamenivši [VERB]
# pohvalivši [VERB]
# naslutivši [VERB]
# završivši [VERB]
# postavivši [VERB]
# pretvorivši [VERB]
# uzdrmavši [VERB]
# dobivši [VERB]
# proširivši [VERB]
# bivši [VERB]
# rekavši [VERB]
# primetivši [VERB]
# počevši [VERB]
# osvojivši [VERB]
# ponovivši [VERB]
# pobedivši [VERB]
# nazivati [VERB]
#     ∟ nazivajući PRESENT_PAT
# znati [VERB]
#     ∟ znajući PRESENT_PAT
# izdvajati [VERB]
#     ∟ izdvajajući PRESENT_PAT
# čitati [VERB]
#     ∟ čitajući PRESENT_PAT
# uzrokovati [VERB]
#     ∟ uzrokujući PRESENT_PAT
# predsedavati [VERB]
#     ∟ predsedavajući PRESENT_PAT
# zahvaljovati [VERB]
#     ∟ zahvaljujući PRESENT_PAT
# otvarati [VERB]
#     ∟ otvarajući PRESENT_PAT
# obeležavati [VERB]
#     ∟ obeležavajući PRESENT_PAT
# završavati [VERB]
#     ∟ završavajući PRESENT_PAT
# preneražavati [VERB]
#     ∟ preneražavajući PRESENT_PAT
# pojavljovati [VERB]
#     ∟ pojavljujući PRESENT_PAT
# obećavati [VERB]
#     ∟ obećavajući PRESENT_PAT
# nedostati [VERB]
#     ∟ nedostajući PRESENT_PAT
# primoravati [VERB]
#     ∟ primoravajući PRESENT_PAT
# potiskovati [VERB]
#     ∟ potiskujući PRESENT_PAT
# prezati [VERB]
#     ∟ prezajući PRESENT_PAT
# zbunjovati [VERB]
#     ∟ zbunjujući PRESENT_PAT
# zbližavati [VERB]
#     ∟ zbližavajući PRESENT_PAT
# zatvarati [VERB]
#     ∟ zatvarajući PRESENT_PAT
# tragati [VERB]
#     ∟ tragajući PRESENT_PAT
# opisovati [VERB]
#     ∟ opisujući PRESENT_PAT
# favorizovati [VERB]
#     ∟ favorizujući PRESENT_PAT
# oslobađati [VERB]
#     ∟ oslobađajući PRESENT_PAT
# ažurirati [VERB]
#     ∟ ažurirajući PRESENT_PAT
# otuđovati [VERB]
#     ∟ otuđujući PRESENT_PAT
# sprečavati [VERB]
#     ∟ sprečavajući PRESENT_PAT
# optužovati [VERB]
#     ∟ optužujući PRESENT_PAT
# upozoravati [VERB]
#     ∟ upozoravajući PRESENT_PAT
# ponavljati [VERB]
#     ∟ ponavljajući PRESENT_PAT
# uključovati [VERB]
#     ∟ uključujući PRESENT_PAT
# savetovati [VERB]
#     ∟ savetujući PRESENT_PAT
# najavljovati [VERB]
#     ∟ najavljujući PRESENT_PAT
# okončavati [VERB]
#     ∟ okončavajući PRESENT_PAT
# odbijati [VERB]
#     ∟ odbijajući PRESENT_PAT
# naglašavati [VERB]
#     ∟ naglašavajući PRESENT_PAT
# pozdravljati [VERB]
#     ∟ pozdravljajući PRESENT_PAT
# dodati [VERB]
#     ∟ dodajući PRESENT_PAT
# bacati [VERB]
#     ∟ bacajući PRESENT_PAT
# suočavati [VERB]
#     ∟ suočavajući PRESENT_PAT
# diskreditovati [VERB]
#     ∟ diskreditujući PRESENT_PAT
# prodati [VERB]
#     ∟ prodajući PRESENT_PAT
# saopštavati [VERB]
#     ∟ saopštavajući PRESENT_PAT
# opstruirati [VERB]
#     ∟ opstruirajući PRESENT_PAT
# podsećati [VERB]
#     ∟ podsećajući PRESENT_PAT
# ubacovati [VERB]
#     ∟ ubacujući PRESENT_PAT
# uveravati [VERB]
#     ∟ uveravajući PRESENT_PAT
# emigrirati [VERB]
#     ∟ emigrirajući PRESENT_PAT
# kritikovati [VERB]
#     ∟ kritikujući PRESENT_PAT
# narastati [VERB]
#     ∟ narastajući PRESENT_PAT
# ukazovati [VERB]
#     ∟ ukazujući PRESENT_PAT
# svrstavati [VERB]
#     ∟ svrstavajući PRESENT_PAT
# pretvarati [VERB]
#     ∟ pretvarajući PRESENT_PAT
# potvrđovati [VERB]
#     ∟ potvrđujući PRESENT_PAT
# čekati [VERB]
#     ∟ čekajući PRESENT_PAT
# primati [VERB]
#     ∟ primajući PRESENT_PAT
# ohrabrovati [VERB]
#     ∟ ohrabrujući PRESENT_PAT
# odgovarati [VERB]
#     ∟ odgovarajući PRESENT_PAT
# protestovati [VERB]
#     ∟ protestujući PRESENT_PAT
# objašnjavati [VERB]
#     ∟ objašnjavajući PRESENT_PAT
# osuđovati [VERB]
#     ∟ osuđujući PRESENT_PAT
# slovean [ADJ]
#     ∟ sloveniji COMP-M-SG
# beskompromisan [ADJ]
#     ∟ beskompromisniji COMP-M-SG
# uticajan [ADJ]
#     ∟ uticajniji COMP-M-SG
# lina [ADJ]
#     ∟ linija COMP-F-SG
# kompleksna [ADJ]
#     ∟ kompleksnija COMP-F-SG
# kompaan [ADJ]
#     ∟ kompaniji COMP-M-SG
# estono [ADJ]
#     ∟ estonije COMP-N-SG
# sloveno [ADJ]
#     ∟ slovenije COMP-N-SG
# opasan [ADJ]
#     ∟ opasnijim COMP-M-PL
# važna [ADJ]
#     ∟ važnija COMP-F-SG
# čečean [ADJ]
#     ∟ čečeniji COMP-M-SG
# deceno [ADJ]
#     ∟ decenije COMP-N-SG
# očigledan [ADJ]
#     ∟ očigledniji COMP-M-SG
# transparentan [ADJ]
#     ∟ transparentnijim COMP-M-PL
# tačno [ADJ]
#     ∟ tačnije COMP-N-SG
# špaan [ADJ]
#     ∟ španiji COMP-M-SG
# urgentan [ADJ]
#     ∟ urgentniji COMP-M-SG
# docno [ADJ]
#     ∟ docnije COMP-N-SG
# aktivno [ADJ]
#     ∟ aktivnije COMP-N-SG
# makedona [ADJ]
#     ∟ makedonija COMP-F-SG
# uan [ADJ]
#     ∟ uniji COMP-M-SG
# britana [ADJ]
#     ∟ britanija COMP-F-SG
# precizan [ADJ]
#     ∟ precizniji COMP-M-SG
# aliana [ADJ]
#     ∟ alianija COMP-F-SG
# makedono [ADJ]
#     ∟ makedonije COMP-N-SG
# rumuan [ADJ]
#     ∟ rumuniji COMP-M-SG
# represivan [ADJ]
#     ∟ represivniji COMP-M-SG
# ceremoan [ADJ]
#     ∟ ceremoniji COMP-M-SG
# litvano [ADJ]
#     ∟ litvanije COMP-N-SG
# apolona [ADJ]
#     ∟ apolonija COMP-F-SG
# slobodan [ADJ]
#     ∟ slobodniji COMP-M-SG
# uno [ADJ]
#     ∟ unije COMP-N-SG
# značajno [ADJ]
#     ∟ značajnije COMP-N-SG
# važno [ADJ]
#     ∟ važnije COMP-N-SG
# jeftino [ADJ]
#     ∟ jeftinije COMP-N-SG
# demokratična [ADJ]
#     ∟ demokratičnija COMP-F-SG
# konkurentna [ADJ]
#     ∟ konkurentnija COMP-F-SG
# svestrano [ADJ]
#     ∟ svestranije COMP-N-SG
# raan [ADJ]
#     ∟ ranijim COMP-M-PL
# važan [ADJ]
#     ∟ važniji COMP-M-SG
# una [ADJ]
#     ∟ unija COMP-F-SG
# sigurno [ADJ]
#     ∟ sigurnije COMP-N-SG
# letono [ADJ]
#     ∟ letonije COMP-N-SG
# potpuno [ADJ]
#     ∟ potpunije COMP-N-SG
# makedoan [ADJ]
#     ∟ makedoniji COMP-M-SG
# mena [ADJ]
#     ∟ menija COMP-F-SG
# pensilvaan [ADJ]
#     ∟ pensilvaniji COMP-M-SG
# rumuna [ADJ]
#     ∟ rumunija COMP-F-SG
# ozbiljan [ADJ]
#     ∟ ozbiljniji COMP-M-SG
# rano [ADJ]
#     ∟ ranije COMP-N-SG
# britano [ADJ]
#     ∟ britanije COMP-N-SG
# efikasan [ADJ]
#     ∟ efikasniji COMP-M-SG
# zainteresovana [ADJ]
#     ∟ zainteresovanija COMP-F-SG
# rasprostranjena [ADJ]
#     ∟ rasprostranjenija COMP-F-SG
# albano [ADJ]
#     ∟ albanije COMP-N-SG
# kompano [ADJ]
#     ∟ kompanije COMP-N-SG
# bezbedan [ADJ]
#     ∟ bezbedniji COMP-M-SG
# pozitivan [ADJ]
#     ∟ pozitivniji COMP-M-SG
# konkretno [ADJ]
#     ∟ konkretnije COMP-N-SG
# efikasna [ADJ]
#     ∟ efikasnija COMP-F-SG
# britaan [ADJ]
#     ∟ britaniji COMP-M-SG
# jevtian [ADJ]
#     ∟ jevtinijim COMP-M-PL
# decena [ADJ]
#     ∟ decenija COMP-F-SG
# ceremono [ADJ]
#     ∟ ceremonije COMP-N-SG
# kompana [ADJ]
#     ∟ kompanija COMP-F-SG
# snažno [ADJ]
#     ∟ snažnije COMP-N-SG
# optimalno [ADJ]
#     ∟ optimalnije COMP-N-SG
# albana [ADJ]
#     ∟ albanija COMP-F-SG
# sigurna [ADJ]
#     ∟ sigurnija COMP-F-SG
# izražean [ADJ]
#     ∟ izraženijim COMP-M-PL
# špana [ADJ]
#     ∟ španija COMP-F-SG
# nezadovoljan [ADJ]
#     ∟ nezadovoljniji COMP-M-SG
# kolona [ADJ]
#     ∟ kolonija COMP-F-SG
# lino [ADJ]
#     ∟ linije COMP-N-SG
# iskusan [ADJ]
#     ∟ iskusnijim COMP-M-PL
# optimističan [ADJ]
#     ∟ optimističniji COMP-M-SG
# značajan [ADJ]
#     ∟ značajniji COMP-M-SG
# moćan [ADJ]
#     ∟ moćniji COMP-M-SG
# striktno [ADJ]
#     ∟ striktnije COMP-N-SG
# albaan [ADJ]
#     ∟ albaniji COMP-M-SG
# telefono [ADJ]
#     ∟ telefonije COMP-N-SG
# rasprostranjean [ADJ]
#     ∟ rasprostranjeniji COMP-M-SG
# slovena [ADJ]
#     ∟ slovenija COMP-F-SG
# diversifikovana [ADJ]
#     ∟ diversifikovanija COMP-F-SG
# lian [ADJ]
#     ∟ liniji COMP-M-SG
# ceremona [ADJ]
#     ∟ ceremonija COMP-F-SG
# kasno [ADJ]
#     ∟ kasnije COMP-N-SG
# rumuno [ADJ]
#     ∟ rumunije COMP-N-SG
# špano [ADJ]
#     ∟ španije COMP-N-SG
# siromašno [ADJ]
#     ∟ siromašnije COMP-N-SG

# %% [markdown]
# ## 2.2 Superlative

# %% [markdown]
# It is fairly easy to find adjectives in superlative form because they almost always have the prefix *naj-*.

# %%
prefix_NAJ = list(set([w for w in ud_content if w.startswith('naj')]))

# %%
prefix_NAJ
# Out:
# ['najbogatijih',
#  'najneslobodnija',
#  'najčešće',
#  'najčuvanijih',
#  'najugledniji',
#  'najdelikatnijoj',
#  'najbolja',
#  'najtraženija',
#  'najvećeg',
#  'najjačih',
#  'najboljem',
#  'najduži',
#  'najavljuje',
#  'najraznovrsnije',
#  'najgorim',
#  'najznačajniji',
#  'najesen',
#  'najrazličitijih',
#  'najzad',
#  'najnoviji',
#  'najbezbednija',
#  'najavile',
#  'najizolovanijom',
#  'najgore',
#  'najvažnijih',
#  'najozbiljnija',
#  'najurgentniji',
#  'najtiražnijeg',
#  'najavljena',
#  'najvećem',
#  'najmodernijeg',
#  'najnoviju',
#  'najteža',
#  'najnovijem',
#  'najjednostavniji',
#  'najverovatnije',
#  'najveći',
#  'najrelevantnijih',
#  'najvećih',
#  'najmoćniji',
#  'najpouzdniji',
#  'najniži',
#  'najtalentovanijih',
#  'najmanju',
#  'najstarijim',
#  'najisplativija',
#  'najuglednijih',
#  'najbezbednijim',
#  'najnasilniju',
#  'najprimetnijih',
#  'najpopularnija',
#  'najznačajnijih',
#  'najčuvenijih',
#  'najvažniju',
#  'najizolovanijih',
#  'najavio',
#  'najbolje',
#  'najrashlađenija',
#  'najslobodnija',
#  'najznačajnija',
#  'najkraća',
#  'najvažnijim',
#  'najpopularnijih',
#  'najvišim',
#  'najplodnija',
#  'najuspešnija',
#  'najteže',
#  'najstarijih',
#  'najozbiljniji',
#  'najnovijih',
#  'najjače',
#  'najjača',
#  'najmoćnije',
#  'najboljim',
#  'najbezbednijih',
#  'najveće',
#  'najsigurnijih',
#  'najčuvenija',
#  'najveća',
#  'najboljeg',
#  'najpoznatiji',
#  'najboljih',
#  'najveću',
#  'najvišeg',
#  'najverovatniji',
#  'najavljenom',
#  'najgorem',
#  'najperfektnije',
#  'najavljen',
#  'najprodavanije',
#  'najavila',
#  'najvažnija',
#  'najdinamičnija',
#  'najsličnija',
#  'najblaže',
#  'najvećim',
#  'najtiražnije',
#  'najpoznatijih',
#  'najspektakularniji',
#  'najsiromašnijim',
#  'najefikasnije',
#  'najstariji',
#  'najavljuju',
#  'najviši',
#  'najmanje',
#  'najznačajnije',
#  'najnovije',
#  'najnovija',
#  'najvažnije',
#  'najbolji',
#  'najistaknutiji',
#  'najnovijim',
#  'najprizemniji',
#  'najviše',
#  'najtežih',
#  'najbolju',
#  'najvažniji']

# %%
def is_superlative_of_existing_base_form(lexicon_entry, superlative):
    if len(lexicon_entry.derived_forms) == 0:
        return False
    
    comparative = superlative[3:]
    for d_form in lexicon_entry.derived_forms:
        if d_form[1].startswith("COMP-") and d_form[0].startswith(comparative):
            gender = d_form[1].split("-")[1]
            number = d_form[1].split("-")[2]
            lexicon_entry.derived_forms.append((superlative, "SUP-{}-{}".format(gender, number)))
            return True
        
    return False
            

for p_NAJ in prefix_NAJ:
    lexicon_entries = [l for l in lexicon if is_superlative_of_existing_base_form(l, p_NAJ)]

# %%
print_lexicon()
# Out:
# rušiti [VERB]
# zamisliti [VERB]
# pretpostaviti [VERB]
# raditi [VERB]
# odstupiti [VERB]
# otvoriti [VERB]
# izvršiti [VERB]
# otkriti [VERB]
# iznositi [VERB]
# ograničiti [VERB]
# tražiti [VERB]
# obilaziti [VERB]
# odvratiti [VERB]
# dozvoliti [VERB]
# razrešiti [VERB]
# proceniti [VERB]
# uhvatiti [VERB]
# povrediti [VERB]
# obaviti [VERB]
# izraditi [VERB]
# protiviti [VERB]
# kazniti [VERB]
# štiti [VERB]
# slediti [VERB]
# pružiti [VERB]
# nastaviti [VERB]
# složiti [VERB]
# posvetiti [VERB]
# pridružiti [VERB]
# odrediti [VERB]
# osetiti [VERB]
# razvodniti [VERB]
# obezbediti [VERB]
# uskladiti [VERB]
# vlastiti [VERB]
# otkloniti [VERB]
# proučiti [VERB]
# nastupiti [VERB]
# skladištiti [VERB]
# nadoknaditi [VERB]
# rešiti [VERB]
# uraditi [VERB]
# ohrabriti [VERB]
# zaštititi [VERB]
# odbaciti [VERB]
# uništiti [VERB]
# zanemariti [VERB]
# potrošiti [VERB]
# nuditi [VERB]
# vratiti [VERB]
# ustanoviti [VERB]
# iskoristiti [VERB]
# desiti [VERB]
# završiti [VERB]
# predstaviti [VERB]
# suočiti [VERB]
# opslužiti [VERB]
# zatražiti [VERB]
# izgraditi [VERB]
# ugroziti [VERB]
# napraviti [VERB]
# dobiti [VERB]
# preporučiti [VERB]
# odobriti [VERB]
# proširiti [VERB]
# zaključiti [VERB]
# namestiti [VERB]
# izmeniti [VERB]
# potvrditi [VERB]
# posetiti [VERB]
# podnositi [VERB]
# dogoditi [VERB]
# usredsrediti [VERB]
# voditi [VERB]
# ponuditi [VERB]
# odgovoriti [VERB]
# pratiti [VERB]
# pojaviti [VERB]
# povratiti [VERB]
# uspostaviti [VERB]
# razotkriti [VERB]
# predložiti [VERB]
# deliti [VERB]
# koristiti [VERB]
# značiti [VERB]
# uočiti [VERB]
# staviti [VERB]
# otpustiti [VERB]
# promeniti [VERB]
# smanjiti [VERB]
# ostvariti [VERB]
# govoriti [VERB]
# naslediti [VERB]
# ostaviti [VERB]
# krediti [VERB]
# zaposliti [VERB]
# osuditi [VERB]
# smisliti [VERB]
# udružiti [VERB]
# razdvojiti [VERB]
# zaštiti [VERB]
# otplatiti [VERB]
# oprostiti [VERB]
# unaprediti [VERB]
# uložiti [VERB]
# shvatiti [VERB]
# pustiti [VERB]
# učiti [VERB]
# prihvatiti [VERB]
# primiti [VERB]
# odnositi [VERB]
# umoriti [VERB]
# prenositi [VERB]
# zavisiti [VERB]
# udvostručiti [VERB]
# patiti [VERB]
# snositi [VERB]
# postaviti [VERB]
# obnoviti [VERB]
# kupiti [VERB]
# razmotriti [VERB]
# zameniti [VERB]
# poslužiti [VERB]
# sprečiti [VERB]
# pripremiti [VERB]
# protumačiti [VERB]
# arvaniti [VERB]
# različiti [VERB]
# napustiti [VERB]
# ponoviti [VERB]
# izmisliti [VERB]
# usuditi [VERB]
# učiniti [VERB]
# izgubiti [VERB]
# pristupiti [VERB]
# omogućiti [VERB]
# preurediti [VERB]
# uslediti [VERB]
# ispuniti [VERB]
# rijaliti [VERB]
# sprovoditi [VERB]
# stvoriti [VERB]
# težiti [VERB]
# unakaziti [VERB]
# doneti [VERB]
# početi [VERB]
# aveti [VERB]
# videti [VERB]
# započeti [VERB]
# predvideti [VERB]
# oseti [VERB]
# uspeti [VERB]
# tereti [VERB]
# anketi [VERB]
# uzeti [VERB]
# preneti [VERB]
# fakulteti [VERB]
# našteti [VERB]
# ćančeti [VERB]
# deveti [VERB]
# preduzeti [VERB]
# univerziteti [VERB]
# razumeti [VERB]
# dijeti [VERB]
# peti [VERB]
# oteti [VERB]
# animoziteti [VERB]
# dopreti [VERB]
# posveti [VERB]
# doprineti [VERB]
# predmeti [VERB]
# antikviteti [VERB]
# preoteti [VERB]
# meti [VERB]
# ahmeti [VERB]
# preti [VERB]
# oživeti [VERB]
# poseti [VERB]
# preuzeti [VERB]
# podneti [VERB]
# menjati [VERB]
# pati [VERB]
# očekivati [VERB]
# izabrati [VERB]
# obavljati [VERB]
#     ∟ obavljajući PRESENT_PAT
# vraćati [VERB]
# pozvati [VERB]
# održavati [VERB]
# omogućavati [VERB]
#     ∟ omogućavajući PRESENT_PAT
# hrvati [VERB]
# učestvovati [VERB]
# falsifikovati [VERB]
# prestati [VERB]
# sećati [VERB]
# izdavati [VERB]
# zapošljavati [VERB]
# organizovati [VERB]
# postavljati [VERB]
#     ∟ postavljajući PRESENT_PAT
# aktivirati [VERB]
# plaćati [VERB]
# razvijati [VERB]
# razmenjivati [VERB]
# imati [VERB]
#     ∟ imajući PRESENT_PAT
# zadržati [VERB]
# postupati [VERB]
# uticati [VERB]
# sati [VERB]
# preispitati [VERB]
# povećati [VERB]
# preduzimati [VERB]
#     ∟ preduzimajući PRESENT_PAT
# klati [VERB]
# insistirati [VERB]
#     ∟ insistirajući PRESENT_PAT
# slati [VERB]
# odavati [VERB]
# oslanjati [VERB]
# advokati [VERB]
# ispričati [VERB]
# reagovati [VERB]
# intervenisati [VERB]
# odvijati [VERB]
# razrešavati [VERB]
# rešavati [VERB]
# uhvati [VERB]
# posmatrati [VERB]
# pokušavati [VERB]
# pregovarati [VERB]
# analizirati [VERB]
# sarađivati [VERB]
# povezati [VERB]
# koštati [VERB]
# držati [VERB]
# funkcionisati [VERB]
# prebacivati [VERB]
# pojačati [VERB]
# pridržavati [VERB]
# glasati [VERB]
# garantovati [VERB]
# pokušati [VERB]
# izazvati [VERB]
# trajati [VERB]
# povrati [VERB]
# dočekivati [VERB]
# bogati [VERB]
# blokirati [VERB]
# sindikati [VERB]
# dati [VERB]
#     ∟ dajući PRESENT_PAT
# fokusirati [VERB]
# verovati [VERB]
# rezultati [VERB]
# finansirati [VERB]
# prisustvovati [VERB]
# suspendovati [VERB]
# smatrati [VERB]
# pružati [VERB]
# prikazati [VERB]
# postati [VERB]
# oklevati [VERB]
# delati [VERB]
# definisati [VERB]
# plakati [VERB]
# mati [VERB]
# zapitati [VERB]
# zloupotrebljavati [VERB]
# modelirati [VERB]
# nadmetati [VERB]
# poboljšati [VERB]
# poslati [VERB]
# zaletati [VERB]
# doputovati [VERB]
# dobijati [VERB]
# apstinirati [VERB]
# zvati [VERB]
# okončati [VERB]
# predstavljati [VERB]
#     ∟ predstavljajući PRESENT_PAT
# požurivati [VERB]
# pokazati [VERB]
# zalagati [VERB]
# otputovati [VERB]
# poznati [VERB]
# prihvati [VERB]
# zahtevati [VERB]
#     ∟ zahtevajući PRESENT_PAT
# palati [VERB]
# nadati [VERB]
# vrati [VERB]
# kopirati [VERB]
# dokazati [VERB]
# ojačati [VERB]
# putovati [VERB]
# investirati [VERB]
# igrati [VERB]
#     ∟ igrajući PRESENT_PAT
# poštovati [VERB]
# bušati [VERB]
# zarađivati [VERB]
# prepoznati [VERB]
# sastati [VERB]
# olakšati [VERB]
# postojati [VERB]
# izolovati [VERB]
# ratifikovati [VERB]
# morati [VERB]
# izražavati [VERB]
#     ∟ izražavajući PRESENT_PAT
# kandidati [VERB]
# podržati [VERB]
# ometati [VERB]
# predati [VERB]
# ostati [VERB]
# plati [VERB]
# sačuvati [VERB]
# cenjkati [VERB]
# primenjivati [VERB]
# pisati [VERB]
# artikulisati [VERB]
# ticati [VERB]
# održati [VERB]
# objavljivati [VERB]
# pervati [VERB]
# prati [VERB]
# intenzivirati [VERB]
# pridati [VERB]
# osećati [VERB]
# raspravljati [VERB]
# isplati [VERB]
# stajati [VERB]
# razgovarati [VERB]
# uključivati [VERB]
# nemati [VERB]
# pozivati [VERB]
#     ∟ pozivajući PRESENT_PAT
# obraćati [VERB]
#     ∟ obraćajući PRESENT_PAT
# smanjivati [VERB]
# zamišljati [VERB]
# obrati [VERB]
# birati [VERB]
# potpisati [VERB]
# izdati [VERB]
# priznati [VERB]
# uračunati [VERB]
# učinivši [VERB]
# zabeleživši [VERB]
# dostigavši [VERB]
# izazvavši [VERB]
# zamenivši [VERB]
# pohvalivši [VERB]
# naslutivši [VERB]
# završivši [VERB]
# postavivši [VERB]
# pretvorivši [VERB]
# uzdrmavši [VERB]
# dobivši [VERB]
# proširivši [VERB]
# bivši [VERB]
# rekavši [VERB]
# primetivši [VERB]
# počevši [VERB]
# osvojivši [VERB]
# ponovivši [VERB]
# pobedivši [VERB]
# nazivati [VERB]
#     ∟ nazivajući PRESENT_PAT
# znati [VERB]
#     ∟ znajući PRESENT_PAT
# izdvajati [VERB]
#     ∟ izdvajajući PRESENT_PAT
# čitati [VERB]
#     ∟ čitajući PRESENT_PAT
# uzrokovati [VERB]
#     ∟ uzrokujući PRESENT_PAT
# predsedavati [VERB]
#     ∟ predsedavajući PRESENT_PAT
# zahvaljovati [VERB]
#     ∟ zahvaljujući PRESENT_PAT
# otvarati [VERB]
#     ∟ otvarajući PRESENT_PAT
# obeležavati [VERB]
#     ∟ obeležavajući PRESENT_PAT
# završavati [VERB]
#     ∟ završavajući PRESENT_PAT
# preneražavati [VERB]
#     ∟ preneražavajući PRESENT_PAT
# pojavljovati [VERB]
#     ∟ pojavljujući PRESENT_PAT
# obećavati [VERB]
#     ∟ obećavajući PRESENT_PAT
# nedostati [VERB]
#     ∟ nedostajući PRESENT_PAT
# primoravati [VERB]
#     ∟ primoravajući PRESENT_PAT
# potiskovati [VERB]
#     ∟ potiskujući PRESENT_PAT
# prezati [VERB]
#     ∟ prezajući PRESENT_PAT
# zbunjovati [VERB]
#     ∟ zbunjujući PRESENT_PAT
# zbližavati [VERB]
#     ∟ zbližavajući PRESENT_PAT
# zatvarati [VERB]
#     ∟ zatvarajući PRESENT_PAT
# tragati [VERB]
#     ∟ tragajući PRESENT_PAT
# opisovati [VERB]
#     ∟ opisujući PRESENT_PAT
# favorizovati [VERB]
#     ∟ favorizujući PRESENT_PAT
# oslobađati [VERB]
#     ∟ oslobađajući PRESENT_PAT
# ažurirati [VERB]
#     ∟ ažurirajući PRESENT_PAT
# otuđovati [VERB]
#     ∟ otuđujući PRESENT_PAT
# sprečavati [VERB]
#     ∟ sprečavajući PRESENT_PAT
# optužovati [VERB]
#     ∟ optužujući PRESENT_PAT
# upozoravati [VERB]
#     ∟ upozoravajući PRESENT_PAT
# ponavljati [VERB]
#     ∟ ponavljajući PRESENT_PAT
# uključovati [VERB]
#     ∟ uključujući PRESENT_PAT
# savetovati [VERB]
#     ∟ savetujući PRESENT_PAT
# najavljovati [VERB]
#     ∟ najavljujući PRESENT_PAT
# okončavati [VERB]
#     ∟ okončavajući PRESENT_PAT
# odbijati [VERB]
#     ∟ odbijajući PRESENT_PAT
# naglašavati [VERB]
#     ∟ naglašavajući PRESENT_PAT
# pozdravljati [VERB]
#     ∟ pozdravljajući PRESENT_PAT
# dodati [VERB]
#     ∟ dodajući PRESENT_PAT
# bacati [VERB]
#     ∟ bacajući PRESENT_PAT
# suočavati [VERB]
#     ∟ suočavajući PRESENT_PAT
# diskreditovati [VERB]
#     ∟ diskreditujući PRESENT_PAT
# prodati [VERB]
#     ∟ prodajući PRESENT_PAT
# saopštavati [VERB]
#     ∟ saopštavajući PRESENT_PAT
# opstruirati [VERB]
#     ∟ opstruirajući PRESENT_PAT
# podsećati [VERB]
#     ∟ podsećajući PRESENT_PAT
# ubacovati [VERB]
#     ∟ ubacujući PRESENT_PAT
# uveravati [VERB]
#     ∟ uveravajući PRESENT_PAT
# emigrirati [VERB]
#     ∟ emigrirajući PRESENT_PAT
# kritikovati [VERB]
#     ∟ kritikujući PRESENT_PAT
# narastati [VERB]
#     ∟ narastajući PRESENT_PAT
# ukazovati [VERB]
#     ∟ ukazujući PRESENT_PAT
# svrstavati [VERB]
#     ∟ svrstavajući PRESENT_PAT
# pretvarati [VERB]
#     ∟ pretvarajući PRESENT_PAT
# potvrđovati [VERB]
#     ∟ potvrđujući PRESENT_PAT
# čekati [VERB]
#     ∟ čekajući PRESENT_PAT
# primati [VERB]
#     ∟ primajući PRESENT_PAT
# ohrabrovati [VERB]
#     ∟ ohrabrujući PRESENT_PAT
# odgovarati [VERB]
#     ∟ odgovarajući PRESENT_PAT
# protestovati [VERB]
#     ∟ protestujući PRESENT_PAT
# objašnjavati [VERB]
#     ∟ objašnjavajući PRESENT_PAT
# osuđovati [VERB]
#     ∟ osuđujući PRESENT_PAT
# slovean [ADJ]
#     ∟ sloveniji COMP-M-SG
# beskompromisan [ADJ]
#     ∟ beskompromisniji COMP-M-SG
# uticajan [ADJ]
#     ∟ uticajniji COMP-M-SG
# lina [ADJ]
#     ∟ linija COMP-F-SG
# kompleksna [ADJ]
#     ∟ kompleksnija COMP-F-SG
# kompaan [ADJ]
#     ∟ kompaniji COMP-M-SG
# estono [ADJ]
#     ∟ estonije COMP-N-SG
# sloveno [ADJ]
#     ∟ slovenije COMP-N-SG
# opasan [ADJ]
#     ∟ opasnijim COMP-M-PL
# važna [ADJ]
#     ∟ važnija COMP-F-SG
#       najvažnija SUP-F-SG
# čečean [ADJ]
#     ∟ čečeniji COMP-M-SG
# deceno [ADJ]
#     ∟ decenije COMP-N-SG
# očigledan [ADJ]
#     ∟ očigledniji COMP-M-SG
# transparentan [ADJ]
#     ∟ transparentnijim COMP-M-PL
# tačno [ADJ]
#     ∟ tačnije COMP-N-SG
# špaan [ADJ]
#     ∟ španiji COMP-M-SG
# urgentan [ADJ]
#     ∟ urgentniji COMP-M-SG
#       najurgentniji SUP-M-SG
# docno [ADJ]
#     ∟ docnije COMP-N-SG
# aktivno [ADJ]
#     ∟ aktivnije COMP-N-SG
# makedona [ADJ]
#     ∟ makedonija COMP-F-SG
# uan [ADJ]
#     ∟ uniji COMP-M-SG
# britana [ADJ]
#     ∟ britanija COMP-F-SG
# precizan [ADJ]
#     ∟ precizniji COMP-M-SG
# aliana [ADJ]
#     ∟ alianija COMP-F-SG
# makedono [ADJ]
#     ∟ makedonije COMP-N-SG
# rumuan [ADJ]
#     ∟ rumuniji COMP-M-SG
# represivan [ADJ]
#     ∟ represivniji COMP-M-SG
# ceremoan [ADJ]
#     ∟ ceremoniji COMP-M-SG
# litvano [ADJ]
#     ∟ litvanije COMP-N-SG
# apolona [ADJ]
#     ∟ apolonija COMP-F-SG
# slobodan [ADJ]
#     ∟ slobodniji COMP-M-SG
# uno [ADJ]
#     ∟ unije COMP-N-SG
# značajno [ADJ]
#     ∟ značajnije COMP-N-SG
#       najznačajnije SUP-N-SG
# važno [ADJ]
#     ∟ važnije COMP-N-SG
#       najvažnije SUP-N-SG
# jeftino [ADJ]
#     ∟ jeftinije COMP-N-SG
# demokratična [ADJ]
#     ∟ demokratičnija COMP-F-SG
# konkurentna [ADJ]
#     ∟ konkurentnija COMP-F-SG
# svestrano [ADJ]
#     ∟ svestranije COMP-N-SG
# raan [ADJ]
#     ∟ ranijim COMP-M-PL
# važan [ADJ]
#     ∟ važniji COMP-M-SG
#       najvažniji SUP-M-SG
# una [ADJ]
#     ∟ unija COMP-F-SG
# sigurno [ADJ]
#     ∟ sigurnije COMP-N-SG
# letono [ADJ]
#     ∟ letonije COMP-N-SG
# potpuno [ADJ]
#     ∟ potpunije COMP-N-SG
# makedoan [ADJ]
#     ∟ makedoniji COMP-M-SG
# mena [ADJ]
#     ∟ menija COMP-F-SG
# pensilvaan [ADJ]
#     ∟ pensilvaniji COMP-M-SG
# rumuna [ADJ]
#     ∟ rumunija COMP-F-SG
# ozbiljan [ADJ]
#     ∟ ozbiljniji COMP-M-SG
#       najozbiljniji SUP-M-SG
# rano [ADJ]
#     ∟ ranije COMP-N-SG
# britano [ADJ]
#     ∟ britanije COMP-N-SG
# efikasan [ADJ]
#     ∟ efikasniji COMP-M-SG
# zainteresovana [ADJ]
#     ∟ zainteresovanija COMP-F-SG
# rasprostranjena [ADJ]
#     ∟ rasprostranjenija COMP-F-SG
# albano [ADJ]
#     ∟ albanije COMP-N-SG
# kompano [ADJ]
#     ∟ kompanije COMP-N-SG
# bezbedan [ADJ]
#     ∟ bezbedniji COMP-M-SG
# pozitivan [ADJ]
#     ∟ pozitivniji COMP-M-SG
# konkretno [ADJ]
#     ∟ konkretnije COMP-N-SG
# efikasna [ADJ]
#     ∟ efikasnija COMP-F-SG
# britaan [ADJ]
#     ∟ britaniji COMP-M-SG
# jevtian [ADJ]
#     ∟ jevtinijim COMP-M-PL
# decena [ADJ]
#     ∟ decenija COMP-F-SG
# ceremono [ADJ]
#     ∟ ceremonije COMP-N-SG
# kompana [ADJ]
#     ∟ kompanija COMP-F-SG
# snažno [ADJ]
#     ∟ snažnije COMP-N-SG
# optimalno [ADJ]
#     ∟ optimalnije COMP-N-SG
# albana [ADJ]
#     ∟ albanija COMP-F-SG
# sigurna [ADJ]
#     ∟ sigurnija COMP-F-SG
# izražean [ADJ]
#     ∟ izraženijim COMP-M-PL
# špana [ADJ]
#     ∟ španija COMP-F-SG
# nezadovoljan [ADJ]
#     ∟ nezadovoljniji COMP-M-SG
# kolona [ADJ]
#     ∟ kolonija COMP-F-SG
# lino [ADJ]
#     ∟ linije COMP-N-SG
# iskusan [ADJ]
#     ∟ iskusnijim COMP-M-PL
# optimističan [ADJ]
#     ∟ optimističniji COMP-M-SG
# značajan [ADJ]
#     ∟ značajniji COMP-M-SG
#       najznačajniji SUP-M-SG
# moćan [ADJ]
#     ∟ moćniji COMP-M-SG
#       najmoćniji SUP-M-SG
# striktno [ADJ]
#     ∟ striktnije COMP-N-SG
# albaan [ADJ]
#     ∟ albaniji COMP-M-SG
# telefono [ADJ]
#     ∟ telefonije COMP-N-SG
# rasprostranjean [ADJ]
#     ∟ rasprostranjeniji COMP-M-SG
# slovena [ADJ]
#     ∟ slovenija COMP-F-SG
# diversifikovana [ADJ]
#     ∟ diversifikovanija COMP-F-SG
# lian [ADJ]
#     ∟ liniji COMP-M-SG
# ceremona [ADJ]
#     ∟ ceremonija COMP-F-SG
# kasno [ADJ]
#     ∟ kasnije COMP-N-SG
# rumuno [ADJ]
#     ∟ rumunije COMP-N-SG
# špano [ADJ]
#     ∟ španije COMP-N-SG
# siromašno [ADJ]
#     ∟ siromašnije COMP-N-SG

# %% [markdown]
# - Prisvojni pridevi (mesta): -ski, -čki, -ški
# - Prisvojni pridevi (?): -ni
# - Prisvojni pridevi (ljudi): -ov, -in, -ev

# %% [markdown]
# ## 2.3 Possessive adjectives

# %% [markdown]
# Possessive adjectives can be of the following forms depending on the type of entity that *possesses*:
#
# 1. *-ov, -ev, -in*: when the entity that possesses is a human being
#     - Examples: Markov "Mark's", Tonijev "Tony's", Nemanjin "Nemanja's"
# 2. *-ski, -čki, -ški*: usually with toponymical entities - countries, ethnicities, cities, villages, regions, etc.
#     - Examples: srpski "Serbian", nemački "German", praški "Prague's"
# 3. *-ni*
#     - Examples: državni "state"

# %% [markdown]
# Of course, adjectives are changed according to gender as well, so we have:
#
# 2. *-ska* (f.), *-sko* (n.), *-čka* (f.), *-čko (n.), *-ška* (f.), *-ško* (n.)
# 3. *-na* (f.), *-no* (n.)
#
# However, the inflection forms for masculine, feminine and neutral gender are the same when inflecting over different cases. The only difference is in the nominative form, so feminine and neutral forms are put under the masculine form.
#
# Singular
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|srpski|srpska|srpsko|
# |genitive|srpskog|srpske|srpskog|
# |dative|srpskom|srpskoj|srpskom|
# |acusative|srpski|srpsku|srpsko|
# |vocative|srpski|srpska|srpsko|
# |instrumental|srpskim|srpskom|srpskim|
# |locative|srpskom|srpskoj|srpskom|
#
# Plural
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|srpski|srpske|srpska|
# |genitive|srpskih|srpskih|srpske|
# |dative|srpskim|srpskim|srpskoj|
# |acusative|srpske|srpske|srpsku|
# |vocative|srpski|srpske|srpska|
# |instrumental|srpskim|srpskim|srpskom|
# |locative|srpskim|srpskim|srpskoj|

# %% [markdown]
# Possible siffixes: *-ski*, *-skog*, *-skom*, *-skim*, *-ska*, *-ske*, *-skoj*, *-sku*, *-skih*, *-sko*

# %% [markdown]
# ### 2.3.1 suffix *-ski* and its inflections

# %%
possessive_adjectives = list(set([w for w in ud_content if w.endswith('ski')]))

# %%
possessive_adjectives
# Out:
# ['rumunski',
#  'španski',
#  'vremenski',
#  'gagovski',
#  'konjanovski',
#  'teoretski',
#  'švedski',
#  'tetovski',
#  'gruevski',
#  'irski',
#  'makedonski',
#  'trajkovski',
#  'imunski',
#  'diplomatski',
#  'hrvatski',
#  'bugarski',
#  'meteorski',
#  'novinarski',
#  'ivanovski',
#  'evropski',
#  'romski',
#  'zemunski',
#  'peruanski',
#  'saudijski',
#  'šahovski',
#  'prevarantski',
#  'vijetnamski',
#  'ministarski',
#  'turski',
#  'amaterski',
#  'londonski',
#  'sofijski',
#  'aleksievski',
#  'briselski',
#  'verski',
#  'nikolovski',
#  'balkanski',
#  'republikanski',
#  'lavovski',
#  'belgijski',
#  'beogradski',
#  'gruzijski',
#  'peševski',
#  'kablovski',
#  'automatski',
#  'kosovski',
#  'jugoslovenski',
#  'evroatlantski',
#  'trojanski',
#  'univerzitetski',
#  'holivudski',
#  'portugalski',
#  'puninski',
#  'penzijski',
#  'antonovski',
#  'britanski',
#  'poposki',
#  'orvelovski',
#  'ohridski',
#  'ljudski',
#  'levičarski',
#  'finski',
#  'istorijski',
#  'izraelski',
#  'kurdski',
#  'avionski',
#  'vrhunski',
#  'svetski',
#  'moldavski',
#  'posttraumatski',
#  'litvanski',
#  'albanski',
#  'spoljnotrgovinski',
#  'stojčevski',
#  'građevinski',
#  'studentski',
#  'finansijski',
#  'srpski',
#  'bosanski',
#  'terapeutski',
#  'islamski',
#  'nilski',
#  'trajkoviski',
#  'carinski',
#  'spisateljski',
#  'istinski',
#  'drumski',
#  'filmski',
#  'budžetski',
#  'herkulovski',
#  'životinjski',
#  'helenski',
#  'sovjetski',
#  'bankarski',
#  'mađarski',
#  'geografski',
#  'francuski',
#  'engleski',
#  'solunski',
#  'dostojevski',
#  'generacijski',
#  'olimpijski',
#  'ruski',
#  'proevropski',
#  'majski',
#  'katastarski',
#  'novozelandski',
#  'ekonomski',
#  'bostonski',
#  'akademski',
#  'poreski',
#  'milošoski',
#  'industrijski',
#  'većinski',
#  'dejtonski',
#  'mančevski',
#  'zakonski',
#  'stavrevski',
#  'ramkovski',
#  'antologijski',
#  'detektivski',
#  'pariski',
#  'lisabonski',
#  'manevski',
#  'televizijski',
#  'sudski',
#  'pakistanski',
#  'medijski',
#  'švajcarski',
#  'bliski',
#  'niski',
#  'poljski',
#  'kiparski',
#  'socijaldemokratski',
#  'trgovinski',
#  'demokratski',
#  'nedemokratski',
#  'energetski',
#  'argentinski',
#  'cerovski',
#  'italijanski',
#  'bučkovski',
#  'proruski',
#  'berlinski',
#  'fudbalski',
#  'crvenkovski',
#  'azilski',
#  'bosforski',
#  'birokratski',
#  'sirijski',
#  'crnogorski']

# %%
for possesive_adj in possessive_adjectives:
    add_to_lexicon(possesive_adj, "ADJ")

# %%
def add_possessive_adjectives(possessive_adjectives, replace_src, replace_dst):
    for possessive_ADJ in possessive_adjectives:
        derived_f = (possessive_ADJ, "POSSESSIVE")
        base_form = possessive_ADJ.replace(replace_src, replace_dst)
        lexicon_entry = get_lexicon_entry(base_form, "ADJ")
        if lexicon_entry is not None:
            lexicon_entry.derived_forms.append(derived_f)
        else:
            add_to_lexicon(base_form, "ADJ", [derived_f])

# %%
def add_adjective_inflection_forms(inflection_suffixes):
    for suffix, base_suffix in inflection_suffixes:
        possessive_adjectives = list(set([w for w in ud_content if w.endswith(suffix)]))
        add_possessive_adjectives(possessive_adjectives, suffix, base_suffix)

# %%
inflection_suffixes = [('skog', 'ski'), ('skom', 'ski'), ('skim', 'ski'), ('ska', 'ski'), ('ske', 'ski'), 
                       ('skoj', 'ski'), ('sku', 'ski'), ('skih', 'ski'), ('sko', 'ski')]
add_adjective_inflection_forms(inflection_suffixes)

# %%
print_lexicon()
# Out:
# rušiti [VERB]
# zamisliti [VERB]
# pretpostaviti [VERB]
# raditi [VERB]
# odstupiti [VERB]
# otvoriti [VERB]
# izvršiti [VERB]
# otkriti [VERB]
# iznositi [VERB]
# ograničiti [VERB]
# tražiti [VERB]
# obilaziti [VERB]
# odvratiti [VERB]
# dozvoliti [VERB]
# razrešiti [VERB]
# proceniti [VERB]
# uhvatiti [VERB]
# povrediti [VERB]
# obaviti [VERB]
# izraditi [VERB]
# protiviti [VERB]
# kazniti [VERB]
# štiti [VERB]
# slediti [VERB]
# pružiti [VERB]
# nastaviti [VERB]
# složiti [VERB]
# posvetiti [VERB]
# pridružiti [VERB]
# odrediti [VERB]
# osetiti [VERB]
# razvodniti [VERB]
# obezbediti [VERB]
# uskladiti [VERB]
# vlastiti [VERB]
# otkloniti [VERB]
# proučiti [VERB]
# nastupiti [VERB]
# skladištiti [VERB]
# nadoknaditi [VERB]
# rešiti [VERB]
# uraditi [VERB]
# ohrabriti [VERB]
# zaštititi [VERB]
# odbaciti [VERB]
# uništiti [VERB]
# zanemariti [VERB]
# potrošiti [VERB]
# nuditi [VERB]
# vratiti [VERB]
# ustanoviti [VERB]
# iskoristiti [VERB]
# desiti [VERB]
# završiti [VERB]
# predstaviti [VERB]
# suočiti [VERB]
# opslužiti [VERB]
# zatražiti [VERB]
# izgraditi [VERB]
# ugroziti [VERB]
# napraviti [VERB]
# dobiti [VERB]
# preporučiti [VERB]
# odobriti [VERB]
# proširiti [VERB]
# zaključiti [VERB]
# namestiti [VERB]
# izmeniti [VERB]
# potvrditi [VERB]
# posetiti [VERB]
# podnositi [VERB]
# dogoditi [VERB]
# usredsrediti [VERB]
# voditi [VERB]
# ponuditi [VERB]
# odgovoriti [VERB]
# pratiti [VERB]
# pojaviti [VERB]
# povratiti [VERB]
# uspostaviti [VERB]
# razotkriti [VERB]
# predložiti [VERB]
# deliti [VERB]
# koristiti [VERB]
# značiti [VERB]
# uočiti [VERB]
# staviti [VERB]
# otpustiti [VERB]
# promeniti [VERB]
# smanjiti [VERB]
# ostvariti [VERB]
# govoriti [VERB]
# naslediti [VERB]
# ostaviti [VERB]
# krediti [VERB]
# zaposliti [VERB]
# osuditi [VERB]
# smisliti [VERB]
# udružiti [VERB]
# razdvojiti [VERB]
# zaštiti [VERB]
# otplatiti [VERB]
# oprostiti [VERB]
# unaprediti [VERB]
# uložiti [VERB]
# shvatiti [VERB]
# pustiti [VERB]
# učiti [VERB]
# prihvatiti [VERB]
# primiti [VERB]
# odnositi [VERB]
# umoriti [VERB]
# prenositi [VERB]
# zavisiti [VERB]
# udvostručiti [VERB]
# patiti [VERB]
# snositi [VERB]
# postaviti [VERB]
# obnoviti [VERB]
# kupiti [VERB]
# razmotriti [VERB]
# zameniti [VERB]
# poslužiti [VERB]
# sprečiti [VERB]
# pripremiti [VERB]
# protumačiti [VERB]
# arvaniti [VERB]
# različiti [VERB]
# napustiti [VERB]
# ponoviti [VERB]
# izmisliti [VERB]
# usuditi [VERB]
# učiniti [VERB]
# izgubiti [VERB]
# pristupiti [VERB]
# omogućiti [VERB]
# preurediti [VERB]
# uslediti [VERB]
# ispuniti [VERB]
# rijaliti [VERB]
# sprovoditi [VERB]
# stvoriti [VERB]
# težiti [VERB]
# unakaziti [VERB]
# doneti [VERB]
# početi [VERB]
# aveti [VERB]
# videti [VERB]
# započeti [VERB]
# predvideti [VERB]
# oseti [VERB]
# uspeti [VERB]
# tereti [VERB]
# anketi [VERB]
# uzeti [VERB]
# preneti [VERB]
# fakulteti [VERB]
# našteti [VERB]
# ćančeti [VERB]
# deveti [VERB]
# preduzeti [VERB]
# univerziteti [VERB]
# razumeti [VERB]
# dijeti [VERB]
# peti [VERB]
# oteti [VERB]
# animoziteti [VERB]
# dopreti [VERB]
# posveti [VERB]
# doprineti [VERB]
# predmeti [VERB]
# antikviteti [VERB]
# preoteti [VERB]
# meti [VERB]
# ahmeti [VERB]
# preti [VERB]
# oživeti [VERB]
# poseti [VERB]
# preuzeti [VERB]
# podneti [VERB]
# menjati [VERB]
# pati [VERB]
# očekivati [VERB]
# izabrati [VERB]
# obavljati [VERB]
#     ∟ obavljajući PRESENT_PAT
# vraćati [VERB]
# pozvati [VERB]
# održavati [VERB]
# omogućavati [VERB]
#     ∟ omogućavajući PRESENT_PAT
# hrvati [VERB]
# učestvovati [VERB]
# falsifikovati [VERB]
# prestati [VERB]
# sećati [VERB]
# izdavati [VERB]
# zapošljavati [VERB]
# organizovati [VERB]
# postavljati [VERB]
#     ∟ postavljajući PRESENT_PAT
# aktivirati [VERB]
# plaćati [VERB]
# razvijati [VERB]
# razmenjivati [VERB]
# imati [VERB]
#     ∟ imajući PRESENT_PAT
# zadržati [VERB]
# postupati [VERB]
# uticati [VERB]
# sati [VERB]
# preispitati [VERB]
# povećati [VERB]
# preduzimati [VERB]
#     ∟ preduzimajući PRESENT_PAT
# klati [VERB]
# insistirati [VERB]
#     ∟ insistirajući PRESENT_PAT
# slati [VERB]
# odavati [VERB]
# oslanjati [VERB]
# advokati [VERB]
# ispričati [VERB]
# reagovati [VERB]
# intervenisati [VERB]
# odvijati [VERB]
# razrešavati [VERB]
# rešavati [VERB]
# uhvati [VERB]
# posmatrati [VERB]
# pokušavati [VERB]
# pregovarati [VERB]
# analizirati [VERB]
# sarađivati [VERB]
# povezati [VERB]
# koštati [VERB]
# držati [VERB]
# funkcionisati [VERB]
# prebacivati [VERB]
# pojačati [VERB]
# pridržavati [VERB]
# glasati [VERB]
# garantovati [VERB]
# pokušati [VERB]
# izazvati [VERB]
# trajati [VERB]
# povrati [VERB]
# dočekivati [VERB]
# bogati [VERB]
# blokirati [VERB]
# sindikati [VERB]
# dati [VERB]
#     ∟ dajući PRESENT_PAT
# fokusirati [VERB]
# verovati [VERB]
# rezultati [VERB]
# finansirati [VERB]
# prisustvovati [VERB]
# suspendovati [VERB]
# smatrati [VERB]
# pružati [VERB]
# prikazati [VERB]
# postati [VERB]
# oklevati [VERB]
# delati [VERB]
# definisati [VERB]
# plakati [VERB]
# mati [VERB]
# zapitati [VERB]
# zloupotrebljavati [VERB]
# modelirati [VERB]
# nadmetati [VERB]
# poboljšati [VERB]
# poslati [VERB]
# zaletati [VERB]
# doputovati [VERB]
# dobijati [VERB]
# apstinirati [VERB]
# zvati [VERB]
# okončati [VERB]
# predstavljati [VERB]
#     ∟ predstavljajući PRESENT_PAT
# požurivati [VERB]
# pokazati [VERB]
# zalagati [VERB]
# otputovati [VERB]
# poznati [VERB]
# prihvati [VERB]
# zahtevati [VERB]
#     ∟ zahtevajući PRESENT_PAT
# palati [VERB]
# nadati [VERB]
# vrati [VERB]
# kopirati [VERB]
# dokazati [VERB]
# ojačati [VERB]
# putovati [VERB]
# investirati [VERB]
# igrati [VERB]
#     ∟ igrajući PRESENT_PAT
# poštovati [VERB]
# bušati [VERB]
# zarađivati [VERB]
# prepoznati [VERB]
# sastati [VERB]
# olakšati [VERB]
# postojati [VERB]
# izolovati [VERB]
# ratifikovati [VERB]
# morati [VERB]
# izražavati [VERB]
#     ∟ izražavajući PRESENT_PAT
# kandidati [VERB]
# podržati [VERB]
# ometati [VERB]
# predati [VERB]
# ostati [VERB]
# plati [VERB]
# sačuvati [VERB]
# cenjkati [VERB]
# primenjivati [VERB]
# pisati [VERB]
# artikulisati [VERB]
# ticati [VERB]
# održati [VERB]
# objavljivati [VERB]
# pervati [VERB]
# prati [VERB]
# intenzivirati [VERB]
# pridati [VERB]
# osećati [VERB]
# raspravljati [VERB]
# isplati [VERB]
# stajati [VERB]
# razgovarati [VERB]
# uključivati [VERB]
# nemati [VERB]
# pozivati [VERB]
#     ∟ pozivajući PRESENT_PAT
# obraćati [VERB]
#     ∟ obraćajući PRESENT_PAT
# smanjivati [VERB]
# zamišljati [VERB]
# obrati [VERB]
# birati [VERB]
# potpisati [VERB]
# izdati [VERB]
# priznati [VERB]
# uračunati [VERB]
# učinivši [VERB]
# zabeleživši [VERB]
# dostigavši [VERB]
# izazvavši [VERB]
# zamenivši [VERB]
# pohvalivši [VERB]
# naslutivši [VERB]
# završivši [VERB]
# postavivši [VERB]
# pretvorivši [VERB]
# uzdrmavši [VERB]
# dobivši [VERB]
# proširivši [VERB]
# bivši [VERB]
# rekavši [VERB]
# primetivši [VERB]
# počevši [VERB]
# osvojivši [VERB]
# ponovivši [VERB]
# pobedivši [VERB]
# nazivati [VERB]
#     ∟ nazivajući PRESENT_PAT
# znati [VERB]
#     ∟ znajući PRESENT_PAT
# izdvajati [VERB]
#     ∟ izdvajajući PRESENT_PAT
# čitati [VERB]
#     ∟ čitajući PRESENT_PAT
# uzrokovati [VERB]
#     ∟ uzrokujući PRESENT_PAT
# predsedavati [VERB]
#     ∟ predsedavajući PRESENT_PAT
# zahvaljovati [VERB]
#     ∟ zahvaljujući PRESENT_PAT
# otvarati [VERB]
#     ∟ otvarajući PRESENT_PAT
# obeležavati [VERB]
#     ∟ obeležavajući PRESENT_PAT
# završavati [VERB]
#     ∟ završavajući PRESENT_PAT
# preneražavati [VERB]
#     ∟ preneražavajući PRESENT_PAT
# pojavljovati [VERB]
#     ∟ pojavljujući PRESENT_PAT
# obećavati [VERB]
#     ∟ obećavajući PRESENT_PAT
# nedostati [VERB]
#     ∟ nedostajući PRESENT_PAT
# primoravati [VERB]
#     ∟ primoravajući PRESENT_PAT
# potiskovati [VERB]
#     ∟ potiskujući PRESENT_PAT
# prezati [VERB]
#     ∟ prezajući PRESENT_PAT
# zbunjovati [VERB]
#     ∟ zbunjujući PRESENT_PAT
# zbližavati [VERB]
#     ∟ zbližavajući PRESENT_PAT
# zatvarati [VERB]
#     ∟ zatvarajući PRESENT_PAT
# tragati [VERB]
#     ∟ tragajući PRESENT_PAT
# opisovati [VERB]
#     ∟ opisujući PRESENT_PAT
# favorizovati [VERB]
#     ∟ favorizujući PRESENT_PAT
# oslobađati [VERB]
#     ∟ oslobađajući PRESENT_PAT
# ažurirati [VERB]
#     ∟ ažurirajući PRESENT_PAT
# otuđovati [VERB]
#     ∟ otuđujući PRESENT_PAT
# sprečavati [VERB]
#     ∟ sprečavajući PRESENT_PAT
# optužovati [VERB]
#     ∟ optužujući PRESENT_PAT
# upozoravati [VERB]
#     ∟ upozoravajući PRESENT_PAT
# ponavljati [VERB]
#     ∟ ponavljajući PRESENT_PAT
# uključovati [VERB]
#     ∟ uključujući PRESENT_PAT
# savetovati [VERB]
#     ∟ savetujući PRESENT_PAT
# najavljovati [VERB]
#     ∟ najavljujući PRESENT_PAT
# okončavati [VERB]
#     ∟ okončavajući PRESENT_PAT
# odbijati [VERB]
#     ∟ odbijajući PRESENT_PAT
# naglašavati [VERB]
#     ∟ naglašavajući PRESENT_PAT
# pozdravljati [VERB]
#     ∟ pozdravljajući PRESENT_PAT
# dodati [VERB]
#     ∟ dodajući PRESENT_PAT
# bacati [VERB]
#     ∟ bacajući PRESENT_PAT
# suočavati [VERB]
#     ∟ suočavajući PRESENT_PAT
# diskreditovati [VERB]
#     ∟ diskreditujući PRESENT_PAT
# prodati [VERB]
#     ∟ prodajući PRESENT_PAT
# saopštavati [VERB]
#     ∟ saopštavajući PRESENT_PAT
# opstruirati [VERB]
#     ∟ opstruirajući PRESENT_PAT
# podsećati [VERB]
#     ∟ podsećajući PRESENT_PAT
# ubacovati [VERB]
#     ∟ ubacujući PRESENT_PAT
# uveravati [VERB]
#     ∟ uveravajući PRESENT_PAT
# emigrirati [VERB]
#     ∟ emigrirajući PRESENT_PAT
# kritikovati [VERB]
#     ∟ kritikujući PRESENT_PAT
# narastati [VERB]
#     ∟ narastajući PRESENT_PAT
# ukazovati [VERB]
#     ∟ ukazujući PRESENT_PAT
# svrstavati [VERB]
#     ∟ svrstavajući PRESENT_PAT
# pretvarati [VERB]
#     ∟ pretvarajući PRESENT_PAT
# potvrđovati [VERB]
#     ∟ potvrđujući PRESENT_PAT
# čekati [VERB]
#     ∟ čekajući PRESENT_PAT
# primati [VERB]
#     ∟ primajući PRESENT_PAT
# ohrabrovati [VERB]
#     ∟ ohrabrujući PRESENT_PAT
# odgovarati [VERB]
#     ∟ odgovarajući PRESENT_PAT
# protestovati [VERB]
#     ∟ protestujući PRESENT_PAT
# objašnjavati [VERB]
#     ∟ objašnjavajući PRESENT_PAT
# osuđovati [VERB]
#     ∟ osuđujući PRESENT_PAT
# slovean [ADJ]
#     ∟ sloveniji COMP-M-SG
# beskompromisan [ADJ]
#     ∟ beskompromisniji COMP-M-SG
# uticajan [ADJ]
#     ∟ uticajniji COMP-M-SG
# lina [ADJ]
#     ∟ linija COMP-F-SG
# kompleksna [ADJ]
#     ∟ kompleksnija COMP-F-SG
# kompaan [ADJ]
#     ∟ kompaniji COMP-M-SG
# estono [ADJ]
#     ∟ estonije COMP-N-SG
# sloveno [ADJ]
#     ∟ slovenije COMP-N-SG
# opasan [ADJ]
#     ∟ opasnijim COMP-M-PL
# važna [ADJ]
#     ∟ važnija COMP-F-SG
#       najvažnija SUP-F-SG
# čečean [ADJ]
#     ∟ čečeniji COMP-M-SG
# deceno [ADJ]
#     ∟ decenije COMP-N-SG
# očigledan [ADJ]
#     ∟ očigledniji COMP-M-SG
# transparentan [ADJ]
#     ∟ transparentnijim COMP-M-PL
# tačno [ADJ]
#     ∟ tačnije COMP-N-SG
# špaan [ADJ]
#     ∟ španiji COMP-M-SG
# urgentan [ADJ]
#     ∟ urgentniji COMP-M-SG
#       najurgentniji SUP-M-SG
# docno [ADJ]
#     ∟ docnije COMP-N-SG
# aktivno [ADJ]
#     ∟ aktivnije COMP-N-SG
# makedona [ADJ]
#     ∟ makedonija COMP-F-SG
# uan [ADJ]
#     ∟ uniji COMP-M-SG
# britana [ADJ]
#     ∟ britanija COMP-F-SG
# precizan [ADJ]
#     ∟ precizniji COMP-M-SG
# aliana [ADJ]
#     ∟ alianija COMP-F-SG
# makedono [ADJ]
#     ∟ makedonije COMP-N-SG
# rumuan [ADJ]
#     ∟ rumuniji COMP-M-SG
# represivan [ADJ]
#     ∟ represivniji COMP-M-SG
# ceremoan [ADJ]
#     ∟ ceremoniji COMP-M-SG
# litvano [ADJ]
#     ∟ litvanije COMP-N-SG
# apolona [ADJ]
#     ∟ apolonija COMP-F-SG
# slobodan [ADJ]
#     ∟ slobodniji COMP-M-SG
# uno [ADJ]
#     ∟ unije COMP-N-SG
# značajno [ADJ]
#     ∟ značajnije COMP-N-SG
#       najznačajnije SUP-N-SG
# važno [ADJ]
#     ∟ važnije COMP-N-SG
#       najvažnije SUP-N-SG
# jeftino [ADJ]
#     ∟ jeftinije COMP-N-SG
# demokratična [ADJ]
#     ∟ demokratičnija COMP-F-SG
# konkurentna [ADJ]
#     ∟ konkurentnija COMP-F-SG
# svestrano [ADJ]
#     ∟ svestranije COMP-N-SG
# raan [ADJ]
#     ∟ ranijim COMP-M-PL
# važan [ADJ]
#     ∟ važniji COMP-M-SG
#       najvažniji SUP-M-SG
# una [ADJ]
#     ∟ unija COMP-F-SG
# sigurno [ADJ]
#     ∟ sigurnije COMP-N-SG
# letono [ADJ]
#     ∟ letonije COMP-N-SG
# potpuno [ADJ]
#     ∟ potpunije COMP-N-SG
# makedoan [ADJ]
#     ∟ makedoniji COMP-M-SG
# mena [ADJ]
#     ∟ menija COMP-F-SG
# pensilvaan [ADJ]
#     ∟ pensilvaniji COMP-M-SG
# rumuna [ADJ]
#     ∟ rumunija COMP-F-SG
# ozbiljan [ADJ]
#     ∟ ozbiljniji COMP-M-SG
#       najozbiljniji SUP-M-SG
# rano [ADJ]
#     ∟ ranije COMP-N-SG
# britano [ADJ]
#     ∟ britanije COMP-N-SG
# efikasan [ADJ]
#     ∟ efikasniji COMP-M-SG
# zainteresovana [ADJ]
#     ∟ zainteresovanija COMP-F-SG
# rasprostranjena [ADJ]
#     ∟ rasprostranjenija COMP-F-SG
# albano [ADJ]
#     ∟ albanije COMP-N-SG
# kompano [ADJ]
#     ∟ kompanije COMP-N-SG
# bezbedan [ADJ]
#     ∟ bezbedniji COMP-M-SG
# pozitivan [ADJ]
#     ∟ pozitivniji COMP-M-SG
# konkretno [ADJ]
#     ∟ konkretnije COMP-N-SG
# efikasna [ADJ]
#     ∟ efikasnija COMP-F-SG
# britaan [ADJ]
#     ∟ britaniji COMP-M-SG
# jevtian [ADJ]
#     ∟ jevtinijim COMP-M-PL
# decena [ADJ]
#     ∟ decenija COMP-F-SG
# ceremono [ADJ]
#     ∟ ceremonije COMP-N-SG
# kompana [ADJ]
#     ∟ kompanija COMP-F-SG
# snažno [ADJ]
#     ∟ snažnije COMP-N-SG
# optimalno [ADJ]
#     ∟ optimalnije COMP-N-SG
# albana [ADJ]
#     ∟ albanija COMP-F-SG
# sigurna [ADJ]
#     ∟ sigurnija COMP-F-SG
# izražean [ADJ]
#     ∟ izraženijim COMP-M-PL
# špana [ADJ]
#     ∟ španija COMP-F-SG
# nezadovoljan [ADJ]
#     ∟ nezadovoljniji COMP-M-SG
# kolona [ADJ]
#     ∟ kolonija COMP-F-SG
# lino [ADJ]
#     ∟ linije COMP-N-SG
# iskusan [ADJ]
#     ∟ iskusnijim COMP-M-PL
# optimističan [ADJ]
#     ∟ optimističniji COMP-M-SG
# značajan [ADJ]
#     ∟ značajniji COMP-M-SG
#       najznačajniji SUP-M-SG
# moćan [ADJ]
#     ∟ moćniji COMP-M-SG
#       najmoćniji SUP-M-SG
# striktno [ADJ]
#     ∟ striktnije COMP-N-SG
# albaan [ADJ]
#     ∟ albaniji COMP-M-SG
# telefono [ADJ]
#     ∟ telefonije COMP-N-SG
# rasprostranjean [ADJ]
#     ∟ rasprostranjeniji COMP-M-SG
# slovena [ADJ]
#     ∟ slovenija COMP-F-SG
# diversifikovana [ADJ]
#     ∟ diversifikovanija COMP-F-SG
# lian [ADJ]
#     ∟ liniji COMP-M-SG
# ceremona [ADJ]
#     ∟ ceremonija COMP-F-SG
# kasno [ADJ]
#     ∟ kasnije COMP-N-SG
# rumuno [ADJ]
#     ∟ rumunije COMP-N-SG
# špano [ADJ]
#     ∟ španije COMP-N-SG
# siromašno [ADJ]
#     ∟ siromašnije COMP-N-SG
# rumunski [ADJ]
#     ∟ rumunskog POSSESSIVE
#       rumunskom POSSESSIVE
#       rumunskim POSSESSIVE
#       rumunska POSSESSIVE
#       rumunske POSSESSIVE
#       rumunskoj POSSESSIVE
#       rumunskih POSSESSIVE
#       rumunsko POSSESSIVE
# španski [ADJ]
#     ∟ španskog POSSESSIVE
#       španskim POSSESSIVE
#       španske POSSESSIVE
#       španskih POSSESSIVE
# vremenski [ADJ]
#     ∟ vremenskim POSSESSIVE
#       vremenskih POSSESSIVE
# gagovski [ADJ]
# konjanovski [ADJ]
#     ∟ konjanovskog POSSESSIVE
# teoretski [ADJ]
# švedski [ADJ]
#     ∟ švedskom POSSESSIVE
#       švedska POSSESSIVE
#       švedske POSSESSIVE
#       švedskoj POSSESSIVE
#       švedsku POSSESSIVE
# tetovski [ADJ]
# gruevski [ADJ]
#     ∟ gruevskog POSSESSIVE
#       gruevskim POSSESSIVE
# irski [ADJ]
#     ∟ irskim POSSESSIVE
#       irska POSSESSIVE
#       irske POSSESSIVE
#       irskoj POSSESSIVE
# makedonski [ADJ]
#     ∟ makedonskog POSSESSIVE
#       makedonskom POSSESSIVE
#       makedonskim POSSESSIVE
#       makedonska POSSESSIVE
#       makedonske POSSESSIVE
#       makedonskoj POSSESSIVE
#       makedonsku POSSESSIVE
#       makedonskih POSSESSIVE
#       makedonsko POSSESSIVE
# trajkovski [ADJ]
#     ∟ trajkovskog POSSESSIVE
# imunski [ADJ]
# diplomatski [ADJ]
#     ∟ diplomatskog POSSESSIVE
#       diplomatskom POSSESSIVE
#       diplomatskim POSSESSIVE
#       diplomatska POSSESSIVE
#       diplomatske POSSESSIVE
#       diplomatskoj POSSESSIVE
#       diplomatsku POSSESSIVE
# hrvatski [ADJ]
#     ∟ hrvatskog POSSESSIVE
#       hrvatskom POSSESSIVE
#       hrvatskim POSSESSIVE
#       hrvatska POSSESSIVE
#       hrvatske POSSESSIVE
#       hrvatskoj POSSESSIVE
#       hrvatsku POSSESSIVE
#       hrvatsko POSSESSIVE
# bugarski [ADJ]
#     ∟ bugarskog POSSESSIVE
#       bugarskom POSSESSIVE
#       bugarskim POSSESSIVE
#       bugarska POSSESSIVE
#       bugarske POSSESSIVE
#       bugarskoj POSSESSIVE
#       bugarsku POSSESSIVE
#       bugarskih POSSESSIVE
#       bugarsko POSSESSIVE
# meteorski [ADJ]
# novinarski [ADJ]
#     ∟ novinarska POSSESSIVE
# ivanovski [ADJ]
# evropski [ADJ]
#     ∟ evropskog POSSESSIVE
#       evropskom POSSESSIVE
#       evropskim POSSESSIVE
#       evropska POSSESSIVE
#       evropske POSSESSIVE
#       evropskoj POSSESSIVE
#       evropsku POSSESSIVE
#       evropskih POSSESSIVE
#       evropsko POSSESSIVE
# romski [ADJ]
#     ∟ romskog POSSESSIVE
#       romskom POSSESSIVE
#       romskim POSSESSIVE
#       romska POSSESSIVE
#       romske POSSESSIVE
#       romskoj POSSESSIVE
# zemunski [ADJ]
#     ∟ zemunskog POSSESSIVE
# peruanski [ADJ]
# saudijski [ADJ]
#     ∟ saudijskog POSSESSIVE
#       saudijska POSSESSIVE
#       saudijske POSSESSIVE
# šahovski [ADJ]
#     ∟ šahovska POSSESSIVE
# prevarantski [ADJ]
# vijetnamski [ADJ]
# ministarski [ADJ]
#     ∟ ministarska POSSESSIVE
# turski [ADJ]
#     ∟ turskog POSSESSIVE
#       turskom POSSESSIVE
#       turskim POSSESSIVE
#       turska POSSESSIVE
#       turske POSSESSIVE
#       turskoj POSSESSIVE
#       tursku POSSESSIVE
#       turskih POSSESSIVE
#       tursko POSSESSIVE
# amaterski [ADJ]
#     ∟ amaterske POSSESSIVE
# londonski [ADJ]
#     ∟ londonskoj POSSESSIVE
# sofijski [ADJ]
#     ∟ sofijskoj POSSESSIVE
# aleksievski [ADJ]
# briselski [ADJ]
#     ∟ briselske POSSESSIVE
# verski [ADJ]
#     ∟ verskog POSSESSIVE
#       verskim POSSESSIVE
#       verske POSSESSIVE
#       versku POSSESSIVE
#       verskih POSSESSIVE
#       versko POSSESSIVE
# nikolovski [ADJ]
# balkanski [ADJ]
#     ∟ balkanskim POSSESSIVE
#       balkanska POSSESSIVE
#       balkanske POSSESSIVE
#       balkanskoj POSSESSIVE
#       balkansku POSSESSIVE
#       balkanskih POSSESSIVE
# republikanski [ADJ]
#     ∟ republikanska POSSESSIVE
# lavovski [ADJ]
# belgijski [ADJ]
#     ∟ belgijskom POSSESSIVE
# beogradski [ADJ]
#     ∟ beogradskog POSSESSIVE
#       beogradskom POSSESSIVE
#       beogradska POSSESSIVE
#       beogradske POSSESSIVE
#       beogradskoj POSSESSIVE
#       beogradsku POSSESSIVE
# gruzijski [ADJ]
#     ∟ gruzijske POSSESSIVE
#       gruzijskoj POSSESSIVE
# peševski [ADJ]
# kablovski [ADJ]
#     ∟ kablovske POSSESSIVE
# automatski [ADJ]
#     ∟ automatskom POSSESSIVE
# kosovski [ADJ]
#     ∟ kosovskog POSSESSIVE
#       kosovskom POSSESSIVE
#       kosovskim POSSESSIVE
#       kosovska POSSESSIVE
#       kosovske POSSESSIVE
#       kosovskoj POSSESSIVE
#       kosovskih POSSESSIVE
#       kosovsko POSSESSIVE
# jugoslovenski [ADJ]
#     ∟ jugoslovenskog POSSESSIVE
#       jugoslovenske POSSESSIVE
#       jugoslovenskoj POSSESSIVE
# evroatlantski [ADJ]
#     ∟ evroatlantskim POSSESSIVE
#       evroatlantske POSSESSIVE
#       evroatlantskoj POSSESSIVE
#       evroatlantsku POSSESSIVE
#       evroatlantskih POSSESSIVE
# trojanski [ADJ]
# univerzitetski [ADJ]
#     ∟ univerzitetskom POSSESSIVE
#       univerzitetskim POSSESSIVE
#       univerzitetske POSSESSIVE
#       univerzitetskih POSSESSIVE
# holivudski [ADJ]
#     ∟ holivudskih POSSESSIVE
# portugalski [ADJ]
#     ∟ portugalske POSSESSIVE
# puninski [ADJ]
# penzijski [ADJ]
#     ∟ penzijskog POSSESSIVE
# antonovski [ADJ]
# britanski [ADJ]
#     ∟ britanskog POSSESSIVE
#       britanskom POSSESSIVE
#       britanska POSSESSIVE
#       britanske POSSESSIVE
#       britansku POSSESSIVE
#       britanskih POSSESSIVE
# poposki [ADJ]
# orvelovski [ADJ]
# ohridski [ADJ]
#     ∟ ohridske POSSESSIVE
# ljudski [ADJ]
#     ∟ ljudskim POSSESSIVE
#       ljudska POSSESSIVE
#       ljudske POSSESSIVE
#       ljudskih POSSESSIVE
# levičarski [ADJ]
#     ∟ levičarskim POSSESSIVE
#       levičarska POSSESSIVE
#       levičarskoj POSSESSIVE
# finski [ADJ]
#     ∟ finska POSSESSIVE
#       finske POSSESSIVE
# istorijski [ADJ]
#     ∟ istorijskog POSSESSIVE
#       istorijskom POSSESSIVE
#       istorijskim POSSESSIVE
#       istorijska POSSESSIVE
#       istorijsku POSSESSIVE
#       istorijskih POSSESSIVE
# izraelski [ADJ]
# kurdski [ADJ]
#     ∟ kurdskog POSSESSIVE
#       kurdskom POSSESSIVE
#       kurdske POSSESSIVE
#       kurdskoj POSSESSIVE
#       kurdsku POSSESSIVE
#       kurdskih POSSESSIVE
# avionski [ADJ]
#     ∟ avionskih POSSESSIVE
# vrhunski [ADJ]
#     ∟ vrhunskom POSSESSIVE
#       vrhunske POSSESSIVE
#       vrhunskih POSSESSIVE
# svetski [ADJ]
#     ∟ svetskog POSSESSIVE
#       svetskom POSSESSIVE
#       svetskim POSSESSIVE
#       svetska POSSESSIVE
#       svetske POSSESSIVE
#       svetskoj POSSESSIVE
#       svetsku POSSESSIVE
#       svetskih POSSESSIVE
#       svetsko POSSESSIVE
# moldavski [ADJ]
#     ∟ moldavska POSSESSIVE
#       moldavske POSSESSIVE
#       moldavskih POSSESSIVE
# posttraumatski [ADJ]
#     ∟ posttraumatskog POSSESSIVE
# litvanski [ADJ]
# albanski [ADJ]
#     ∟ albanskog POSSESSIVE
#       albanskom POSSESSIVE
#       albanskim POSSESSIVE
#       albanska POSSESSIVE
#       albanske POSSESSIVE
#       albanskoj POSSESSIVE
#       albansku POSSESSIVE
#       albanskih POSSESSIVE
# spoljnotrgovinski [ADJ]
# stojčevski [ADJ]
# građevinski [ADJ]
#     ∟ građevinskog POSSESSIVE
#       građevinske POSSESSIVE
# studentski [ADJ]
#     ∟ studentskog POSSESSIVE
#       studentskim POSSESSIVE
#       studentske POSSESSIVE
#       studentskih POSSESSIVE
# finansijski [ADJ]
#     ∟ finansijskog POSSESSIVE
#       finansijskom POSSESSIVE
#       finansijskim POSSESSIVE
#       finansijska POSSESSIVE
#       finansijske POSSESSIVE
#       finansijsku POSSESSIVE
#       finansijskih POSSESSIVE
# srpski [ADJ]
#     ∟ srpskog POSSESSIVE
#       srpskom POSSESSIVE
#       srpskim POSSESSIVE
#       srpska POSSESSIVE
#       srpske POSSESSIVE
#       srpskoj POSSESSIVE
#       srpsku POSSESSIVE
#       srpskih POSSESSIVE
#       srpsko POSSESSIVE
# bosanski [ADJ]
#     ∟ bosanskim POSSESSIVE
#       bosanska POSSESSIVE
#       bosanske POSSESSIVE
#       bosanskih POSSESSIVE
# terapeutski [ADJ]
#     ∟ terapeutsko POSSESSIVE
# islamski [ADJ]
#     ∟ islamskim POSSESSIVE
#       islamska POSSESSIVE
#       islamske POSSESSIVE
#       islamsku POSSESSIVE
#       islamskih POSSESSIVE
# nilski [ADJ]
#     ∟ nilskog POSSESSIVE
# trajkoviski [ADJ]
# carinski [ADJ]
#     ∟ carinskog POSSESSIVE
#       carinska POSSESSIVE
#       carinske POSSESSIVE
#       carinskoj POSSESSIVE
#       carinskih POSSESSIVE
# spisateljski [ADJ]
# istinski [ADJ]
#     ∟ istinske POSSESSIVE
# drumski [ADJ]
# filmski [ADJ]
#     ∟ filmskom POSSESSIVE
#       filmskih POSSESSIVE
# budžetski [ADJ]
#     ∟ budžetskog POSSESSIVE
#       budžetskom POSSESSIVE
#       budžetskim POSSESSIVE
#       budžetska POSSESSIVE
#       budžetskih POSSESSIVE
# herkulovski [ADJ]
# životinjski [ADJ]
# helenski [ADJ]
#     ∟ helensko POSSESSIVE
# sovjetski [ADJ]
#     ∟ sovjetskom POSSESSIVE
# bankarski [ADJ]
#     ∟ bankarskim POSSESSIVE
#       bankarske POSSESSIVE
# mađarski [ADJ]
#     ∟ mađarske POSSESSIVE
#       mađarskoj POSSESSIVE
# geografski [ADJ]
# francuski [ADJ]
#     ∟ francuskog POSSESSIVE
#       francuskom POSSESSIVE
#       francuska POSSESSIVE
#       francuske POSSESSIVE
#       francuskoj POSSESSIVE
#       francusku POSSESSIVE
#       francuskih POSSESSIVE
# engleski [ADJ]
#     ∟ engleska POSSESSIVE
# solunski [ADJ]
#     ∟ solunske POSSESSIVE
#       solunsku POSSESSIVE
# dostojevski [ADJ]
# generacijski [ADJ]
# olimpijski [ADJ]
#     ∟ olimpijskom POSSESSIVE
#       olimpijska POSSESSIVE
# ruski [ADJ]
#     ∟ ruskog POSSESSIVE
#       ruskim POSSESSIVE
#       ruske POSSESSIVE
#       ruskoj POSSESSIVE
#       rusku POSSESSIVE
#       ruskih POSSESSIVE
# proevropski [ADJ]
#     ∟ proevropske POSSESSIVE
#       proevropskoj POSSESSIVE
# majski [ADJ]
#     ∟ majskog POSSESSIVE
# katastarski [ADJ]
# novozelandski [ADJ]
# ekonomski [ADJ]
#     ∟ ekonomskog POSSESSIVE
#       ekonomskom POSSESSIVE
#       ekonomskim POSSESSIVE
#       ekonomska POSSESSIVE
#       ekonomske POSSESSIVE
#       ekonomskoj POSSESSIVE
#       ekonomsku POSSESSIVE
#       ekonomskih POSSESSIVE
# bostonski [ADJ]
# akademski [ADJ]
#     ∟ akademska POSSESSIVE
#       akademske POSSESSIVE
#       akademskoj POSSESSIVE
#       akademskih POSSESSIVE
# poreski [ADJ]
#     ∟ poreskom POSSESSIVE
#       poreska POSSESSIVE
#       poreske POSSESSIVE
#       poreskoj POSSESSIVE
#       poreskih POSSESSIVE
# milošoski [ADJ]
# industrijski [ADJ]
#     ∟ industrijskim POSSESSIVE
#       industrijskih POSSESSIVE
# većinski [ADJ]
# dejtonski [ADJ]
#     ∟ dejtonskog POSSESSIVE
#       dejtonskim POSSESSIVE
# mančevski [ADJ]
#     ∟ mančevskog POSSESSIVE
# zakonski [ADJ]
#     ∟ zakonskog POSSESSIVE
#       zakonskom POSSESSIVE
#       zakonske POSSESSIVE
#       zakonsku POSSESSIVE
#       zakonskih POSSESSIVE
# stavrevski [ADJ]
# ramkovski [ADJ]
#     ∟ ramkovskog POSSESSIVE
#       ramkovskom POSSESSIVE
# antologijski [ADJ]
# detektivski [ADJ]
# pariski [ADJ]
# lisabonski [ADJ]
# manevski [ADJ]
# televizijski [ADJ]
#     ∟ televizijske POSSESSIVE
# sudski [ADJ]
#     ∟ sudskog POSSESSIVE
#       sudskom POSSESSIVE
#       sudskim POSSESSIVE
#       sudskoj POSSESSIVE
#       sudskih POSSESSIVE
#       sudsko POSSESSIVE
# pakistanski [ADJ]
#     ∟ pakistanske POSSESSIVE
# medijski [ADJ]
#     ∟ medijskog POSSESSIVE
#       medijskom POSSESSIVE
#       medijske POSSESSIVE
#       medijskih POSSESSIVE
# švajcarski [ADJ]
#     ∟ švajcarskog POSSESSIVE
#       švajcarske POSSESSIVE
#       švajcarskoj POSSESSIVE
# bliski [ADJ]
#     ∟ bliskog POSSESSIVE
#       bliskom POSSESSIVE
#       bliskoj POSSESSIVE
#       blisku POSSESSIVE
# niski [ADJ]
#     ∟ niskom POSSESSIVE
#       niska POSSESSIVE
#       nisku POSSESSIVE
#       niskih POSSESSIVE
# poljski [ADJ]
#     ∟ poljske POSSESSIVE
#       poljskoj POSSESSIVE
#       poljskih POSSESSIVE
# kiparski [ADJ]
#     ∟ kiparskog POSSESSIVE
#       kiparskom POSSESSIVE
#       kiparskim POSSESSIVE
#       kiparske POSSESSIVE
#       kiparskih POSSESSIVE
# socijaldemokratski [ADJ]
#     ∟ socijaldemokratskog POSSESSIVE
#       socijaldemokratskom POSSESSIVE
#       socijaldemokratska POSSESSIVE
#       socijaldemokratske POSSESSIVE
#       socijaldemokratskoj POSSESSIVE
# trgovinski [ADJ]
#     ∟ trgovinskog POSSESSIVE
#       trgovinske POSSESSIVE
# demokratski [ADJ]
#     ∟ demokratskog POSSESSIVE
#       demokratskom POSSESSIVE
#       demokratskim POSSESSIVE
#       demokratska POSSESSIVE
#       demokratske POSSESSIVE
#       demokratsku POSSESSIVE
#       demokratskih POSSESSIVE
#       demokratsko POSSESSIVE
# nedemokratski [ADJ]
# energetski [ADJ]
#     ∟ energetskim POSSESSIVE
#       energetska POSSESSIVE
#       energetske POSSESSIVE
#       energetskih POSSESSIVE
# argentinski [ADJ]
#     ∟ argentinske POSSESSIVE
# cerovski [ADJ]
# italijanski [ADJ]
#     ∟ italijanskog POSSESSIVE
#       italijanske POSSESSIVE
# bučkovski [ADJ]
# proruski [ADJ]
# berlinski [ADJ]
# fudbalski [ADJ]
#     ∟ fudbalskog POSSESSIVE
#       fudbalskim POSSESSIVE
#       fudbalska POSSESSIVE
#       fudbalske POSSESSIVE
#       fudbalskih POSSESSIVE
#       fudbalsko POSSESSIVE
# crvenkovski [ADJ]
#     ∟ crvenkovskim POSSESSIVE
# azilski [ADJ]
#     ∟ azilskog POSSESSIVE
# bosforski [ADJ]
# birokratski [ADJ]
#     ∟ birokratske POSSESSIVE
# sirijski [ADJ]
#     ∟ sirijskog POSSESSIVE
# crnogorski [ADJ]
#     ∟ crnogorskom POSSESSIVE
#       crnogorskim POSSESSIVE
#       crnogorska POSSESSIVE
#       crnogorske POSSESSIVE
#       crnogorskoj POSSESSIVE
#       crnogorsku POSSESSIVE
# reformski [ADJ]
#     ∟ reformskog POSSESSIVE
#       reformskim POSSESSIVE
#       reformske POSSESSIVE
#       reformskih POSSESSIVE
# pridnjestrovski [ADJ]
#     ∟ pridnjestrovskog POSSESSIVE
# istanbulski [ADJ]
#     ∟ istanbulskog POSSESSIVE
#       istanbulskom POSSESSIVE
#       istanbulska POSSESSIVE
#       istanbulske POSSESSIVE
# telefonski [ADJ]
#     ∟ telefonskog POSSESSIVE
#       telefonske POSSESSIVE
# lezbejski [ADJ]
#     ∟ lezbejskog POSSESSIVE
# deoničarski [ADJ]
#     ∟ deoničarskog POSSESSIVE
# pokrajinski [ADJ]
#     ∟ pokrajinskog POSSESSIVE
# jadranski [ADJ]
#     ∟ jadranskog POSSESSIVE
#       jadranske POSSESSIVE
# trenerski [ADJ]
#     ∟ trenerskog POSSESSIVE
# egipatski [ADJ]
#     ∟ egipatskog POSSESSIVE
# letonski [ADJ]
#     ∟ letonskog POSSESSIVE
# libijski [ADJ]
#     ∟ libijskog POSSESSIVE
# palestinski [ADJ]
#     ∟ palestinskog POSSESSIVE
# filozofski [ADJ]
#     ∟ filozofskog POSSESSIVE
# sufijski [ADJ]
#     ∟ sufijskog POSSESSIVE
# filharmonijski [ADJ]
#     ∟ filharmonijskog POSSESSIVE
# suštinski [ADJ]
#     ∟ suštinskog POSSESSIVE
#       suštinskim POSSESSIVE
#       suštinska POSSESSIVE
# mediteranski [ADJ]
#     ∟ mediteranskog POSSESSIVE
#       mediteranskim POSSESSIVE
# praistorijski [ADJ]
#     ∟ praistorijskog POSSESSIVE
# vizantijski [ADJ]
#     ∟ vizantijskog POSSESSIVE
# sportski [ADJ]
#     ∟ sportskog POSSESSIVE
#       sportskom POSSESSIVE
#       sportske POSSESSIVE
#       sportskih POSSESSIVE
# holandski [ADJ]
#     ∟ holandskog POSSESSIVE
#       holandska POSSESSIVE
#       holandske POSSESSIVE
# arhajski [ADJ]
#     ∟ arhajskog POSSESSIVE
# sarajevski [ADJ]
#     ∟ sarajevskog POSSESSIVE
#       sarajevskom POSSESSIVE
#       sarajevskim POSSESSIVE
#       sarajevska POSSESSIVE
#       sarajevskoj POSSESSIVE
# oktobarski [ADJ]
#     ∟ oktobarskog POSSESSIVE
#       oktobarske POSSESSIVE
#       oktobarskih POSSESSIVE
# aprilski [ADJ]
#     ∟ aprilskog POSSESSIVE
# vehabijski [ADJ]
#     ∟ vehabijskog POSSESSIVE
# kineski [ADJ]
#     ∟ kineskog POSSESSIVE
# ženski [ADJ]
#     ∟ ženskog POSSESSIVE
#       ženskom POSSESSIVE
#       ženskim POSSESSIVE
#       ženska POSSESSIVE
#       ženskoj POSSESSIVE
#       ženskih POSSESSIVE
#       žensko POSSESSIVE
# softverski [ADJ]
#     ∟ softverskog POSSESSIVE
#       softverskoj POSSESSIVE
#       softverskih POSSESSIVE
# muslimanski [ADJ]
#     ∟ muslimanskog POSSESSIVE
#       muslimanska POSSESSIVE
#       muslimanske POSSESSIVE
#       muslimanskoj POSSESSIVE
# tračanski [ADJ]
#     ∟ tračanskog POSSESSIVE
#       tračansko POSSESSIVE
# gangsterski [ADJ]
#     ∟ gangsterskog POSSESSIVE
# piranski [ADJ]
#     ∟ piranskog POSSESSIVE
# tuzlanski [ADJ]
#     ∟ tuzlanskog POSSESSIVE
# akcijski [ADJ]
#     ∟ akcijskog POSSESSIVE
#       akcijskih POSSESSIVE
# partenonski [ADJ]
#     ∟ partenonskog POSSESSIVE
# indijski [ADJ]
#     ∟ indijskog POSSESSIVE
# višedecenijski [ADJ]
#     ∟ višedecenijskog POSSESSIVE
#       višedecenijske POSSESSIVE
# zatvorski [ADJ]
#     ∟ zatvorskog POSSESSIVE
#       zatvorskom POSSESSIVE
#       zatvorska POSSESSIVE
#       zatvorske POSSESSIVE
#       zatvorsku POSSESSIVE
# arapski [ADJ]
#     ∟ arapskog POSSESSIVE
#       arapskim POSSESSIVE
# transbalkanski [ADJ]
#     ∟ transbalkanskog POSSESSIVE
# duvanski [ADJ]
#     ∟ duvanskog POSSESSIVE
# masačusetski [ADJ]
#     ∟ masačusetskog POSSESSIVE
# policijski [ADJ]
#     ∟ policijskog POSSESSIVE
#       policijskim POSSESSIVE
#       policijska POSSESSIVE
#       policijske POSSESSIVE
#       policijskoj POSSESSIVE
#       policijsku POSSESSIVE
#       policijskih POSSESSIVE
# gradski [ADJ]
#     ∟ gradskog POSSESSIVE
#       gradskoj POSSESSIVE
# rimski [ADJ]
#     ∟ rimskog POSSESSIVE
#       rimskih POSSESSIVE
# utiski [ADJ]
#     ∟ utiskom POSSESSIVE
# junski [ADJ]
#     ∟ junskom POSSESSIVE
# dvoranski [ADJ]
#     ∟ dvoranskom POSSESSIVE
# polistirenski [ADJ]
#     ∟ polistirenskom POSSESSIVE
# crnomorski [ADJ]
#     ∟ crnomorskom POSSESSIVE
#       crnomorska POSSESSIVE
#       crnomorske POSSESSIVE
# operski [ADJ]
#     ∟ operskom POSSESSIVE
# radikalski [ADJ]
#     ∟ radikalskom POSSESSIVE
# konsultantski [ADJ]
#     ∟ konsultantskom POSSESSIVE
# austrijski [ADJ]
#     ∟ austrijskom POSSESSIVE
#       austrijska POSSESSIVE
#       austrijske POSSESSIVE
# biometrijski [ADJ]
#     ∟ biometrijskom POSSESSIVE
#       biometrijskim POSSESSIVE
#       biometrijske POSSESSIVE
# manjinski [ADJ]
#     ∟ manjinskom POSSESSIVE
#       manjinskim POSSESSIVE
#       manjinska POSSESSIVE
#       manjinske POSSESSIVE
#       manjinsku POSSESSIVE
#       manjinskih POSSESSIVE
#       manjinsko POSSESSIVE
# vojski [ADJ]
#     ∟ vojskom POSSESSIVE
#       vojska POSSESSIVE
#       vojske POSSESSIVE
#       vojsku POSSESSIVE
# teniski [ADJ]
#     ∟ teniskom POSSESSIVE
# pritiski [ADJ]
#     ∟ pritiskom POSSESSIVE
#       pritiska POSSESSIVE
# germanski [ADJ]
#     ∟ germanskom POSSESSIVE
# februarski [ADJ]
#     ∟ februarskom POSSESSIVE
# atletski [ADJ]
#     ∟ atletskom POSSESSIVE
# skadarski [ADJ]
#     ∟ skadarskom POSSESSIVE
#       skadarsko POSSESSIVE
# martovski [ADJ]
#     ∟ martovskim POSSESSIVE
#       martovskih POSSESSIVE
# transatlantski [ADJ]
#     ∟ transatlantskim POSSESSIVE
#       transatlantskih POSSESSIVE
# ilirski [ADJ]
#     ∟ ilirskim POSSESSIVE
# genetski [ADJ]
#     ∟ genetskim POSSESSIVE
# izvorski [ADJ]
#     ∟ izvorskim POSSESSIVE
# tajlandski [ADJ]
#     ∟ tajlandskim POSSESSIVE
# rodopski [ADJ]
#     ∟ rodopskim POSSESSIVE
# diktatorski [ADJ]
#     ∟ diktatorskim POSSESSIVE
# građanski [ADJ]
#     ∟ građanskim POSSESSIVE
#       građanska POSSESSIVE
#       građanske POSSESSIVE
#       građanskoj POSSESSIVE
#       građanskih POSSESSIVE
# novembarski [ADJ]
#     ∟ novembarskim POSSESSIVE
# kajmanski [ADJ]
#     ∟ kajmanskim POSSESSIVE
# pomorski [ADJ]
#     ∟ pomorskim POSSESSIVE
#       pomorska POSSESSIVE
# kišlovski [ADJ]
#     ∟ kišlovskim POSSESSIVE
# sociodemografski [ADJ]
#     ∟ sociodemografskim POSSESSIVE
# predatorski [ADJ]
#     ∟ predatorskim POSSESSIVE
# disciplinski [ADJ]
#     ∟ disciplinska POSSESSIVE
# vojvođanski [ADJ]
#     ∟ vojvođanska POSSESSIVE
#       vojvođanske POSSESSIVE
#       vojvođanskih POSSESSIVE
# prijateljski [ADJ]
#     ∟ prijateljska POSSESSIVE
#       prijateljske POSSESSIVE
#       prijateljskih POSSESSIVE
# velinovski [ADJ]
#     ∟ velinovska POSSESSIVE
# kinematografski [ADJ]
#     ∟ kinematografska POSSESSIVE
# ekspertski [ADJ]
#     ∟ ekspertska POSSESSIVE
#       ekspertskih POSSESSIVE
# socioekonomski [ADJ]
#     ∟ socioekonomska POSSESSIVE
# šengenski [ADJ]
#     ∟ šengenska POSSESSIVE
# stojkovski [ADJ]
#     ∟ stojkovska POSSESSIVE
# padinski [ADJ]
#     ∟ padinska POSSESSIVE
# elenovski [ADJ]
#     ∟ elenovska POSSESSIVE
# bonski [ADJ]
#     ∟ bonska POSSESSIVE
#       bonskih POSSESSIVE
# damaski [ADJ]
#     ∟ damaska POSSESSIVE
# imovinski [ADJ]
#     ∟ imovinska POSSESSIVE
#       imovinsku POSSESSIVE
#       imovinskih POSSESSIVE
# kraljevski [ADJ]
#     ∟ kraljevska POSSESSIVE
# protivtenkovski [ADJ]
#     ∟ protivtenkovska POSSESSIVE
#       protivtenkovske POSSESSIVE
# podravski [ADJ]
#     ∟ podravska POSSESSIVE
# autokratski [ADJ]
#     ∟ autokratska POSSESSIVE
# bavarski [ADJ]
#     ∟ bavarska POSSESSIVE
# kroski [ADJ]
#     ∟ kroska POSSESSIVE
# zalaski [ADJ]
#     ∟ zalaska POSSESSIVE
# kaspijski [ADJ]
#     ∟ kaspijska POSSESSIVE
# grozdanovski [ADJ]
#     ∟ grozdanovska POSSESSIVE
# peski [ADJ]
#     ∟ peska POSSESSIVE
# skopski [ADJ]
#     ∟ skopska POSSESSIVE
# valkanovski [ADJ]
#     ∟ valkanovska POSSESSIVE
# dvotrećinski [ADJ]
#     ∟ dvotrećinska POSSESSIVE
#       dvotrećinsku POSSESSIVE
# petkovski [ADJ]
#     ∟ petkovska POSSESSIVE
# proročanski [ADJ]
#     ∟ proročanska POSSESSIVE
# panevropski [ADJ]
#     ∟ panevropska POSSESSIVE
# elektronski [ADJ]
#     ∟ elektronska POSSESSIVE
#       elektronsku POSSESSIVE
#       elektronskih POSSESSIVE
#       elektronsko POSSESSIVE
# izlaski [ADJ]
#     ∟ izlaska POSSESSIVE
#       izlasku POSSESSIVE
# jevrejski [ADJ]
#     ∟ jevrejska POSSESSIVE
#       jevrejskih POSSESSIVE
# paparoski [ADJ]
#     ∟ paparoska POSSESSIVE
# prekomorski [ADJ]
#     ∟ prekomorska POSSESSIVE
# farmaceutski [ADJ]
#     ∟ farmaceutska POSSESSIVE
#       farmaceutskoj POSSESSIVE
#       farmaceutskih POSSESSIVE
# štipski [ADJ]
#     ∟ štipska POSSESSIVE
# zafirovski [ADJ]
#     ∟ zafirovska POSSESSIVE
# novinski [ADJ]
#     ∟ novinska POSSESSIVE
#       novinskoj POSSESSIVE
#       novinskih POSSESSIVE
# elektroenergetski [ADJ]
#     ∟ elektroenergetska POSSESSIVE
#       elektroenergetsku POSSESSIVE
# tinejdžerski [ADJ]
#     ∟ tinejdžerska POSSESSIVE
# danski [ADJ]
#     ∟ danska POSSESSIVE
#       danskoj POSSESSIVE
#       dansku POSSESSIVE
# ulaski [ADJ]
#     ∟ ulaska POSSESSIVE
#       ulasku POSSESSIVE
# spiski [ADJ]
#     ∟ spiska POSSESSIVE
# floreaski [ADJ]
#     ∟ floreaska POSSESSIVE
# jermenski [ADJ]
#     ∟ jermenska POSSESSIVE
# tenderski [ADJ]
#     ∟ tenderske POSSESSIVE
#       tendersku POSSESSIVE
# dorski [ADJ]
#     ∟ dorske POSSESSIVE
# revizorski [ADJ]
#     ∟ revizorske POSSESSIVE
# demografski [ADJ]
#     ∟ demografske POSSESSIVE
# neprijateljski [ADJ]
#     ∟ neprijateljske POSSESSIVE
# profesorski [ADJ]
#     ∟ profesorske POSSESSIVE
# omladinski [ADJ]
#     ∟ omladinske POSSESSIVE
# aerodromski [ADJ]
#     ∟ aerodromske POSSESSIVE
# kompjuterski [ADJ]
#     ∟ kompjuterske POSSESSIVE
#       kompjutersku POSSESSIVE
#       kompjuterskih POSSESSIVE
# medicinski [ADJ]
#     ∟ medicinske POSSESSIVE
# postdiplomski [ADJ]
#     ∟ postdiplomske POSSESSIVE
# laserski [ADJ]
#     ∟ laserske POSSESSIVE
# vašingtonski [ADJ]
#     ∟ vašingtonske POSSESSIVE
# logorski [ADJ]
#     ∟ logorske POSSESSIVE
# makroekonomski [ADJ]
#     ∟ makroekonomske POSSESSIVE
# organski [ADJ]
#     ∟ organske POSSESSIVE
# terenski [ADJ]
#     ∟ terenske POSSESSIVE
# inženjerski [ADJ]
#     ∟ inženjerske POSSESSIVE
# dablinski [ADJ]
#     ∟ dablinske POSSESSIVE
# ljuski [ADJ]
#     ∟ ljuske POSSESSIVE
# automobilski [ADJ]
#     ∟ automobilske POSSESSIVE
#       automobilsku POSSESSIVE
# entitetski [ADJ]
#     ∟ entitetske POSSESSIVE
#       entitetskih POSSESSIVE
# topografski [ADJ]
#     ∟ topografske POSSESSIVE
# prištinski [ADJ]
#     ∟ prištinske POSSESSIVE
# partijski [ADJ]
#     ∟ partijske POSSESSIVE
# božinovski [ADJ]
#     ∟ božinovske POSSESSIVE
# štamparski [ADJ]
#     ∟ štamparske POSSESSIVE
# školski [ADJ]
#     ∟ školske POSSESSIVE
# desničarski [ADJ]
#     ∟ desničarske POSSESSIVE
# morski [ADJ]
#     ∟ morske POSSESSIVE
#       morsku POSSESSIVE
#       morskih POSSESSIVE
# pivarski [ADJ]
#     ∟ pivarske POSSESSIVE
# registarski [ADJ]
#     ∟ registarske POSSESSIVE
#       registarskih POSSESSIVE
# uski [ADJ]
#     ∟ uske POSSESSIVE
#       usko POSSESSIVE
# planinski [ADJ]
#     ∟ planinske POSSESSIVE
# međuentitetski [ADJ]
#     ∟ međuentitetske POSSESSIVE
# snajperski [ADJ]
#     ∟ snajperske POSSESSIVE
# islandski [ADJ]
#     ∟ islandske POSSESSIVE
#       islandsku POSSESSIVE
# dunavski [ADJ]
#     ∟ dunavske POSSESSIVE
# austrougarski [ADJ]
#     ∟ austrougarskoj POSSESSIVE
# egejski [ADJ]
#     ∟ egejskoj POSSESSIVE
# preševski [ADJ]
#     ∟ preševskoj POSSESSIVE
# petrovaradinski [ADJ]
#     ∟ petrovaradinskoj POSSESSIVE
# porodiljski [ADJ]
#     ∟ porodiljskoj POSSESSIVE
# ambasadorski [ADJ]
#     ∟ ambasadorskoj POSSESSIVE
# latinski [ADJ]
#     ∟ latinskoj POSSESSIVE
# popeski [ADJ]
#     ∟ popesku POSSESSIVE
# draguleski [ADJ]
#     ∟ dragulesku POSSESSIVE
# maneski [ADJ]
#     ∟ manesku POSSESSIVE
# franciski [ADJ]
#     ∟ francisku POSSESSIVE
# teokratski [ADJ]
#     ∟ teokratsku POSSESSIVE
# serotoninski [ADJ]
#     ∟ serotoninsku POSSESSIVE
#       serotoninskih POSSESSIVE
# konferencijski [ADJ]
#     ∟ konferencijsku POSSESSIVE
# baseski [ADJ]
#     ∟ basesku POSSESSIVE
# šumski [ADJ]
#     ∟ šumskih POSSESSIVE
# partnerski [ADJ]
#     ∟ partnerskih POSSESSIVE
# klupski [ADJ]
#     ∟ klupskih POSSESSIVE
# istočnoevropski [ADJ]
#     ∟ istočnoevropskih POSSESSIVE
# propalestinski [ADJ]
#     ∟ propalestinskih POSSESSIVE
# zemaljski [ADJ]
#     ∟ zemaljskih POSSESSIVE
#       zemaljsko POSSESSIVE
# azijski [ADJ]
#     ∟ azijskih POSSESSIVE
# sapunski [ADJ]
#     ∟ sapunskih POSSESSIVE
# piratski [ADJ]
#     ∟ piratskih POSSESSIVE
# špediterski [ADJ]
#     ∟ špediterskih POSSESSIVE
# hemijski [ADJ]
#     ∟ hemijskih POSSESSIVE
#       hemijsko POSSESSIVE
# obalski [ADJ]
#     ∟ obalskih POSSESSIVE
# nemuslimanski [ADJ]
#     ∟ nemuslimanskih POSSESSIVE
# septembarski [ADJ]
#     ∟ septembarskih POSSESSIVE
# pionirski [ADJ]
#     ∟ pionirskih POSSESSIVE
# benzinski [ADJ]
#     ∟ benzinskih POSSESSIVE
# opštinski [ADJ]
#     ∟ opštinskih POSSESSIVE
# hrišćanski [ADJ]
#     ∟ hrišćanskih POSSESSIVE
# festivalski [ADJ]
#     ∟ festivalskih POSSESSIVE
# autorski [ADJ]
#     ∟ autorskih POSSESSIVE
# tematski [ADJ]
#     ∟ tematskih POSSESSIVE
# dobrosusedski [ADJ]
#     ∟ dobrosusedskih POSSESSIVE
# rumuski [ADJ]
#     ∟ rumuskih POSSESSIVE
# komunikacijski [ADJ]
#     ∟ komunikacijskih POSSESSIVE
# avganistanski [ADJ]
#     ∟ avganistanskih POSSESSIVE
# seoski [ADJ]
#     ∟ seoskih POSSESSIVE
# premijerski [ADJ]
#     ∟ premijersko POSSESSIVE
# kuhinjski [ADJ]
#     ∟ kuhinjsko POSSESSIVE
# otomanski [ADJ]
#     ∟ otomansko POSSESSIVE
# stihijski [ADJ]
#     ∟ stihijsko POSSESSIVE
# teorijski [ADJ]
#     ∟ teorijsko POSSESSIVE
# uneski [ADJ]
#     ∟ unesko POSSESSIVE
# postmiloševićevski [ADJ]
#     ∟ postmiloševićevsko POSSESSIVE

# %% [markdown]
# ### 2.3.2 suffix *-čki* and its inflections

# %% [markdown]
# Singular
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|nemački|nemačka|nemačko|
# |genitive|nemačkog|nemačke|nemačkog|
# |dative|nemačkom|nemačkoj|nemačkom|
# |acusative|nemački|nemačku|nemačko|
# |vocative|nemački|nemačka|nemačko|
# |instrumental|nemačkim|nemačkom|nemačkim|
# |locative|nemačkom|nemačkoj|nemačkom|
#
# Plural
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|nemački|nemačke|nemačka|
# |genitive|nemačkih|nemačkih|nemačke|
# |dative|nemačkim|nemačkim|nemačkoj|
# |acusative|nemačke|nemačke|nemačku|
# |vocative|nemački|nemačke|nemačka|
# |instrumental|nemačkim|nemačkim|nemačkom|
# |locative|nemačkim|nemačkim|nemačkoj|

# %% [markdown]
# Possible suffixes: *-čki*, *-čkog*, *-čkom*, *-čka*, *-čkih*, *-čkim*, *-čko*, *-čke*, *-čkoj*, *-čku*

# %%
possessive_adjectives = list(set([w for w in ud_content if w.endswith('čki')]))

# %%
possessive_adjectives
# Out:
# ['predsednički',
#  'bošnjački',
#  'železnički',
#  'američki',
#  'muzički',
#  'radnički',
#  'tehnički',
#  'umetnički',
#  'putnički',
#  'ekstremistički',
#  'teroristički',
#  'etnički',
#  'monopolistički',
#  'statistički',
#  'posmatrački',
#  'preduzetnički',
#  'politički',
#  'slovenački',
#  'turistički',
#  'višestranački',
#  'pacifički',
#  'stranački',
#  'grčki',
#  'komunistički',
#  'irački',
#  'populistički',
#  'brodovlasnički',
#  'nemački',
#  'prostački',
#  'zajednički',
#  'pregovarački',
#  'međuetnički',
#  'ultranacionalistički']

# %%
for possesive_adj in possessive_adjectives:
    add_to_lexicon(possesive_adj, "ADJ")

# %%
inflection_suffixes = [('čkog', 'čki'), ('čkom', 'čki'), ('čka', 'čki'), ('čkih', 'čki'), ('čkim', 'čki'), ('čko', 'čki'), 
                      ('čke', 'čki'), ('čkoj', 'čki'), ('čku', 'čki')]

add_adjective_inflection_forms(inflection_suffixes)

# %%
print_lexicon()
# Out:
# rušiti [VERB]
# zamisliti [VERB]
# pretpostaviti [VERB]
# raditi [VERB]
# odstupiti [VERB]
# otvoriti [VERB]
# izvršiti [VERB]
# otkriti [VERB]
# iznositi [VERB]
# ograničiti [VERB]
# tražiti [VERB]
# obilaziti [VERB]
# odvratiti [VERB]
# dozvoliti [VERB]
# razrešiti [VERB]
# proceniti [VERB]
# uhvatiti [VERB]
# povrediti [VERB]
# obaviti [VERB]
# izraditi [VERB]
# protiviti [VERB]
# kazniti [VERB]
# štiti [VERB]
# slediti [VERB]
# pružiti [VERB]
# nastaviti [VERB]
# složiti [VERB]
# posvetiti [VERB]
# pridružiti [VERB]
# odrediti [VERB]
# osetiti [VERB]
# razvodniti [VERB]
# obezbediti [VERB]
# uskladiti [VERB]
# vlastiti [VERB]
# otkloniti [VERB]
# proučiti [VERB]
# nastupiti [VERB]
# skladištiti [VERB]
# nadoknaditi [VERB]
# rešiti [VERB]
# uraditi [VERB]
# ohrabriti [VERB]
# zaštititi [VERB]
# odbaciti [VERB]
# uništiti [VERB]
# zanemariti [VERB]
# potrošiti [VERB]
# nuditi [VERB]
# vratiti [VERB]
# ustanoviti [VERB]
# iskoristiti [VERB]
# desiti [VERB]
# završiti [VERB]
# predstaviti [VERB]
# suočiti [VERB]
# opslužiti [VERB]
# zatražiti [VERB]
# izgraditi [VERB]
# ugroziti [VERB]
# napraviti [VERB]
# dobiti [VERB]
# preporučiti [VERB]
# odobriti [VERB]
# proširiti [VERB]
# zaključiti [VERB]
# namestiti [VERB]
# izmeniti [VERB]
# potvrditi [VERB]
# posetiti [VERB]
# podnositi [VERB]
# dogoditi [VERB]
# usredsrediti [VERB]
# voditi [VERB]
# ponuditi [VERB]
# odgovoriti [VERB]
# pratiti [VERB]
# pojaviti [VERB]
# povratiti [VERB]
# uspostaviti [VERB]
# razotkriti [VERB]
# predložiti [VERB]
# deliti [VERB]
# koristiti [VERB]
# značiti [VERB]
# uočiti [VERB]
# staviti [VERB]
# otpustiti [VERB]
# promeniti [VERB]
# smanjiti [VERB]
# ostvariti [VERB]
# govoriti [VERB]
# naslediti [VERB]
# ostaviti [VERB]
# krediti [VERB]
# zaposliti [VERB]
# osuditi [VERB]
# smisliti [VERB]
# udružiti [VERB]
# razdvojiti [VERB]
# zaštiti [VERB]
# otplatiti [VERB]
# oprostiti [VERB]
# unaprediti [VERB]
# uložiti [VERB]
# shvatiti [VERB]
# pustiti [VERB]
# učiti [VERB]
# prihvatiti [VERB]
# primiti [VERB]
# odnositi [VERB]
# umoriti [VERB]
# prenositi [VERB]
# zavisiti [VERB]
# udvostručiti [VERB]
# patiti [VERB]
# snositi [VERB]
# postaviti [VERB]
# obnoviti [VERB]
# kupiti [VERB]
# razmotriti [VERB]
# zameniti [VERB]
# poslužiti [VERB]
# sprečiti [VERB]
# pripremiti [VERB]
# protumačiti [VERB]
# arvaniti [VERB]
# različiti [VERB]
# napustiti [VERB]
# ponoviti [VERB]
# izmisliti [VERB]
# usuditi [VERB]
# učiniti [VERB]
# izgubiti [VERB]
# pristupiti [VERB]
# omogućiti [VERB]
# preurediti [VERB]
# uslediti [VERB]
# ispuniti [VERB]
# rijaliti [VERB]
# sprovoditi [VERB]
# stvoriti [VERB]
# težiti [VERB]
# unakaziti [VERB]
# doneti [VERB]
# početi [VERB]
# aveti [VERB]
# videti [VERB]
# započeti [VERB]
# predvideti [VERB]
# oseti [VERB]
# uspeti [VERB]
# tereti [VERB]
# anketi [VERB]
# uzeti [VERB]
# preneti [VERB]
# fakulteti [VERB]
# našteti [VERB]
# ćančeti [VERB]
# deveti [VERB]
# preduzeti [VERB]
# univerziteti [VERB]
# razumeti [VERB]
# dijeti [VERB]
# peti [VERB]
# oteti [VERB]
# animoziteti [VERB]
# dopreti [VERB]
# posveti [VERB]
# doprineti [VERB]
# predmeti [VERB]
# antikviteti [VERB]
# preoteti [VERB]
# meti [VERB]
# ahmeti [VERB]
# preti [VERB]
# oživeti [VERB]
# poseti [VERB]
# preuzeti [VERB]
# podneti [VERB]
# menjati [VERB]
# pati [VERB]
# očekivati [VERB]
# izabrati [VERB]
# obavljati [VERB]
#     ∟ obavljajući PRESENT_PAT
# vraćati [VERB]
# pozvati [VERB]
# održavati [VERB]
# omogućavati [VERB]
#     ∟ omogućavajući PRESENT_PAT
# hrvati [VERB]
# učestvovati [VERB]
# falsifikovati [VERB]
# prestati [VERB]
# sećati [VERB]
# izdavati [VERB]
# zapošljavati [VERB]
# organizovati [VERB]
# postavljati [VERB]
#     ∟ postavljajući PRESENT_PAT
# aktivirati [VERB]
# plaćati [VERB]
# razvijati [VERB]
# razmenjivati [VERB]
# imati [VERB]
#     ∟ imajući PRESENT_PAT
# zadržati [VERB]
# postupati [VERB]
# uticati [VERB]
# sati [VERB]
# preispitati [VERB]
# povećati [VERB]
# preduzimati [VERB]
#     ∟ preduzimajući PRESENT_PAT
# klati [VERB]
# insistirati [VERB]
#     ∟ insistirajući PRESENT_PAT
# slati [VERB]
# odavati [VERB]
# oslanjati [VERB]
# advokati [VERB]
# ispričati [VERB]
# reagovati [VERB]
# intervenisati [VERB]
# odvijati [VERB]
# razrešavati [VERB]
# rešavati [VERB]
# uhvati [VERB]
# posmatrati [VERB]
# pokušavati [VERB]
# pregovarati [VERB]
# analizirati [VERB]
# sarađivati [VERB]
# povezati [VERB]
# koštati [VERB]
# držati [VERB]
# funkcionisati [VERB]
# prebacivati [VERB]
# pojačati [VERB]
# pridržavati [VERB]
# glasati [VERB]
# garantovati [VERB]
# pokušati [VERB]
# izazvati [VERB]
# trajati [VERB]
# povrati [VERB]
# dočekivati [VERB]
# bogati [VERB]
# blokirati [VERB]
# sindikati [VERB]
# dati [VERB]
#     ∟ dajući PRESENT_PAT
# fokusirati [VERB]
# verovati [VERB]
# rezultati [VERB]
# finansirati [VERB]
# prisustvovati [VERB]
# suspendovati [VERB]
# smatrati [VERB]
# pružati [VERB]
# prikazati [VERB]
# postati [VERB]
# oklevati [VERB]
# delati [VERB]
# definisati [VERB]
# plakati [VERB]
# mati [VERB]
# zapitati [VERB]
# zloupotrebljavati [VERB]
# modelirati [VERB]
# nadmetati [VERB]
# poboljšati [VERB]
# poslati [VERB]
# zaletati [VERB]
# doputovati [VERB]
# dobijati [VERB]
# apstinirati [VERB]
# zvati [VERB]
# okončati [VERB]
# predstavljati [VERB]
#     ∟ predstavljajući PRESENT_PAT
# požurivati [VERB]
# pokazati [VERB]
# zalagati [VERB]
# otputovati [VERB]
# poznati [VERB]
# prihvati [VERB]
# zahtevati [VERB]
#     ∟ zahtevajući PRESENT_PAT
# palati [VERB]
# nadati [VERB]
# vrati [VERB]
# kopirati [VERB]
# dokazati [VERB]
# ojačati [VERB]
# putovati [VERB]
# investirati [VERB]
# igrati [VERB]
#     ∟ igrajući PRESENT_PAT
# poštovati [VERB]
# bušati [VERB]
# zarađivati [VERB]
# prepoznati [VERB]
# sastati [VERB]
# olakšati [VERB]
# postojati [VERB]
# izolovati [VERB]
# ratifikovati [VERB]
# morati [VERB]
# izražavati [VERB]
#     ∟ izražavajući PRESENT_PAT
# kandidati [VERB]
# podržati [VERB]
# ometati [VERB]
# predati [VERB]
# ostati [VERB]
# plati [VERB]
# sačuvati [VERB]
# cenjkati [VERB]
# primenjivati [VERB]
# pisati [VERB]
# artikulisati [VERB]
# ticati [VERB]
# održati [VERB]
# objavljivati [VERB]
# pervati [VERB]
# prati [VERB]
# intenzivirati [VERB]
# pridati [VERB]
# osećati [VERB]
# raspravljati [VERB]
# isplati [VERB]
# stajati [VERB]
# razgovarati [VERB]
# uključivati [VERB]
# nemati [VERB]
# pozivati [VERB]
#     ∟ pozivajući PRESENT_PAT
# obraćati [VERB]
#     ∟ obraćajući PRESENT_PAT
# smanjivati [VERB]
# zamišljati [VERB]
# obrati [VERB]
# birati [VERB]
# potpisati [VERB]
# izdati [VERB]
# priznati [VERB]
# uračunati [VERB]
# učinivši [VERB]
# zabeleživši [VERB]
# dostigavši [VERB]
# izazvavši [VERB]
# zamenivši [VERB]
# pohvalivši [VERB]
# naslutivši [VERB]
# završivši [VERB]
# postavivši [VERB]
# pretvorivši [VERB]
# uzdrmavši [VERB]
# dobivši [VERB]
# proširivši [VERB]
# bivši [VERB]
# rekavši [VERB]
# primetivši [VERB]
# počevši [VERB]
# osvojivši [VERB]
# ponovivši [VERB]
# pobedivši [VERB]
# nazivati [VERB]
#     ∟ nazivajući PRESENT_PAT
# znati [VERB]
#     ∟ znajući PRESENT_PAT
# izdvajati [VERB]
#     ∟ izdvajajući PRESENT_PAT
# čitati [VERB]
#     ∟ čitajući PRESENT_PAT
# uzrokovati [VERB]
#     ∟ uzrokujući PRESENT_PAT
# predsedavati [VERB]
#     ∟ predsedavajući PRESENT_PAT
# zahvaljovati [VERB]
#     ∟ zahvaljujući PRESENT_PAT
# otvarati [VERB]
#     ∟ otvarajući PRESENT_PAT
# obeležavati [VERB]
#     ∟ obeležavajući PRESENT_PAT
# završavati [VERB]
#     ∟ završavajući PRESENT_PAT
# preneražavati [VERB]
#     ∟ preneražavajući PRESENT_PAT
# pojavljovati [VERB]
#     ∟ pojavljujući PRESENT_PAT
# obećavati [VERB]
#     ∟ obećavajući PRESENT_PAT
# nedostati [VERB]
#     ∟ nedostajući PRESENT_PAT
# primoravati [VERB]
#     ∟ primoravajući PRESENT_PAT
# potiskovati [VERB]
#     ∟ potiskujući PRESENT_PAT
# prezati [VERB]
#     ∟ prezajući PRESENT_PAT
# zbunjovati [VERB]
#     ∟ zbunjujući PRESENT_PAT
# zbližavati [VERB]
#     ∟ zbližavajući PRESENT_PAT
# zatvarati [VERB]
#     ∟ zatvarajući PRESENT_PAT
# tragati [VERB]
#     ∟ tragajući PRESENT_PAT
# opisovati [VERB]
#     ∟ opisujući PRESENT_PAT
# favorizovati [VERB]
#     ∟ favorizujući PRESENT_PAT
# oslobađati [VERB]
#     ∟ oslobađajući PRESENT_PAT
# ažurirati [VERB]
#     ∟ ažurirajući PRESENT_PAT
# otuđovati [VERB]
#     ∟ otuđujući PRESENT_PAT
# sprečavati [VERB]
#     ∟ sprečavajući PRESENT_PAT
# optužovati [VERB]
#     ∟ optužujući PRESENT_PAT
# upozoravati [VERB]
#     ∟ upozoravajući PRESENT_PAT
# ponavljati [VERB]
#     ∟ ponavljajući PRESENT_PAT
# uključovati [VERB]
#     ∟ uključujući PRESENT_PAT
# savetovati [VERB]
#     ∟ savetujući PRESENT_PAT
# najavljovati [VERB]
#     ∟ najavljujući PRESENT_PAT
# okončavati [VERB]
#     ∟ okončavajući PRESENT_PAT
# odbijati [VERB]
#     ∟ odbijajući PRESENT_PAT
# naglašavati [VERB]
#     ∟ naglašavajući PRESENT_PAT
# pozdravljati [VERB]
#     ∟ pozdravljajući PRESENT_PAT
# dodati [VERB]
#     ∟ dodajući PRESENT_PAT
# bacati [VERB]
#     ∟ bacajući PRESENT_PAT
# suočavati [VERB]
#     ∟ suočavajući PRESENT_PAT
# diskreditovati [VERB]
#     ∟ diskreditujući PRESENT_PAT
# prodati [VERB]
#     ∟ prodajući PRESENT_PAT
# saopštavati [VERB]
#     ∟ saopštavajući PRESENT_PAT
# opstruirati [VERB]
#     ∟ opstruirajući PRESENT_PAT
# podsećati [VERB]
#     ∟ podsećajući PRESENT_PAT
# ubacovati [VERB]
#     ∟ ubacujući PRESENT_PAT
# uveravati [VERB]
#     ∟ uveravajući PRESENT_PAT
# emigrirati [VERB]
#     ∟ emigrirajući PRESENT_PAT
# kritikovati [VERB]
#     ∟ kritikujući PRESENT_PAT
# narastati [VERB]
#     ∟ narastajući PRESENT_PAT
# ukazovati [VERB]
#     ∟ ukazujući PRESENT_PAT
# svrstavati [VERB]
#     ∟ svrstavajući PRESENT_PAT
# pretvarati [VERB]
#     ∟ pretvarajući PRESENT_PAT
# potvrđovati [VERB]
#     ∟ potvrđujući PRESENT_PAT
# čekati [VERB]
#     ∟ čekajući PRESENT_PAT
# primati [VERB]
#     ∟ primajući PRESENT_PAT
# ohrabrovati [VERB]
#     ∟ ohrabrujući PRESENT_PAT
# odgovarati [VERB]
#     ∟ odgovarajući PRESENT_PAT
# protestovati [VERB]
#     ∟ protestujući PRESENT_PAT
# objašnjavati [VERB]
#     ∟ objašnjavajući PRESENT_PAT
# osuđovati [VERB]
#     ∟ osuđujući PRESENT_PAT
# slovean [ADJ]
#     ∟ sloveniji COMP-M-SG
# beskompromisan [ADJ]
#     ∟ beskompromisniji COMP-M-SG
# uticajan [ADJ]
#     ∟ uticajniji COMP-M-SG
# lina [ADJ]
#     ∟ linija COMP-F-SG
# kompleksna [ADJ]
#     ∟ kompleksnija COMP-F-SG
# kompaan [ADJ]
#     ∟ kompaniji COMP-M-SG
# estono [ADJ]
#     ∟ estonije COMP-N-SG
# sloveno [ADJ]
#     ∟ slovenije COMP-N-SG
# opasan [ADJ]
#     ∟ opasnijim COMP-M-PL
# važna [ADJ]
#     ∟ važnija COMP-F-SG
#       najvažnija SUP-F-SG
# čečean [ADJ]
#     ∟ čečeniji COMP-M-SG
# deceno [ADJ]
#     ∟ decenije COMP-N-SG
# očigledan [ADJ]
#     ∟ očigledniji COMP-M-SG
# transparentan [ADJ]
#     ∟ transparentnijim COMP-M-PL
# tačno [ADJ]
#     ∟ tačnije COMP-N-SG
# špaan [ADJ]
#     ∟ španiji COMP-M-SG
# urgentan [ADJ]
#     ∟ urgentniji COMP-M-SG
#       najurgentniji SUP-M-SG
# docno [ADJ]
#     ∟ docnije COMP-N-SG
# aktivno [ADJ]
#     ∟ aktivnije COMP-N-SG
# makedona [ADJ]
#     ∟ makedonija COMP-F-SG
# uan [ADJ]
#     ∟ uniji COMP-M-SG
# britana [ADJ]
#     ∟ britanija COMP-F-SG
# precizan [ADJ]
#     ∟ precizniji COMP-M-SG
# aliana [ADJ]
#     ∟ alianija COMP-F-SG
# makedono [ADJ]
#     ∟ makedonije COMP-N-SG
# rumuan [ADJ]
#     ∟ rumuniji COMP-M-SG
# represivan [ADJ]
#     ∟ represivniji COMP-M-SG
# ceremoan [ADJ]
#     ∟ ceremoniji COMP-M-SG
# litvano [ADJ]
#     ∟ litvanije COMP-N-SG
# apolona [ADJ]
#     ∟ apolonija COMP-F-SG
# slobodan [ADJ]
#     ∟ slobodniji COMP-M-SG
# uno [ADJ]
#     ∟ unije COMP-N-SG
# značajno [ADJ]
#     ∟ značajnije COMP-N-SG
#       najznačajnije SUP-N-SG
# važno [ADJ]
#     ∟ važnije COMP-N-SG
#       najvažnije SUP-N-SG
# jeftino [ADJ]
#     ∟ jeftinije COMP-N-SG
# demokratična [ADJ]
#     ∟ demokratičnija COMP-F-SG
# konkurentna [ADJ]
#     ∟ konkurentnija COMP-F-SG
# svestrano [ADJ]
#     ∟ svestranije COMP-N-SG
# raan [ADJ]
#     ∟ ranijim COMP-M-PL
# važan [ADJ]
#     ∟ važniji COMP-M-SG
#       najvažniji SUP-M-SG
# una [ADJ]
#     ∟ unija COMP-F-SG
# sigurno [ADJ]
#     ∟ sigurnije COMP-N-SG
# letono [ADJ]
#     ∟ letonije COMP-N-SG
# potpuno [ADJ]
#     ∟ potpunije COMP-N-SG
# makedoan [ADJ]
#     ∟ makedoniji COMP-M-SG
# mena [ADJ]
#     ∟ menija COMP-F-SG
# pensilvaan [ADJ]
#     ∟ pensilvaniji COMP-M-SG
# rumuna [ADJ]
#     ∟ rumunija COMP-F-SG
# ozbiljan [ADJ]
#     ∟ ozbiljniji COMP-M-SG
#       najozbiljniji SUP-M-SG
# rano [ADJ]
#     ∟ ranije COMP-N-SG
# britano [ADJ]
#     ∟ britanije COMP-N-SG
# efikasan [ADJ]
#     ∟ efikasniji COMP-M-SG
# zainteresovana [ADJ]
#     ∟ zainteresovanija COMP-F-SG
# rasprostranjena [ADJ]
#     ∟ rasprostranjenija COMP-F-SG
# albano [ADJ]
#     ∟ albanije COMP-N-SG
# kompano [ADJ]
#     ∟ kompanije COMP-N-SG
# bezbedan [ADJ]
#     ∟ bezbedniji COMP-M-SG
# pozitivan [ADJ]
#     ∟ pozitivniji COMP-M-SG
# konkretno [ADJ]
#     ∟ konkretnije COMP-N-SG
# efikasna [ADJ]
#     ∟ efikasnija COMP-F-SG
# britaan [ADJ]
#     ∟ britaniji COMP-M-SG
# jevtian [ADJ]
#     ∟ jevtinijim COMP-M-PL
# decena [ADJ]
#     ∟ decenija COMP-F-SG
# ceremono [ADJ]
#     ∟ ceremonije COMP-N-SG
# kompana [ADJ]
#     ∟ kompanija COMP-F-SG
# snažno [ADJ]
#     ∟ snažnije COMP-N-SG
# optimalno [ADJ]
#     ∟ optimalnije COMP-N-SG
# albana [ADJ]
#     ∟ albanija COMP-F-SG
# sigurna [ADJ]
#     ∟ sigurnija COMP-F-SG
# izražean [ADJ]
#     ∟ izraženijim COMP-M-PL
# špana [ADJ]
#     ∟ španija COMP-F-SG
# nezadovoljan [ADJ]
#     ∟ nezadovoljniji COMP-M-SG
# kolona [ADJ]
#     ∟ kolonija COMP-F-SG
# lino [ADJ]
#     ∟ linije COMP-N-SG
# iskusan [ADJ]
#     ∟ iskusnijim COMP-M-PL
# optimističan [ADJ]
#     ∟ optimističniji COMP-M-SG
# značajan [ADJ]
#     ∟ značajniji COMP-M-SG
#       najznačajniji SUP-M-SG
# moćan [ADJ]
#     ∟ moćniji COMP-M-SG
#       najmoćniji SUP-M-SG
# striktno [ADJ]
#     ∟ striktnije COMP-N-SG
# albaan [ADJ]
#     ∟ albaniji COMP-M-SG
# telefono [ADJ]
#     ∟ telefonije COMP-N-SG
# rasprostranjean [ADJ]
#     ∟ rasprostranjeniji COMP-M-SG
# slovena [ADJ]
#     ∟ slovenija COMP-F-SG
# diversifikovana [ADJ]
#     ∟ diversifikovanija COMP-F-SG
# lian [ADJ]
#     ∟ liniji COMP-M-SG
# ceremona [ADJ]
#     ∟ ceremonija COMP-F-SG
# kasno [ADJ]
#     ∟ kasnije COMP-N-SG
# rumuno [ADJ]
#     ∟ rumunije COMP-N-SG
# špano [ADJ]
#     ∟ španije COMP-N-SG
# siromašno [ADJ]
#     ∟ siromašnije COMP-N-SG
# rumunski [ADJ]
#     ∟ rumunskog POSSESSIVE
#       rumunskom POSSESSIVE
#       rumunskim POSSESSIVE
#       rumunska POSSESSIVE
#       rumunske POSSESSIVE
#       rumunskoj POSSESSIVE
#       rumunskih POSSESSIVE
#       rumunsko POSSESSIVE
# španski [ADJ]
#     ∟ španskog POSSESSIVE
#       španskim POSSESSIVE
#       španske POSSESSIVE
#       španskih POSSESSIVE
# vremenski [ADJ]
#     ∟ vremenskim POSSESSIVE
#       vremenskih POSSESSIVE
# gagovski [ADJ]
# konjanovski [ADJ]
#     ∟ konjanovskog POSSESSIVE
# teoretski [ADJ]
# švedski [ADJ]
#     ∟ švedskom POSSESSIVE
#       švedska POSSESSIVE
#       švedske POSSESSIVE
#       švedskoj POSSESSIVE
#       švedsku POSSESSIVE
# tetovski [ADJ]
# gruevski [ADJ]
#     ∟ gruevskog POSSESSIVE
#       gruevskim POSSESSIVE
# irski [ADJ]
#     ∟ irskim POSSESSIVE
#       irska POSSESSIVE
#       irske POSSESSIVE
#       irskoj POSSESSIVE
# makedonski [ADJ]
#     ∟ makedonskog POSSESSIVE
#       makedonskom POSSESSIVE
#       makedonskim POSSESSIVE
#       makedonska POSSESSIVE
#       makedonske POSSESSIVE
#       makedonskoj POSSESSIVE
#       makedonsku POSSESSIVE
#       makedonskih POSSESSIVE
#       makedonsko POSSESSIVE
# trajkovski [ADJ]
#     ∟ trajkovskog POSSESSIVE
# imunski [ADJ]
# diplomatski [ADJ]
#     ∟ diplomatskog POSSESSIVE
#       diplomatskom POSSESSIVE
#       diplomatskim POSSESSIVE
#       diplomatska POSSESSIVE
#       diplomatske POSSESSIVE
#       diplomatskoj POSSESSIVE
#       diplomatsku POSSESSIVE
# hrvatski [ADJ]
#     ∟ hrvatskog POSSESSIVE
#       hrvatskom POSSESSIVE
#       hrvatskim POSSESSIVE
#       hrvatska POSSESSIVE
#       hrvatske POSSESSIVE
#       hrvatskoj POSSESSIVE
#       hrvatsku POSSESSIVE
#       hrvatsko POSSESSIVE
# bugarski [ADJ]
#     ∟ bugarskog POSSESSIVE
#       bugarskom POSSESSIVE
#       bugarskim POSSESSIVE
#       bugarska POSSESSIVE
#       bugarske POSSESSIVE
#       bugarskoj POSSESSIVE
#       bugarsku POSSESSIVE
#       bugarskih POSSESSIVE
#       bugarsko POSSESSIVE
# meteorski [ADJ]
# novinarski [ADJ]
#     ∟ novinarska POSSESSIVE
# ivanovski [ADJ]
# evropski [ADJ]
#     ∟ evropskog POSSESSIVE
#       evropskom POSSESSIVE
#       evropskim POSSESSIVE
#       evropska POSSESSIVE
#       evropske POSSESSIVE
#       evropskoj POSSESSIVE
#       evropsku POSSESSIVE
#       evropskih POSSESSIVE
#       evropsko POSSESSIVE
# romski [ADJ]
#     ∟ romskog POSSESSIVE
#       romskom POSSESSIVE
#       romskim POSSESSIVE
#       romska POSSESSIVE
#       romske POSSESSIVE
#       romskoj POSSESSIVE
# zemunski [ADJ]
#     ∟ zemunskog POSSESSIVE
# peruanski [ADJ]
# saudijski [ADJ]
#     ∟ saudijskog POSSESSIVE
#       saudijska POSSESSIVE
#       saudijske POSSESSIVE
# šahovski [ADJ]
#     ∟ šahovska POSSESSIVE
# prevarantski [ADJ]
# vijetnamski [ADJ]
# ministarski [ADJ]
#     ∟ ministarska POSSESSIVE
# turski [ADJ]
#     ∟ turskog POSSESSIVE
#       turskom POSSESSIVE
#       turskim POSSESSIVE
#       turska POSSESSIVE
#       turske POSSESSIVE
#       turskoj POSSESSIVE
#       tursku POSSESSIVE
#       turskih POSSESSIVE
#       tursko POSSESSIVE
# amaterski [ADJ]
#     ∟ amaterske POSSESSIVE
# londonski [ADJ]
#     ∟ londonskoj POSSESSIVE
# sofijski [ADJ]
#     ∟ sofijskoj POSSESSIVE
# aleksievski [ADJ]
# briselski [ADJ]
#     ∟ briselske POSSESSIVE
# verski [ADJ]
#     ∟ verskog POSSESSIVE
#       verskim POSSESSIVE
#       verske POSSESSIVE
#       versku POSSESSIVE
#       verskih POSSESSIVE
#       versko POSSESSIVE
# nikolovski [ADJ]
# balkanski [ADJ]
#     ∟ balkanskim POSSESSIVE
#       balkanska POSSESSIVE
#       balkanske POSSESSIVE
#       balkanskoj POSSESSIVE
#       balkansku POSSESSIVE
#       balkanskih POSSESSIVE
# republikanski [ADJ]
#     ∟ republikanska POSSESSIVE
# lavovski [ADJ]
# belgijski [ADJ]
#     ∟ belgijskom POSSESSIVE
# beogradski [ADJ]
#     ∟ beogradskog POSSESSIVE
#       beogradskom POSSESSIVE
#       beogradska POSSESSIVE
#       beogradske POSSESSIVE
#       beogradskoj POSSESSIVE
#       beogradsku POSSESSIVE
# gruzijski [ADJ]
#     ∟ gruzijske POSSESSIVE
#       gruzijskoj POSSESSIVE
# peševski [ADJ]
# kablovski [ADJ]
#     ∟ kablovske POSSESSIVE
# automatski [ADJ]
#     ∟ automatskom POSSESSIVE
# kosovski [ADJ]
#     ∟ kosovskog POSSESSIVE
#       kosovskom POSSESSIVE
#       kosovskim POSSESSIVE
#       kosovska POSSESSIVE
#       kosovske POSSESSIVE
#       kosovskoj POSSESSIVE
#       kosovskih POSSESSIVE
#       kosovsko POSSESSIVE
# jugoslovenski [ADJ]
#     ∟ jugoslovenskog POSSESSIVE
#       jugoslovenske POSSESSIVE
#       jugoslovenskoj POSSESSIVE
# evroatlantski [ADJ]
#     ∟ evroatlantskim POSSESSIVE
#       evroatlantske POSSESSIVE
#       evroatlantskoj POSSESSIVE
#       evroatlantsku POSSESSIVE
#       evroatlantskih POSSESSIVE
# trojanski [ADJ]
# univerzitetski [ADJ]
#     ∟ univerzitetskom POSSESSIVE
#       univerzitetskim POSSESSIVE
#       univerzitetske POSSESSIVE
#       univerzitetskih POSSESSIVE
# holivudski [ADJ]
#     ∟ holivudskih POSSESSIVE
# portugalski [ADJ]
#     ∟ portugalske POSSESSIVE
# puninski [ADJ]
# penzijski [ADJ]
#     ∟ penzijskog POSSESSIVE
# antonovski [ADJ]
# britanski [ADJ]
#     ∟ britanskog POSSESSIVE
#       britanskom POSSESSIVE
#       britanska POSSESSIVE
#       britanske POSSESSIVE
#       britansku POSSESSIVE
#       britanskih POSSESSIVE
# poposki [ADJ]
# orvelovski [ADJ]
# ohridski [ADJ]
#     ∟ ohridske POSSESSIVE
# ljudski [ADJ]
#     ∟ ljudskim POSSESSIVE
#       ljudska POSSESSIVE
#       ljudske POSSESSIVE
#       ljudskih POSSESSIVE
# levičarski [ADJ]
#     ∟ levičarskim POSSESSIVE
#       levičarska POSSESSIVE
#       levičarskoj POSSESSIVE
# finski [ADJ]
#     ∟ finska POSSESSIVE
#       finske POSSESSIVE
# istorijski [ADJ]
#     ∟ istorijskog POSSESSIVE
#       istorijskom POSSESSIVE
#       istorijskim POSSESSIVE
#       istorijska POSSESSIVE
#       istorijsku POSSESSIVE
#       istorijskih POSSESSIVE
# izraelski [ADJ]
# kurdski [ADJ]
#     ∟ kurdskog POSSESSIVE
#       kurdskom POSSESSIVE
#       kurdske POSSESSIVE
#       kurdskoj POSSESSIVE
#       kurdsku POSSESSIVE
#       kurdskih POSSESSIVE
# avionski [ADJ]
#     ∟ avionskih POSSESSIVE
# vrhunski [ADJ]
#     ∟ vrhunskom POSSESSIVE
#       vrhunske POSSESSIVE
#       vrhunskih POSSESSIVE
# svetski [ADJ]
#     ∟ svetskog POSSESSIVE
#       svetskom POSSESSIVE
#       svetskim POSSESSIVE
#       svetska POSSESSIVE
#       svetske POSSESSIVE
#       svetskoj POSSESSIVE
#       svetsku POSSESSIVE
#       svetskih POSSESSIVE
#       svetsko POSSESSIVE
# moldavski [ADJ]
#     ∟ moldavska POSSESSIVE
#       moldavske POSSESSIVE
#       moldavskih POSSESSIVE
# posttraumatski [ADJ]
#     ∟ posttraumatskog POSSESSIVE
# litvanski [ADJ]
# albanski [ADJ]
#     ∟ albanskog POSSESSIVE
#       albanskom POSSESSIVE
#       albanskim POSSESSIVE
#       albanska POSSESSIVE
#       albanske POSSESSIVE
#       albanskoj POSSESSIVE
#       albansku POSSESSIVE
#       albanskih POSSESSIVE
# spoljnotrgovinski [ADJ]
# stojčevski [ADJ]
# građevinski [ADJ]
#     ∟ građevinskog POSSESSIVE
#       građevinske POSSESSIVE
# studentski [ADJ]
#     ∟ studentskog POSSESSIVE
#       studentskim POSSESSIVE
#       studentske POSSESSIVE
#       studentskih POSSESSIVE
# finansijski [ADJ]
#     ∟ finansijskog POSSESSIVE
#       finansijskom POSSESSIVE
#       finansijskim POSSESSIVE
#       finansijska POSSESSIVE
#       finansijske POSSESSIVE
#       finansijsku POSSESSIVE
#       finansijskih POSSESSIVE
# srpski [ADJ]
#     ∟ srpskog POSSESSIVE
#       srpskom POSSESSIVE
#       srpskim POSSESSIVE
#       srpska POSSESSIVE
#       srpske POSSESSIVE
#       srpskoj POSSESSIVE
#       srpsku POSSESSIVE
#       srpskih POSSESSIVE
#       srpsko POSSESSIVE
# bosanski [ADJ]
#     ∟ bosanskim POSSESSIVE
#       bosanska POSSESSIVE
#       bosanske POSSESSIVE
#       bosanskih POSSESSIVE
# terapeutski [ADJ]
#     ∟ terapeutsko POSSESSIVE
# islamski [ADJ]
#     ∟ islamskim POSSESSIVE
#       islamska POSSESSIVE
#       islamske POSSESSIVE
#       islamsku POSSESSIVE
#       islamskih POSSESSIVE
# nilski [ADJ]
#     ∟ nilskog POSSESSIVE
# trajkoviski [ADJ]
# carinski [ADJ]
#     ∟ carinskog POSSESSIVE
#       carinska POSSESSIVE
#       carinske POSSESSIVE
#       carinskoj POSSESSIVE
#       carinskih POSSESSIVE
# spisateljski [ADJ]
# istinski [ADJ]
#     ∟ istinske POSSESSIVE
# drumski [ADJ]
# filmski [ADJ]
#     ∟ filmskom POSSESSIVE
#       filmskih POSSESSIVE
# budžetski [ADJ]
#     ∟ budžetskog POSSESSIVE
#       budžetskom POSSESSIVE
#       budžetskim POSSESSIVE
#       budžetska POSSESSIVE
#       budžetskih POSSESSIVE
# herkulovski [ADJ]
# životinjski [ADJ]
# helenski [ADJ]
#     ∟ helensko POSSESSIVE
# sovjetski [ADJ]
#     ∟ sovjetskom POSSESSIVE
# bankarski [ADJ]
#     ∟ bankarskim POSSESSIVE
#       bankarske POSSESSIVE
# mađarski [ADJ]
#     ∟ mađarske POSSESSIVE
#       mađarskoj POSSESSIVE
# geografski [ADJ]
# francuski [ADJ]
#     ∟ francuskog POSSESSIVE
#       francuskom POSSESSIVE
#       francuska POSSESSIVE
#       francuske POSSESSIVE
#       francuskoj POSSESSIVE
#       francusku POSSESSIVE
#       francuskih POSSESSIVE
# engleski [ADJ]
#     ∟ engleska POSSESSIVE
# solunski [ADJ]
#     ∟ solunske POSSESSIVE
#       solunsku POSSESSIVE
# dostojevski [ADJ]
# generacijski [ADJ]
# olimpijski [ADJ]
#     ∟ olimpijskom POSSESSIVE
#       olimpijska POSSESSIVE
# ruski [ADJ]
#     ∟ ruskog POSSESSIVE
#       ruskim POSSESSIVE
#       ruske POSSESSIVE
#       ruskoj POSSESSIVE
#       rusku POSSESSIVE
#       ruskih POSSESSIVE
# proevropski [ADJ]
#     ∟ proevropske POSSESSIVE
#       proevropskoj POSSESSIVE
# majski [ADJ]
#     ∟ majskog POSSESSIVE
# katastarski [ADJ]
# novozelandski [ADJ]
# ekonomski [ADJ]
#     ∟ ekonomskog POSSESSIVE
#       ekonomskom POSSESSIVE
#       ekonomskim POSSESSIVE
#       ekonomska POSSESSIVE
#       ekonomske POSSESSIVE
#       ekonomskoj POSSESSIVE
#       ekonomsku POSSESSIVE
#       ekonomskih POSSESSIVE
# bostonski [ADJ]
# akademski [ADJ]
#     ∟ akademska POSSESSIVE
#       akademske POSSESSIVE
#       akademskoj POSSESSIVE
#       akademskih POSSESSIVE
# poreski [ADJ]
#     ∟ poreskom POSSESSIVE
#       poreska POSSESSIVE
#       poreske POSSESSIVE
#       poreskoj POSSESSIVE
#       poreskih POSSESSIVE
# milošoski [ADJ]
# industrijski [ADJ]
#     ∟ industrijskim POSSESSIVE
#       industrijskih POSSESSIVE
# većinski [ADJ]
# dejtonski [ADJ]
#     ∟ dejtonskog POSSESSIVE
#       dejtonskim POSSESSIVE
# mančevski [ADJ]
#     ∟ mančevskog POSSESSIVE
# zakonski [ADJ]
#     ∟ zakonskog POSSESSIVE
#       zakonskom POSSESSIVE
#       zakonske POSSESSIVE
#       zakonsku POSSESSIVE
#       zakonskih POSSESSIVE
# stavrevski [ADJ]
# ramkovski [ADJ]
#     ∟ ramkovskog POSSESSIVE
#       ramkovskom POSSESSIVE
# antologijski [ADJ]
# detektivski [ADJ]
# pariski [ADJ]
# lisabonski [ADJ]
# manevski [ADJ]
# televizijski [ADJ]
#     ∟ televizijske POSSESSIVE
# sudski [ADJ]
#     ∟ sudskog POSSESSIVE
#       sudskom POSSESSIVE
#       sudskim POSSESSIVE
#       sudskoj POSSESSIVE
#       sudskih POSSESSIVE
#       sudsko POSSESSIVE
# pakistanski [ADJ]
#     ∟ pakistanske POSSESSIVE
# medijski [ADJ]
#     ∟ medijskog POSSESSIVE
#       medijskom POSSESSIVE
#       medijske POSSESSIVE
#       medijskih POSSESSIVE
# švajcarski [ADJ]
#     ∟ švajcarskog POSSESSIVE
#       švajcarske POSSESSIVE
#       švajcarskoj POSSESSIVE
# bliski [ADJ]
#     ∟ bliskog POSSESSIVE
#       bliskom POSSESSIVE
#       bliskoj POSSESSIVE
#       blisku POSSESSIVE
# niski [ADJ]
#     ∟ niskom POSSESSIVE
#       niska POSSESSIVE
#       nisku POSSESSIVE
#       niskih POSSESSIVE
# poljski [ADJ]
#     ∟ poljske POSSESSIVE
#       poljskoj POSSESSIVE
#       poljskih POSSESSIVE
# kiparski [ADJ]
#     ∟ kiparskog POSSESSIVE
#       kiparskom POSSESSIVE
#       kiparskim POSSESSIVE
#       kiparske POSSESSIVE
#       kiparskih POSSESSIVE
# socijaldemokratski [ADJ]
#     ∟ socijaldemokratskog POSSESSIVE
#       socijaldemokratskom POSSESSIVE
#       socijaldemokratska POSSESSIVE
#       socijaldemokratske POSSESSIVE
#       socijaldemokratskoj POSSESSIVE
# trgovinski [ADJ]
#     ∟ trgovinskog POSSESSIVE
#       trgovinske POSSESSIVE
# demokratski [ADJ]
#     ∟ demokratskog POSSESSIVE
#       demokratskom POSSESSIVE
#       demokratskim POSSESSIVE
#       demokratska POSSESSIVE
#       demokratske POSSESSIVE
#       demokratsku POSSESSIVE
#       demokratskih POSSESSIVE
#       demokratsko POSSESSIVE
# nedemokratski [ADJ]
# energetski [ADJ]
#     ∟ energetskim POSSESSIVE
#       energetska POSSESSIVE
#       energetske POSSESSIVE
#       energetskih POSSESSIVE
# argentinski [ADJ]
#     ∟ argentinske POSSESSIVE
# cerovski [ADJ]
# italijanski [ADJ]
#     ∟ italijanskog POSSESSIVE
#       italijanske POSSESSIVE
# bučkovski [ADJ]
# proruski [ADJ]
# berlinski [ADJ]
# fudbalski [ADJ]
#     ∟ fudbalskog POSSESSIVE
#       fudbalskim POSSESSIVE
#       fudbalska POSSESSIVE
#       fudbalske POSSESSIVE
#       fudbalskih POSSESSIVE
#       fudbalsko POSSESSIVE
# crvenkovski [ADJ]
#     ∟ crvenkovskim POSSESSIVE
# azilski [ADJ]
#     ∟ azilskog POSSESSIVE
# bosforski [ADJ]
# birokratski [ADJ]
#     ∟ birokratske POSSESSIVE
# sirijski [ADJ]
#     ∟ sirijskog POSSESSIVE
# crnogorski [ADJ]
#     ∟ crnogorskom POSSESSIVE
#       crnogorskim POSSESSIVE
#       crnogorska POSSESSIVE
#       crnogorske POSSESSIVE
#       crnogorskoj POSSESSIVE
#       crnogorsku POSSESSIVE
# reformski [ADJ]
#     ∟ reformskog POSSESSIVE
#       reformskim POSSESSIVE
#       reformske POSSESSIVE
#       reformskih POSSESSIVE
# pridnjestrovski [ADJ]
#     ∟ pridnjestrovskog POSSESSIVE
# istanbulski [ADJ]
#     ∟ istanbulskog POSSESSIVE
#       istanbulskom POSSESSIVE
#       istanbulska POSSESSIVE
#       istanbulske POSSESSIVE
# telefonski [ADJ]
#     ∟ telefonskog POSSESSIVE
#       telefonske POSSESSIVE
# lezbejski [ADJ]
#     ∟ lezbejskog POSSESSIVE
# deoničarski [ADJ]
#     ∟ deoničarskog POSSESSIVE
# pokrajinski [ADJ]
#     ∟ pokrajinskog POSSESSIVE
# jadranski [ADJ]
#     ∟ jadranskog POSSESSIVE
#       jadranske POSSESSIVE
# trenerski [ADJ]
#     ∟ trenerskog POSSESSIVE
# egipatski [ADJ]
#     ∟ egipatskog POSSESSIVE
# letonski [ADJ]
#     ∟ letonskog POSSESSIVE
# libijski [ADJ]
#     ∟ libijskog POSSESSIVE
# palestinski [ADJ]
#     ∟ palestinskog POSSESSIVE
# filozofski [ADJ]
#     ∟ filozofskog POSSESSIVE
# sufijski [ADJ]
#     ∟ sufijskog POSSESSIVE
# filharmonijski [ADJ]
#     ∟ filharmonijskog POSSESSIVE
# suštinski [ADJ]
#     ∟ suštinskog POSSESSIVE
#       suštinskim POSSESSIVE
#       suštinska POSSESSIVE
# mediteranski [ADJ]
#     ∟ mediteranskog POSSESSIVE
#       mediteranskim POSSESSIVE
# praistorijski [ADJ]
#     ∟ praistorijskog POSSESSIVE
# vizantijski [ADJ]
#     ∟ vizantijskog POSSESSIVE
# sportski [ADJ]
#     ∟ sportskog POSSESSIVE
#       sportskom POSSESSIVE
#       sportske POSSESSIVE
#       sportskih POSSESSIVE
# holandski [ADJ]
#     ∟ holandskog POSSESSIVE
#       holandska POSSESSIVE
#       holandske POSSESSIVE
# arhajski [ADJ]
#     ∟ arhajskog POSSESSIVE
# sarajevski [ADJ]
#     ∟ sarajevskog POSSESSIVE
#       sarajevskom POSSESSIVE
#       sarajevskim POSSESSIVE
#       sarajevska POSSESSIVE
#       sarajevskoj POSSESSIVE
# oktobarski [ADJ]
#     ∟ oktobarskog POSSESSIVE
#       oktobarske POSSESSIVE
#       oktobarskih POSSESSIVE
# aprilski [ADJ]
#     ∟ aprilskog POSSESSIVE
# vehabijski [ADJ]
#     ∟ vehabijskog POSSESSIVE
# kineski [ADJ]
#     ∟ kineskog POSSESSIVE
# ženski [ADJ]
#     ∟ ženskog POSSESSIVE
#       ženskom POSSESSIVE
#       ženskim POSSESSIVE
#       ženska POSSESSIVE
#       ženskoj POSSESSIVE
#       ženskih POSSESSIVE
#       žensko POSSESSIVE
# softverski [ADJ]
#     ∟ softverskog POSSESSIVE
#       softverskoj POSSESSIVE
#       softverskih POSSESSIVE
# muslimanski [ADJ]
#     ∟ muslimanskog POSSESSIVE
#       muslimanska POSSESSIVE
#       muslimanske POSSESSIVE
#       muslimanskoj POSSESSIVE
# tračanski [ADJ]
#     ∟ tračanskog POSSESSIVE
#       tračansko POSSESSIVE
# gangsterski [ADJ]
#     ∟ gangsterskog POSSESSIVE
# piranski [ADJ]
#     ∟ piranskog POSSESSIVE
# tuzlanski [ADJ]
#     ∟ tuzlanskog POSSESSIVE
# akcijski [ADJ]
#     ∟ akcijskog POSSESSIVE
#       akcijskih POSSESSIVE
# partenonski [ADJ]
#     ∟ partenonskog POSSESSIVE
# indijski [ADJ]
#     ∟ indijskog POSSESSIVE
# višedecenijski [ADJ]
#     ∟ višedecenijskog POSSESSIVE
#       višedecenijske POSSESSIVE
# zatvorski [ADJ]
#     ∟ zatvorskog POSSESSIVE
#       zatvorskom POSSESSIVE
#       zatvorska POSSESSIVE
#       zatvorske POSSESSIVE
#       zatvorsku POSSESSIVE
# arapski [ADJ]
#     ∟ arapskog POSSESSIVE
#       arapskim POSSESSIVE
# transbalkanski [ADJ]
#     ∟ transbalkanskog POSSESSIVE
# duvanski [ADJ]
#     ∟ duvanskog POSSESSIVE
# masačusetski [ADJ]
#     ∟ masačusetskog POSSESSIVE
# policijski [ADJ]
#     ∟ policijskog POSSESSIVE
#       policijskim POSSESSIVE
#       policijska POSSESSIVE
#       policijske POSSESSIVE
#       policijskoj POSSESSIVE
#       policijsku POSSESSIVE
#       policijskih POSSESSIVE
# gradski [ADJ]
#     ∟ gradskog POSSESSIVE
#       gradskoj POSSESSIVE
# rimski [ADJ]
#     ∟ rimskog POSSESSIVE
#       rimskih POSSESSIVE
# utiski [ADJ]
#     ∟ utiskom POSSESSIVE
# junski [ADJ]
#     ∟ junskom POSSESSIVE
# dvoranski [ADJ]
#     ∟ dvoranskom POSSESSIVE
# polistirenski [ADJ]
#     ∟ polistirenskom POSSESSIVE
# crnomorski [ADJ]
#     ∟ crnomorskom POSSESSIVE
#       crnomorska POSSESSIVE
#       crnomorske POSSESSIVE
# operski [ADJ]
#     ∟ operskom POSSESSIVE
# radikalski [ADJ]
#     ∟ radikalskom POSSESSIVE
# konsultantski [ADJ]
#     ∟ konsultantskom POSSESSIVE
# austrijski [ADJ]
#     ∟ austrijskom POSSESSIVE
#       austrijska POSSESSIVE
#       austrijske POSSESSIVE
# biometrijski [ADJ]
#     ∟ biometrijskom POSSESSIVE
#       biometrijskim POSSESSIVE
#       biometrijske POSSESSIVE
# manjinski [ADJ]
#     ∟ manjinskom POSSESSIVE
#       manjinskim POSSESSIVE
#       manjinska POSSESSIVE
#       manjinske POSSESSIVE
#       manjinsku POSSESSIVE
#       manjinskih POSSESSIVE
#       manjinsko POSSESSIVE
# vojski [ADJ]
#     ∟ vojskom POSSESSIVE
#       vojska POSSESSIVE
#       vojske POSSESSIVE
#       vojsku POSSESSIVE
# teniski [ADJ]
#     ∟ teniskom POSSESSIVE
# pritiski [ADJ]
#     ∟ pritiskom POSSESSIVE
#       pritiska POSSESSIVE
# germanski [ADJ]
#     ∟ germanskom POSSESSIVE
# februarski [ADJ]
#     ∟ februarskom POSSESSIVE
# atletski [ADJ]
#     ∟ atletskom POSSESSIVE
# skadarski [ADJ]
#     ∟ skadarskom POSSESSIVE
#       skadarsko POSSESSIVE
# martovski [ADJ]
#     ∟ martovskim POSSESSIVE
#       martovskih POSSESSIVE
# transatlantski [ADJ]
#     ∟ transatlantskim POSSESSIVE
#       transatlantskih POSSESSIVE
# ilirski [ADJ]
#     ∟ ilirskim POSSESSIVE
# genetski [ADJ]
#     ∟ genetskim POSSESSIVE
# izvorski [ADJ]
#     ∟ izvorskim POSSESSIVE
# tajlandski [ADJ]
#     ∟ tajlandskim POSSESSIVE
# rodopski [ADJ]
#     ∟ rodopskim POSSESSIVE
# diktatorski [ADJ]
#     ∟ diktatorskim POSSESSIVE
# građanski [ADJ]
#     ∟ građanskim POSSESSIVE
#       građanska POSSESSIVE
#       građanske POSSESSIVE
#       građanskoj POSSESSIVE
#       građanskih POSSESSIVE
# novembarski [ADJ]
#     ∟ novembarskim POSSESSIVE
# kajmanski [ADJ]
#     ∟ kajmanskim POSSESSIVE
# pomorski [ADJ]
#     ∟ pomorskim POSSESSIVE
#       pomorska POSSESSIVE
# kišlovski [ADJ]
#     ∟ kišlovskim POSSESSIVE
# sociodemografski [ADJ]
#     ∟ sociodemografskim POSSESSIVE
# predatorski [ADJ]
#     ∟ predatorskim POSSESSIVE
# disciplinski [ADJ]
#     ∟ disciplinska POSSESSIVE
# vojvođanski [ADJ]
#     ∟ vojvođanska POSSESSIVE
#       vojvođanske POSSESSIVE
#       vojvođanskih POSSESSIVE
# prijateljski [ADJ]
#     ∟ prijateljska POSSESSIVE
#       prijateljske POSSESSIVE
#       prijateljskih POSSESSIVE
# velinovski [ADJ]
#     ∟ velinovska POSSESSIVE
# kinematografski [ADJ]
#     ∟ kinematografska POSSESSIVE
# ekspertski [ADJ]
#     ∟ ekspertska POSSESSIVE
#       ekspertskih POSSESSIVE
# socioekonomski [ADJ]
#     ∟ socioekonomska POSSESSIVE
# šengenski [ADJ]
#     ∟ šengenska POSSESSIVE
# stojkovski [ADJ]
#     ∟ stojkovska POSSESSIVE
# padinski [ADJ]
#     ∟ padinska POSSESSIVE
# elenovski [ADJ]
#     ∟ elenovska POSSESSIVE
# bonski [ADJ]
#     ∟ bonska POSSESSIVE
#       bonskih POSSESSIVE
# damaski [ADJ]
#     ∟ damaska POSSESSIVE
# imovinski [ADJ]
#     ∟ imovinska POSSESSIVE
#       imovinsku POSSESSIVE
#       imovinskih POSSESSIVE
# kraljevski [ADJ]
#     ∟ kraljevska POSSESSIVE
# protivtenkovski [ADJ]
#     ∟ protivtenkovska POSSESSIVE
#       protivtenkovske POSSESSIVE
# podravski [ADJ]
#     ∟ podravska POSSESSIVE
# autokratski [ADJ]
#     ∟ autokratska POSSESSIVE
# bavarski [ADJ]
#     ∟ bavarska POSSESSIVE
# kroski [ADJ]
#     ∟ kroska POSSESSIVE
# zalaski [ADJ]
#     ∟ zalaska POSSESSIVE
# kaspijski [ADJ]
#     ∟ kaspijska POSSESSIVE
# grozdanovski [ADJ]
#     ∟ grozdanovska POSSESSIVE
# peski [ADJ]
#     ∟ peska POSSESSIVE
# skopski [ADJ]
#     ∟ skopska POSSESSIVE
# valkanovski [ADJ]
#     ∟ valkanovska POSSESSIVE
# dvotrećinski [ADJ]
#     ∟ dvotrećinska POSSESSIVE
#       dvotrećinsku POSSESSIVE
# petkovski [ADJ]
#     ∟ petkovska POSSESSIVE
# proročanski [ADJ]
#     ∟ proročanska POSSESSIVE
# panevropski [ADJ]
#     ∟ panevropska POSSESSIVE
# elektronski [ADJ]
#     ∟ elektronska POSSESSIVE
#       elektronsku POSSESSIVE
#       elektronskih POSSESSIVE
#       elektronsko POSSESSIVE
# izlaski [ADJ]
#     ∟ izlaska POSSESSIVE
#       izlasku POSSESSIVE
# jevrejski [ADJ]
#     ∟ jevrejska POSSESSIVE
#       jevrejskih POSSESSIVE
# paparoski [ADJ]
#     ∟ paparoska POSSESSIVE
# prekomorski [ADJ]
#     ∟ prekomorska POSSESSIVE
# farmaceutski [ADJ]
#     ∟ farmaceutska POSSESSIVE
#       farmaceutskoj POSSESSIVE
#       farmaceutskih POSSESSIVE
# štipski [ADJ]
#     ∟ štipska POSSESSIVE
# zafirovski [ADJ]
#     ∟ zafirovska POSSESSIVE
# novinski [ADJ]
#     ∟ novinska POSSESSIVE
#       novinskoj POSSESSIVE
#       novinskih POSSESSIVE
# elektroenergetski [ADJ]
#     ∟ elektroenergetska POSSESSIVE
#       elektroenergetsku POSSESSIVE
# tinejdžerski [ADJ]
#     ∟ tinejdžerska POSSESSIVE
# danski [ADJ]
#     ∟ danska POSSESSIVE
#       danskoj POSSESSIVE
#       dansku POSSESSIVE
# ulaski [ADJ]
#     ∟ ulaska POSSESSIVE
#       ulasku POSSESSIVE
# spiski [ADJ]
#     ∟ spiska POSSESSIVE
# floreaski [ADJ]
#     ∟ floreaska POSSESSIVE
# jermenski [ADJ]
#     ∟ jermenska POSSESSIVE
# tenderski [ADJ]
#     ∟ tenderske POSSESSIVE
#       tendersku POSSESSIVE
# dorski [ADJ]
#     ∟ dorske POSSESSIVE
# revizorski [ADJ]
#     ∟ revizorske POSSESSIVE
# demografski [ADJ]
#     ∟ demografske POSSESSIVE
# neprijateljski [ADJ]
#     ∟ neprijateljske POSSESSIVE
# profesorski [ADJ]
#     ∟ profesorske POSSESSIVE
# omladinski [ADJ]
#     ∟ omladinske POSSESSIVE
# aerodromski [ADJ]
#     ∟ aerodromske POSSESSIVE
# kompjuterski [ADJ]
#     ∟ kompjuterske POSSESSIVE
#       kompjutersku POSSESSIVE
#       kompjuterskih POSSESSIVE
# medicinski [ADJ]
#     ∟ medicinske POSSESSIVE
# postdiplomski [ADJ]
#     ∟ postdiplomske POSSESSIVE
# laserski [ADJ]
#     ∟ laserske POSSESSIVE
# vašingtonski [ADJ]
#     ∟ vašingtonske POSSESSIVE
# logorski [ADJ]
#     ∟ logorske POSSESSIVE
# makroekonomski [ADJ]
#     ∟ makroekonomske POSSESSIVE
# organski [ADJ]
#     ∟ organske POSSESSIVE
# terenski [ADJ]
#     ∟ terenske POSSESSIVE
# inženjerski [ADJ]
#     ∟ inženjerske POSSESSIVE
# dablinski [ADJ]
#     ∟ dablinske POSSESSIVE
# ljuski [ADJ]
#     ∟ ljuske POSSESSIVE
# automobilski [ADJ]
#     ∟ automobilske POSSESSIVE
#       automobilsku POSSESSIVE
# entitetski [ADJ]
#     ∟ entitetske POSSESSIVE
#       entitetskih POSSESSIVE
# topografski [ADJ]
#     ∟ topografske POSSESSIVE
# prištinski [ADJ]
#     ∟ prištinske POSSESSIVE
# partijski [ADJ]
#     ∟ partijske POSSESSIVE
# božinovski [ADJ]
#     ∟ božinovske POSSESSIVE
# štamparski [ADJ]
#     ∟ štamparske POSSESSIVE
# školski [ADJ]
#     ∟ školske POSSESSIVE
# desničarski [ADJ]
#     ∟ desničarske POSSESSIVE
# morski [ADJ]
#     ∟ morske POSSESSIVE
#       morsku POSSESSIVE
#       morskih POSSESSIVE
# pivarski [ADJ]
#     ∟ pivarske POSSESSIVE
# registarski [ADJ]
#     ∟ registarske POSSESSIVE
#       registarskih POSSESSIVE
# uski [ADJ]
#     ∟ uske POSSESSIVE
#       usko POSSESSIVE
# planinski [ADJ]
#     ∟ planinske POSSESSIVE
# međuentitetski [ADJ]
#     ∟ međuentitetske POSSESSIVE
# snajperski [ADJ]
#     ∟ snajperske POSSESSIVE
# islandski [ADJ]
#     ∟ islandske POSSESSIVE
#       islandsku POSSESSIVE
# dunavski [ADJ]
#     ∟ dunavske POSSESSIVE
# austrougarski [ADJ]
#     ∟ austrougarskoj POSSESSIVE
# egejski [ADJ]
#     ∟ egejskoj POSSESSIVE
# preševski [ADJ]
#     ∟ preševskoj POSSESSIVE
# petrovaradinski [ADJ]
#     ∟ petrovaradinskoj POSSESSIVE
# porodiljski [ADJ]
#     ∟ porodiljskoj POSSESSIVE
# ambasadorski [ADJ]
#     ∟ ambasadorskoj POSSESSIVE
# latinski [ADJ]
#     ∟ latinskoj POSSESSIVE
# popeski [ADJ]
#     ∟ popesku POSSESSIVE
# draguleski [ADJ]
#     ∟ dragulesku POSSESSIVE
# maneski [ADJ]
#     ∟ manesku POSSESSIVE
# franciski [ADJ]
#     ∟ francisku POSSESSIVE
# teokratski [ADJ]
#     ∟ teokratsku POSSESSIVE
# serotoninski [ADJ]
#     ∟ serotoninsku POSSESSIVE
#       serotoninskih POSSESSIVE
# konferencijski [ADJ]
#     ∟ konferencijsku POSSESSIVE
# baseski [ADJ]
#     ∟ basesku POSSESSIVE
# šumski [ADJ]
#     ∟ šumskih POSSESSIVE
# partnerski [ADJ]
#     ∟ partnerskih POSSESSIVE
# klupski [ADJ]
#     ∟ klupskih POSSESSIVE
# istočnoevropski [ADJ]
#     ∟ istočnoevropskih POSSESSIVE
# propalestinski [ADJ]
#     ∟ propalestinskih POSSESSIVE
# zemaljski [ADJ]
#     ∟ zemaljskih POSSESSIVE
#       zemaljsko POSSESSIVE
# azijski [ADJ]
#     ∟ azijskih POSSESSIVE
# sapunski [ADJ]
#     ∟ sapunskih POSSESSIVE
# piratski [ADJ]
#     ∟ piratskih POSSESSIVE
# špediterski [ADJ]
#     ∟ špediterskih POSSESSIVE
# hemijski [ADJ]
#     ∟ hemijskih POSSESSIVE
#       hemijsko POSSESSIVE
# obalski [ADJ]
#     ∟ obalskih POSSESSIVE
# nemuslimanski [ADJ]
#     ∟ nemuslimanskih POSSESSIVE
# septembarski [ADJ]
#     ∟ septembarskih POSSESSIVE
# pionirski [ADJ]
#     ∟ pionirskih POSSESSIVE
# benzinski [ADJ]
#     ∟ benzinskih POSSESSIVE
# opštinski [ADJ]
#     ∟ opštinskih POSSESSIVE
# hrišćanski [ADJ]
#     ∟ hrišćanskih POSSESSIVE
# festivalski [ADJ]
#     ∟ festivalskih POSSESSIVE
# autorski [ADJ]
#     ∟ autorskih POSSESSIVE
# tematski [ADJ]
#     ∟ tematskih POSSESSIVE
# dobrosusedski [ADJ]
#     ∟ dobrosusedskih POSSESSIVE
# rumuski [ADJ]
#     ∟ rumuskih POSSESSIVE
# komunikacijski [ADJ]
#     ∟ komunikacijskih POSSESSIVE
# avganistanski [ADJ]
#     ∟ avganistanskih POSSESSIVE
# seoski [ADJ]
#     ∟ seoskih POSSESSIVE
# premijerski [ADJ]
#     ∟ premijersko POSSESSIVE
# kuhinjski [ADJ]
#     ∟ kuhinjsko POSSESSIVE
# otomanski [ADJ]
#     ∟ otomansko POSSESSIVE
# stihijski [ADJ]
#     ∟ stihijsko POSSESSIVE
# teorijski [ADJ]
#     ∟ teorijsko POSSESSIVE
# uneski [ADJ]
#     ∟ unesko POSSESSIVE
# postmiloševićevski [ADJ]
#     ∟ postmiloševićevsko POSSESSIVE
# predsednički [ADJ]
#     ∟ predsedničkog POSSESSIVE
#       predsedničkih POSSESSIVE
#       predsedničke POSSESSIVE
#       predsedničku POSSESSIVE
# bošnjački [ADJ]
#     ∟ bošnjačkog POSSESSIVE
#       bošnjačkom POSSESSIVE
#       bošnjačkih POSSESSIVE
#       bošnjačke POSSESSIVE
# železnički [ADJ]
#     ∟ železnička POSSESSIVE
#       železničkih POSSESSIVE
#       železničkim POSSESSIVE
#       železničke POSSESSIVE
#       železničkoj POSSESSIVE
# američki [ADJ]
#     ∟ američkog POSSESSIVE
#       američkom POSSESSIVE
#       američka POSSESSIVE
#       američkih POSSESSIVE
#       američkim POSSESSIVE
#       američke POSSESSIVE
#       američku POSSESSIVE
# muzički [ADJ]
#     ∟ muzičkog POSSESSIVE
#       muzičkom POSSESSIVE
#       muzičku POSSESSIVE
# radnički [ADJ]
#     ∟ radničke POSSESSIVE
# tehnički [ADJ]
#     ∟ tehničkih POSSESSIVE
#       tehničkim POSSESSIVE
#       tehničko POSSESSIVE
#       tehničke POSSESSIVE
# umetnički [ADJ]
#     ∟ umetnička POSSESSIVE
#       umetničke POSSESSIVE
#       umetničkoj POSSESSIVE
# putnički [ADJ]
# ekstremistički [ADJ]
#     ∟ ekstremistička POSSESSIVE
#       ekstremističkih POSSESSIVE
#       ekstremističke POSSESSIVE
# teroristički [ADJ]
#     ∟ terorističkog POSSESSIVE
#       teroristička POSSESSIVE
#       terorističkih POSSESSIVE
#       terorističkim POSSESSIVE
#       terorističke POSSESSIVE
# etnički [ADJ]
#     ∟ etničkog POSSESSIVE
#       etnička POSSESSIVE
#       etničkih POSSESSIVE
#       etničkim POSSESSIVE
#       etničke POSSESSIVE
#       etničkoj POSSESSIVE
#       etničku POSSESSIVE
# monopolistički [ADJ]
#     ∟ monopolističkih POSSESSIVE
#       monopolističke POSSESSIVE
#       monopolističku POSSESSIVE
# statistički [ADJ]
#     ∟ statističkog POSSESSIVE
#       statističkim POSSESSIVE
# posmatrački [ADJ]
#     ∟ posmatračkog POSSESSIVE
#       posmatračka POSSESSIVE
#       posmatračkoj POSSESSIVE
# preduzetnički [ADJ]
# politički [ADJ]
#     ∟ političkog POSSESSIVE
#       političkom POSSESSIVE
#       politička POSSESSIVE
#       političkih POSSESSIVE
#       političkim POSSESSIVE
#       političko POSSESSIVE
#       političke POSSESSIVE
#       političkoj POSSESSIVE
#       političku POSSESSIVE
# slovenački [ADJ]
#     ∟ slovenačkom POSSESSIVE
#       slovenačka POSSESSIVE
#       slovenačkim POSSESSIVE
#       slovenačko POSSESSIVE
# turistički [ADJ]
#     ∟ turističkog POSSESSIVE
#       turističkom POSSESSIVE
#       turistička POSSESSIVE
#       turističkih POSSESSIVE
#       turističkoj POSSESSIVE
# višestranački [ADJ]
#     ∟ višestranačke POSSESSIVE
#       višestranačku POSSESSIVE
# pacifički [ADJ]
# stranački [ADJ]
#     ∟ stranačka POSSESSIVE
#       stranačkih POSSESSIVE
#       stranačkim POSSESSIVE
# grčki [ADJ]
#     ∟ grčkog POSSESSIVE
#       grčkom POSSESSIVE
#       grčka POSSESSIVE
#       grčkih POSSESSIVE
#       grčkim POSSESSIVE
#       grčko POSSESSIVE
#       grčke POSSESSIVE
#       grčkoj POSSESSIVE
#       grčku POSSESSIVE
# komunistički [ADJ]
#     ∟ komunističkog POSSESSIVE
#       komunističkim POSSESSIVE
#       komunističke POSSESSIVE
#       komunističku POSSESSIVE
# irački [ADJ]
#     ∟ iračkih POSSESSIVE
#       iračkim POSSESSIVE
#       iračkoj POSSESSIVE
# populistički [ADJ]
# brodovlasnički [ADJ]
# nemački [ADJ]
#     ∟ nemačkog POSSESSIVE
#       nemačka POSSESSIVE
#       nemačkih POSSESSIVE
#       nemačkim POSSESSIVE
#       nemačke POSSESSIVE
#       nemačkoj POSSESSIVE
#       nemačku POSSESSIVE
# prostački [ADJ]
# zajednički [ADJ]
#     ∟ zajedničkog POSSESSIVE
#       zajedničkom POSSESSIVE
#       zajednička POSSESSIVE
#       zajedničkim POSSESSIVE
#       zajedničko POSSESSIVE
#       zajedničke POSSESSIVE
#       zajedničkoj POSSESSIVE
#       zajedničku POSSESSIVE
# pregovarački [ADJ]
#     ∟ pregovaračkog POSSESSIVE
#       pregovaračka POSSESSIVE
#       pregovaračkih POSSESSIVE
#       pregovaračku POSSESSIVE
# međuetnički [ADJ]
#     ∟ međuetničkih POSSESSIVE
# ultranacionalistički [ADJ]
#     ∟ ultranacionalističkih POSSESSIVE
#       ultranacionalističke POSSESSIVE
# geopolitički [ADJ]
#     ∟ geopolitičkog POSSESSIVE
#       geopolitičkom POSSESSIVE
#       geopolitičkoj POSSESSIVE
# analitički [ADJ]
#     ∟ analitičkog POSSESSIVE
# veštački [ADJ]
#     ∟ veštačkog POSSESSIVE
#       veštačku POSSESSIVE
# čitalački [ADJ]
#     ∟ čitalačkog POSSESSIVE
# srebrenički [ADJ]
#     ∟ srebreničkog POSSESSIVE
#       srebreničkom POSSESSIVE
# predstavnički [ADJ]
#     ∟ predstavničkog POSSESSIVE
# staljinistički [ADJ]
#     ∟ staljinističkog POSSESSIVE
# severnoafrički [ADJ]
#     ∟ severnoafričkog POSSESSIVE
# prevoznički [ADJ]
#     ∟ prevozničkog POSSESSIVE
# fizički [ADJ]
#     ∟ fizičkog POSSESSIVE
#       fizička POSSESSIVE
#       fizičko POSSESSIVE
#       fizičke POSSESSIVE
# poslanički [ADJ]
#     ∟ poslaničkog POSSESSIVE
#       poslaničkih POSSESSIVE
#       poslaničke POSSESSIVE
# predavački [ADJ]
#     ∟ predavačkog POSSESSIVE
#       predavačkih POSSESSIVE
# vlasnički [ADJ]
#     ∟ vlasničkom POSSESSIVE
#       vlasnička POSSESSIVE
#       vlasničkih POSSESSIVE
# jezički [ADJ]
#     ∟ jezičkom POSSESSIVE
#       jezičku POSSESSIVE
# postkomunistički [ADJ]
#     ∟ postkomunističkom POSSESSIVE
#       postkomunističkih POSSESSIVE
# zagrebački [ADJ]
#     ∟ zagrebačkom POSSESSIVE
#       zagrebačke POSSESSIVE
# plivački [ADJ]
#     ∟ plivačkom POSSESSIVE
#       plivačkim POSSESSIVE
# brčki [ADJ]
#     ∟ brčkom POSSESSIVE
# nacistički [ADJ]
#     ∟ nacističkom POSSESSIVE
#       nacističkim POSSESSIVE
#       nacističke POSSESSIVE
# antiteroristički [ADJ]
#     ∟ antiteroristička POSSESSIVE
#       antiterorističke POSSESSIVE
# osvetnički [ADJ]
#     ∟ osvetnička POSSESSIVE
# nacionalistički [ADJ]
#     ∟ nacionalistička POSSESSIVE
#       nacionalističke POSSESSIVE
#       nacionalističku POSSESSIVE
# ručki [ADJ]
#     ∟ ručka POSSESSIVE
# pljački [ADJ]
#     ∟ pljačka POSSESSIVE
#       pljačke POSSESSIVE
# opljački [ADJ]
#     ∟ opljačka POSSESSIVE
# dugački [ADJ]
#     ∟ dugačka POSSESSIVE
#       dugačke POSSESSIVE
# tački [ADJ]
#     ∟ tačka POSSESSIVE
#       tačku POSSESSIVE
# socijalistički [ADJ]
#     ∟ socijalistička POSSESSIVE
#       socijalističkih POSSESSIVE
#       socijalističke POSSESSIVE
#       socijalističkoj POSSESSIVE
#       socijalističku POSSESSIVE
# borački [ADJ]
#     ∟ boračka POSSESSIVE
# ludački [ADJ]
#     ∟ ludačka POSSESSIVE
# antički [ADJ]
#     ∟ antičkih POSSESSIVE
# katolički [ADJ]
#     ∟ katoličkih POSSESSIVE
#       katoličke POSSESSIVE
# nasilnički [ADJ]
#     ∟ nasilničkih POSSESSIVE
# unutarpolitički [ADJ]
#     ∟ unutarpolitičkih POSSESSIVE
# forenzički [ADJ]
#     ∟ forenzičkih POSSESSIVE
# etički [ADJ]
#     ∟ etičkih POSSESSIVE
# glasački [ADJ]
#     ∟ glasačkih POSSESSIVE
#       glasačke POSSESSIVE
# dužnički [ADJ]
#     ∟ dužničkih POSSESSIVE
# protivnički [ADJ]
#     ∟ protivničkih POSSESSIVE
#       protivničke POSSESSIVE
# kriminalistički [ADJ]
#     ∟ kriminalističkih POSSESSIVE
#       kriminalističke POSSESSIVE
# nedomorodački [ADJ]
#     ∟ nedomorodačkih POSSESSIVE
# afrički [ADJ]
#     ∟ afričkih POSSESSIVE
# seizmički [ADJ]
#     ∟ seizmičkim POSSESSIVE
# vozački [ADJ]
#     ∟ vozačkim POSSESSIVE
# senzacionalistički [ADJ]
#     ∟ senzacionalističkim POSSESSIVE
#       senzacionalističke POSSESSIVE
# lingvistički [ADJ]
#     ∟ lingvističkim POSSESSIVE
# informatički [ADJ]
#     ∟ informatičko POSSESSIVE
# multietnički [ADJ]
#     ∟ multietničko POSSESSIVE
# narkotički [ADJ]
#     ∟ narkotičko POSSESSIVE
# birački [ADJ]
#     ∟ biračko POSSESSIVE
# aktivistički [ADJ]
#     ∟ aktivističke POSSESSIVE
# sandžački [ADJ]
#     ∟ sandžačke POSSESSIVE
# borilački [ADJ]
#     ∟ borilačke POSSESSIVE
# dijagnostički [ADJ]
#     ∟ dijagnostičke POSSESSIVE
# igrački [ADJ]
#     ∟ igračke POSSESSIVE
# kukavički [ADJ]
#     ∟ kukavičke POSSESSIVE
# oslobodilački [ADJ]
#     ∟ oslobodilačke POSSESSIVE
# zaključki [ADJ]
#     ∟ zaključke POSSESSIVE
# glumački [ADJ]
#     ∟ glumačke POSSESSIVE
#       glumačku POSSESSIVE
# oportunistički [ADJ]
#     ∟ oportunističke POSSESSIVE
# rasistički [ADJ]
#     ∟ rasističke POSSESSIVE
# riječki [ADJ]
#     ∟ riječkoj POSSESSIVE
# bečki [ADJ]
#     ∟ bečkoj POSSESSIVE
# optuženički [ADJ]
#     ∟ optuženičkoj POSSESSIVE
# uređivački [ADJ]
#     ∟ uređivačku POSSESSIVE
# bački [ADJ]
#     ∟ bačku POSSESSIVE
# lučki [ADJ]
#     ∟ lučku POSSESSIVE
# antikomunistički [ADJ]
#     ∟ antikomunističku POSSESSIVE
# državnički [ADJ]
#     ∟ državničku POSSESSIVE

# %% [markdown]
# ### 2.3.3 suffix *-ški* and its inflections

# %% [markdown]
# Singular
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|češki|češka|češko|
# |genitive|češkog|češke|češkog|
# |dative|češkom|češkoj|češkom|
# |acusative|češki|češku|češko|
# |vocative|češki|češka|češko|
# |instrumental|češkim|češkom|češkim|
# |locative|češkom|češkoj|češkom|
#
# Plural
#
# | case | masculine | feminine | neutral |
# |------|-----------|----------|---------|
# |nominative|češki|češke|češka|
# |genitive|čeških|čeških|češke|
# |dative|češkim|češkim|češkoj|
# |acusative|češke|češke|češku|
# |vocative|češki|češke|češka|
# |instrumental|češkim|češkim|češkom|
# |locative|češkim|češkim|češkoj|

# %% [markdown]
# Possible suffixes: *-ški*, *-škog*, *-škom*, *-ška*, *-ških*, *-škim*, *-ško*, *-ške*, *-škoj*, *-šku*

# %%
possessive_adjectives = list(set([w for w in ud_content if w.endswith('ški')]))

# %%
possessive_adjectives
# Out:
# ['zoološki',
#  'ideološki',
#  'haški',
#  'malteški',
#  'muški',
#  'tehnološki',
#  'bombaški',
#  'norveški',
#  'češki',
#  'njujorški',
#  'strateški',
#  'luksemburški']

# %%
for possesive_adj in possessive_adjectives:
    add_to_lexicon(possesive_adj, "ADJ")

# %%
inflection_suffixes = [('škog', 'ški'), ('škom', 'ški'), ('ška', 'ški'), ('ških', 'ški'), ('škim', 'ški'), ('ško', 'ški'), 
                      ('ške', 'ški'), ('škoj', 'ški'), ('šku', 'ški')]

add_adjective_inflection_forms(inflection_suffixes)

# %%
print_lexicon()
# Out:
# rušiti [VERB]
# zamisliti [VERB]
# pretpostaviti [VERB]
# raditi [VERB]
# odstupiti [VERB]
# otvoriti [VERB]
# izvršiti [VERB]
# otkriti [VERB]
# iznositi [VERB]
# ograničiti [VERB]
# tražiti [VERB]
# obilaziti [VERB]
# odvratiti [VERB]
# dozvoliti [VERB]
# razrešiti [VERB]
# proceniti [VERB]
# uhvatiti [VERB]
# povrediti [VERB]
# obaviti [VERB]
# izraditi [VERB]
# protiviti [VERB]
# kazniti [VERB]
# štiti [VERB]
# slediti [VERB]
# pružiti [VERB]
# nastaviti [VERB]
# složiti [VERB]
# posvetiti [VERB]
# pridružiti [VERB]
# odrediti [VERB]
# osetiti [VERB]
# razvodniti [VERB]
# obezbediti [VERB]
# uskladiti [VERB]
# vlastiti [VERB]
# otkloniti [VERB]
# proučiti [VERB]
# nastupiti [VERB]
# skladištiti [VERB]
# nadoknaditi [VERB]
# rešiti [VERB]
# uraditi [VERB]
# ohrabriti [VERB]
# zaštititi [VERB]
# odbaciti [VERB]
# uništiti [VERB]
# zanemariti [VERB]
# potrošiti [VERB]
# nuditi [VERB]
# vratiti [VERB]
# ustanoviti [VERB]
# iskoristiti [VERB]
# desiti [VERB]
# završiti [VERB]
# predstaviti [VERB]
# suočiti [VERB]
# opslužiti [VERB]
# zatražiti [VERB]
# izgraditi [VERB]
# ugroziti [VERB]
# napraviti [VERB]
# dobiti [VERB]
# preporučiti [VERB]
# odobriti [VERB]
# proširiti [VERB]
# zaključiti [VERB]
# namestiti [VERB]
# izmeniti [VERB]
# potvrditi [VERB]
# posetiti [VERB]
# podnositi [VERB]
# dogoditi [VERB]
# usredsrediti [VERB]
# voditi [VERB]
# ponuditi [VERB]
# odgovoriti [VERB]
# pratiti [VERB]
# pojaviti [VERB]
# povratiti [VERB]
# uspostaviti [VERB]
# razotkriti [VERB]
# predložiti [VERB]
# deliti [VERB]
# koristiti [VERB]
# značiti [VERB]
# uočiti [VERB]
# staviti [VERB]
# otpustiti [VERB]
# promeniti [VERB]
# smanjiti [VERB]
# ostvariti [VERB]
# govoriti [VERB]
# naslediti [VERB]
# ostaviti [VERB]
# krediti [VERB]
# zaposliti [VERB]
# osuditi [VERB]
# smisliti [VERB]
# udružiti [VERB]
# razdvojiti [VERB]
# zaštiti [VERB]
# otplatiti [VERB]
# oprostiti [VERB]
# unaprediti [VERB]
# uložiti [VERB]
# shvatiti [VERB]
# pustiti [VERB]
# učiti [VERB]
# prihvatiti [VERB]
# primiti [VERB]
# odnositi [VERB]
# umoriti [VERB]
# prenositi [VERB]
# zavisiti [VERB]
# udvostručiti [VERB]
# patiti [VERB]
# snositi [VERB]
# postaviti [VERB]
# obnoviti [VERB]
# kupiti [VERB]
# razmotriti [VERB]
# zameniti [VERB]
# poslužiti [VERB]
# sprečiti [VERB]
# pripremiti [VERB]
# protumačiti [VERB]
# arvaniti [VERB]
# različiti [VERB]
# napustiti [VERB]
# ponoviti [VERB]
# izmisliti [VERB]
# usuditi [VERB]
# učiniti [VERB]
# izgubiti [VERB]
# pristupiti [VERB]
# omogućiti [VERB]
# preurediti [VERB]
# uslediti [VERB]
# ispuniti [VERB]
# rijaliti [VERB]
# sprovoditi [VERB]
# stvoriti [VERB]
# težiti [VERB]
# unakaziti [VERB]
# doneti [VERB]
# početi [VERB]
# aveti [VERB]
# videti [VERB]
# započeti [VERB]
# predvideti [VERB]
# oseti [VERB]
# uspeti [VERB]
# tereti [VERB]
# anketi [VERB]
# uzeti [VERB]
# preneti [VERB]
# fakulteti [VERB]
# našteti [VERB]
# ćančeti [VERB]
# deveti [VERB]
# preduzeti [VERB]
# univerziteti [VERB]
# razumeti [VERB]
# dijeti [VERB]
# peti [VERB]
# oteti [VERB]
# animoziteti [VERB]
# dopreti [VERB]
# posveti [VERB]
# doprineti [VERB]
# predmeti [VERB]
# antikviteti [VERB]
# preoteti [VERB]
# meti [VERB]
# ahmeti [VERB]
# preti [VERB]
# oživeti [VERB]
# poseti [VERB]
# preuzeti [VERB]
# podneti [VERB]
# menjati [VERB]
# pati [VERB]
# očekivati [VERB]
# izabrati [VERB]
# obavljati [VERB]
#     ∟ obavljajući PRESENT_PAT
# vraćati [VERB]
# pozvati [VERB]
# održavati [VERB]
# omogućavati [VERB]
#     ∟ omogućavajući PRESENT_PAT
# hrvati [VERB]
# učestvovati [VERB]
# falsifikovati [VERB]
# prestati [VERB]
# sećati [VERB]
# izdavati [VERB]
# zapošljavati [VERB]
# organizovati [VERB]
# postavljati [VERB]
#     ∟ postavljajući PRESENT_PAT
# aktivirati [VERB]
# plaćati [VERB]
# razvijati [VERB]
# razmenjivati [VERB]
# imati [VERB]
#     ∟ imajući PRESENT_PAT
# zadržati [VERB]
# postupati [VERB]
# uticati [VERB]
# sati [VERB]
# preispitati [VERB]
# povećati [VERB]
# preduzimati [VERB]
#     ∟ preduzimajući PRESENT_PAT
# klati [VERB]
# insistirati [VERB]
#     ∟ insistirajući PRESENT_PAT
# slati [VERB]
# odavati [VERB]
# oslanjati [VERB]
# advokati [VERB]
# ispričati [VERB]
# reagovati [VERB]
# intervenisati [VERB]
# odvijati [VERB]
# razrešavati [VERB]
# rešavati [VERB]
# uhvati [VERB]
# posmatrati [VERB]
# pokušavati [VERB]
# pregovarati [VERB]
# analizirati [VERB]
# sarađivati [VERB]
# povezati [VERB]
# koštati [VERB]
# držati [VERB]
# funkcionisati [VERB]
# prebacivati [VERB]
# pojačati [VERB]
# pridržavati [VERB]
# glasati [VERB]
# garantovati [VERB]
# pokušati [VERB]
# izazvati [VERB]
# trajati [VERB]
# povrati [VERB]
# dočekivati [VERB]
# bogati [VERB]
# blokirati [VERB]
# sindikati [VERB]
# dati [VERB]
#     ∟ dajući PRESENT_PAT
# fokusirati [VERB]
# verovati [VERB]
# rezultati [VERB]
# finansirati [VERB]
# prisustvovati [VERB]
# suspendovati [VERB]
# smatrati [VERB]
# pružati [VERB]
# prikazati [VERB]
# postati [VERB]
# oklevati [VERB]
# delati [VERB]
# definisati [VERB]
# plakati [VERB]
# mati [VERB]
# zapitati [VERB]
# zloupotrebljavati [VERB]
# modelirati [VERB]
# nadmetati [VERB]
# poboljšati [VERB]
# poslati [VERB]
# zaletati [VERB]
# doputovati [VERB]
# dobijati [VERB]
# apstinirati [VERB]
# zvati [VERB]
# okončati [VERB]
# predstavljati [VERB]
#     ∟ predstavljajući PRESENT_PAT
# požurivati [VERB]
# pokazati [VERB]
# zalagati [VERB]
# otputovati [VERB]
# poznati [VERB]
# prihvati [VERB]
# zahtevati [VERB]
#     ∟ zahtevajući PRESENT_PAT
# palati [VERB]
# nadati [VERB]
# vrati [VERB]
# kopirati [VERB]
# dokazati [VERB]
# ojačati [VERB]
# putovati [VERB]
# investirati [VERB]
# igrati [VERB]
#     ∟ igrajući PRESENT_PAT
# poštovati [VERB]
# bušati [VERB]
# zarađivati [VERB]
# prepoznati [VERB]
# sastati [VERB]
# olakšati [VERB]
# postojati [VERB]
# izolovati [VERB]
# ratifikovati [VERB]
# morati [VERB]
# izražavati [VERB]
#     ∟ izražavajući PRESENT_PAT
# kandidati [VERB]
# podržati [VERB]
# ometati [VERB]
# predati [VERB]
# ostati [VERB]
# plati [VERB]
# sačuvati [VERB]
# cenjkati [VERB]
# primenjivati [VERB]
# pisati [VERB]
# artikulisati [VERB]
# ticati [VERB]
# održati [VERB]
# objavljivati [VERB]
# pervati [VERB]
# prati [VERB]
# intenzivirati [VERB]
# pridati [VERB]
# osećati [VERB]
# raspravljati [VERB]
# isplati [VERB]
# stajati [VERB]
# razgovarati [VERB]
# uključivati [VERB]
# nemati [VERB]
# pozivati [VERB]
#     ∟ pozivajući PRESENT_PAT
# obraćati [VERB]
#     ∟ obraćajući PRESENT_PAT
# smanjivati [VERB]
# zamišljati [VERB]
# obrati [VERB]
# birati [VERB]
# potpisati [VERB]
# izdati [VERB]
# priznati [VERB]
# uračunati [VERB]
# učinivši [VERB]
# zabeleživši [VERB]
# dostigavši [VERB]
# izazvavši [VERB]
# zamenivši [VERB]
# pohvalivši [VERB]
# naslutivši [VERB]
# završivši [VERB]
# postavivši [VERB]
# pretvorivši [VERB]
# uzdrmavši [VERB]
# dobivši [VERB]
# proširivši [VERB]
# bivši [VERB]
# rekavši [VERB]
# primetivši [VERB]
# počevši [VERB]
# osvojivši [VERB]
# ponovivši [VERB]
# pobedivši [VERB]
# nazivati [VERB]
#     ∟ nazivajući PRESENT_PAT
# znati [VERB]
#     ∟ znajući PRESENT_PAT
# izdvajati [VERB]
#     ∟ izdvajajući PRESENT_PAT
# čitati [VERB]
#     ∟ čitajući PRESENT_PAT
# uzrokovati [VERB]
#     ∟ uzrokujući PRESENT_PAT
# predsedavati [VERB]
#     ∟ predsedavajući PRESENT_PAT
# zahvaljovati [VERB]
#     ∟ zahvaljujući PRESENT_PAT
# otvarati [VERB]
#     ∟ otvarajući PRESENT_PAT
# obeležavati [VERB]
#     ∟ obeležavajući PRESENT_PAT
# završavati [VERB]
#     ∟ završavajući PRESENT_PAT
# preneražavati [VERB]
#     ∟ preneražavajući PRESENT_PAT
# pojavljovati [VERB]
#     ∟ pojavljujući PRESENT_PAT
# obećavati [VERB]
#     ∟ obećavajući PRESENT_PAT
# nedostati [VERB]
#     ∟ nedostajući PRESENT_PAT
# primoravati [VERB]
#     ∟ primoravajući PRESENT_PAT
# potiskovati [VERB]
#     ∟ potiskujući PRESENT_PAT
# prezati [VERB]
#     ∟ prezajući PRESENT_PAT
# zbunjovati [VERB]
#     ∟ zbunjujući PRESENT_PAT
# zbližavati [VERB]
#     ∟ zbližavajući PRESENT_PAT
# zatvarati [VERB]
#     ∟ zatvarajući PRESENT_PAT
# tragati [VERB]
#     ∟ tragajući PRESENT_PAT
# opisovati [VERB]
#     ∟ opisujući PRESENT_PAT
# favorizovati [VERB]
#     ∟ favorizujući PRESENT_PAT
# oslobađati [VERB]
#     ∟ oslobađajući PRESENT_PAT
# ažurirati [VERB]
#     ∟ ažurirajući PRESENT_PAT
# otuđovati [VERB]
#     ∟ otuđujući PRESENT_PAT
# sprečavati [VERB]
#     ∟ sprečavajući PRESENT_PAT
# optužovati [VERB]
#     ∟ optužujući PRESENT_PAT
# upozoravati [VERB]
#     ∟ upozoravajući PRESENT_PAT
# ponavljati [VERB]
#     ∟ ponavljajući PRESENT_PAT
# uključovati [VERB]
#     ∟ uključujući PRESENT_PAT
# savetovati [VERB]
#     ∟ savetujući PRESENT_PAT
# najavljovati [VERB]
#     ∟ najavljujući PRESENT_PAT
# okončavati [VERB]
#     ∟ okončavajući PRESENT_PAT
# odbijati [VERB]
#     ∟ odbijajući PRESENT_PAT
# naglašavati [VERB]
#     ∟ naglašavajući PRESENT_PAT
# pozdravljati [VERB]
#     ∟ pozdravljajući PRESENT_PAT
# dodati [VERB]
#     ∟ dodajući PRESENT_PAT
# bacati [VERB]
#     ∟ bacajući PRESENT_PAT
# suočavati [VERB]
#     ∟ suočavajući PRESENT_PAT
# diskreditovati [VERB]
#     ∟ diskreditujući PRESENT_PAT
# prodati [VERB]
#     ∟ prodajući PRESENT_PAT
# saopštavati [VERB]
#     ∟ saopštavajući PRESENT_PAT
# opstruirati [VERB]
#     ∟ opstruirajući PRESENT_PAT
# podsećati [VERB]
#     ∟ podsećajući PRESENT_PAT
# ubacovati [VERB]
#     ∟ ubacujući PRESENT_PAT
# uveravati [VERB]
#     ∟ uveravajući PRESENT_PAT
# emigrirati [VERB]
#     ∟ emigrirajući PRESENT_PAT
# kritikovati [VERB]
#     ∟ kritikujući PRESENT_PAT
# narastati [VERB]
#     ∟ narastajući PRESENT_PAT
# ukazovati [VERB]
#     ∟ ukazujući PRESENT_PAT
# svrstavati [VERB]
#     ∟ svrstavajući PRESENT_PAT
# pretvarati [VERB]
#     ∟ pretvarajući PRESENT_PAT
# potvrđovati [VERB]
#     ∟ potvrđujući PRESENT_PAT
# čekati [VERB]
#     ∟ čekajući PRESENT_PAT
# primati [VERB]
#     ∟ primajući PRESENT_PAT
# ohrabrovati [VERB]
#     ∟ ohrabrujući PRESENT_PAT
# odgovarati [VERB]
#     ∟ odgovarajući PRESENT_PAT
# protestovati [VERB]
#     ∟ protestujući PRESENT_PAT
# objašnjavati [VERB]
#     ∟ objašnjavajući PRESENT_PAT
# osuđovati [VERB]
#     ∟ osuđujući PRESENT_PAT
# slovean [ADJ]
#     ∟ sloveniji COMP-M-SG
# beskompromisan [ADJ]
#     ∟ beskompromisniji COMP-M-SG
# uticajan [ADJ]
#     ∟ uticajniji COMP-M-SG
# lina [ADJ]
#     ∟ linija COMP-F-SG
# kompleksna [ADJ]
#     ∟ kompleksnija COMP-F-SG
# kompaan [ADJ]
#     ∟ kompaniji COMP-M-SG
# estono [ADJ]
#     ∟ estonije COMP-N-SG
# sloveno [ADJ]
#     ∟ slovenije COMP-N-SG
# opasan [ADJ]
#     ∟ opasnijim COMP-M-PL
# važna [ADJ]
#     ∟ važnija COMP-F-SG
#       najvažnija SUP-F-SG
# čečean [ADJ]
#     ∟ čečeniji COMP-M-SG
# deceno [ADJ]
#     ∟ decenije COMP-N-SG
# očigledan [ADJ]
#     ∟ očigledniji COMP-M-SG
# transparentan [ADJ]
#     ∟ transparentnijim COMP-M-PL
# tačno [ADJ]
#     ∟ tačnije COMP-N-SG
# špaan [ADJ]
#     ∟ španiji COMP-M-SG
# urgentan [ADJ]
#     ∟ urgentniji COMP-M-SG
#       najurgentniji SUP-M-SG
# docno [ADJ]
#     ∟ docnije COMP-N-SG
# aktivno [ADJ]
#     ∟ aktivnije COMP-N-SG
# makedona [ADJ]
#     ∟ makedonija COMP-F-SG
# uan [ADJ]
#     ∟ uniji COMP-M-SG
# britana [ADJ]
#     ∟ britanija COMP-F-SG
# precizan [ADJ]
#     ∟ precizniji COMP-M-SG
# aliana [ADJ]
#     ∟ alianija COMP-F-SG
# makedono [ADJ]
#     ∟ makedonije COMP-N-SG
# rumuan [ADJ]
#     ∟ rumuniji COMP-M-SG
# represivan [ADJ]
#     ∟ represivniji COMP-M-SG
# ceremoan [ADJ]
#     ∟ ceremoniji COMP-M-SG
# litvano [ADJ]
#     ∟ litvanije COMP-N-SG
# apolona [ADJ]
#     ∟ apolonija COMP-F-SG
# slobodan [ADJ]
#     ∟ slobodniji COMP-M-SG
# uno [ADJ]
#     ∟ unije COMP-N-SG
# značajno [ADJ]
#     ∟ značajnije COMP-N-SG
#       najznačajnije SUP-N-SG
# važno [ADJ]
#     ∟ važnije COMP-N-SG
#       najvažnije SUP-N-SG
# jeftino [ADJ]
#     ∟ jeftinije COMP-N-SG
# demokratična [ADJ]
#     ∟ demokratičnija COMP-F-SG
# konkurentna [ADJ]
#     ∟ konkurentnija COMP-F-SG
# svestrano [ADJ]
#     ∟ svestranije COMP-N-SG
# raan [ADJ]
#     ∟ ranijim COMP-M-PL
# važan [ADJ]
#     ∟ važniji COMP-M-SG
#       najvažniji SUP-M-SG
# una [ADJ]
#     ∟ unija COMP-F-SG
# sigurno [ADJ]
#     ∟ sigurnije COMP-N-SG
# letono [ADJ]
#     ∟ letonije COMP-N-SG
# potpuno [ADJ]
#     ∟ potpunije COMP-N-SG
# makedoan [ADJ]
#     ∟ makedoniji COMP-M-SG
# mena [ADJ]
#     ∟ menija COMP-F-SG
# pensilvaan [ADJ]
#     ∟ pensilvaniji COMP-M-SG
# rumuna [ADJ]
#     ∟ rumunija COMP-F-SG
# ozbiljan [ADJ]
#     ∟ ozbiljniji COMP-M-SG
#       najozbiljniji SUP-M-SG
# rano [ADJ]
#     ∟ ranije COMP-N-SG
# britano [ADJ]
#     ∟ britanije COMP-N-SG
# efikasan [ADJ]
#     ∟ efikasniji COMP-M-SG
# zainteresovana [ADJ]
#     ∟ zainteresovanija COMP-F-SG
# rasprostranjena [ADJ]
#     ∟ rasprostranjenija COMP-F-SG
# albano [ADJ]
#     ∟ albanije COMP-N-SG
# kompano [ADJ]
#     ∟ kompanije COMP-N-SG
# bezbedan [ADJ]
#     ∟ bezbedniji COMP-M-SG
# pozitivan [ADJ]
#     ∟ pozitivniji COMP-M-SG
# konkretno [ADJ]
#     ∟ konkretnije COMP-N-SG
# efikasna [ADJ]
#     ∟ efikasnija COMP-F-SG
# britaan [ADJ]
#     ∟ britaniji COMP-M-SG
# jevtian [ADJ]
#     ∟ jevtinijim COMP-M-PL
# decena [ADJ]
#     ∟ decenija COMP-F-SG
# ceremono [ADJ]
#     ∟ ceremonije COMP-N-SG
# kompana [ADJ]
#     ∟ kompanija COMP-F-SG
# snažno [ADJ]
#     ∟ snažnije COMP-N-SG
# optimalno [ADJ]
#     ∟ optimalnije COMP-N-SG
# albana [ADJ]
#     ∟ albanija COMP-F-SG
# sigurna [ADJ]
#     ∟ sigurnija COMP-F-SG
# izražean [ADJ]
#     ∟ izraženijim COMP-M-PL
# špana [ADJ]
#     ∟ španija COMP-F-SG
# nezadovoljan [ADJ]
#     ∟ nezadovoljniji COMP-M-SG
# kolona [ADJ]
#     ∟ kolonija COMP-F-SG
# lino [ADJ]
#     ∟ linije COMP-N-SG
# iskusan [ADJ]
#     ∟ iskusnijim COMP-M-PL
# optimističan [ADJ]
#     ∟ optimističniji COMP-M-SG
# značajan [ADJ]
#     ∟ značajniji COMP-M-SG
#       najznačajniji SUP-M-SG
# moćan [ADJ]
#     ∟ moćniji COMP-M-SG
#       najmoćniji SUP-M-SG
# striktno [ADJ]
#     ∟ striktnije COMP-N-SG
# albaan [ADJ]
#     ∟ albaniji COMP-M-SG
# telefono [ADJ]
#     ∟ telefonije COMP-N-SG
# rasprostranjean [ADJ]
#     ∟ rasprostranjeniji COMP-M-SG
# slovena [ADJ]
#     ∟ slovenija COMP-F-SG
# diversifikovana [ADJ]
#     ∟ diversifikovanija COMP-F-SG
# lian [ADJ]
#     ∟ liniji COMP-M-SG
# ceremona [ADJ]
#     ∟ ceremonija COMP-F-SG
# kasno [ADJ]
#     ∟ kasnije COMP-N-SG
# rumuno [ADJ]
#     ∟ rumunije COMP-N-SG
# špano [ADJ]
#     ∟ španije COMP-N-SG
# siromašno [ADJ]
#     ∟ siromašnije COMP-N-SG
# rumunski [ADJ]
#     ∟ rumunskog POSSESSIVE
#       rumunskom POSSESSIVE
#       rumunskim POSSESSIVE
#       rumunska POSSESSIVE
#       rumunske POSSESSIVE
#       rumunskoj POSSESSIVE
#       rumunskih POSSESSIVE
#       rumunsko POSSESSIVE
# španski [ADJ]
#     ∟ španskog POSSESSIVE
#       španskim POSSESSIVE
#       španske POSSESSIVE
#       španskih POSSESSIVE
# vremenski [ADJ]
#     ∟ vremenskim POSSESSIVE
#       vremenskih POSSESSIVE
# gagovski [ADJ]
# konjanovski [ADJ]
#     ∟ konjanovskog POSSESSIVE
# teoretski [ADJ]
# švedski [ADJ]
#     ∟ švedskom POSSESSIVE
#       švedska POSSESSIVE
#       švedske POSSESSIVE
#       švedskoj POSSESSIVE
#       švedsku POSSESSIVE
# tetovski [ADJ]
# gruevski [ADJ]
#     ∟ gruevskog POSSESSIVE
#       gruevskim POSSESSIVE
# irski [ADJ]
#     ∟ irskim POSSESSIVE
#       irska POSSESSIVE
#       irske POSSESSIVE
#       irskoj POSSESSIVE
# makedonski [ADJ]
#     ∟ makedonskog POSSESSIVE
#       makedonskom POSSESSIVE
#       makedonskim POSSESSIVE
#       makedonska POSSESSIVE
#       makedonske POSSESSIVE
#       makedonskoj POSSESSIVE
#       makedonsku POSSESSIVE
#       makedonskih POSSESSIVE
#       makedonsko POSSESSIVE
# trajkovski [ADJ]
#     ∟ trajkovskog POSSESSIVE
# imunski [ADJ]
# diplomatski [ADJ]
#     ∟ diplomatskog POSSESSIVE
#       diplomatskom POSSESSIVE
#       diplomatskim POSSESSIVE
#       diplomatska POSSESSIVE
#       diplomatske POSSESSIVE
#       diplomatskoj POSSESSIVE
#       diplomatsku POSSESSIVE
# hrvatski [ADJ]
#     ∟ hrvatskog POSSESSIVE
#       hrvatskom POSSESSIVE
#       hrvatskim POSSESSIVE
#       hrvatska POSSESSIVE
#       hrvatske POSSESSIVE
#       hrvatskoj POSSESSIVE
#       hrvatsku POSSESSIVE
#       hrvatsko POSSESSIVE
# bugarski [ADJ]
#     ∟ bugarskog POSSESSIVE
#       bugarskom POSSESSIVE
#       bugarskim POSSESSIVE
#       bugarska POSSESSIVE
#       bugarske POSSESSIVE
#       bugarskoj POSSESSIVE
#       bugarsku POSSESSIVE
#       bugarskih POSSESSIVE
#       bugarsko POSSESSIVE
# meteorski [ADJ]
# novinarski [ADJ]
#     ∟ novinarska POSSESSIVE
# ivanovski [ADJ]
# evropski [ADJ]
#     ∟ evropskog POSSESSIVE
#       evropskom POSSESSIVE
#       evropskim POSSESSIVE
#       evropska POSSESSIVE
#       evropske POSSESSIVE
#       evropskoj POSSESSIVE
#       evropsku POSSESSIVE
#       evropskih POSSESSIVE
#       evropsko POSSESSIVE
# romski [ADJ]
#     ∟ romskog POSSESSIVE
#       romskom POSSESSIVE
#       romskim POSSESSIVE
#       romska POSSESSIVE
#       romske POSSESSIVE
#       romskoj POSSESSIVE
# zemunski [ADJ]
#     ∟ zemunskog POSSESSIVE
# peruanski [ADJ]
# saudijski [ADJ]
#     ∟ saudijskog POSSESSIVE
#       saudijska POSSESSIVE
#       saudijske POSSESSIVE
# šahovski [ADJ]
#     ∟ šahovska POSSESSIVE
# prevarantski [ADJ]
# vijetnamski [ADJ]
# ministarski [ADJ]
#     ∟ ministarska POSSESSIVE
# turski [ADJ]
#     ∟ turskog POSSESSIVE
#       turskom POSSESSIVE
#       turskim POSSESSIVE
#       turska POSSESSIVE
#       turske POSSESSIVE
#       turskoj POSSESSIVE
#       tursku POSSESSIVE
#       turskih POSSESSIVE
#       tursko POSSESSIVE
# amaterski [ADJ]
#     ∟ amaterske POSSESSIVE
# londonski [ADJ]
#     ∟ londonskoj POSSESSIVE
# sofijski [ADJ]
#     ∟ sofijskoj POSSESSIVE
# aleksievski [ADJ]
# briselski [ADJ]
#     ∟ briselske POSSESSIVE
# verski [ADJ]
#     ∟ verskog POSSESSIVE
#       verskim POSSESSIVE
#       verske POSSESSIVE
#       versku POSSESSIVE
#       verskih POSSESSIVE
#       versko POSSESSIVE
# nikolovski [ADJ]
# balkanski [ADJ]
#     ∟ balkanskim POSSESSIVE
#       balkanska POSSESSIVE
#       balkanske POSSESSIVE
#       balkanskoj POSSESSIVE
#       balkansku POSSESSIVE
#       balkanskih POSSESSIVE
# republikanski [ADJ]
#     ∟ republikanska POSSESSIVE
# lavovski [ADJ]
# belgijski [ADJ]
#     ∟ belgijskom POSSESSIVE
# beogradski [ADJ]
#     ∟ beogradskog POSSESSIVE
#       beogradskom POSSESSIVE
#       beogradska POSSESSIVE
#       beogradske POSSESSIVE
#       beogradskoj POSSESSIVE
#       beogradsku POSSESSIVE
# gruzijski [ADJ]
#     ∟ gruzijske POSSESSIVE
#       gruzijskoj POSSESSIVE
# peševski [ADJ]
# kablovski [ADJ]
#     ∟ kablovske POSSESSIVE
# automatski [ADJ]
#     ∟ automatskom POSSESSIVE
# kosovski [ADJ]
#     ∟ kosovskog POSSESSIVE
#       kosovskom POSSESSIVE
#       kosovskim POSSESSIVE
#       kosovska POSSESSIVE
#       kosovske POSSESSIVE
#       kosovskoj POSSESSIVE
#       kosovskih POSSESSIVE
#       kosovsko POSSESSIVE
# jugoslovenski [ADJ]
#     ∟ jugoslovenskog POSSESSIVE
#       jugoslovenske POSSESSIVE
#       jugoslovenskoj POSSESSIVE
# evroatlantski [ADJ]
#     ∟ evroatlantskim POSSESSIVE
#       evroatlantske POSSESSIVE
#       evroatlantskoj POSSESSIVE
#       evroatlantsku POSSESSIVE
#       evroatlantskih POSSESSIVE
# trojanski [ADJ]
# univerzitetski [ADJ]
#     ∟ univerzitetskom POSSESSIVE
#       univerzitetskim POSSESSIVE
#       univerzitetske POSSESSIVE
#       univerzitetskih POSSESSIVE
# holivudski [ADJ]
#     ∟ holivudskih POSSESSIVE
# portugalski [ADJ]
#     ∟ portugalske POSSESSIVE
# puninski [ADJ]
# penzijski [ADJ]
#     ∟ penzijskog POSSESSIVE
# antonovski [ADJ]
# britanski [ADJ]
#     ∟ britanskog POSSESSIVE
#       britanskom POSSESSIVE
#       britanska POSSESSIVE
#       britanske POSSESSIVE
#       britansku POSSESSIVE
#       britanskih POSSESSIVE
# poposki [ADJ]
# orvelovski [ADJ]
# ohridski [ADJ]
#     ∟ ohridske POSSESSIVE
# ljudski [ADJ]
#     ∟ ljudskim POSSESSIVE
#       ljudska POSSESSIVE
#       ljudske POSSESSIVE
#       ljudskih POSSESSIVE
# levičarski [ADJ]
#     ∟ levičarskim POSSESSIVE
#       levičarska POSSESSIVE
#       levičarskoj POSSESSIVE
# finski [ADJ]
#     ∟ finska POSSESSIVE
#       finske POSSESSIVE
# istorijski [ADJ]
#     ∟ istorijskog POSSESSIVE
#       istorijskom POSSESSIVE
#       istorijskim POSSESSIVE
#       istorijska POSSESSIVE
#       istorijsku POSSESSIVE
#       istorijskih POSSESSIVE
# izraelski [ADJ]
# kurdski [ADJ]
#     ∟ kurdskog POSSESSIVE
#       kurdskom POSSESSIVE
#       kurdske POSSESSIVE
#       kurdskoj POSSESSIVE
#       kurdsku POSSESSIVE
#       kurdskih POSSESSIVE
# avionski [ADJ]
#     ∟ avionskih POSSESSIVE
# vrhunski [ADJ]
#     ∟ vrhunskom POSSESSIVE
#       vrhunske POSSESSIVE
#       vrhunskih POSSESSIVE
# svetski [ADJ]
#     ∟ svetskog POSSESSIVE
#       svetskom POSSESSIVE
#       svetskim POSSESSIVE
#       svetska POSSESSIVE
#       svetske POSSESSIVE
#       svetskoj POSSESSIVE
#       svetsku POSSESSIVE
#       svetskih POSSESSIVE
#       svetsko POSSESSIVE
# moldavski [ADJ]
#     ∟ moldavska POSSESSIVE
#       moldavske POSSESSIVE
#       moldavskih POSSESSIVE
# posttraumatski [ADJ]
#     ∟ posttraumatskog POSSESSIVE
# litvanski [ADJ]
# albanski [ADJ]
#     ∟ albanskog POSSESSIVE
#       albanskom POSSESSIVE
#       albanskim POSSESSIVE
#       albanska POSSESSIVE
#       albanske POSSESSIVE
#       albanskoj POSSESSIVE
#       albansku POSSESSIVE
#       albanskih POSSESSIVE
# spoljnotrgovinski [ADJ]
# stojčevski [ADJ]
# građevinski [ADJ]
#     ∟ građevinskog POSSESSIVE
#       građevinske POSSESSIVE
# studentski [ADJ]
#     ∟ studentskog POSSESSIVE
#       studentskim POSSESSIVE
#       studentske POSSESSIVE
#       studentskih POSSESSIVE
# finansijski [ADJ]
#     ∟ finansijskog POSSESSIVE
#       finansijskom POSSESSIVE
#       finansijskim POSSESSIVE
#       finansijska POSSESSIVE
#       finansijske POSSESSIVE
#       finansijsku POSSESSIVE
#       finansijskih POSSESSIVE
# srpski [ADJ]
#     ∟ srpskog POSSESSIVE
#       srpskom POSSESSIVE
#       srpskim POSSESSIVE
#       srpska POSSESSIVE
#       srpske POSSESSIVE
#       srpskoj POSSESSIVE
#       srpsku POSSESSIVE
#       srpskih POSSESSIVE
#       srpsko POSSESSIVE
# bosanski [ADJ]
#     ∟ bosanskim POSSESSIVE
#       bosanska POSSESSIVE
#       bosanske POSSESSIVE
#       bosanskih POSSESSIVE
# terapeutski [ADJ]
#     ∟ terapeutsko POSSESSIVE
# islamski [ADJ]
#     ∟ islamskim POSSESSIVE
#       islamska POSSESSIVE
#       islamske POSSESSIVE
#       islamsku POSSESSIVE
#       islamskih POSSESSIVE
# nilski [ADJ]
#     ∟ nilskog POSSESSIVE
# trajkoviski [ADJ]
# carinski [ADJ]
#     ∟ carinskog POSSESSIVE
#       carinska POSSESSIVE
#       carinske POSSESSIVE
#       carinskoj POSSESSIVE
#       carinskih POSSESSIVE
# spisateljski [ADJ]
# istinski [ADJ]
#     ∟ istinske POSSESSIVE
# drumski [ADJ]
# filmski [ADJ]
#     ∟ filmskom POSSESSIVE
#       filmskih POSSESSIVE
# budžetski [ADJ]
#     ∟ budžetskog POSSESSIVE
#       budžetskom POSSESSIVE
#       budžetskim POSSESSIVE
#       budžetska POSSESSIVE
#       budžetskih POSSESSIVE
# herkulovski [ADJ]
# životinjski [ADJ]
# helenski [ADJ]
#     ∟ helensko POSSESSIVE
# sovjetski [ADJ]
#     ∟ sovjetskom POSSESSIVE
# bankarski [ADJ]
#     ∟ bankarskim POSSESSIVE
#       bankarske POSSESSIVE
# mađarski [ADJ]
#     ∟ mađarske POSSESSIVE
#       mađarskoj POSSESSIVE
# geografski [ADJ]
# francuski [ADJ]
#     ∟ francuskog POSSESSIVE
#       francuskom POSSESSIVE
#       francuska POSSESSIVE
#       francuske POSSESSIVE
#       francuskoj POSSESSIVE
#       francusku POSSESSIVE
#       francuskih POSSESSIVE
# engleski [ADJ]
#     ∟ engleska POSSESSIVE
# solunski [ADJ]
#     ∟ solunske POSSESSIVE
#       solunsku POSSESSIVE
# dostojevski [ADJ]
# generacijski [ADJ]
# olimpijski [ADJ]
#     ∟ olimpijskom POSSESSIVE
#       olimpijska POSSESSIVE
# ruski [ADJ]
#     ∟ ruskog POSSESSIVE
#       ruskim POSSESSIVE
#       ruske POSSESSIVE
#       ruskoj POSSESSIVE
#       rusku POSSESSIVE
#       ruskih POSSESSIVE
# proevropski [ADJ]
#     ∟ proevropske POSSESSIVE
#       proevropskoj POSSESSIVE
# majski [ADJ]
#     ∟ majskog POSSESSIVE
# katastarski [ADJ]
# novozelandski [ADJ]
# ekonomski [ADJ]
#     ∟ ekonomskog POSSESSIVE
#       ekonomskom POSSESSIVE
#       ekonomskim POSSESSIVE
#       ekonomska POSSESSIVE
#       ekonomske POSSESSIVE
#       ekonomskoj POSSESSIVE
#       ekonomsku POSSESSIVE
#       ekonomskih POSSESSIVE
# bostonski [ADJ]
# akademski [ADJ]
#     ∟ akademska POSSESSIVE
#       akademske POSSESSIVE
#       akademskoj POSSESSIVE
#       akademskih POSSESSIVE
# poreski [ADJ]
#     ∟ poreskom POSSESSIVE
#       poreska POSSESSIVE
#       poreske POSSESSIVE
#       poreskoj POSSESSIVE
#       poreskih POSSESSIVE
# milošoski [ADJ]
# industrijski [ADJ]
#     ∟ industrijskim POSSESSIVE
#       industrijskih POSSESSIVE
# većinski [ADJ]
# dejtonski [ADJ]
#     ∟ dejtonskog POSSESSIVE
#       dejtonskim POSSESSIVE
# mančevski [ADJ]
#     ∟ mančevskog POSSESSIVE
# zakonski [ADJ]
#     ∟ zakonskog POSSESSIVE
#       zakonskom POSSESSIVE
#       zakonske POSSESSIVE
#       zakonsku POSSESSIVE
#       zakonskih POSSESSIVE
# stavrevski [ADJ]
# ramkovski [ADJ]
#     ∟ ramkovskog POSSESSIVE
#       ramkovskom POSSESSIVE
# antologijski [ADJ]
# detektivski [ADJ]
# pariski [ADJ]
# lisabonski [ADJ]
# manevski [ADJ]
# televizijski [ADJ]
#     ∟ televizijske POSSESSIVE
# sudski [ADJ]
#     ∟ sudskog POSSESSIVE
#       sudskom POSSESSIVE
#       sudskim POSSESSIVE
#       sudskoj POSSESSIVE
#       sudskih POSSESSIVE
#       sudsko POSSESSIVE
# pakistanski [ADJ]
#     ∟ pakistanske POSSESSIVE
# medijski [ADJ]
#     ∟ medijskog POSSESSIVE
#       medijskom POSSESSIVE
#       medijske POSSESSIVE
#       medijskih POSSESSIVE
# švajcarski [ADJ]
#     ∟ švajcarskog POSSESSIVE
#       švajcarske POSSESSIVE
#       švajcarskoj POSSESSIVE
# bliski [ADJ]
#     ∟ bliskog POSSESSIVE
#       bliskom POSSESSIVE
#       bliskoj POSSESSIVE
#       blisku POSSESSIVE
# niski [ADJ]
#     ∟ niskom POSSESSIVE
#       niska POSSESSIVE
#       nisku POSSESSIVE
#       niskih POSSESSIVE
# poljski [ADJ]
#     ∟ poljske POSSESSIVE
#       poljskoj POSSESSIVE
#       poljskih POSSESSIVE
# kiparski [ADJ]
#     ∟ kiparskog POSSESSIVE
#       kiparskom POSSESSIVE
#       kiparskim POSSESSIVE
#       kiparske POSSESSIVE
#       kiparskih POSSESSIVE
# socijaldemokratski [ADJ]
#     ∟ socijaldemokratskog POSSESSIVE
#       socijaldemokratskom POSSESSIVE
#       socijaldemokratska POSSESSIVE
#       socijaldemokratske POSSESSIVE
#       socijaldemokratskoj POSSESSIVE
# trgovinski [ADJ]
#     ∟ trgovinskog POSSESSIVE
#       trgovinske POSSESSIVE
# demokratski [ADJ]
#     ∟ demokratskog POSSESSIVE
#       demokratskom POSSESSIVE
#       demokratskim POSSESSIVE
#       demokratska POSSESSIVE
#       demokratske POSSESSIVE
#       demokratsku POSSESSIVE
#       demokratskih POSSESSIVE
#       demokratsko POSSESSIVE
# nedemokratski [ADJ]
# energetski [ADJ]
#     ∟ energetskim POSSESSIVE
#       energetska POSSESSIVE
#       energetske POSSESSIVE
#       energetskih POSSESSIVE
# argentinski [ADJ]
#     ∟ argentinske POSSESSIVE
# cerovski [ADJ]
# italijanski [ADJ]
#     ∟ italijanskog POSSESSIVE
#       italijanske POSSESSIVE
# bučkovski [ADJ]
# proruski [ADJ]
# berlinski [ADJ]
# fudbalski [ADJ]
#     ∟ fudbalskog POSSESSIVE
#       fudbalskim POSSESSIVE
#       fudbalska POSSESSIVE
#       fudbalske POSSESSIVE
#       fudbalskih POSSESSIVE
#       fudbalsko POSSESSIVE
# crvenkovski [ADJ]
#     ∟ crvenkovskim POSSESSIVE
# azilski [ADJ]
#     ∟ azilskog POSSESSIVE
# bosforski [ADJ]
# birokratski [ADJ]
#     ∟ birokratske POSSESSIVE
# sirijski [ADJ]
#     ∟ sirijskog POSSESSIVE
# crnogorski [ADJ]
#     ∟ crnogorskom POSSESSIVE
#       crnogorskim POSSESSIVE
#       crnogorska POSSESSIVE
#       crnogorske POSSESSIVE
#       crnogorskoj POSSESSIVE
#       crnogorsku POSSESSIVE
# reformski [ADJ]
#     ∟ reformskog POSSESSIVE
#       reformskim POSSESSIVE
#       reformske POSSESSIVE
#       reformskih POSSESSIVE
# pridnjestrovski [ADJ]
#     ∟ pridnjestrovskog POSSESSIVE
# istanbulski [ADJ]
#     ∟ istanbulskog POSSESSIVE
#       istanbulskom POSSESSIVE
#       istanbulska POSSESSIVE
#       istanbulske POSSESSIVE
# telefonski [ADJ]
#     ∟ telefonskog POSSESSIVE
#       telefonske POSSESSIVE
# lezbejski [ADJ]
#     ∟ lezbejskog POSSESSIVE
# deoničarski [ADJ]
#     ∟ deoničarskog POSSESSIVE
# pokrajinski [ADJ]
#     ∟ pokrajinskog POSSESSIVE
# jadranski [ADJ]
#     ∟ jadranskog POSSESSIVE
#       jadranske POSSESSIVE
# trenerski [ADJ]
#     ∟ trenerskog POSSESSIVE
# egipatski [ADJ]
#     ∟ egipatskog POSSESSIVE
# letonski [ADJ]
#     ∟ letonskog POSSESSIVE
# libijski [ADJ]
#     ∟ libijskog POSSESSIVE
# palestinski [ADJ]
#     ∟ palestinskog POSSESSIVE
# filozofski [ADJ]
#     ∟ filozofskog POSSESSIVE
# sufijski [ADJ]
#     ∟ sufijskog POSSESSIVE
# filharmonijski [ADJ]
#     ∟ filharmonijskog POSSESSIVE
# suštinski [ADJ]
#     ∟ suštinskog POSSESSIVE
#       suštinskim POSSESSIVE
#       suštinska POSSESSIVE
# mediteranski [ADJ]
#     ∟ mediteranskog POSSESSIVE
#       mediteranskim POSSESSIVE
# praistorijski [ADJ]
#     ∟ praistorijskog POSSESSIVE
# vizantijski [ADJ]
#     ∟ vizantijskog POSSESSIVE
# sportski [ADJ]
#     ∟ sportskog POSSESSIVE
#       sportskom POSSESSIVE
#       sportske POSSESSIVE
#       sportskih POSSESSIVE
# holandski [ADJ]
#     ∟ holandskog POSSESSIVE
#       holandska POSSESSIVE
#       holandske POSSESSIVE
# arhajski [ADJ]
#     ∟ arhajskog POSSESSIVE
# sarajevski [ADJ]
#     ∟ sarajevskog POSSESSIVE
#       sarajevskom POSSESSIVE
#       sarajevskim POSSESSIVE
#       sarajevska POSSESSIVE
#       sarajevskoj POSSESSIVE
# oktobarski [ADJ]
#     ∟ oktobarskog POSSESSIVE
#       oktobarske POSSESSIVE
#       oktobarskih POSSESSIVE
# aprilski [ADJ]
#     ∟ aprilskog POSSESSIVE
# vehabijski [ADJ]
#     ∟ vehabijskog POSSESSIVE
# kineski [ADJ]
#     ∟ kineskog POSSESSIVE
# ženski [ADJ]
#     ∟ ženskog POSSESSIVE
#       ženskom POSSESSIVE
#       ženskim POSSESSIVE
#       ženska POSSESSIVE
#       ženskoj POSSESSIVE
#       ženskih POSSESSIVE
#       žensko POSSESSIVE
# softverski [ADJ]
#     ∟ softverskog POSSESSIVE
#       softverskoj POSSESSIVE
#       softverskih POSSESSIVE
# muslimanski [ADJ]
#     ∟ muslimanskog POSSESSIVE
#       muslimanska POSSESSIVE
#       muslimanske POSSESSIVE
#       muslimanskoj POSSESSIVE
# tračanski [ADJ]
#     ∟ tračanskog POSSESSIVE
#       tračansko POSSESSIVE
# gangsterski [ADJ]
#     ∟ gangsterskog POSSESSIVE
# piranski [ADJ]
#     ∟ piranskog POSSESSIVE
# tuzlanski [ADJ]
#     ∟ tuzlanskog POSSESSIVE
# akcijski [ADJ]
#     ∟ akcijskog POSSESSIVE
#       akcijskih POSSESSIVE
# partenonski [ADJ]
#     ∟ partenonskog POSSESSIVE
# indijski [ADJ]
#     ∟ indijskog POSSESSIVE
# višedecenijski [ADJ]
#     ∟ višedecenijskog POSSESSIVE
#       višedecenijske POSSESSIVE
# zatvorski [ADJ]
#     ∟ zatvorskog POSSESSIVE
#       zatvorskom POSSESSIVE
#       zatvorska POSSESSIVE
#       zatvorske POSSESSIVE
#       zatvorsku POSSESSIVE
# arapski [ADJ]
#     ∟ arapskog POSSESSIVE
#       arapskim POSSESSIVE
# transbalkanski [ADJ]
#     ∟ transbalkanskog POSSESSIVE
# duvanski [ADJ]
#     ∟ duvanskog POSSESSIVE
# masačusetski [ADJ]
#     ∟ masačusetskog POSSESSIVE
# policijski [ADJ]
#     ∟ policijskog POSSESSIVE
#       policijskim POSSESSIVE
#       policijska POSSESSIVE
#       policijske POSSESSIVE
#       policijskoj POSSESSIVE
#       policijsku POSSESSIVE
#       policijskih POSSESSIVE
# gradski [ADJ]
#     ∟ gradskog POSSESSIVE
#       gradskoj POSSESSIVE
# rimski [ADJ]
#     ∟ rimskog POSSESSIVE
#       rimskih POSSESSIVE
# utiski [ADJ]
#     ∟ utiskom POSSESSIVE
# junski [ADJ]
#     ∟ junskom POSSESSIVE
# dvoranski [ADJ]
#     ∟ dvoranskom POSSESSIVE
# polistirenski [ADJ]
#     ∟ polistirenskom POSSESSIVE
# crnomorski [ADJ]
#     ∟ crnomorskom POSSESSIVE
#       crnomorska POSSESSIVE
#       crnomorske POSSESSIVE
# operski [ADJ]
#     ∟ operskom POSSESSIVE
# radikalski [ADJ]
#     ∟ radikalskom POSSESSIVE
# konsultantski [ADJ]
#     ∟ konsultantskom POSSESSIVE
# austrijski [ADJ]
#     ∟ austrijskom POSSESSIVE
#       austrijska POSSESSIVE
#       austrijske POSSESSIVE
# biometrijski [ADJ]
#     ∟ biometrijskom POSSESSIVE
#       biometrijskim POSSESSIVE
#       biometrijske POSSESSIVE
# manjinski [ADJ]
#     ∟ manjinskom POSSESSIVE
#       manjinskim POSSESSIVE
#       manjinska POSSESSIVE
#       manjinske POSSESSIVE
#       manjinsku POSSESSIVE
#       manjinskih POSSESSIVE
#       manjinsko POSSESSIVE
# vojski [ADJ]
#     ∟ vojskom POSSESSIVE
#       vojska POSSESSIVE
#       vojske POSSESSIVE
#       vojsku POSSESSIVE
# teniski [ADJ]
#     ∟ teniskom POSSESSIVE
# pritiski [ADJ]
#     ∟ pritiskom POSSESSIVE
#       pritiska POSSESSIVE
# germanski [ADJ]
#     ∟ germanskom POSSESSIVE
# februarski [ADJ]
#     ∟ februarskom POSSESSIVE
# atletski [ADJ]
#     ∟ atletskom POSSESSIVE
# skadarski [ADJ]
#     ∟ skadarskom POSSESSIVE
#       skadarsko POSSESSIVE
# martovski [ADJ]
#     ∟ martovskim POSSESSIVE
#       martovskih POSSESSIVE
# transatlantski [ADJ]
#     ∟ transatlantskim POSSESSIVE
#       transatlantskih POSSESSIVE
# ilirski [ADJ]
#     ∟ ilirskim POSSESSIVE
# genetski [ADJ]
#     ∟ genetskim POSSESSIVE
# izvorski [ADJ]
#     ∟ izvorskim POSSESSIVE
# tajlandski [ADJ]
#     ∟ tajlandskim POSSESSIVE
# rodopski [ADJ]
#     ∟ rodopskim POSSESSIVE
# diktatorski [ADJ]
#     ∟ diktatorskim POSSESSIVE
# građanski [ADJ]
#     ∟ građanskim POSSESSIVE
#       građanska POSSESSIVE
#       građanske POSSESSIVE
#       građanskoj POSSESSIVE
#       građanskih POSSESSIVE
# novembarski [ADJ]
#     ∟ novembarskim POSSESSIVE
# kajmanski [ADJ]
#     ∟ kajmanskim POSSESSIVE
# pomorski [ADJ]
#     ∟ pomorskim POSSESSIVE
#       pomorska POSSESSIVE
# kišlovski [ADJ]
#     ∟ kišlovskim POSSESSIVE
# sociodemografski [ADJ]
#     ∟ sociodemografskim POSSESSIVE
# predatorski [ADJ]
#     ∟ predatorskim POSSESSIVE
# disciplinski [ADJ]
#     ∟ disciplinska POSSESSIVE
# vojvođanski [ADJ]
#     ∟ vojvođanska POSSESSIVE
#       vojvođanske POSSESSIVE
#       vojvođanskih POSSESSIVE
# prijateljski [ADJ]
#     ∟ prijateljska POSSESSIVE
#       prijateljske POSSESSIVE
#       prijateljskih POSSESSIVE
# velinovski [ADJ]
#     ∟ velinovska POSSESSIVE
# kinematografski [ADJ]
#     ∟ kinematografska POSSESSIVE
# ekspertski [ADJ]
#     ∟ ekspertska POSSESSIVE
#       ekspertskih POSSESSIVE
# socioekonomski [ADJ]
#     ∟ socioekonomska POSSESSIVE
# šengenski [ADJ]
#     ∟ šengenska POSSESSIVE
# stojkovski [ADJ]
#     ∟ stojkovska POSSESSIVE
# padinski [ADJ]
#     ∟ padinska POSSESSIVE
# elenovski [ADJ]
#     ∟ elenovska POSSESSIVE
# bonski [ADJ]
#     ∟ bonska POSSESSIVE
#       bonskih POSSESSIVE
# damaski [ADJ]
#     ∟ damaska POSSESSIVE
# imovinski [ADJ]
#     ∟ imovinska POSSESSIVE
#       imovinsku POSSESSIVE
#       imovinskih POSSESSIVE
# kraljevski [ADJ]
#     ∟ kraljevska POSSESSIVE
# protivtenkovski [ADJ]
#     ∟ protivtenkovska POSSESSIVE
#       protivtenkovske POSSESSIVE
# podravski [ADJ]
#     ∟ podravska POSSESSIVE
# autokratski [ADJ]
#     ∟ autokratska POSSESSIVE
# bavarski [ADJ]
#     ∟ bavarska POSSESSIVE
# kroski [ADJ]
#     ∟ kroska POSSESSIVE
# zalaski [ADJ]
#     ∟ zalaska POSSESSIVE
# kaspijski [ADJ]
#     ∟ kaspijska POSSESSIVE
# grozdanovski [ADJ]
#     ∟ grozdanovska POSSESSIVE
# peski [ADJ]
#     ∟ peska POSSESSIVE
# skopski [ADJ]
#     ∟ skopska POSSESSIVE
# valkanovski [ADJ]
#     ∟ valkanovska POSSESSIVE
# dvotrećinski [ADJ]
#     ∟ dvotrećinska POSSESSIVE
#       dvotrećinsku POSSESSIVE
# petkovski [ADJ]
#     ∟ petkovska POSSESSIVE
# proročanski [ADJ]
#     ∟ proročanska POSSESSIVE
# panevropski [ADJ]
#     ∟ panevropska POSSESSIVE
# elektronski [ADJ]
#     ∟ elektronska POSSESSIVE
#       elektronsku POSSESSIVE
#       elektronskih POSSESSIVE
#       elektronsko POSSESSIVE
# izlaski [ADJ]
#     ∟ izlaska POSSESSIVE
#       izlasku POSSESSIVE
# jevrejski [ADJ]
#     ∟ jevrejska POSSESSIVE
#       jevrejskih POSSESSIVE
# paparoski [ADJ]
#     ∟ paparoska POSSESSIVE
# prekomorski [ADJ]
#     ∟ prekomorska POSSESSIVE
# farmaceutski [ADJ]
#     ∟ farmaceutska POSSESSIVE
#       farmaceutskoj POSSESSIVE
#       farmaceutskih POSSESSIVE
# štipski [ADJ]
#     ∟ štipska POSSESSIVE
# zafirovski [ADJ]
#     ∟ zafirovska POSSESSIVE
# novinski [ADJ]
#     ∟ novinska POSSESSIVE
#       novinskoj POSSESSIVE
#       novinskih POSSESSIVE
# elektroenergetski [ADJ]
#     ∟ elektroenergetska POSSESSIVE
#       elektroenergetsku POSSESSIVE
# tinejdžerski [ADJ]
#     ∟ tinejdžerska POSSESSIVE
# danski [ADJ]
#     ∟ danska POSSESSIVE
#       danskoj POSSESSIVE
#       dansku POSSESSIVE
# ulaski [ADJ]
#     ∟ ulaska POSSESSIVE
#       ulasku POSSESSIVE
# spiski [ADJ]
#     ∟ spiska POSSESSIVE
# floreaski [ADJ]
#     ∟ floreaska POSSESSIVE
# jermenski [ADJ]
#     ∟ jermenska POSSESSIVE
# tenderski [ADJ]
#     ∟ tenderske POSSESSIVE
#       tendersku POSSESSIVE
# dorski [ADJ]
#     ∟ dorske POSSESSIVE
# revizorski [ADJ]
#     ∟ revizorske POSSESSIVE
# demografski [ADJ]
#     ∟ demografske POSSESSIVE
# neprijateljski [ADJ]
#     ∟ neprijateljske POSSESSIVE
# profesorski [ADJ]
#     ∟ profesorske POSSESSIVE
# omladinski [ADJ]
#     ∟ omladinske POSSESSIVE
# aerodromski [ADJ]
#     ∟ aerodromske POSSESSIVE
# kompjuterski [ADJ]
#     ∟ kompjuterske POSSESSIVE
#       kompjutersku POSSESSIVE
#       kompjuterskih POSSESSIVE
# medicinski [ADJ]
#     ∟ medicinske POSSESSIVE
# postdiplomski [ADJ]
#     ∟ postdiplomske POSSESSIVE
# laserski [ADJ]
#     ∟ laserske POSSESSIVE
# vašingtonski [ADJ]
#     ∟ vašingtonske POSSESSIVE
# logorski [ADJ]
#     ∟ logorske POSSESSIVE
# makroekonomski [ADJ]
#     ∟ makroekonomske POSSESSIVE
# organski [ADJ]
#     ∟ organske POSSESSIVE
# terenski [ADJ]
#     ∟ terenske POSSESSIVE
# inženjerski [ADJ]
#     ∟ inženjerske POSSESSIVE
# dablinski [ADJ]
#     ∟ dablinske POSSESSIVE
# ljuski [ADJ]
#     ∟ ljuske POSSESSIVE
# automobilski [ADJ]
#     ∟ automobilske POSSESSIVE
#       automobilsku POSSESSIVE
# entitetski [ADJ]
#     ∟ entitetske POSSESSIVE
#       entitetskih POSSESSIVE
# topografski [ADJ]
#     ∟ topografske POSSESSIVE
# prištinski [ADJ]
#     ∟ prištinske POSSESSIVE
# partijski [ADJ]
#     ∟ partijske POSSESSIVE
# božinovski [ADJ]
#     ∟ božinovske POSSESSIVE
# štamparski [ADJ]
#     ∟ štamparske POSSESSIVE
# školski [ADJ]
#     ∟ školske POSSESSIVE
# desničarski [ADJ]
#     ∟ desničarske POSSESSIVE
# morski [ADJ]
#     ∟ morske POSSESSIVE
#       morsku POSSESSIVE
#       morskih POSSESSIVE
# pivarski [ADJ]
#     ∟ pivarske POSSESSIVE
# registarski [ADJ]
#     ∟ registarske POSSESSIVE
#       registarskih POSSESSIVE
# uski [ADJ]
#     ∟ uske POSSESSIVE
#       usko POSSESSIVE
# planinski [ADJ]
#     ∟ planinske POSSESSIVE
# međuentitetski [ADJ]
#     ∟ međuentitetske POSSESSIVE
# snajperski [ADJ]
#     ∟ snajperske POSSESSIVE
# islandski [ADJ]
#     ∟ islandske POSSESSIVE
#       islandsku POSSESSIVE
# dunavski [ADJ]
#     ∟ dunavske POSSESSIVE
# austrougarski [ADJ]
#     ∟ austrougarskoj POSSESSIVE
# egejski [ADJ]
#     ∟ egejskoj POSSESSIVE
# preševski [ADJ]
#     ∟ preševskoj POSSESSIVE
# petrovaradinski [ADJ]
#     ∟ petrovaradinskoj POSSESSIVE
# porodiljski [ADJ]
#     ∟ porodiljskoj POSSESSIVE
# ambasadorski [ADJ]
#     ∟ ambasadorskoj POSSESSIVE
# latinski [ADJ]
#     ∟ latinskoj POSSESSIVE
# popeski [ADJ]
#     ∟ popesku POSSESSIVE
# draguleski [ADJ]
#     ∟ dragulesku POSSESSIVE
# maneski [ADJ]
#     ∟ manesku POSSESSIVE
# franciski [ADJ]
#     ∟ francisku POSSESSIVE
# teokratski [ADJ]
#     ∟ teokratsku POSSESSIVE
# serotoninski [ADJ]
#     ∟ serotoninsku POSSESSIVE
#       serotoninskih POSSESSIVE
# konferencijski [ADJ]
#     ∟ konferencijsku POSSESSIVE
# baseski [ADJ]
#     ∟ basesku POSSESSIVE
# šumski [ADJ]
#     ∟ šumskih POSSESSIVE
# partnerski [ADJ]
#     ∟ partnerskih POSSESSIVE
# klupski [ADJ]
#     ∟ klupskih POSSESSIVE
# istočnoevropski [ADJ]
#     ∟ istočnoevropskih POSSESSIVE
# propalestinski [ADJ]
#     ∟ propalestinskih POSSESSIVE
# zemaljski [ADJ]
#     ∟ zemaljskih POSSESSIVE
#       zemaljsko POSSESSIVE
# azijski [ADJ]
#     ∟ azijskih POSSESSIVE
# sapunski [ADJ]
#     ∟ sapunskih POSSESSIVE
# piratski [ADJ]
#     ∟ piratskih POSSESSIVE
# špediterski [ADJ]
#     ∟ špediterskih POSSESSIVE
# hemijski [ADJ]
#     ∟ hemijskih POSSESSIVE
#       hemijsko POSSESSIVE
# obalski [ADJ]
#     ∟ obalskih POSSESSIVE
# nemuslimanski [ADJ]
#     ∟ nemuslimanskih POSSESSIVE
# septembarski [ADJ]
#     ∟ septembarskih POSSESSIVE
# pionirski [ADJ]
#     ∟ pionirskih POSSESSIVE
# benzinski [ADJ]
#     ∟ benzinskih POSSESSIVE
# opštinski [ADJ]
#     ∟ opštinskih POSSESSIVE
# hrišćanski [ADJ]
#     ∟ hrišćanskih POSSESSIVE
# festivalski [ADJ]
#     ∟ festivalskih POSSESSIVE
# autorski [ADJ]
#     ∟ autorskih POSSESSIVE
# tematski [ADJ]
#     ∟ tematskih POSSESSIVE
# dobrosusedski [ADJ]
#     ∟ dobrosusedskih POSSESSIVE
# rumuski [ADJ]
#     ∟ rumuskih POSSESSIVE
# komunikacijski [ADJ]
#     ∟ komunikacijskih POSSESSIVE
# avganistanski [ADJ]
#     ∟ avganistanskih POSSESSIVE
# seoski [ADJ]
#     ∟ seoskih POSSESSIVE
# premijerski [ADJ]
#     ∟ premijersko POSSESSIVE
# kuhinjski [ADJ]
#     ∟ kuhinjsko POSSESSIVE
# otomanski [ADJ]
#     ∟ otomansko POSSESSIVE
# stihijski [ADJ]
#     ∟ stihijsko POSSESSIVE
# teorijski [ADJ]
#     ∟ teorijsko POSSESSIVE
# uneski [ADJ]
#     ∟ unesko POSSESSIVE
# postmiloševićevski [ADJ]
#     ∟ postmiloševićevsko POSSESSIVE
# predsednički [ADJ]
#     ∟ predsedničkog POSSESSIVE
#       predsedničkih POSSESSIVE
#       predsedničke POSSESSIVE
#       predsedničku POSSESSIVE
# bošnjački [ADJ]
#     ∟ bošnjačkog POSSESSIVE
#       bošnjačkom POSSESSIVE
#       bošnjačkih POSSESSIVE
#       bošnjačke POSSESSIVE
# železnički [ADJ]
#     ∟ železnička POSSESSIVE
#       železničkih POSSESSIVE
#       železničkim POSSESSIVE
#       železničke POSSESSIVE
#       železničkoj POSSESSIVE
# američki [ADJ]
#     ∟ američkog POSSESSIVE
#       američkom POSSESSIVE
#       američka POSSESSIVE
#       američkih POSSESSIVE
#       američkim POSSESSIVE
#       američke POSSESSIVE
#       američku POSSESSIVE
# muzički [ADJ]
#     ∟ muzičkog POSSESSIVE
#       muzičkom POSSESSIVE
#       muzičku POSSESSIVE
# radnički [ADJ]
#     ∟ radničke POSSESSIVE
# tehnički [ADJ]
#     ∟ tehničkih POSSESSIVE
#       tehničkim POSSESSIVE
#       tehničko POSSESSIVE
#       tehničke POSSESSIVE
# umetnički [ADJ]
#     ∟ umetnička POSSESSIVE
#       umetničke POSSESSIVE
#       umetničkoj POSSESSIVE
# putnički [ADJ]
# ekstremistički [ADJ]
#     ∟ ekstremistička POSSESSIVE
#       ekstremističkih POSSESSIVE
#       ekstremističke POSSESSIVE
# teroristički [ADJ]
#     ∟ terorističkog POSSESSIVE
#       teroristička POSSESSIVE
#       terorističkih POSSESSIVE
#       terorističkim POSSESSIVE
#       terorističke POSSESSIVE
# etnički [ADJ]
#     ∟ etničkog POSSESSIVE
#       etnička POSSESSIVE
#       etničkih POSSESSIVE
#       etničkim POSSESSIVE
#       etničke POSSESSIVE
#       etničkoj POSSESSIVE
#       etničku POSSESSIVE
# monopolistički [ADJ]
#     ∟ monopolističkih POSSESSIVE
#       monopolističke POSSESSIVE
#       monopolističku POSSESSIVE
# statistički [ADJ]
#     ∟ statističkog POSSESSIVE
#       statističkim POSSESSIVE
# posmatrački [ADJ]
#     ∟ posmatračkog POSSESSIVE
#       posmatračka POSSESSIVE
#       posmatračkoj POSSESSIVE
# preduzetnički [ADJ]
# politički [ADJ]
#     ∟ političkog POSSESSIVE
#       političkom POSSESSIVE
#       politička POSSESSIVE
#       političkih POSSESSIVE
#       političkim POSSESSIVE
#       političko POSSESSIVE
#       političke POSSESSIVE
#       političkoj POSSESSIVE
#       političku POSSESSIVE
# slovenački [ADJ]
#     ∟ slovenačkom POSSESSIVE
#       slovenačka POSSESSIVE
#       slovenačkim POSSESSIVE
#       slovenačko POSSESSIVE
# turistički [ADJ]
#     ∟ turističkog POSSESSIVE
#       turističkom POSSESSIVE
#       turistička POSSESSIVE
#       turističkih POSSESSIVE
#       turističkoj POSSESSIVE
# višestranački [ADJ]
#     ∟ višestranačke POSSESSIVE
#       višestranačku POSSESSIVE
# pacifički [ADJ]
# stranački [ADJ]
#     ∟ stranačka POSSESSIVE
#       stranačkih POSSESSIVE
#       stranačkim POSSESSIVE
# grčki [ADJ]
#     ∟ grčkog POSSESSIVE
#       grčkom POSSESSIVE
#       grčka POSSESSIVE
#       grčkih POSSESSIVE
#       grčkim POSSESSIVE
#       grčko POSSESSIVE
#       grčke POSSESSIVE
#       grčkoj POSSESSIVE
#       grčku POSSESSIVE
# komunistički [ADJ]
#     ∟ komunističkog POSSESSIVE
#       komunističkim POSSESSIVE
#       komunističke POSSESSIVE
#       komunističku POSSESSIVE
# irački [ADJ]
#     ∟ iračkih POSSESSIVE
#       iračkim POSSESSIVE
#       iračkoj POSSESSIVE
# populistički [ADJ]
# brodovlasnički [ADJ]
# nemački [ADJ]
#     ∟ nemačkog POSSESSIVE
#       nemačka POSSESSIVE
#       nemačkih POSSESSIVE
#       nemačkim POSSESSIVE
#       nemačke POSSESSIVE
#       nemačkoj POSSESSIVE
#       nemačku POSSESSIVE
# prostački [ADJ]
# zajednički [ADJ]
#     ∟ zajedničkog POSSESSIVE
#       zajedničkom POSSESSIVE
#       zajednička POSSESSIVE
#       zajedničkim POSSESSIVE
#       zajedničko POSSESSIVE
#       zajedničke POSSESSIVE
#       zajedničkoj POSSESSIVE
#       zajedničku POSSESSIVE
# pregovarački [ADJ]
#     ∟ pregovaračkog POSSESSIVE
#       pregovaračka POSSESSIVE
#       pregovaračkih POSSESSIVE
#       pregovaračku POSSESSIVE
# međuetnički [ADJ]
#     ∟ međuetničkih POSSESSIVE
# ultranacionalistički [ADJ]
#     ∟ ultranacionalističkih POSSESSIVE
#       ultranacionalističke POSSESSIVE
# geopolitički [ADJ]
#     ∟ geopolitičkog POSSESSIVE
#       geopolitičkom POSSESSIVE
#       geopolitičkoj POSSESSIVE
# analitički [ADJ]
#     ∟ analitičkog POSSESSIVE
# veštački [ADJ]
#     ∟ veštačkog POSSESSIVE
#       veštačku POSSESSIVE
# čitalački [ADJ]
#     ∟ čitalačkog POSSESSIVE
# srebrenički [ADJ]
#     ∟ srebreničkog POSSESSIVE
#       srebreničkom POSSESSIVE
# predstavnički [ADJ]
#     ∟ predstavničkog POSSESSIVE
# staljinistički [ADJ]
#     ∟ staljinističkog POSSESSIVE
# severnoafrički [ADJ]
#     ∟ severnoafričkog POSSESSIVE
# prevoznički [ADJ]
#     ∟ prevozničkog POSSESSIVE
# fizički [ADJ]
#     ∟ fizičkog POSSESSIVE
#       fizička POSSESSIVE
#       fizičko POSSESSIVE
#       fizičke POSSESSIVE
# poslanički [ADJ]
#     ∟ poslaničkog POSSESSIVE
#       poslaničkih POSSESSIVE
#       poslaničke POSSESSIVE
# predavački [ADJ]
#     ∟ predavačkog POSSESSIVE
#       predavačkih POSSESSIVE
# vlasnički [ADJ]
#     ∟ vlasničkom POSSESSIVE
#       vlasnička POSSESSIVE
#       vlasničkih POSSESSIVE
# jezički [ADJ]
#     ∟ jezičkom POSSESSIVE
#       jezičku POSSESSIVE
# postkomunistički [ADJ]
#     ∟ postkomunističkom POSSESSIVE
#       postkomunističkih POSSESSIVE
# zagrebački [ADJ]
#     ∟ zagrebačkom POSSESSIVE
#       zagrebačke POSSESSIVE
# plivački [ADJ]
#     ∟ plivačkom POSSESSIVE
#       plivačkim POSSESSIVE
# brčki [ADJ]
#     ∟ brčkom POSSESSIVE
# nacistički [ADJ]
#     ∟ nacističkom POSSESSIVE
#       nacističkim POSSESSIVE
#       nacističke POSSESSIVE
# antiteroristički [ADJ]
#     ∟ antiteroristička POSSESSIVE
#       antiterorističke POSSESSIVE
# osvetnički [ADJ]
#     ∟ osvetnička POSSESSIVE
# nacionalistički [ADJ]
#     ∟ nacionalistička POSSESSIVE
#       nacionalističke POSSESSIVE
#       nacionalističku POSSESSIVE
# ručki [ADJ]
#     ∟ ručka POSSESSIVE
# pljački [ADJ]
#     ∟ pljačka POSSESSIVE
#       pljačke POSSESSIVE
# opljački [ADJ]
#     ∟ opljačka POSSESSIVE
# dugački [ADJ]
#     ∟ dugačka POSSESSIVE
#       dugačke POSSESSIVE
# tački [ADJ]
#     ∟ tačka POSSESSIVE
#       tačku POSSESSIVE
# socijalistički [ADJ]
#     ∟ socijalistička POSSESSIVE
#       socijalističkih POSSESSIVE
#       socijalističke POSSESSIVE
#       socijalističkoj POSSESSIVE
#       socijalističku POSSESSIVE
# borački [ADJ]
#     ∟ boračka POSSESSIVE
# ludački [ADJ]
#     ∟ ludačka POSSESSIVE
# antički [ADJ]
#     ∟ antičkih POSSESSIVE
# katolički [ADJ]
#     ∟ katoličkih POSSESSIVE
#       katoličke POSSESSIVE
# nasilnički [ADJ]
#     ∟ nasilničkih POSSESSIVE
# unutarpolitički [ADJ]
#     ∟ unutarpolitičkih POSSESSIVE
# forenzički [ADJ]
#     ∟ forenzičkih POSSESSIVE
# etički [ADJ]
#     ∟ etičkih POSSESSIVE
# glasački [ADJ]
#     ∟ glasačkih POSSESSIVE
#       glasačke POSSESSIVE
# dužnički [ADJ]
#     ∟ dužničkih POSSESSIVE
# protivnički [ADJ]
#     ∟ protivničkih POSSESSIVE
#       protivničke POSSESSIVE
# kriminalistički [ADJ]
#     ∟ kriminalističkih POSSESSIVE
#       kriminalističke POSSESSIVE
# nedomorodački [ADJ]
#     ∟ nedomorodačkih POSSESSIVE
# afrički [ADJ]
#     ∟ afričkih POSSESSIVE
# seizmički [ADJ]
#     ∟ seizmičkim POSSESSIVE
# vozački [ADJ]
#     ∟ vozačkim POSSESSIVE
# senzacionalistički [ADJ]
#     ∟ senzacionalističkim POSSESSIVE
#       senzacionalističke POSSESSIVE
# lingvistički [ADJ]
#     ∟ lingvističkim POSSESSIVE
# informatički [ADJ]
#     ∟ informatičko POSSESSIVE
# multietnički [ADJ]
#     ∟ multietničko POSSESSIVE
# narkotički [ADJ]
#     ∟ narkotičko POSSESSIVE
# birački [ADJ]
#     ∟ biračko POSSESSIVE
# aktivistički [ADJ]
#     ∟ aktivističke POSSESSIVE
# sandžački [ADJ]
#     ∟ sandžačke POSSESSIVE
# borilački [ADJ]
#     ∟ borilačke POSSESSIVE
# dijagnostički [ADJ]
#     ∟ dijagnostičke POSSESSIVE
# igrački [ADJ]
#     ∟ igračke POSSESSIVE
# kukavički [ADJ]
#     ∟ kukavičke POSSESSIVE
# oslobodilački [ADJ]
#     ∟ oslobodilačke POSSESSIVE
# zaključki [ADJ]
#     ∟ zaključke POSSESSIVE
# glumački [ADJ]
#     ∟ glumačke POSSESSIVE
#       glumačku POSSESSIVE
# oportunistički [ADJ]
#     ∟ oportunističke POSSESSIVE
# rasistički [ADJ]
#     ∟ rasističke POSSESSIVE
# riječki [ADJ]
#     ∟ riječkoj POSSESSIVE
# bečki [ADJ]
#     ∟ bečkoj POSSESSIVE
# optuženički [ADJ]
#     ∟ optuženičkoj POSSESSIVE
# uređivački [ADJ]
#     ∟ uređivačku POSSESSIVE
# bački [ADJ]
#     ∟ bačku POSSESSIVE
# lučki [ADJ]
#     ∟ lučku POSSESSIVE
# antikomunistički [ADJ]
#     ∟ antikomunističku POSSESSIVE
# državnički [ADJ]
#     ∟ državničku POSSESSIVE
# zoološki [ADJ]
#     ∟ zoološkog POSSESSIVE
# ideološki [ADJ]
#     ∟ ideološko POSSESSIVE
#       ideološke POSSESSIVE
# haški [ADJ]
#     ∟ haškim POSSESSIVE
# malteški [ADJ]
# muški [ADJ]
#     ∟ muškom POSSESSIVE
#       muška POSSESSIVE
#       muških POSSESSIVE
#       muške POSSESSIVE
#       muškoj POSSESSIVE
#       mušku POSSESSIVE
# tehnološki [ADJ]
#     ∟ tehnološkog POSSESSIVE
#       tehnološkim POSSESSIVE
#       tehnološke POSSESSIVE
# bombaški [ADJ]
#     ∟ bombaškog POSSESSIVE
#       bombaškom POSSESSIVE
#       bombaških POSSESSIVE
# norveški [ADJ]
#     ∟ norveške POSSESSIVE
# češki [ADJ]
#     ∟ češka POSSESSIVE
#       češke POSSESSIVE
# njujorški [ADJ]
# strateški [ADJ]
#     ∟ strateškog POSSESSIVE
#       strateška POSSESSIVE
#       strateškim POSSESSIVE
#       strateško POSSESSIVE
#       strateške POSSESSIVE
# luksemburški [ADJ]
# skijaški [ADJ]
#     ∟ skijaškog POSSESSIVE
# helsinški [ADJ]
#     ∟ helsinškog POSSESSIVE
# pedagoški [ADJ]
#     ∟ pedagoškog POSSESSIVE
# teški [ADJ]
#     ∟ teškog POSSESSIVE
#       teška POSSESSIVE
#       teških POSSESSIVE
#       teškim POSSESSIVE
#       teško POSSESSIVE
#       teške POSSESSIVE
#       teškoj POSSESSIVE
#       tešku POSSESSIVE
# demagoški [ADJ]
#     ∟ demagoškog POSSESSIVE
# imunološki [ADJ]
#     ∟ imunološkog POSSESSIVE
# kriminološki [ADJ]
#     ∟ kriminološkog POSSESSIVE
# podrški [ADJ]
#     ∟ podrškom POSSESSIVE
#       podrška POSSESSIVE
#       podrške POSSESSIVE
#       podršku POSSESSIVE
# graški [ADJ]
#     ∟ graška POSSESSIVE
# ruški [ADJ]
#     ∟ ruška POSSESSIVE
# đumiški [ADJ]
#     ∟ đumiška POSSESSIVE
# košarkaški [ADJ]
#     ∟ košarkaška POSSESSIVE
# seizmološki [ADJ]
#     ∟ seizmoloških POSSESSIVE
# ekološki [ADJ]
#     ∟ ekoloških POSSESSIVE
#       ekološkim POSSESSIVE
# mafijaški [ADJ]
#     ∟ mafijaškim POSSESSIVE
#       mafijaške POSSESSIVE
# duški [ADJ]
#     ∟ duško POSSESSIVE
# psihološki [ADJ]
#     ∟ psihološko POSSESSIVE
#       psihološke POSSESSIVE
# bukureški [ADJ]
#     ∟ bukureške POSSESSIVE
# arheološki [ADJ]
#     ∟ arheološke POSSESSIVE
#       arheološkoj POSSESSIVE
#       arheološku POSSESSIVE
# puški [ADJ]
#     ∟ puške POSSESSIVE
# antimafijaški [ADJ]
#     ∟ antimafijaške POSSESSIVE
# greški [ADJ]
#     ∟ greške POSSESSIVE
# ćoški [ADJ]
#     ∟ ćošku POSSESSIVE
